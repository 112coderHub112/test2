# %%
import math
from datetime import date
from datetime import datetime
from datetime import timedelta

# %%
def NYdate(jula_year):
    ny = jula_year*0.25875-int(jula_year/4 +0.5)+int(jula_year/100 +0.38)-int(jula_year/400 +0.595)-5.53375
    jultin =  ((jula_year*292207)+373)%800
    hour,frac = divmod(jultin*24,800)
    minute,frac = divmod(frac*60,800)
    second,frac = divmod(frac*60,800)
    christ_year = jula_year+638
    dtny = datetime(christ_year, 4, int(ny), hour , minute, second)
    return dtny;

# %%
class hora:
    def __init__(self,dt):
        self.dt = dt  
        jula_year = dt.year-638    
        d = date(dt.year,dt.month,dt.day)
        dtf= datetime(dt.year,dt.month,dt.day,0,0)        
        dtny = NYdate(jula_year)
        dny = date(dtny.year,dtny.month,dtny.day)
        
        if (dt>=dtny):
            jula_newyear = jula_year
        elif (dt<dtny):
            jula_newyear = jula_year-1
            dtny = NYdate(jula_newyear)
            dny = date(dtny.year,dtny.month,dtny.day)

            
        temp = (jula_newyear*292207)+373
        ahra = (temp//800)+1
        jultin =  temp%800

        kj = 800-jultin
        temp,aw= divmod((ahra*11)+650,692)
        masG,dT=divmod((ahra+temp),30)

        au = (ahra-621)%3232
        van = ahra%7

        stin = (d-dny).days
        sec = (dt-dtf).seconds

        ahra_ = ahra+stin
        stkm = (stin-1)*800
        kj_ = kj + stkm + sec//108

        awjt = (stin-1)*703+aw
        aws = awjt+(sec*703)//86400
        awdT,aw_=divmod(aws,692)
        temp,dT_=divmod((awdT+dT),30)
        masG_ = masG+temp
        van_=ahra_%7

        if (au+stin > 3232):
            au_ = au+stin-3232
        else: au_= au+stin        
        
        
##########################SUN###############################
        sun_table = [[35,32,27,22,13,5],
                     [0,35,67,94,116,129]]

        z = kj_ // 24350
        z_remainder = kj_ % 24350
        degree = z_remainder//811
        d_remainder = z_remainder % 811
        minute = d_remainder//14

        d_total = z*30+degree
        mathasun = d_total*60+minute-3


        if mathasun >= 21600:
            raise Exception('mathasun exceed or equal 21600')
        elif mathasun < 0:
            raise Exception('mathasun below 0')
        elif mathasun < 4800:
            pholsun = 21600+mathasun-4800
        else:
            pholsun = mathasun-4800


        if pholsun >= 21600:
            raise Exception('pholsun exceed or equal 21600')
        elif pholsun < 0:
            raise Exception('pholsun below 0')
        elif pholsun >= 0 and pholsun <5400:
            pholGA = pholsun

        elif pholsun >= 5400 and pholsun <10800:
            pholGA = 10800-pholsun

        elif pholsun >= 10800 and pholsun <16200:
            pholGA = pholsun-10800

        elif pholsun >= 16200:
            pholGA = 21600-pholsun


        khan = pholGA // 900
        pushlip = pholGA % 900


        jyaGA = (sun_table[0][khan]*pushlip) // 900
        ravipphol = sun_table[1][khan]+jyaGA


        if pholsun < 10800:
            Ssun = mathasun-ravipphol
        elif pholsun > 10800:
            Ssun= mathasun+ravipphol
        elif pholsun == 10800:
            if(ravipphol != 0):raise Exception('pholsun=10800 but ravipphol not 0')
            Ssun= mathasun

        if Ssun < 0:
            Ssun = Ssun+21600
        elif Ssun > 21600:
            Ssun= Ssun-21600
            
        #zodiac,frac = divmod(Ssun,1800)
        #degree,minute = divmod(frac,60)    
#        sun = []
#        sun.append(Ssun)
#         sun.append(Ssun//1800)
#         sun.append((Ssun%1800)//60)
#         sun.append((Ssun%1800)%60)

##########################MOON###############################

        moon_table = [[77,71,61,47,30,10],
                     [0,77,148,209,256,296]]

        temp = (au_-1)*86400+sec

        #zodiac,frac = divmod(x,23270400)
        #degree,frac = divmod(frac,775680)
        #minute = frac // 12928

        zodiac = temp//23270400
        degree = (temp%23270400)//775680
        minute = ((temp%23270400)%775680)//12928
        d_total = zodiac*30+degree
        mtu = d_total*60+minute+2


        mathamoon = mathasun + aw_ +(aw_//25)+(dT_*720)-40
        if mathamoon >= 21600: 
            mathamoon = mathamoon-21600

        if mathamoon >= 21600:
            raise Exception('mathamoon exceed or equal 21600')
        elif mathamoon < 0:
            raise Exception('mathamoon below 0')
        elif mtu >= 21600:
            raise Exception('mtu exceed or equal 21600')
        elif mtu < 0:
            raise Exception('mtu below 0')
        elif mathamoon>=mtu:
            uv =  mathamoon-mtu
        elif mathamoon<mtu:
            uv = 21600+mathamoon-mtu


        if uv >= 21600:
            raise Exception('uv exceed or equal 21600')
        elif uv < 0:
            raise Exception('uv below 0')
        elif uv >= 0 and uv <5400:
            pholGA = uv
        elif uv >= 5400 and uv <10800:
            pholGA = 10800-uv
        elif uv >= 10800 and uv <16200:
            pholGA = uv-10800
        elif uv >= 16200:
            pholGA = 21600-uv


        khan = pholGA // 900
        pushlip = pholGA % 900

        jyaGA = (moon_table[0][khan]*pushlip) // 900
        chandraphol = moon_table[1][khan]+jyaGA

        if uv < 10800:
            Smoon = mathamoon-chandraphol
        elif uv > 10800:
            Smoon= mathamoon+chandraphol
        elif uv == 10800:
            if(chandraphol != 0):raise Exception('uv=10800 but chandraphol not 0')
            Smoon= mathamoon

        if Smoon < 0:
            Smoon = Smoon+21600
        elif Smoon > 21600:
            Smoon= Smoon-21600









        self.dtny = dtny 
        self.dny = dny 
        self.ahra = ahra 
        self.jultin = jultin 
        self.kj = kj 
        self.aw = aw 
        self.masG = masG 
        self.dT = dT
        self.au = au 
        self.van = van 
        self.stin = stin 
        self.sec = sec 
        
        self.ahra_ = ahra_ 
        self.kj_ = kj_ 
        self.aw_ = aw_ 
        self.masG_ = masG_ 
        self.dT_ = dT_
        self.au_ = au_ 
        self.van_ = van_
 
        self.sun = Ssun
        self.moon = Smoon

# %%
day,month,year,hour,minute = 2,6,2519,23,55

christ_year = year-543
offset = timedelta(minutes=18)
dt= datetime(christ_year,month,day,hour,minute)-offset

a = hora(dt)  
print('dt =', a.dt)
print('dtnt =', a.dtny)
print('ahra =', a.ahra)
print('jultin =', a.jultin)
print('kj =', a.kj)
print('aw =', a.aw)
print('masG =', a.masG)
print('dT =', a.dT)
print('au =', a.au)
print('van =', a.van)

print('stin =', a.stin)
print('sec =', a.sec)
print('ahra_ =', a.ahra_)
print('kj_ =', a.kj_)
print('aw_ =', a.aw_)
print('masG_ =', a.masG_)
print('dT_ =', a.dT_)
print('au_ =', a.au_)
print('van_ =', a.van_)

print('sun =', a.sun)
print('moon =', a.moon)
# Out:
# dt = 1976-06-02 23:37:00
# dtnt = 1976-04-15 16:10:12
# ahra = 488717
# jultin = 539
# kj = 261
# aw = 389
# masG = 16549
# dT = 16
# au = 64
# van = 5
# stin = 48
# sec = 85020
# ahra_ = 488765
# kj_ = 38648
# aw_ = 213
# masG_ = 16551
# dT_ = 5
# au_ = 112
# van_ = 4
# sun = 2924
# moon = 6334
# sun = 8647
# moon = 21063

# %%
import math
from datetime import date
from datetime import datetime
from datetime import timedelta

#day,month,year,hour,minute = 30,3,2550,8,55
#day,month,year,hour,minute = 27,1,2527,9,49
day,month,year,hour,minute = 2,6,2519,23,55
christ_year = year-543
jula_year = year-1181
offset = timedelta(minutes=18)
dt= datetime(christ_year,month,day,hour,minute)-offset
dtf= datetime(dt.year,dt.month,dt.day,0,0)
d = date(dt.year,dt.month,dt.day)

def NYdate(jula_year):
    ny = jula_year*0.25875-int(jula_year/4 +0.5)+int(jula_year/100 +0.38)-int(jula_year/400 +0.595)-5.53375
    jultin =  ((jula_year*292207)+373)%800
    hour,frac = divmod(jultin*24,800)
    minute,frac = divmod(frac*60,800)
    second,frac = divmod(frac*60,800)
    christ_year = jula_year+638
    dtny = datetime(christ_year, 4, int(ny), hour , minute, second)
    return dtny;

# %%
dtny = NYdate(jula_year)
dny = date(dtny.year,dtny.month,dtny.day)
    
if (dt>=dtny):
    jula_newyear = jula_year
elif (dt<dtny):
    jula_newyear = jula_year-1
    dtny = NYdate(jula_newyear)
    dny = date(dtny.year,dtny.month,dtny.day)

print('datetimeSpeculate=',dt)
print('datetime_ny =',dtny)
print('jula_year =',jula_year)
print('jula_newyear =',jula_newyear)
# Out:
# datetimeSpeculate= 1976-06-02 23:37:00
# datetime_ny = 1976-04-15 16:10:12
# jula_year = 1338
# jula_newyear = 1338

# %%
temp = (jula_newyear*292207)+373
ahra = (temp//800)+1
jultin =  temp%800

kj = 800-jultin
temp,aw= divmod((ahra*11)+650,692)
masG,dT=divmod((ahra+temp),30)

au = (ahra-621)%3232
van = ahra%7

stin = (d-dny).days
sec = (dt-dtf).seconds

# %%
print('ahra=',ahra)
print('jultin=',jultin)
print('kj=',kj)
print('aw=',aw)
print('masG=',masG)
print('dT=',dT)
print('au=',au)
print('van=',van)
print('stin=',stin)
print('sec=',sec)
# Out:
# ahra= 488717
# jultin= 539
# kj= 261
# aw= 389
# masG= 16549
# dT= 16
# au= 64
# van= 5
# stin= 48
# sec= 85020

# %%
ahra_ = ahra+stin
stkm = (stin-1)*800
kj_ = kj + stkm + sec//108

awjt = (stin-1)*703+aw
aws = awjt+(sec*703)//86400
awdT,aw_=divmod(aws,692)
temp,dT_=divmod((awdT+dT),30)
masG_ = masG+temp
van_=ahra_%7

if (au+stin > 3232):
    au_ = au+stin-3232
else: au_= au+stin

# %%
print('ahra_=',ahra_)
print('kj_=',kj_)
print('aw_=',aw_)
print('dT_=',dT_)
print('masG_=',masG_)
print('au_=',au_)
print('van_=',van_)
# Out:
# ahra_= 488765
# kj_= 38648
# aw_= 213
# dT_= 5
# masG_= 16551
# au_= 112
# van_= 4

# %%
sun_table = [[35,32,27,22,13,5],
             [0,35,67,94,116,129]]


z = kj_ // 24350
z_remainder = kj_ % 24350
degree = z_remainder//811
d_remainder = z_remainder % 811
minute = d_remainder//14

d_total = z*30+degree
mathasun = d_total*60+minute-3


if mathasun >= 21600:
    raise Exception('mathasun exceed or equal 21600')
elif mathasun < 0:
    raise Exception('mathasun below 0')
elif mathasun < 4800:
    pholsun = 21600+mathasun-4800
else:
    pholsun = mathasun-4800


if pholsun >= 21600:
    raise Exception('pholsun exceed or equal 21600')
elif pholsun < 0:
    raise Exception('pholsun below 0')
elif pholsun >= 0 and pholsun <5400:
    pholGA = pholsun

elif pholsun >= 5400 and pholsun <10800:
    pholGA = 10800-pholsun

elif pholsun >= 10800 and pholsun <16200:
    pholGA = pholsun-10800

elif pholsun >= 16200:
    pholGA = 21600-pholsun
    

khan = pholGA // 900
pushlip = pholGA % 900


jyaGA = (sun_table[0][khan]*pushlip) // 900
ravipphol = sun_table[1][khan]+jyaGA


if pholsun < 10800:
    Ssun = mathasun-ravipphol
elif pholsun > 10800:
    Ssun= mathasun+ravipphol
elif pholsun == 10800:
    if(ravipphol != 0):raise Exception('pholsun=10800 but ravipphol not 0')
    Ssun= mathasun

if Ssun < 0:
    Ssun = Ssun+21600
elif Ssun > 21600:
    Ssun= Ssun-21600

zodiac,frac = divmod(Ssun,1800)
degree,minute = divmod(frac,60)



print('mathasun =',mathasun)
print('pholsun =',pholsun)
print('pholGA =',pholGA)
print('khan =',khan)
print('pushlip =',pushlip)
print('ravipphol =',ravipphol)
print('Ssun =',Ssun)
print('zodiac =',zodiac)
print('degree =',degree)
print('minute =',minute)
# Out:
# mathasun = 2853
# pholsun = 19653
# pholGA = 1947
# khan = 2
# pushlip = 147
# ravipphol = 71
# Ssun = 2924
# zodiac = 1
# degree = 18
# minute = 44

# %%
moon_table = [[77,71,61,47,30,10],
             [0,77,148,209,256,296]]

temp = (au_-1)*86400+sec

#zodiac,frac = divmod(x,23270400)
#degree,frac = divmod(frac,775680)
#minute = frac // 12928

zodiac = temp//23270400
degree = (temp%23270400)//775680
minute = ((temp%23270400)%775680)//12928
d_total = zodiac*30+degree
mtu = d_total*60+minute+2


mathamoon = mathasun + aw_ +(aw_//25)+(dT_*720)-40
if mathamoon >= 21600: 
    mathamoon = mathamoon-21600

if mathamoon >= 21600:
    raise Exception('mathamoon exceed or equal 21600')
elif mathamoon < 0:
    raise Exception('mathamoon below 0')
elif mtu >= 21600:
    raise Exception('mtu exceed or equal 21600')
elif mtu < 0:
    raise Exception('mtu below 0')
elif mathamoon>=mtu:
    uv =  mathamoon-mtu
elif mathamoon<mtu:
    uv = 21600+mathamoon-mtu
    

if uv >= 21600:
    raise Exception('uv exceed or equal 21600')
elif uv < 0:
    raise Exception('uv below 0')
elif uv >= 0 and uv <5400:
    pholGA = uv
elif uv >= 5400 and uv <10800:
    pholGA = 10800-uv
elif uv >= 10800 and uv <16200:
    pholGA = uv-10800
elif uv >= 16200:
    pholGA = 21600-uv


khan = pholGA // 900
pushlip = pholGA % 900

jyaGA = (moon_table[0][khan]*pushlip) // 900
chandraphol = moon_table[1][khan]+jyaGA

if uv < 10800:
    Smoon = mathamoon-chandraphol
elif uv > 10800:
    Smoon= mathamoon+chandraphol
elif uv == 10800:
    if(chandraphol != 0):raise Exception('uv=10800 but chandraphol not 0')
    Smoon= mathamoon

if Smoon < 0:
    Smoon = Smoon+21600
elif Smoon > 21600:
    Smoon= Smoon-21600

zodiac,frac = divmod(Smoon,1800)
degree,minute = divmod(frac,60)

print('zodiac=',zodiac)
print('degree=',degree)
print('minute=',minute)
print('mtu=',mtu)
print('mathamoon=',mathamoon)
print('uv=',uv)
print('pholGA=',pholGA)
print('khan =',khan)
print('pushlip =',pushlip)
print('jyaGA =',jyaGA)
print('chandraphol =',chandraphol)
print('Smoon =',Smoon)
print('zodiac =',zodiac)
print('degree =',degree)
print('minute =',minute)
# Out:
# zodiac= 3
# degree= 15
# minute= 34
# mtu= 750
# mathamoon= 6634
# uv= 5884
# pholGA= 4916
# khan = 5
# pushlip = 416
# jyaGA = 4
# chandraphol = 300
# Smoon = 6334
# zodiac = 3
# degree = 15
# minute = 34

# %%
matharavi = mathasun-23
srb = jula_newyear-610
manut = (srb*21600)+ matharavi

a = manut//20
b = manut//265
pmt = (a+b)%21600

Srahu = 15150-pmt
if Srahu<0:
    Srahu = Srahu+21600
    
    
zodiac,frac = divmod(Srahu,1800)
degree,minute = divmod(frac,60)



print('matharavi =',matharavi)
print('srb =',srb)
print('manut =',manut)
print('pmt =',pmt)
print('a =',a)
print('b =',b)
print('Srahu =',Srahu)
print('zodiac =',zodiac)
print('degree =',degree)
print('minute =',minute)


# import pandas as pd
# df = pd.DataFrame()
# df = df.append({'dt' : dt, 
#                 'rahu.z' : zodiac,
#                 'rahu.d' : degree,          
#                 'rahu.m' : minute              
#                } , ignore_index=True)
# df.set_index('dt',inplace=True)
# df[['rahu.z','rahu.d','rahu.m']]
# Out:
# matharavi = 2830
# srb = 728
# manut = 15727630
# pmt = 3330
# a = 786381
# b = 59349
# Srahu = 11820
# zodiac = 6
# degree = 17
# minute = 0

# %%
matharavi = mathasun-23
srb = jula_newyear-610
manut = (srb*21600)+ matharavi

pholgt = (ahra_-345)%679
mathageth = (pholgt*21600 + (sec*21600)//86400)//679
Sgeth = 21600-mathageth
zodiac,frac = divmod(Sgeth,1800)
degree,minute = divmod(frac,60)

print('Sgeth =',Sgeth)
print('zodiac =',zodiac)
print('degree =',degree)
print('minute =',minute)
# Out:
# Sgeth = 5536
# zodiac = 3
# degree = 2
# minute = 16

# %%
mathaMars = ((manut*1)//2 + (manut*16)//505 + 5420)%21600
pholMars = mathaMars-7620
if pholMars<0:
    pholMars = pholMars+21600

ptma = (pholMars//5400)+1
if ptma == 1:
    puchaPT = pholMars
    khotiPT = 5400-pholMars
elif ptma == 2:
    puchaPT = 10800-pholMars
    khotiPT = pholMars-5400
elif ptma == 3:
    puchaPT = pholMars-10800
    khotiPT = 16200-pholMars
elif ptma == 4:
    puchaPT = 21600-pholMars
    khotiPT = pholMars-16200
    
# puchaPT = 1064
# khotiPT = 4336
    
if puchaPT < 0:
    raise Exception('puchaPT is below 0')
elif puchaPT > 5400:
    raise Exception('puchaPT is greater than 5400')
elif puchaPT < 1800:
    MTpucha = (puchaPT*14640)//1800
elif (puchaPT >= 1800) and (puchaPT < 3600) :
    MTpucha = (((puchaPT-1800)*10980)//1800)+14640
elif puchaPT >= 3600 :
    MTpucha = (((puchaPT-3600)*3660)//1800)+25620

if khotiPT < 0:
    raise Exception('khotiPT is below 0')
elif khotiPT > 5400:
    raise Exception('khotiPT is greater than 5400')
elif khotiPT < 1800:
    MTKhoti = (khotiPT*14640)//1800
elif (khotiPT >= 1800) and (khotiPT < 3600) :
    MTKhoti = (((khotiPT-1800)*10980)//1800)+14640
elif khotiPT >= 3600 :
    MTKhoti = (((khotiPT-3600)*3660)//1800)+25620

MTKhoti = (MTKhoti+30)//60
khotiphol = MTKhoti//2


if (ptma ==1) or (ptma ==4):
    MTcheta = 45*60 + khotiphol
elif (ptma ==2) or (ptma ==3):
    MTcheta=  45*60 - khotiphol
    
MTphol = (MTpucha*60)//MTcheta


if (ptma ==1) or (ptma ==2):
    if (mathaMars - MTphol)>=0:
        MTS = mathaMars - MTphol
    elif (mathaMars - MTphol)<0:
        MTS =  mathaMars - MTphol + 21600
        print('MTS =',mathaMars - MTphol,'adjust to',MTS)          
        
elif (ptma ==3) or (ptma ==4):
    if (mathaMars + MTphol)>=21600:
        MTS = mathaMars + MTphol - 21600
        print('MTS =',mathaMars + MTphol,'adjust to',MTS)
    elif(mathaMars + MTphol)<21600:
        MTS = mathaMars + MTphol


pholMT = MTS-matharavi
if pholMT<0:
    pholMT=pholMT+21600

ptnd = (pholMT//5400)+1
if ptnd == 1:
    puchaTY = pholMT
    khotiTY = 5400-pholMT
elif ptnd == 2:
    puchaTY = 10800-pholMT
    khotiTY = pholMT-5400
elif ptnd == 3:
    puchaTY = pholMT-10800
    khotiTY = 16200-pholMT
elif ptnd == 4:
    puchaTY = 21600-pholMT
    khotiTY = pholMT-16200

if puchaTY < 0:
    raise Exception('puchaTY is below 0')
elif puchaTY > 5400:
    raise Exception('puchaTY is greater than 5400')
elif puchaTY < 1800:
    SGPucha = (puchaTY*14640)//1800
elif (puchaTY >= 1800) and (puchaTY < 3600) :
    SGPucha = (((puchaTY-1800)*10980)//1800)+14640
elif puchaTY >= 3600 :
    SGPucha = (((puchaTY-3600)*3660)//1800)+25620

if khotiTY < 0:
    raise Exception('khotiTY is below 0')
elif khotiTY > 5400:
    raise Exception('khotiTY is greater than 5400')
elif khotiTY < 1800:
    SGKhoti = (khotiTY*14640)//1800
elif (khotiTY >= 1800) and (khotiTY < 3600) :
    SGKhoti = (((khotiTY-1800)*10980)//1800)+14640
elif khotiTY >= 3600 :
    SGKhoti = (((khotiTY-3600)*3660)//1800)+25620

SGKhoti = (SGKhoti+30)//60
SGphol = ((SGPucha+30)//60)//3

p= (4*MTcheta)//15 
sp = p+SGphol

if (ptnd ==1) or (ptnd ==4):
    SGcheta = sp + SGKhoti
elif (ptnd ==2) or (ptnd ==3):
    SGcheta = sp - SGKhoti

if SGcheta < 0:
    raise Exception('SGcheta < 0')
elif khotiTY > 21600:
    raise Exception('SGcheta > SGcheta')

mahaphol = (SGPucha*60)//SGcheta

if (ptnd ==1) or (ptnd ==2):
    if (MTS - mahaphol)>=0:
        Smars = MTS - mahaphol
    elif (MTS - mahaphol)<0:
        Smars =  MTS - mahaphol + 21600
        print('Smars =',MTS - mahaphol,'adjust to',Smars)          
        
elif (ptnd ==3) or (ptnd ==4):
    if (MTS + mahaphol)>=21600:
        Smars = MTS + mahaphol - 21600
        print('Smars =',MTS + mahaphol,'adjust to',Smars)
    elif(MTS + mahaphol)<21600:
        Smars = MTS + mahaphol

zodiac,frac = divmod(Smars,1800)
degree,minute = divmod(frac,60)


print('matharavi =',matharavi)
print('manut =',manut)
print('mathaMars =',mathaMars)
print('pholMars =',pholMars)
print('puchaPT =',puchaPT)
print('khotiPT =',khotiPT)
print('MTpucha =',MTpucha)
print('MTKhoti =',MTKhoti)
print('khotiphol =',khotiphol)
print('MTcheta =',MTcheta)
print('MTphol =',MTphol)
print('MTS =',MTS)
print('pholMT =',pholMT)
print('ptnd =',ptnd)
print('puchaTY =',puchaTY)
print('khotiTY =',khotiTY)
print('SGPucha =',SGPucha)
print('SGKhoti =',SGKhoti)
print('p =',p)
print('SGphol =',SGphol)
print('sp =',sp)
print('SGcheta =',SGcheta)
print('mahaphol =',mahaphol)
print('Smars =',Smars)
print('zodiac =',zodiac)
print('degree =',degree)
print('minute =',minute)
# Out:
# matharavi = 19685
# manut = 15744485
# mathaMars = 17297
# pholMars = 9677
# puchaPT = 1123
# khotiPT = 4277
# MTpucha = 9133
# MTKhoti = 450
# khotiphol = 225
# MTcheta = 2475
# MTphol = 221
# MTS = 17076
# pholMT = 18991
# ptnd = 4
# puchaTY = 2609
# khotiTY = 2791
# SGPucha = 19574
# SGKhoti = 345
# p = 660
# SGphol = 108
# sp = 768
# SGcheta = 1113
# mahaphol = 1055
# Smars = 18131
# zodiac = 10
# degree = 2
# minute = 11

# %%
mathaMY = ((manut*7)//46 + (manut*4)//1 + 10642)%21600
pholMY = matharavi-13200
if pholMY < 0:
    pholMY = pholMY+21600

ptma = (pholMY//5400)+1
if ptma == 1:
    puchaPT = pholMY
    khotiPT = 5400-pholMY
elif ptma == 2:
    puchaPT = 10800-pholMY
    khotiPT = pholMY-5400
elif ptma == 3:
    puchaPT = pholMY-10800
    khotiPT = 16200-pholMY
elif ptma == 4:
    puchaPT = 21600-pholMY
    khotiPT = pholMY-16200
    
# puchaPT = 1064
# khotiPT = 4336
    
if puchaPT < 0:
    raise Exception('puchaPT is below 0')
elif puchaPT > 5400:
    raise Exception('puchaPT is greater than 5400')
elif puchaPT < 1800:
    MTpucha = (puchaPT*14640)//1800
elif (puchaPT >= 1800) and (puchaPT < 3600) :
    MTpucha = (((puchaPT-1800)*10980)//1800)+14640
elif puchaPT >= 3600 :
    MTpucha = (((puchaPT-3600)*3660)//1800)+25620

if khotiPT < 0:
    raise Exception('khotiPT is below 0')
elif khotiPT > 5400:
    raise Exception('khotiPT is greater than 5400')
elif khotiPT < 1800:
    MTKhoti = (khotiPT*14640)//1800
elif (khotiPT >= 1800) and (khotiPT < 3600) :
    MTKhoti = (((khotiPT-1800)*10980)//1800)+14640
elif khotiPT >= 3600 :
    MTKhoti = (((khotiPT-3600)*3660)//1800)+25620

MTKhoti = (MTKhoti+30)//60
khotiphol = MTKhoti//2


if (ptma ==1) or (ptma ==4):
    MTcheta = 100*60 + khotiphol
elif (ptma ==2) or (ptma ==3):
    MTcheta=  100*60 - khotiphol
    
MTphol = (MTpucha*60)//MTcheta


if (ptma ==1) or (ptma ==2):
    if (matharavi  - MTphol)>=0:
        MTS = matharavi  - MTphol
    elif (matharavi  - MTphol)<0:
        MTS =  matharavi  - MTphol + 21600
        print('MTS =',matharavi  - MTphol,'adjust to',MTS)          
        
elif (ptma ==3) or (ptma ==4):
    if (matharavi  + MTphol)>=21600:
        MTS = matharavi  + MTphol - 21600
        print('MTS =',matharavi  + MTphol,'adjust to',MTS)
    elif(matharavi  + MTphol)<21600:
        MTS = matharavi  + MTphol


pholMT = MTS-mathaMY
if pholMT<0:
    pholMT=pholMT+21600

ptnd = (pholMT//5400)+1
if ptnd == 1:
    puchaTY = pholMT
    khotiTY = 5400-pholMT
elif ptnd == 2:
    puchaTY = 10800-pholMT
    khotiTY = pholMT-5400
elif ptnd == 3:
    puchaTY = pholMT-10800
    khotiTY = 16200-pholMT
elif ptnd == 4:
    puchaTY = 21600-pholMT
    khotiTY = pholMT-16200

if puchaTY < 0:
    raise Exception('puchaTY is below 0')
elif puchaTY > 5400:
    raise Exception('puchaTY is greater than 5400')
elif puchaTY < 1800:
    SGPucha = (puchaTY*14640)//1800
elif (puchaTY >= 1800) and (puchaTY < 3600) :
    SGPucha = (((puchaTY-1800)*10980)//1800)+14640
elif puchaTY >= 3600 :
    SGPucha = (((puchaTY-3600)*3660)//1800)+25620

if khotiTY < 0:
    raise Exception('khotiTY is below 0')
elif khotiTY > 5400:
    raise Exception('khotiTY is greater than 5400')
elif khotiTY < 1800:
    SGKhoti = (khotiTY*14640)//1800
elif (khotiTY >= 1800) and (khotiTY < 3600) :
    SGKhoti = (((khotiTY-1800)*10980)//1800)+14640
elif khotiTY >= 3600 :
    SGKhoti = (((khotiTY-3600)*3660)//1800)+25620

SGKhoti = (SGKhoti+30)//60
SGphol = ((SGPucha+30)//60)//3

p= 21*60
sp = p+SGphol

if (ptnd ==1) or (ptnd ==4):
    SGcheta = sp + SGKhoti
elif (ptnd ==2) or (ptnd ==3):
    SGcheta = sp - SGKhoti

if SGcheta < 0:
    raise Exception('SGcheta < 0')
elif khotiTY > 21600:
    raise Exception('SGcheta > SGcheta')

mahaphol = (SGPucha*60)//SGcheta

if (ptnd ==1) or (ptnd ==2):
    if (MTS - mahaphol)>=0:
        SMercury = MTS - mahaphol
    elif (MTS - mahaphol)<0:
        SMercury =  MTS - mahaphol + 21600
        print('Smars =',MTS - mahaphol,'adjust to',Smars)          
        
elif (ptnd ==3) or (ptnd ==4):
    if (MTS + mahaphol)>=21600:
        SMercury = MTS + mahaphol - 21600
        print('Smars =',MTS + mahaphol,'adjust to',Smars)
    elif(MTS + mahaphol)<21600:
        SMercury = MTS + mahaphol

zodiac,frac = divmod(SMercury,1800)
degree,minute = divmod(frac,60)


print('matharavi =',matharavi)
print('manut =',manut)
print('mathaMY =',mathaMY)
print('pholMY =',pholMY)
print('ptma =',ptma)
print('puchaPT =',puchaPT)
print('khotiPT =',khotiPT)
print('MTpucha =',MTpucha)
print('MTKhoti =',MTKhoti)
print('khotiphol =',khotiphol)
print('MTcheta =',MTcheta)
print('MTphol =',MTphol)
print('MTS =',MTS)
print('pholMT =',pholMT)
print('ptnd =',ptnd)
print('puchaTY =',puchaTY)
print('khotiTY =',khotiTY)
print('SGPucha =',SGPucha)
print('SGKhoti =',SGKhoti)
print('p =',p)
print('SGphol =',SGphol)
print('sp =',sp)
print('SGcheta =',SGcheta)
print('mahaphol =',mahaphol)
print('SMercury =',SMercury)
print('zodiac =',zodiac)
print('degree =',degree)
print('minute =',minute)
# Out:
# matharavi = 19685
# manut = 15744485
# mathaMY = 1281
# pholMY = 6485
# ptma = 2
# puchaPT = 4315
# khotiPT = 1085
# MTpucha = 27073
# MTKhoti = 147
# khotiphol = 73
# MTcheta = 5927
# MTphol = 274
# MTS = 19411
# pholMT = 18130
# ptnd = 4
# puchaTY = 3470
# khotiTY = 1930
# SGPucha = 24827
# SGKhoti = 257
# p = 1260
# SGphol = 138
# sp = 1398
# SGcheta = 1655
# mahaphol = 900
# SMercury = 20311
# zodiac = 11
# degree = 8
# minute = 31

# %%
mathaVenus = ((manut*5)//3 - (manut*10)//243 + 10944)%21600
pholVenus = matharavi-4800
if pholVenus < 0:
    pholVenus = pholVenus+21600

ptma = (pholVenus//5400)+1
if ptma == 1:
    puchaPT = pholVenus
    khotiPT = 5400-pholVenus
elif ptma == 2:
    puchaPT = 10800-pholVenus
    khotiPT = pholVenus-5400
elif ptma == 3:
    puchaPT = pholVenus-10800
    khotiPT = 16200-pholVenus
elif ptma == 4:
    puchaPT = 21600-pholVenus
    khotiPT = pholVenus-16200
    
# puchaPT = 1064
# khotiPT = 4336

if puchaPT < 0:
    raise Exception('puchaPT is below 0')
elif puchaPT > 5400:
    raise Exception('puchaPT is greater than 5400')
elif puchaPT < 1800:
    MTpucha = (puchaPT*14640)//1800
elif (puchaPT >= 1800) and (puchaPT < 3600) :
    MTpucha = (((puchaPT-1800)*10980)//1800)+14640
elif puchaPT >= 3600 :
    MTpucha = (((puchaPT-3600)*3660)//1800)+25620

if khotiPT < 0:
    raise Exception('khotiPT is below 0')
elif khotiPT > 5400:
    raise Exception('khotiPT is greater than 5400')
elif khotiPT < 1800:
    MTKhoti = (khotiPT*14640)//1800
elif (khotiPT >= 1800) and (khotiPT < 3600) :
    MTKhoti = (((khotiPT-1800)*10980)//1800)+14640
elif khotiPT >= 3600 :
    MTKhoti = (((khotiPT-3600)*3660)//1800)+25620

MTKhoti = (MTKhoti+30)//60
khotiphol = MTKhoti//2


if (ptma ==1) or (ptma ==4):
    MTcheta = 320*60 + khotiphol
elif (ptma ==2) or (ptma ==3):
    MTcheta=  320*60 - khotiphol
    
MTphol = (MTpucha*60)//MTcheta


if (ptma ==1) or (ptma ==2):
    if (matharavi  - MTphol)>=0:
        MTS = matharavi  - MTphol
    elif (matharavi  - MTphol)<0:
        MTS =  matharavi  - MTphol + 21600
        print('MTS =',matharavi  - MTphol,'adjust to',MTS)          
        
elif (ptma ==3) or (ptma ==4):
    if (matharavi  + MTphol)>=21600:
        MTS = matharavi  + MTphol - 21600
        print('MTS =',matharavi  + MTphol,'adjust to',MTS)
    elif(matharavi  + MTphol)<21600:
        MTS = matharavi  + MTphol


pholMT = MTS-mathaVenus
if pholMT<0:
    pholMT=pholMT+21600

ptnd = (pholMT//5400)+1
if ptnd == 1:
    puchaTY = pholMT
    khotiTY = 5400-pholMT
elif ptnd == 2:
    puchaTY = 10800-pholMT
    khotiTY = pholMT-5400
elif ptnd == 3:
    puchaTY = pholMT-10800
    khotiTY = 16200-pholMT
elif ptnd == 4:
    puchaTY = 21600-pholMT
    khotiTY = pholMT-16200

if puchaTY < 0:
    raise Exception('puchaTY is below 0')
elif puchaTY > 5400:
    raise Exception('puchaTY is greater than 5400')
elif puchaTY < 1800:
    SGPucha = (puchaTY*14640)//1800
elif (puchaTY >= 1800) and (puchaTY < 3600) :
    SGPucha = (((puchaTY-1800)*10980)//1800)+14640
elif puchaTY >= 3600 :
    SGPucha = (((puchaTY-3600)*3660)//1800)+25620

if khotiTY < 0:
    raise Exception('khotiTY is below 0')
elif khotiTY > 5400:
    raise Exception('khotiTY is greater than 5400')
elif khotiTY < 1800:
    SGKhoti = (khotiTY*14640)//1800
elif (khotiTY >= 1800) and (khotiTY < 3600) :
    SGKhoti = (((khotiTY-1800)*10980)//1800)+14640
elif khotiTY >= 3600 :
    SGKhoti = (((khotiTY-3600)*3660)//1800)+25620

SGKhoti = (SGKhoti+30)//60
SGphol = ((SGPucha+30)//60)//3

p= 11*60
sp = p+SGphol

if (ptnd ==1) or (ptnd ==4):
    SGcheta = sp + SGKhoti
elif (ptnd ==2) or (ptnd ==3):
    SGcheta = sp - SGKhoti

if SGcheta < 0:
    raise Exception('SGcheta < 0')
elif khotiTY > 21600:
    raise Exception('SGcheta > SGcheta')

mahaphol = (SGPucha*60)//SGcheta

if (ptnd ==1) or (ptnd ==2):
    if (MTS - mahaphol)>=0:
        SVenus = MTS - mahaphol
    elif (MTS - mahaphol)<0:
        SVenus =  MTS - mahaphol + 21600
        print('SVenus =',MTS - mahaphol,'adjust to',SVenus)          
        
elif (ptnd ==3) or (ptnd ==4):
    if (MTS + mahaphol)>=21600:
        SVenus = MTS + mahaphol - 21600
        print('SVenus =',MTS + mahaphol,'adjust to',SVenus)
    elif(MTS + mahaphol)<21600:
        SVenus = MTS + mahaphol

zodiac,frac = divmod(SVenus,1800)
degree,minute = divmod(frac,60)


print('matharavi =',matharavi)
print('manut =',manut)
print('mathaVenus =',mathaVenus)
print('pholVenus =',pholVenus)
print('ptma =',ptma)
print('puchaPT =',puchaPT)
print('khotiPT =',khotiPT)
print('MTpucha =',MTpucha)
print('MTKhoti =',MTKhoti)
print('khotiphol =',khotiphol)
print('MTcheta =',MTcheta)
print('MTphol =',MTphol)
print('MTS =',MTS)
print('pholMT =',pholMT)
print('ptnd =',ptnd)
print('puchaTY =',puchaTY)
print('khotiTY =',khotiTY)
print('SGPucha =',SGPucha)
print('SGKhoti =',SGKhoti)
print('p =',p)
print('SGphol =',SGphol)
print('sp =',sp)
print('SGcheta =',SGcheta)
print('mahaphol =',mahaphol)
print('SVenus =',SVenus)
print('zodiac =',zodiac)
print('degree =',degree)
print('minute =',minute)
# Out:
# SVenus = 21885 adjust to 285
# matharavi = 19685
# manut = 15744485
# mathaVenus = 7831
# pholVenus = 14885
# ptma = 3
# puchaPT = 4085
# khotiPT = 1315
# MTpucha = 26606
# MTKhoti = 178
# khotiphol = 89
# MTcheta = 19111
# MTphol = 83
# MTS = 19768
# pholMT = 11937
# ptnd = 3
# puchaTY = 1137
# khotiTY = 4263
# SGPucha = 9247
# SGKhoti = 449
# p = 660
# SGphol = 51
# sp = 711
# SGcheta = 262
# mahaphol = 2117
# SVenus = 285
# zodiac = 0
# degree = 4
# minute = 45

# %%
mathaJP = ((manut*1)//12 + (manut*1)//1032 + 14297)%21600
pholJP = mathaJP-10320
if pholJP<0:
    pholJP = pholJP+21600

ptma = (pholJP//5400)+1
if ptma == 1:
    puchaPT = pholJP
    khotiPT = 5400-pholJP
elif ptma == 2:
    puchaPT = 10800-pholJP
    khotiPT = pholJP-5400
elif ptma == 3:
    puchaPT = pholJP-10800
    khotiPT = 16200-pholJP
elif ptma == 4:
    puchaPT = 21600-pholJP
    khotiPT = pholJP-16200
    
# puchaPT = 1064
# khotiPT = 4336
    
if puchaPT < 0:
    raise Exception('puchaPT is below 0')
elif puchaPT > 5400:
    raise Exception('puchaPT is greater than 5400')
elif puchaPT < 1800:
    MTpucha = (puchaPT*14640)//1800
elif (puchaPT >= 1800) and (puchaPT < 3600) :
    MTpucha = (((puchaPT-1800)*10980)//1800)+14640
elif puchaPT >= 3600 :
    MTpucha = (((puchaPT-3600)*3660)//1800)+25620

if khotiPT < 0:
    raise Exception('khotiPT is below 0')
elif khotiPT > 5400:
    raise Exception('khotiPT is greater than 5400')
elif khotiPT < 1800:
    MTKhoti = (khotiPT*14640)//1800
elif (khotiPT >= 1800) and (khotiPT < 3600) :
    MTKhoti = (((khotiPT-1800)*10980)//1800)+14640
elif khotiPT >= 3600 :
    MTKhoti = (((khotiPT-3600)*3660)//1800)+25620

MTKhoti = (MTKhoti+30)//60
khotiphol = MTKhoti//2


if (ptma ==1) or (ptma ==4):
    MTcheta = 92*60 + khotiphol
elif (ptma ==2) or (ptma ==3):
    MTcheta=  92*60 - khotiphol
    
MTphol = (MTpucha*60)//MTcheta


if (ptma ==1) or (ptma ==2):
    if (mathaJP - MTphol)>=0:
        MTS = mathaJP - MTphol
    elif (mathaJP - MTphol)<0:
        MTS =  mathaJP - MTphol + 21600
        print('MTS =',mathaJP - MTphol,'adjust to',MTS)          
        
elif (ptma ==3) or (ptma ==4):
    if (mathaJP + MTphol)>=21600:
        MTS = mathaJP + MTphol - 21600
        print('MTS =',mathaJP + MTphol,'adjust to',MTS)
    elif(mathaJP + MTphol)<21600:
        MTS = mathaJP + MTphol


pholMT = MTS-matharavi
if pholMT<0:
    pholMT=pholMT+21600

ptnd = (pholMT//5400)+1
if ptnd == 1:
    puchaTY = pholMT
    khotiTY = 5400-pholMT
elif ptnd == 2:
    puchaTY = 10800-pholMT
    khotiTY = pholMT-5400
elif ptnd == 3:
    puchaTY = pholMT-10800
    khotiTY = 16200-pholMT
elif ptnd == 4:
    puchaTY = 21600-pholMT
    khotiTY = pholMT-16200

if puchaTY < 0:
    raise Exception('puchaTY is below 0')
elif puchaTY > 5400:
    raise Exception('puchaTY is greater than 5400')
elif puchaTY < 1800:
    SGPucha = (puchaTY*14640)//1800
elif (puchaTY >= 1800) and (puchaTY < 3600) :
    SGPucha = (((puchaTY-1800)*10980)//1800)+14640
elif puchaTY >= 3600 :
    SGPucha = (((puchaTY-3600)*3660)//1800)+25620

if khotiTY < 0:
    raise Exception('khotiTY is below 0')
elif khotiTY > 5400:
    raise Exception('khotiTY is greater than 5400')
elif khotiTY < 1800:
    SGKhoti = (khotiTY*14640)//1800
elif (khotiTY >= 1800) and (khotiTY < 3600) :
    SGKhoti = (((khotiTY-1800)*10980)//1800)+14640
elif khotiTY >= 3600 :
    SGKhoti = (((khotiTY-3600)*3660)//1800)+25620

SGKhoti = (SGKhoti+30)//60
SGphol = ((SGPucha+30)//60)//3

p= (3*MTcheta)//7 
sp = p+SGphol

if (ptnd ==1) or (ptnd ==4):
    SGcheta = sp + SGKhoti
elif (ptnd ==2) or (ptnd ==3):
    SGcheta = sp - SGKhoti

if SGcheta < 0:
    raise Exception('SGcheta < 0')
elif khotiTY > 21600:
    raise Exception('SGcheta > SGcheta')

mahaphol = (SGPucha*60)//SGcheta

if (ptnd ==1) or (ptnd ==2):
    if (MTS - mahaphol)>=0:
        Jupiter = MTS - mahaphol
    elif (MTS - mahaphol)<0:
        Jupiter =  MTS - mahaphol + 21600
        print('Smars =',MTS - mahaphol,'adjust to',Smars)          
        
elif (ptnd ==3) or (ptnd ==4):
    if (MTS + mahaphol)>=21600:
        Jupiter = MTS + mahaphol - 21600
        print('Smars =',MTS + mahaphol,'adjust to',Smars)
    elif(MTS + mahaphol)<21600:
        Jupiter = MTS + mahaphol

zodiac,frac = divmod(Jupiter,1800)
degree,minute = divmod(frac,60)


print('matharavi =',matharavi)
print('manut =',manut)
print('mathaJP =',mathaJP)
print('pholJP =',pholJP)
print('ptma =',ptma)
print('puchaPT =',puchaPT)
print('khotiPT =',khotiPT)
print('MTpucha =',MTpucha)
print('MTKhoti =',MTKhoti)
print('khotiphol =',khotiphol)
print('MTcheta =',MTcheta)
print('MTphol =',MTphol)
print('MTS =',MTS)
print('pholMT =',pholMT)
print('ptnd =',ptnd)
print('puchaTY =',puchaTY)
print('khotiTY =',khotiTY)
print('SGPucha =',SGPucha)
print('SGKhoti =',SGKhoti)
print('p =',p)
print('SGphol =',SGphol)
print('sp =',sp)
print('SGcheta =',SGcheta)
print('mahaphol =',mahaphol)
print('Jupiter =',Jupiter)
print('zodiac =',zodiac)
print('degree =',degree)
print('minute =',minute)
# Out:
# matharavi = 19685
# manut = 15744485
# mathaJP = 2393
# pholJP = 13673
# ptma = 3
# puchaPT = 2873
# khotiPT = 2527
# MTpucha = 21185
# MTKhoti = 318
# khotiphol = 159
# MTcheta = 5361
# MTphol = 237
# MTS = 2630
# pholMT = 4545
# ptnd = 1
# puchaTY = 4545
# khotiTY = 855
# SGPucha = 27541
# SGKhoti = 116
# p = 2297
# SGphol = 153
# sp = 2450
# SGcheta = 2566
# mahaphol = 643
# Jupiter = 1987
# zodiac = 1
# degree = 3
# minute = 7

# %%
mathaSaturn = ((manut*1)//30 + (manut*6)//10000 + 11944)%21600
pholSaturn= mathaSaturn-14820
if pholSaturn<0:
    pholSaturn = pholSaturn+21600

ptma = (pholSaturn//5400)+1
if ptma == 1:
    puchaPT = pholSaturn
    khotiPT = 5400-pholSaturn
elif ptma == 2:
    puchaPT = 10800-pholSaturn
    khotiPT = pholSaturn-5400
elif ptma == 3:
    puchaPT = pholSaturn-10800
    khotiPT = 16200-pholSaturn
elif ptma == 4:
    puchaPT = 21600-pholSaturn
    khotiPT = pholSaturn-16200
    
# puchaPT = 1064
# khotiPT = 4336
    
if puchaPT < 0:
    raise Exception('puchaPT is below 0')
elif puchaPT > 5400:
    raise Exception('puchaPT is greater than 5400')
elif puchaPT < 1800:
    MTpucha = (puchaPT*14640)//1800
elif (puchaPT >= 1800) and (puchaPT < 3600) :
    MTpucha = (((puchaPT-1800)*10980)//1800)+14640
elif puchaPT >= 3600 :
    MTpucha = (((puchaPT-3600)*3660)//1800)+25620

if khotiPT < 0:
    raise Exception('khotiPT is below 0')
elif khotiPT > 5400:
    raise Exception('khotiPT is greater than 5400')
elif khotiPT < 1800:
    MTKhoti = (khotiPT*14640)//1800
elif (khotiPT >= 1800) and (khotiPT < 3600) :
    MTKhoti = (((khotiPT-1800)*10980)//1800)+14640
elif khotiPT >= 3600 :
    MTKhoti = (((khotiPT-3600)*3660)//1800)+25620

MTKhoti = (MTKhoti+30)//60
khotiphol = MTKhoti//2


if (ptma ==1) or (ptma ==4):
    MTcheta = 63*60 + khotiphol
elif (ptma ==2) or (ptma ==3):
    MTcheta=  63*60 - khotiphol
    
MTphol = (MTpucha*60)//MTcheta


if (ptma ==1) or (ptma ==2):
    if (mathaSaturn - MTphol)>=0:
        MTS = mathaSaturn - MTphol
    elif (mathaSaturn - MTphol)<0:
        MTS =  mathaSaturn - MTphol + 21600
        print('MTS =',mathaSaturn - MTphol,'adjust to',MTS)          
        
elif (ptma ==3) or (ptma ==4):
    if (mathaSaturn + MTphol)>=21600:
        MTS = mathaSaturn + MTphol - 21600
        print('MTS =',mathaSaturn + MTphol,'adjust to',MTS)
    elif(mathaSaturn + MTphol)<21600:
        MTS = mathaSaturn + MTphol


pholMT = MTS-matharavi
if pholMT<0:
    pholMT=pholMT+21600

ptnd = (pholMT//5400)+1
if ptnd == 1:
    puchaTY = pholMT
    khotiTY = 5400-pholMT
elif ptnd == 2:
    puchaTY = 10800-pholMT
    khotiTY = pholMT-5400
elif ptnd == 3:
    puchaTY = pholMT-10800
    khotiTY = 16200-pholMT
elif ptnd == 4:
    puchaTY = 21600-pholMT
    khotiTY = pholMT-16200

if puchaTY < 0:
    raise Exception('puchaTY is below 0')
elif puchaTY > 5400:
    raise Exception('puchaTY is greater than 5400')
elif puchaTY < 1800:
    SGPucha = (puchaTY*14640)//1800
elif (puchaTY >= 1800) and (puchaTY < 3600) :
    SGPucha = (((puchaTY-1800)*10980)//1800)+14640
elif puchaTY >= 3600 :
    SGPucha = (((puchaTY-3600)*3660)//1800)+25620

if khotiTY < 0:
    raise Exception('khotiTY is below 0')
elif khotiTY > 5400:
    raise Exception('khotiTY is greater than 5400')
elif khotiTY < 1800:
    SGKhoti = (khotiTY*14640)//1800
elif (khotiTY >= 1800) and (khotiTY < 3600) :
    SGKhoti = (((khotiTY-1800)*10980)//1800)+14640
elif khotiTY >= 3600 :
    SGKhoti = (((khotiTY-3600)*3660)//1800)+25620

SGKhoti = (SGKhoti+30)//60
SGphol = ((SGPucha+30)//60)//3

p= (7*MTcheta)//6 
sp = p+SGphol

if (ptnd ==1) or (ptnd ==4):
    SGcheta = sp + SGKhoti
elif (ptnd ==2) or (ptnd ==3):
    SGcheta = sp - SGKhoti

if SGcheta < 0:
    raise Exception('SGcheta < 0')
elif khotiTY > 21600:
    raise Exception('SGcheta > SGcheta')

mahaphol = (SGPucha*60)//SGcheta

if (ptnd ==1) or (ptnd ==2):
    if (MTS - mahaphol)>=0:
        SSaturn = MTS - mahaphol
    elif (MTS - mahaphol)<0:
        SSaturn =  MTS - mahaphol + 21600
        print('Smars =',MTS - mahaphol,'adjust to',Smars)          
        
elif (ptnd ==3) or (ptnd ==4):
    if (MTS + mahaphol)>=21600:
        SSaturn = MTS + mahaphol - 21600
        print('Smars =',MTS + mahaphol,'adjust to',Smars)
    elif(MTS + mahaphol)<21600:
        SSaturn = MTS + mahaphol

zodiac,frac = divmod(SSaturn,1800)
degree,minute = divmod(frac,60)


print('matharavi =',matharavi)
print('manut =',manut)
print('mathaSaturn =',mathaSaturn)
print('pholSaturn =',pholSaturn)
print('ptma =',ptma)
print('puchaPT =',puchaPT)
print('khotiPT =',khotiPT)
print('MTpucha =',MTpucha)
print('MTKhoti =',MTKhoti)
print('khotiphol =',khotiphol)
print('MTcheta =',MTcheta)
print('MTphol =',MTphol)
print('MTS =',MTS)
print('pholMT =',pholMT)
print('ptnd =',ptnd)
print('puchaTY =',puchaTY)
print('khotiTY =',khotiTY)
print('SGPucha =',SGPucha)
print('SGKhoti =',SGKhoti)
print('p =',p)
print('SGphol =',SGphol)
print('sp =',sp)
print('SGcheta =',SGcheta)
print('mahaphol =',mahaphol)
print('SSaturn =',SSaturn)
print('zodiac =',zodiac)
print('degree =',degree)
print('minute =',minute)
# Out:
# matharavi = 19685
# manut = 15744485
# mathaSaturn = 6206
# pholSaturn = 12986
# ptma = 3
# puchaPT = 2186
# khotiPT = 3214
# MTpucha = 16994
# MTKhoti = 388
# khotiphol = 194
# MTcheta = 3586
# MTphol = 284
# MTS = 6490
# pholMT = 8405
# ptnd = 2
# puchaTY = 2395
# khotiTY = 3005
# SGPucha = 18269
# SGKhoti = 367
# p = 4183
# SGphol = 101
# sp = 4284
# SGcheta = 3917
# mahaphol = 279
# SSaturn = 6211
# zodiac = 3
# degree = 13
# minute = 31

# %%
mathaURS= ((manut*1)//84 + (manut*1)//7224 + 16277)%21600
pholURS= mathaURS-7440
if pholURS<0:
    pholURS = pholURS+21600

ptma = (pholURS//5400)+1
if ptma == 1:
    puchaPT = pholURS
    khotiPT = 5400-pholURS
elif ptma == 2:
    puchaPT = 10800-pholURS
    khotiPT = pholURS-5400
elif ptma == 3:
    puchaPT = pholURS-10800
    khotiPT = 16200-pholURS
elif ptma == 4:
    puchaPT = 21600-pholURS
    khotiPT = pholURS-16200
    
# puchaPT = 1064
# khotiPT = 4336
    
if puchaPT < 0:
    raise Exception('puchaPT is below 0')
elif puchaPT > 5400:
    raise Exception('puchaPT is greater than 5400')
elif puchaPT < 1800:
    MTpucha = (puchaPT*14640)//1800
elif (puchaPT >= 1800) and (puchaPT < 3600) :
    MTpucha = (((puchaPT-1800)*10980)//1800)+14640
elif puchaPT >= 3600 :
    MTpucha = (((puchaPT-3600)*3660)//1800)+25620

if khotiPT < 0:
    raise Exception('khotiPT is below 0')
elif khotiPT > 5400:
    raise Exception('khotiPT is greater than 5400')
elif khotiPT < 1800:
    MTKhoti = (khotiPT*14640)//1800
elif (khotiPT >= 1800) and (khotiPT < 3600) :
    MTKhoti = (((khotiPT-1800)*10980)//1800)+14640
elif khotiPT >= 3600 :
    MTKhoti = (((khotiPT-3600)*3660)//1800)+25620

MTKhoti = (MTKhoti+30)//60
khotiphol = MTKhoti//2


if (ptma ==1) or (ptma ==4):
    MTcheta = 644*60 + khotiphol
elif (ptma ==2) or (ptma ==3):
    MTcheta=  644*60 - khotiphol
    
MTphol = (MTpucha*60)//MTcheta


if (ptma ==1) or (ptma ==2):
    if (mathaURS - MTphol)>=0:
        MTS = mathaURS - MTphol
    elif (mathaURS - MTphol)<0:
        MTS =  mathaURS - MTphol + 21600
        print('MTS =',mathaURS - MTphol,'adjust to',MTS)          
        
elif (ptma ==3) or (ptma ==4):
    if (mathaURS + MTphol)>=21600:
        MTS = mathaURS + MTphol - 21600
        print('MTS =',mathaURS + MTphol,'adjust to',MTS)
    elif(mathaURS + MTphol)<21600:
        MTS = mathaURS + MTphol


pholMT = MTS-matharavi
if pholMT<0:
    pholMT=pholMT+21600

ptnd = (pholMT//5400)+1
if ptnd == 1:
    puchaTY = pholMT
    khotiTY = 5400-pholMT
elif ptnd == 2:
    puchaTY = 10800-pholMT
    khotiTY = pholMT-5400
elif ptnd == 3:
    puchaTY = pholMT-10800
    khotiTY = 16200-pholMT
elif ptnd == 4:
    puchaTY = 21600-pholMT
    khotiTY = pholMT-16200

if puchaTY < 0:
    raise Exception('puchaTY is below 0')
elif puchaTY > 5400:
    raise Exception('puchaTY is greater than 5400')
elif puchaTY < 1800:
    SGPucha = (puchaTY*14640)//1800
elif (puchaTY >= 1800) and (puchaTY < 3600) :
    SGPucha = (((puchaTY-1800)*10980)//1800)+14640
elif puchaTY >= 3600 :
    SGPucha = (((puchaTY-3600)*3660)//1800)+25620

if khotiTY < 0:
    raise Exception('khotiTY is below 0')
elif khotiTY > 5400:
    raise Exception('khotiTY is greater than 5400')
elif khotiTY < 1800:
    SGKhoti = (khotiTY*14640)//1800
elif (khotiTY >= 1800) and (khotiTY < 3600) :
    SGKhoti = (((khotiTY-1800)*10980)//1800)+14640
elif khotiTY >= 3600 :
    SGKhoti = (((khotiTY-3600)*3660)//1800)+25620

SGKhoti = (SGKhoti+30)//60
SGphol = ((SGPucha+30)//60)//3

p= (3*MTcheta)//7 
sp = p+SGphol

if (ptnd ==1) or (ptnd ==4):
    SGcheta = sp + SGKhoti
elif (ptnd ==2) or (ptnd ==3):
    SGcheta = sp - SGKhoti

if SGcheta < 0:
    raise Exception('SGcheta < 0')
elif khotiTY > 21600:
    raise Exception('SGcheta > SGcheta')

mahaphol = (SGPucha*60)//SGcheta

if (ptnd ==1) or (ptnd ==2):
    if (MTS - mahaphol)>=0:
        SUranus = MTS - mahaphol
    elif (MTS - mahaphol)<0:
        SUranus =  MTS - mahaphol + 21600
        print('SUranus =',MTS - mahaphol,'adjust to',SUranus)          
        
elif (ptnd ==3) or (ptnd ==4):
    if (MTS + mahaphol)>=21600:
        SUranus = MTS + mahaphol - 21600
        print('SUranus =',MTS + mahaphol,'adjust to',SUranus)
    elif(MTS + mahaphol)<21600:
        SUranus = MTS + mahaphol

zodiac,frac = divmod(SUranus,1800)
degree,minute = divmod(frac,60)


print('matharavi =',matharavi)
print('manut =',manut)
print('mathaURS =',mathaURS)
print('pholURS =',pholURS)
print('ptma =',ptma)
print('puchaPT =',puchaPT)
print('khotiPT =',khotiPT)
print('MTpucha =',MTpucha)
print('MTKhoti =',MTKhoti)
print('khotiphol =',khotiphol)
print('MTcheta =',MTcheta)
print('MTphol =',MTphol)
print('MTS =',MTS)
print('pholMT =',pholMT)
print('ptnd =',ptnd)
print('puchaTY =',puchaTY)
print('khotiTY =',khotiTY)
print('SGPucha =',SGPucha)
print('SGKhoti =',SGKhoti)
print('p =',p)
print('SGphol =',SGphol)
print('sp =',sp)
print('SGcheta =',SGcheta)
print('mahaphol =',mahaphol)
print('SUranus =',SUranus)
print('zodiac =',zodiac)
print('degree =',degree)
print('minute =',minute)
# Out:
# matharavi = 19685
# manut = 15744485
# mathaURS = 11490
# pholURS = 4050
# ptma = 1
# puchaPT = 4050
# khotiPT = 1350
# MTpucha = 26535
# MTKhoti = 183
# khotiphol = 91
# MTcheta = 38731
# MTphol = 41
# MTS = 11449
# pholMT = 13364
# ptnd = 3
# puchaTY = 2564
# khotiTY = 2836
# SGPucha = 19300
# SGKhoti = 349
# p = 16599
# SGphol = 107
# sp = 16706
# SGcheta = 16357
# mahaphol = 70
# SUranus = 11519
# zodiac = 6
# degree = 11
# minute = 59

# %%
import pandas as pd
s_ravi = {
    'jya': [35,32,27,22,13,5],
    'ravi': [0,35,67,94,116,129]
}
#df = pd.DataFrame(s_ravi)
df = pd.DataFrame(s_ravi)
#df.iloc[1] = [kj,Ssun]
#df.append(data)
df = df.append({'kj' : 'Sahil' , 'sun' : 22} , ignore_index=True)
df = df.append({'kj' : 'Sahil' , 'sun' : 22} , ignore_index=True)

df = df.append({'kj' : 'Sahil' , 'sun' : 22 , 'datetime' : dt} , ignore_index=True)
df = df.append({'kj' : 'Sahil' , 'sun' : 22 , 'datetime' : dtny} , ignore_index=True)


#df.to_csv(r"C:\Users\JACK\Desktop\out.csv")

# %% [markdown]
# #
