# %%
import math
from datetime import date
from datetime import datetime
from datetime import timedelta
import pandas as pd

# %%
def NYdate(jula_year):
    ny = jula_year*0.25875-int(jula_year/4 +0.5)+int(jula_year/100 +0.38)-int(jula_year/400 +0.595)-5.53375
    jultin =  ((jula_year*292207)+373)%800
    hour,frac = divmod(jultin*24,800)
    minute,frac = divmod(frac*60,800)
    second,frac = divmod(frac*60,800)
    christ_year = jula_year+638
    dtny = datetime(christ_year, 4, int(ny), hour , minute, second)
    return dtny;

# %%
class hora:
    def __init__(self,dt):
        offset = timedelta(minutes=18)
        dt= dt-offset
        jula_year = dt.year-638    
        d = date(dt.year,dt.month,dt.day)
        dtf= datetime(dt.year,dt.month,dt.day,0,0)        
        dtny = NYdate(jula_year)
        dny = date(dtny.year,dtny.month,dtny.day)
        
        if (dt>=dtny):
            jula_newyear = jula_year
        elif (dt<dtny):
            jula_newyear = jula_year-1
            dtny = NYdate(jula_newyear)
            dny = date(dtny.year,dtny.month,dtny.day)

            
        temp = (jula_newyear*292207)+373
        ahra = (temp//800)+1
        jultin =  temp%800

        kj = 800-jultin
        temp,aw= divmod((ahra*11)+650,692)
        masG,dT=divmod((ahra+temp),30)

        au = (ahra-621)%3232
        van = ahra%7

        stin = (d-dny).days
        sec = (dt-dtf).seconds

        ahra_ = ahra+stin
        stkm = (stin-1)*800
        kj_ = kj + stkm + sec//108

        awjt = (stin-1)*703+aw
        aws = awjt+(sec*703)//86400
        awdT,aw_=divmod(aws,692)
        temp,dT_=divmod((awdT+dT),30)
        masG_ = masG+temp
        van_=ahra_%7

        if (au+stin > 3232):
            au_ = au+stin-3232
        else: au_= au+stin        
        
        
##########################SUN###############################
        sun_table = [[35,32,27,22,13,5,0],
                     [0,35,67,94,116,129,134]]

        z = kj_ // 24350
        z_remainder = kj_ % 24350
        degree = z_remainder//811
        d_remainder = z_remainder % 811
        minute = d_remainder//14

        d_total = z*30+degree
        mathasun = d_total*60+minute-3


        if mathasun >= 21600:
            raise Exception('mathasun exceed or equal 21600')
        elif mathasun < 0:
            raise Exception('mathasun below 0')
        elif mathasun < 4800:
            pholsun = 21600+mathasun-4800
        else:
            pholsun = mathasun-4800


        if pholsun >= 21600:
            raise Exception('pholsun exceed or equal 21600')
        elif pholsun < 0:
            raise Exception('pholsun below 0')
        elif pholsun >= 0 and pholsun <5400:
            pholGA = pholsun

        elif pholsun >= 5400 and pholsun <10800:
            pholGA = 10800-pholsun

        elif pholsun >= 10800 and pholsun <16200:
            pholGA = pholsun-10800

        elif pholsun >= 16200:
            pholGA = 21600-pholsun


        khan = pholGA // 900
        pushlip = pholGA % 900


        jyaGA = (sun_table[0][khan]*pushlip) // 900
        ravipphol = sun_table[1][khan]+jyaGA


        if pholsun < 10800:
            Ssun = mathasun-ravipphol
        elif pholsun > 10800:
            Ssun= mathasun+ravipphol
        elif pholsun == 10800:
            if(ravipphol != 0):raise Exception('pholsun=10800 but ravipphol not 0')
            Ssun= mathasun

        if Ssun < 0:
            Ssun = Ssun+21600
        elif Ssun > 21600:
            Ssun= Ssun-21600
            
        #zodiac,frac = divmod(Ssun,1800)
        #degree,minute = divmod(frac,60)    
#        sun = []
#        sun.append(Ssun)
#         sun.append(Ssun//1800)
#         sun.append((Ssun%1800)//60)
#         sun.append((Ssun%1800)%60)

#         print('pholGA =',pholGA)
#         print('khan =',khan)
#         print('kj_ =',kj_)
#         print('mathasun =',mathasun)
#         print('Ssun =',Ssun)

##########################MOON###############################

        moon_table = [[77,71,61,47,30,10,0],
                     [0,77,148,209,256,286,296]]

        temp = (au_-1)*86400+sec

        #zodiac,frac = divmod(x,23270400)
        #degree,frac = divmod(frac,775680)
        #minute = frac // 12928

        zodiac = temp//23270400
        degree = (temp%23270400)//775680
        minute = ((temp%23270400)%775680)//12928
        d_total = zodiac*30+degree
        mtu = d_total*60+minute+2


        mathamoon = mathasun + aw_ +(aw_//25)+(dT_*720)-40
        if mathamoon >= 21600: 
            mathamoon = mathamoon-21600
        if mtu >= 21600: 
            mtu = mtu-21600

#        if mathamoon >= 21600:
#            raise Exception('mathamoon exceed or equal 21600')
#        if mtu >= 21600:
#            raise Exception('mtu exceed or equal 21600')
        if mathamoon < 0:
            raise Exception('mathamoon below 0')
        elif mtu < 0:
            raise Exception('mtu below 0')
        elif mathamoon>=mtu:
            uv =  mathamoon-mtu
        elif mathamoon<mtu:
            uv = 21600+mathamoon-mtu


        if uv >= 21600:
            raise Exception('uv exceed or equal 21600')
        elif uv < 0:
            raise Exception('uv below 0')
        elif uv >= 0 and uv <5400:
            pholGA = uv
        elif uv >= 5400 and uv <10800:
            pholGA = 10800-uv
        elif uv >= 10800 and uv <16200:
            pholGA = uv-10800
        elif uv >= 16200:
            pholGA = 21600-uv


        khan = pholGA // 900
        pushlip = pholGA % 900

        jyaGA = (moon_table[0][khan]*pushlip) // 900
        chandraphol = moon_table[1][khan]+jyaGA

        if uv < 10800:
            Smoon = mathamoon-chandraphol
        elif uv > 10800:
            Smoon= mathamoon+chandraphol
        elif uv == 10800:
            if(chandraphol != 0):raise Exception('uv=10800 but chandraphol not 0')
            Smoon= mathamoon

        if Smoon < 0:
            Smoon = Smoon+21600
        elif Smoon > 21600:
            Smoon= Smoon-21600


##########################RAHU###############################
        matharavi = mathasun-23
        srb = jula_newyear-610
        manut = (srb*21600)+ matharavi

        a = manut//20
        b = manut//265
        pmt = (a+b)%21600

        Srahu = 15150-pmt
        if Srahu<0:
            Srahu = Srahu+21600

##########################GETH###############################
        pholgt = (ahra_-345)%679
        mathageth = (pholgt*21600 + (sec*21600)//86400)//679
        Sgeth = 21600-mathageth
        zodiac,frac = divmod(Sgeth,1800)
        degree,minute = divmod(frac,60)

        


                
##########################Inner Plannets##################################
        plannet = ['mercury','venus']
        for plannet in plannet: 
            if plannet  == 'mercury':
                matha = ((manut*7)//46 + (manut*4)//1 + 10642)%21600
                pholPK = matharavi-13200
            elif plannet == 'venus':
                matha = ((manut*5)//3 - (manut*10)//243 + 10944)%21600
                pholPK = matharavi-4800
                
            if pholPK<0:
                pholPK = pholPK+21600

            ptma = (pholPK//5400)+1
            if ptma == 1:
                puchaPT = pholPK
                khotiPT = 5400-pholPK
            elif ptma == 2:
                puchaPT = 10800-pholPK
                khotiPT = pholPK-5400
            elif ptma == 3:
                puchaPT = pholPK-10800
                khotiPT = 16200-pholPK
            elif ptma == 4:
                puchaPT = 21600-pholPK
                khotiPT = pholPK-16200

            # puchaPT = 1064
            # khotiPT = 4336

            if puchaPT < 0:
                raise Exception('puchaPT is below 0')
            elif puchaPT > 5400:
                raise Exception('puchaPT is greater than 5400')
            elif puchaPT < 1800:
                MTpucha = (puchaPT*14640)//1800
            elif (puchaPT >= 1800) and (puchaPT < 3600) :
                MTpucha = (((puchaPT-1800)*10980)//1800)+14640
            elif puchaPT >= 3600 :
                MTpucha = (((puchaPT-3600)*3660)//1800)+25620

            if khotiPT < 0:
                raise Exception('khotiPT is below 0')
            elif khotiPT > 5400:
                raise Exception('khotiPT is greater than 5400')
            elif khotiPT < 1800:
                MTKhoti = (khotiPT*14640)//1800
            elif (khotiPT >= 1800) and (khotiPT < 3600) :
                MTKhoti = (((khotiPT-1800)*10980)//1800)+14640
            elif khotiPT >= 3600 :
                MTKhoti = (((khotiPT-3600)*3660)//1800)+25620

            MTKhoti = (MTKhoti+30)//60
            khotiphol = MTKhoti//2


            if plannet == 'mercury':
                if (ptma ==1) or (ptma ==4):
                    MTcheta = 100*60 + khotiphol
                elif (ptma ==2) or (ptma ==3):
                    MTcheta=  100*60 - khotiphol
            elif plannet == 'venus':
                if (ptma ==1) or (ptma ==4):
                    MTcheta = 320*60 + khotiphol
                elif (ptma ==2) or (ptma ==3):
                    MTcheta=  320*60 - khotiphol          
            
            

            MTphol = (MTpucha*60)//MTcheta


            if (ptma ==1) or (ptma ==2):
                if (matharavi  - MTphol)>=0:
                    MTS = matharavi  - MTphol
                elif (matharavi  - MTphol)<0:
                    MTS =  matharavi  - MTphol + 21600
                    print('MTS =',matharavi  - MTphol,'adjust to',MTS)          

            elif (ptma ==3) or (ptma ==4):
                if (matharavi  + MTphol)>=21600:
                    MTS = matharavi  + MTphol - 21600
                    print('MTS =',matharavi  + MTphol,'adjust to',MTS)
                elif(matharavi  + MTphol)<21600:
                    MTS = matharavi  + MTphol


            pholMT = MTS-matha
            if pholMT<0:
                pholMT=pholMT+21600

            ptnd = (pholMT//5400)+1
            if ptnd == 1:
                puchaTY = pholMT
                khotiTY = 5400-pholMT
            elif ptnd == 2:
                puchaTY = 10800-pholMT
                khotiTY = pholMT-5400
            elif ptnd == 3:
                puchaTY = pholMT-10800
                khotiTY = 16200-pholMT
            elif ptnd == 4:
                puchaTY = 21600-pholMT
                khotiTY = pholMT-16200

            if puchaTY < 0:
                raise Exception('puchaTY is below 0')
            elif puchaTY > 5400:
                raise Exception('puchaTY is greater than 5400')
            elif puchaTY < 1800:
                SGPucha = (puchaTY*14640)//1800
            elif (puchaTY >= 1800) and (puchaTY < 3600) :
                SGPucha = (((puchaTY-1800)*10980)//1800)+14640
            elif puchaTY >= 3600 :
                SGPucha = (((puchaTY-3600)*3660)//1800)+25620

            if khotiTY < 0:
                raise Exception('khotiTY is below 0')
            elif khotiTY > 5400:
                raise Exception('khotiTY is greater than 5400')
            elif khotiTY < 1800:
                SGKhoti = (khotiTY*14640)//1800
            elif (khotiTY >= 1800) and (khotiTY < 3600) :
                SGKhoti = (((khotiTY-1800)*10980)//1800)+14640
            elif khotiTY >= 3600 :
                SGKhoti = (((khotiTY-3600)*3660)//1800)+25620

            SGKhoti = (SGKhoti+30)//60
            SGphol = ((SGPucha+30)//60)//3


            if plannet == 'mercury': p= 21*60
            elif plannet == 'venus': p= 11*60            
            
            
            sp = p+SGphol

            if (ptnd ==1) or (ptnd ==4):
                SGcheta = sp + SGKhoti
            elif (ptnd ==2) or (ptnd ==3):
                SGcheta = sp - SGKhoti

            if SGcheta < 0:
                raise Exception('SGcheta < 0')
            elif khotiTY > 21600:
                raise Exception('SGcheta > SGcheta')

            mahaphol = (SGPucha*60)//SGcheta
            
            
            
            if plannet == 'mercury': 
                if (ptnd ==1) or (ptnd ==2):
                    if (MTS - mahaphol)>=0:
                        SMercury = MTS - mahaphol
                    elif (MTS - mahaphol)<0:
                        SMercury =  MTS - mahaphol + 21600
                        print('Smercury =',MTS - mahaphol,'adjust to',SMercury)          

                elif (ptnd ==3) or (ptnd ==4):
                    if (MTS + mahaphol)>=21600:
                        SMercury = MTS + mahaphol - 21600
                        print('SMercury =',MTS + mahaphol,'adjust to',SMercury)
                    elif(MTS + mahaphol)<21600:
                        SMercury = MTS + mahaphol
            elif plannet == 'venus': 
                if (ptnd ==1) or (ptnd ==2):
                    if (MTS - mahaphol)>=0:
                        SVenus = MTS - mahaphol
                    elif (MTS - mahaphol)<0:
                        SVenus =  MTS - mahaphol + 21600
                        print('SVenus =',MTS - mahaphol,'adjust to',SVenus)          

                elif (ptnd ==3) or (ptnd ==4):
                    if (MTS + mahaphol)>=21600:
                        SVenus = MTS + mahaphol - 21600
                        print('SVenus =',MTS + mahaphol,'adjust to',SVenus)
                    elif(MTS + mahaphol)<21600:
                        SVenus = MTS + mahaphol               





                
##########################Other Plannets####################################

        plannet = ['mars','jupiter','saturn','uranus']
        for plannet in plannet: 
 
            if plannet  == 'mars':
                matha  =  ((manut*1)//2 + (manut*16)//505 + 5420)%21600         
                pholPK = matha-7620
            elif plannet == 'jupiter':
                matha  = ((manut*1)//12 + (manut*1)//1032 + 14297)%21600
                pholPK = matha-10320
            elif plannet == 'saturn':
                matha  = ((manut*1)//30 + (manut*6)//10000 + 11944)%21600
                pholPK = matha-14820
            elif plannet == 'uranus':
                matha  = ((manut*1)//84 + (manut*1)//7224 + 16277)%21600
                pholPK = matha-7440        

            if pholPK<0:
                pholPK = pholPK+21600


            ptma = (pholPK//5400)+1
            if ptma == 1:
                puchaPT = pholPK
                khotiPT = 5400-pholPK
            elif ptma == 2:
                puchaPT = 10800-pholPK
                khotiPT = pholPK-5400
            elif ptma == 3:
                puchaPT = pholPK-10800
                khotiPT = 16200-pholPK
            elif ptma == 4:
                puchaPT = 21600-pholPK
                khotiPT = pholPK-16200

            # puchaPT = 1064
            # khotiPT = 4336

            if puchaPT < 0:
                raise Exception('puchaPT is below 0')
            elif puchaPT > 5400:
                raise Exception('puchaPT is greater than 5400')
            elif puchaPT < 1800:
                MTpucha = (puchaPT*14640)//1800
            elif (puchaPT >= 1800) and (puchaPT < 3600) :
                MTpucha = (((puchaPT-1800)*10980)//1800)+14640
            elif puchaPT >= 3600 :
                MTpucha = (((puchaPT-3600)*3660)//1800)+25620

            if khotiPT < 0:
                raise Exception('khotiPT is below 0')
            elif khotiPT > 5400:
                raise Exception('khotiPT is greater than 5400')
            elif khotiPT < 1800:
                MTKhoti = (khotiPT*14640)//1800
            elif (khotiPT >= 1800) and (khotiPT < 3600) :
                MTKhoti = (((khotiPT-1800)*10980)//1800)+14640
            elif khotiPT >= 3600 :
                MTKhoti = (((khotiPT-3600)*3660)//1800)+25620

            MTKhoti = (MTKhoti+30)//60
            khotiphol = MTKhoti//2


            if plannet == 'mars':
                if (ptma ==1) or (ptma ==4):
                    MTcheta = 45*60 + khotiphol
                elif (ptma ==2) or (ptma ==3):
                    MTcheta=  45*60 - khotiphol
            elif plannet == 'jupiter':
                if (ptma ==1) or (ptma ==4):
                    MTcheta = 92*60 + khotiphol
                elif (ptma ==2) or (ptma ==3):
                    MTcheta=  92*60 - khotiphol
            elif plannet == 'saturn':
                if (ptma ==1) or (ptma ==4):
                    MTcheta = 63*60 + khotiphol
                elif (ptma ==2) or (ptma ==3):
                    MTcheta=  63*60 - khotiphol
            elif plannet == 'uranus':
                if (ptma ==1) or (ptma ==4):
                    MTcheta = 644*60 + khotiphol
                elif (ptma ==2) or (ptma ==3):
                    MTcheta=  644*60 - khotiphol  



            MTphol = (MTpucha*60)//MTcheta


            if (ptma ==1) or (ptma ==2):
                if (matha - MTphol)>=0:
                    MTS = matha - MTphol
                elif (matha - MTphol)<0:
                    MTS =  matha - MTphol + 21600
                    print('MTS =',matha - MTphol,'adjust to',MTS)          

            elif (ptma ==3) or (ptma ==4):
                if (matha + MTphol)>=21600:
                    MTS = matha + MTphol - 21600
                    print('MTS =',matha + MTphol,'adjust to',MTS)
                elif(matha + MTphol)<21600:
                    MTS = matha + MTphol


            pholMT = MTS-matharavi
            if pholMT<0:
                pholMT=pholMT+21600

            ptnd = (pholMT//5400)+1
            if ptnd == 1:
                puchaTY = pholMT
                khotiTY = 5400-pholMT
            elif ptnd == 2:
                puchaTY = 10800-pholMT
                khotiTY = pholMT-5400
            elif ptnd == 3:
                puchaTY = pholMT-10800
                khotiTY = 16200-pholMT
            elif ptnd == 4:
                puchaTY = 21600-pholMT
                khotiTY = pholMT-16200

            if puchaTY < 0:
                raise Exception('puchaTY is below 0')
            elif puchaTY > 5400:
                raise Exception('puchaTY is greater than 5400')
            elif puchaTY < 1800:
                SGPucha = (puchaTY*14640)//1800
            elif (puchaTY >= 1800) and (puchaTY < 3600) :
                SGPucha = (((puchaTY-1800)*10980)//1800)+14640
            elif puchaTY >= 3600 :
                SGPucha = (((puchaTY-3600)*3660)//1800)+25620

            if khotiTY < 0:
                raise Exception('khotiTY is below 0')
            elif khotiTY > 5400:
                raise Exception('khotiTY is greater than 5400')
            elif khotiTY < 1800:
                SGKhoti = (khotiTY*14640)//1800
            elif (khotiTY >= 1800) and (khotiTY < 3600) :
                SGKhoti = (((khotiTY-1800)*10980)//1800)+14640
            elif khotiTY >= 3600 :
                SGKhoti = (((khotiTY-3600)*3660)//1800)+25620

            SGKhoti = (SGKhoti+30)//60
            SGphol = ((SGPucha+30)//60)//3

            
            if plannet == 'mars': p= (4*MTcheta)//15 
            elif plannet == 'jupiter': p= (3*MTcheta)//7
            elif plannet == 'saturn': p= (7*MTcheta)//6 
            elif plannet == 'uranus':p= (3*MTcheta)//7 
    

            sp = p+SGphol
            if (ptnd ==1) or (ptnd ==4):
                SGcheta = sp + SGKhoti
            elif (ptnd ==2) or (ptnd ==3):
                SGcheta = sp - SGKhoti

            if SGcheta < 0:
                raise Exception('SGcheta < 0')
            elif khotiTY > 21600:
                raise Exception('SGcheta > SGcheta')

            mahaphol = (SGPucha*60)//SGcheta

            

            if plannet == 'mars':
                if (ptnd ==1) or (ptnd ==2):
                    if (MTS - mahaphol)>=0:
                        Smars = MTS - mahaphol
                    elif (MTS - mahaphol)<0:
                        Smars =  MTS - mahaphol + 21600
                        print('Smars =',MTS - mahaphol,'adjust to',Smars)          

                elif (ptnd ==3) or (ptnd ==4):
                    if (MTS + mahaphol)>=21600:
                        Smars = MTS + mahaphol - 21600
                        print('Smars =',MTS + mahaphol,'adjust to',Smars)
                    elif(MTS + mahaphol)<21600:
                        Smars = MTS + mahaphol 
            elif plannet == 'jupiter':
                if (ptnd ==1) or (ptnd ==2):
                    if (MTS - mahaphol)>=0:
                        Jupiter = MTS - mahaphol
                    elif (MTS - mahaphol)<0:
                        Jupiter =  MTS - mahaphol + 21600
                        print('Jupiter =',MTS - mahaphol,'adjust to',Jupiter)          

                elif (ptnd ==3) or (ptnd ==4):
                    if (MTS + mahaphol)>=21600:
                        Jupiter = MTS + mahaphol - 21600
                        print('Jupiter =',MTS + mahaphol,'adjust to',Jupiter)
                    elif(MTS + mahaphol)<21600:
                        Jupiter = MTS + mahaphol 
            elif plannet == 'saturn':
                if (ptnd ==1) or (ptnd ==2):
                    if (MTS - mahaphol)>=0:
                        SSaturn = MTS - mahaphol
                    elif (MTS - mahaphol)<0:
                        SSaturn =  MTS - mahaphol + 21600
                        print('SSaturn =',MTS - mahaphol,'adjust to',SSaturn)          

                elif (ptnd ==3) or (ptnd ==4):
                    if (MTS + mahaphol)>=21600:
                        SSaturn = MTS + mahaphol - 21600
                        print('SSaturn =',MTS + mahaphol,'adjust to',SSaturn)
                    elif(MTS + mahaphol)<21600:
                        SSaturn = MTS + mahaphol
            elif plannet == 'uranus':
                if (ptnd ==1) or (ptnd ==2):
                    if (MTS - mahaphol)>=0:
                        SUranus = MTS - mahaphol
                    elif (MTS - mahaphol)<0:
                        SUranus =  MTS - mahaphol + 21600
                        print('SUranus =',MTS - mahaphol,'adjust to',SUranus)          

                elif (ptnd ==3) or (ptnd ==4):
                    if (MTS + mahaphol)>=21600:
                        SUranus = MTS + mahaphol - 21600
                        print('SUranus =',MTS + mahaphol,'adjust to',SUranus)
                    elif(MTS + mahaphol)<21600:
                        SUranus = MTS + mahaphol 
    



        

#         print('uv =',uv)
#         print('pholGA =',pholGA)
#         print('khan =',khan)
#         print('Smoon =',Smoon)

        print('au_ =',au_)
        print('mtu =',mtu)
        print('uv =',uv)
        print('Smoon =',Smoon)

        #TS Parameter (yearly parameter) 
        self.dt = dt  
        self.dtny = dtny 
        self.dny = dny 
        self.ahra = ahra 
        self.jultin = jultin 
        self.kj = kj 
        self.aw = aw 
        self.masG = masG 
        self.dT = dT
        self.au = au 
        self.van = van 
        
        #Given Datetime parameter
        self.stin = stin 
        self.sec = sec 
        self.ahra_ = ahra_ 
        self.kj_ = kj_ 
        self.aw_ = aw_ 
        self.masG_ = masG_ 
        self.dT_ = dT_
        self.au_ = au_ 
        self.van_ = van_
     
        #locations in zodiac (minutes maximum = 21600) 
        self.sun = Ssun
        self.moon = Smoon
        self.rahu = Srahu
        self.geth = Sgeth
        self.mars = Smars
        self.mercury = SMercury
        self.venus = SVenus
        self.jupiter = Jupiter
        self.saturn = SSaturn
        self.uranus = SUranus

# %%
startdate = datetime(2035,4,16,0,0)
df = pd.DataFrame()
count = 108000
#count = 10000
#count = 1000

#select timeframe
#interval = 'day'
interval = 'minutes'

for i in range(0,count):
    if interval=='minutes':
        diff = timedelta(minutes=i)
    elif interval=='day':
        diff = timedelta(days=i)
        
    dt = startdate+diff
    h = hora(dt)    
    data = {
        #'dt': dt,
        #'dtny': h.dtny,        
        'dt': str(dt.day)+'/'+str(dt.month)+'/'+str(dt.year+543)+' '+str(dt.hour)+':'+str(dt.minute),
        'dtny': str(h.dtny.day)+'/'+str(h.dtny.month)+'/'+str(h.dtny.year+543)+' '+str(h.dtny.hour)+':'+str(h.dtny.minute)+':'+str(h.dtny.second),
        'ahra' : h.ahra,
        'jultin': h.jultin,
        'kj' : h.kj,
        'aw' : h.aw,
        'masG' : h.masG,
        'dT' : h.dT,
        'au' : h.au,
        'van' : h.van,
        
        'stin' : h.stin,
        'sec': h.sec,
        'ahra_' : h.ahra_,
        'kj_' : h.kj_,
        'aw_' : h.aw_,
        'masG_' : h.masG_,
        'dT_' : h.dT_,
        'au_' : h.au_,
        'van_' : h.van_,

        'sun' : h.sun,
        'moon': h.moon,
        'rahu' : h.rahu,
        'geth' : h.geth,
        'mars' : h.mars,
        'mercury' : h.mercury,
        'venus' : h.venus,
        'jupiter' : h.jupiter,
        'saturn' : h.saturn,
        'uranus' : h.uranus
    }


    print(dt.day,dt.month,dt.year,dt.hour,':',dt.minute)
    #df = pd.DataFrame(data)
    df = df.append(data , ignore_index=True)


ListofPlannets = ['sun','moon','rahu','geth','mars','mercury','venus','jupiter','saturn','uranus'] 
for planet in ListofPlannets:
    zodiac = planet+"_Z"
    degree = planet+"_D"
    minute = planet+"_M"
    df[zodiac] =  df[planet]//1800 
    df[degree] =  (df[planet]%1800)//60 
    df[minute] =  (df[planet]%1800)%60
    
#df['sun_delta'] = df['sun'] 


#df.to_csv(r"C:\Users\JACK\Desktop\S_out.csv")

#df.dtypes

# data = {
#     'dt': [startdate],
#     'sun' : [h.sun],
#     'moon': [h.moon],
#     'rahu' : [h.rahu],
#     'geth' : [h.geth],
#     'mars' : [h.mars],
#     'mercury' : [h.mercury],
#     'venus' : [h.venus],
#     'jupiter' : [h.jupiter],
#     'saturn' : [h.saturn],
#     'uranus' : [h.uranus]
# }
#startdate = datetime(2019,4,16,0,0) mathasun-
# Out:
# MTS = -87 adjust to 21513
# SMercury = 22773 adjust to 1173
# SVenus = -1633 adjust to 19967
# au_ = 2224
# mtu = 14865
# uv = 14832
# Smoon = 8367
# 19 4 2035 0 : 0
# MTS = -87 adjust to 21513
# SMercury = 22773 adjust to 1173
# SVenus = -1633 adjust to 19967
# au_ = 2224
# mtu = 14865
# uv = 14832
# Smoon = 8367
# 19 4 2035 0 : 1
# MTS = -87 adjust to 21513
# SMercury = 22773 adjust to 1173
# SVenus = -1633 adjust to 19967
# au_ = 2224
# mtu = 14865
# uv = 14833
# Smoon = 8368
# 19 4 2035 0 : 2
# MTS = -87 adjust to 21513
# SMercury = 22773 adjust to 1173
# SVenus = -1633 adjust to 19967
# au_ = 2224
# mtu = 14865
# uv = 14833
# Smoon = 8368
# 19 4 2035 0 : 3
# MTS = -87 adjust to 21513
# SMercury = 22773 adjust to 1173
# SVenus = -1633 adjust to 19967
# au_ = 2224
# mtu = 14865
# uv = 14834
# Smoon = 8369
# 19 4 2035 0 : 4
# MTS = -87 adjust to 21513
# SMercury = 22773 adjust to 1173
# SVenus = -1633 adjust to 19967
# au_ = 2224
# mtu = 14865
# uv = 14834
# Smoon = 8369
# 19 4 2035 0 : 5
# MTS = -87 adjust to 21513
# SMercury = 22773 adjust to 1173
# SVenus = -1633 adjust to 19967
# au_ = 2224
# mtu = 14865
# uv = 14835
# Smoon = 8370
# 19 4 2035 0 : 6
# MTS = -87 adjust to 21513
# SMercury = 22773 adjust to 1173
# SVenus = -1633 adjust to 19967
# au_ = 2224
# mtu = 14865
# uv = 14835
# Smoon = 8370
# 19 4 2035 0 : 7
# MTS = -87 adjust to 21513
# SMercury = 22773 adjust to 1173
# SVenus = -1633 adjust to 19967
# au_ = 2224
# mtu = 14865
# uv = 14837
# Smoon = 8372
# 19 4 2035 0 : 8
# MTS = -87 adjust to 21513
# SMercury = 22773 adjust to 1173
# SVenus = -1633 adjust to 19967
# au_ = 2224
# mtu = 14865
# uv = 14837
# Smoon = 8372
# 19 4 2035 0 : 9
# MTS = -87 adjust to 21513
# SMercury = 22773 adjust to 1173
# SVenus = -1633 adjust to 19967
# au_ = 2224
# mtu = 14865
# uv = 14838
# Smoon = 8373
# 19 4 2035 0 : 10
# MTS = -87 adjust to 21513
# SMercury = 22773 adjust to 1173
# SVenus = -1633 adjust to 19967
# au_ = 2224
# mtu = 14865
# uv = 14838
# Smoon = 8373
# 19 4 2035 0 : 11
# MTS = -87 adjust to 21513
# SMercury = 22773 adjust to 1173
# SVenus = -1633 adjust to 19967
# au_ = 2224
# mtu = 14865
# uv = 14839
# Smoon = 8374
# 19 4 2035 0 : 12
# MTS = -87 adjust to 21513
# SMercury = 22773 adjust to 1173
# SVenus = -1633 adjust to 19967
# au_ = 2224
# mtu = 14865
# uv = 14839
# Smoon = 8374
# 19 4 2035 0 : 13
# MTS = -87 adjust to 21513
# SMercury = 22773 adjust to 1173
# SVenus = -1633 adjust to 19967
# au_ = 2224
# mtu = 14865
# uv = 14840
# Smoon = 8375
# 19 4 2035 0 : 14
# MTS = -87 adjust to 21513
# SMercury = 22773 adjust to 1173
# SVenus = -1633 adjust to 19967
# au_ = 2224
# mtu = 14865
# uv = 14840
# Smoon = 8375
# 19 4 2035 0 : 15
# MTS = -87 adjust to 21513
# SMercury = 22773 adjust to 1173
# SVenus = -1633 adjust to 19967
# au_ = 2224
# mtu = 14865
# uv = 14841
# Smoon = 8376
# 19 4 2035 0 : 16
# MTS = -87 adjust to 21513
# SMercury = 22773 adjust to 1173
# SVenus = -1633 adjust to 19967
# au_ = 2224
# mtu = 14865
# uv = 14841
# Smoon = 8376
# 19 4 2035 0 : 17
# MTS = -87 adjust to 21513
# SMercury = 22773 adjust to 1173
# SVenus = -1633 adjust to 19967
# au_ = 2225
# mtu = 14865
# uv = 14842
# Smoon = 8377
# 19 4 2035 0 : 18
# MTS = -87 adjust to 21513
# SMercury = 22773 adjust to 1173
# SVenus = -1633 adjust to 19967
# au_ = 2225
# mtu = 14865
# uv = 14842
# Smoon = 8377
# 19 4 2035 0 : 19
# MTS = -87 adjust to 21513
# SMercury = 22773 adjust to 1173
# SVenus = -1633 adjust to 19967
# au_ = 2225
# mtu = 14865
# uv = 14842
# Smoon = 8377
# 19 4 2035 0 : 20
# MTS = -87 adjust to 21513
# SMercury = 22773 adjust to 1173
# SVenus = -1633 adjust to 19967
# au_ = 2225
# mtu = 14865
# uv = 14843
# Smoon = 8378
# 19 4 2035 0 : 21
# MTS = -86 adjust to 21514
# SMercury = 22773 adjust to 1173
# SVenus = -1632 adjust to 19968
# au_ = 2225
# mtu = 14865
# uv = 14844
# Smoon = 8379
# 19 4 2035 0 : 22
# MTS = -86 adjust to 21514
# SMercury = 22773 adjust to 1173
# SVenus = -1632 adjust to 19968
# au_ = 2225
# mtu = 14865
# uv = 14845
# Smoon = 8380
# 19 4 2035 0 : 23
# MTS = -86 adjust to 21514
# SMercury = 22773 adjust to 1173
# SVenus = -1632 adjust to 19968
# au_ = 2225
# mtu = 14865
# uv = 14845
# Smoon = 8380
# 19 4 2035 0 : 24
# MTS = -86 adjust to 21514
# SMercury = 22773 adjust to 1173
# SVenus = -1632 adjust to 19968
# au_ = 2225
# mtu = 14865
# uv = 14846
# Smoon = 8381
# 19 4 2035 0 : 25
# MTS = -86 adjust to 21514
# SMercury = 22773 adjust to 1173
# SVenus = -1632 adjust to 19968
# au_ = 2225
# mtu = 14865
# uv = 14846
# Smoon = 8381
# 19 4 2035 0 : 26
# MTS = -86 adjust to 21514
# SMercury = 22773 adjust to 1173
# SVenus = -1632 adjust to 19968
# au_ = 2225
# mtu = 14865
# uv = 14847
# Smoon = 8382
# 19 4 2035 0 : 27
# MTS = -86 adjust to 21514
# SMercury = 22773 adjust to 1173
# SVenus = -1632 adjust to 19968
# au_ = 2225
# mtu = 14865
# uv = 14847
# Smoon = 8382
# 19 4 2035 0 : 28
# MTS = -86 adjust to 21514
# SMercury = 22773 adjust to 1173
# SVenus = -1632 adjust to 19968
# au_ = 2225
# mtu = 14865
# uv = 14848
# Smoon = 8383
# 19 4 2035 0 : 29
# MTS = -86 adjust to 21514
# SMercury = 22773 adjust to 1173
# SVenus = -1632 adjust to 19968
# au_ = 2225
# mtu = 14865
# uv = 14848
# Smoon = 8383
# 19 4 2035 0 : 30
# MTS = -86 adjust to 21514
# SMercury = 22773 adjust to 1173
# SVenus = -1632 adjust to 19968
# au_ = 2225
# mtu = 14865
# uv = 14849
# Smoon = 8384
# 19 4 2035 0 : 31
# MTS = -86 adjust to 21514
# SMercury = 22773 adjust to 1173
# SVenus = -1632 adjust to 19968
# au_ = 2225
# mtu = 14865
# uv = 14849
# Smoon = 8384
# 19 4 2035 0 : 32
# MTS = -86 adjust to 21514
# SMercury = 22773 adjust to 1173
# SVenus = -1632 adjust to 19968
# au_ = 2225
# mtu = 14865
# uv = 14850
# Smoon = 8386
# 19 4 2035 0 : 33
# MTS = -86 adjust to 21514
# SMercury = 22773 adjust to 1173
# SVenus = -1632 adjust to 19968
# au_ = 2225
# mtu = 14865
# uv = 14850
# Smoon = 8386
# 19 4 2035 0 : 34
# MTS = -86 adjust to 21514
# SMercury = 22773 adjust to 1173
# SVenus = -1632 adjust to 19968
# au_ = 2225
# mtu = 14865
# uv = 14851
# Smoon = 8387
# 19 4 2035 0 : 35
# MTS = -86 adjust to 21514
# SMercury = 22773 adjust to 1173
# SVenus = -1632 adjust to 19968
# au_ = 2225
# mtu = 14865
# uv = 14851
# Smoon = 8387
# 19 4 2035 0 : 36
# MTS = -86 adjust to 21514
# SMercury = 22773 adjust to 1173
# SVenus = -1632 adjust to 19968
# au_ = 2225
# mtu = 14865
# uv = 14852
# Smoon = 8388
# 19 4 2035 0 : 37
# MTS = -86 adjust to 21514
# SMercury = 22773 adjust to 1173
# SVenus = -1632 adjust to 19968
# au_ = 2225
# mtu = 14865
# uv = 14852
# Smoon = 8388
# 19 4 2035 0 : 38
# MTS = -86 adjust to 21514
# SMercury = 22773 adjust to 1173
# SVenus = -1632 adjust to 19968
# au_ = 2225
# mtu = 14865
# uv = 14853
# Smoon = 8389
# 19 4 2035 0 : 39
# MTS = -86 adjust to 21514
# SMercury = 22773 adjust to 1173
# SVenus = -1632 adjust to 19968
# au_ = 2225
# mtu = 14865
# uv = 14853
# Smoon = 8389
# 19 4 2035 0 : 40
# MTS = -86 adjust to 21514
# SMercury = 22773 adjust to 1173
# SVenus = -1632 adjust to 19968
# au_ = 2225
# mtu = 14865
# uv = 14854
# Smoon = 8390
# 19 4 2035 0 : 41
# MTS = -86 adjust to 21514
# SMercury = 22773 adjust to 1173
# SVenus = -1632 adjust to 19968
# au_ = 2225
# mtu = 14865
# uv = 14854
# Smoon = 8390
# 19 4 2035 0 : 42
# MTS = -86 adjust to 21514
# SMercury = 22773 adjust to 1173
# SVenus = -1632 adjust to 19968
# au_ = 2225
# mtu = 14865
# uv = 14855
# Smoon = 8391
# 19 4 2035 0 : 43
# MTS = -86 adjust to 21514
# SMercury = 22773 adjust to 1173
# SVenus = -1632 adjust to 19968
# au_ = 2225
# mtu = 14865
# uv = 14855
# Smoon = 8391
# 19 4 2035 0 : 44
# MTS = -86 adjust to 21514
# SMercury = 22773 adjust to 1173
# SVenus = -1632 adjust to 19968
# au_ = 2225
# mtu = 14865
# uv = 14856
# Smoon = 8392
# 19 4 2035 0 : 45
# MTS = -86 adjust to 21514
# SMercury = 22773 adjust to 1173
# SVenus = -1632 adjust to 19968
# au_ = 2225
# mtu = 14865
# uv = 14856
# Smoon = 8392
# 19 4 2035 0 : 46
# MTS = -85 adjust to 21515
# SMercury = 22774 adjust to 1174
# SVenus = -1631 adjust to 19969
# au_ = 2225
# mtu = 14865
# uv = 14858
# Smoon = 8394
# 19 4 2035 0 : 47
# MTS = -85 adjust to 21515
# SMercury = 22774 adjust to 1174
# SVenus = -1631 adjust to 19969
# au_ = 2225
# mtu = 14865
# uv = 14858
# Smoon = 8394
# 19 4 2035 0 : 48
# MTS = -85 adjust to 21515
# SMercury = 22774 adjust to 1174
# SVenus = -1631 adjust to 19969
# au_ = 2225
# mtu = 14865
# uv = 14859
# Smoon = 8395
# 19 4 2035 0 : 49
# MTS = -85 adjust to 21515
# SMercury = 22774 adjust to 1174
# SVenus = -1631 adjust to 19969
# au_ = 2225
# mtu = 14865
# uv = 14859
# Smoon = 8395
# 19 4 2035 0 : 50
# MTS = -85 adjust to 21515
# SMercury = 22774 adjust to 1174
# SVenus = -1631 adjust to 19969
# au_ = 2225
# mtu = 14865
# uv = 14860
# Smoon = 8396
# 19 4 2035 0 : 51
# MTS = -85 adjust to 21515
# SMercury = 22774 adjust to 1174
# SVenus = -1631 adjust to 19969
# au_ = 2225
# mtu = 14865
# uv = 14860
# Smoon = 8396
# 19 4 2035 0 : 52
# MTS = -85 adjust to 21515
# SMercury = 22774 adjust to 1174
# SVenus = -1631 adjust to 19969
# au_ = 2225
# mtu = 14865
# uv = 14861
# Smoon = 8397
# 19 4 2035 0 : 53
# MTS = -85 adjust to 21515
# SMercury = 22774 adjust to 1174
# SVenus = -1631 adjust to 19969
# au_ = 2225
# mtu = 14865
# uv = 14861
# Smoon = 8397
# 19 4 2035 0 : 54
# MTS = -85 adjust to 21515
# SMercury = 22774 adjust to 1174
# SVenus = -1631 adjust to 19969
# au_ = 2225
# mtu = 14865
# uv = 14862
# Smoon = 8398
# 19 4 2035 0 : 55
# MTS = -85 adjust to 21515
# SMercury = 22774 adjust to 1174
# SVenus = -1631 adjust to 19969
# au_ = 2225
# mtu = 14865
# uv = 14862
# Smoon = 8398
# 19 4 2035 0 : 56
# MTS = -85 adjust to 21515
# SMercury = 22774 adjust to 1174
# SVenus = -1631 adjust to 19969
# au_ = 2225
# mtu = 14865
# uv = 14863
# Smoon = 8399
# 19 4 2035 0 : 57
# MTS = -85 adjust to 21515
# SMercury = 22774 adjust to 1174
# SVenus = -1631 adjust to 19969
# au_ = 2225
# mtu = 14865
# uv = 14863
# Smoon = 8399
# 19 4 2035 0 : 58
# MTS = -85 adjust to 21515
# SMercury = 22774 adjust to 1174
# SVenus = -1631 adjust to 19969
# au_ = 2225
# mtu = 14865
# uv = 14865
# Smoon = 8401
# 19 4 2035 0 : 59
# MTS = -85 adjust to 21515
# SMercury = 22774 adjust to 1174
# SVenus = -1631 adjust to 19969
# au_ = 2225
# mtu = 14865
# uv = 14865
# Smoon = 8401
# 19 4 2035 1 : 0
# MTS = -85 adjust to 21515
# SMercury = 22774 adjust to 1174
# SVenus = -1631 adjust to 19969
# au_ = 2225
# mtu = 14865
# uv = 14865
# Smoon = 8401
# 19 4 2035 1 : 1
# MTS = -85 adjust to 21515
# SMercury = 22774 adjust to 1174
# SVenus = -1631 adjust to 19969
# au_ = 2225
# mtu = 14865
# uv = 14866
# Smoon = 8402
# 19 4 2035 1 : 2
# MTS = -85 adjust to 21515
# SMercury = 22774 adjust to 1174
# SVenus = -1631 adjust to 19969
# au_ = 2225
# mtu = 14865
# uv = 14866
# Smoon = 8402
# 19 4 2035 1 : 3
# MTS = -85 adjust to 21515
# SMercury = 22774 adjust to 1174
# SVenus = -1631 adjust to 19969
# au_ = 2225
# mtu = 14865
# uv = 14867
# Smoon = 8403
# 19 4 2035 1 : 4
# MTS = -85 adjust to 21515
# SMercury = 22774 adjust to 1174
# SVenus = -1631 adjust to 19969
# au_ = 2225
# mtu = 14865
# uv = 14867
# Smoon = 8403
# 19 4 2035 1 : 5
# MTS = -85 adjust to 21515
# SMercury = 22774 adjust to 1174
# SVenus = -1631 adjust to 19969
# au_ = 2225
# mtu = 14865
# uv = 14868
# Smoon = 8404
# 19 4 2035 1 : 6
# MTS = -85 adjust to 21515
# SMercury = 22774 adjust to 1174
# SVenus = -1631 adjust to 19969
# au_ = 2225
# mtu = 14865
# uv = 14868
# Smoon = 8404
# 19 4 2035 1 : 7
# MTS = -85 adjust to 21515
# SMercury = 22774 adjust to 1174
# SVenus = -1631 adjust to 19969
# au_ = 2225
# mtu = 14865
# uv = 14869
# Smoon = 8405
# 19 4 2035 1 : 8
# MTS = -85 adjust to 21515
# SMercury = 22774 adjust to 1174
# SVenus = -1631 adjust to 19969
# au_ = 2225
# mtu = 14865
# uv = 14869
# Smoon = 8405
# 19 4 2035 1 : 9
# MTS = -85 adjust to 21515
# SMercury = 22774 adjust to 1174
# SVenus = -1631 adjust to 19969
# au_ = 2225
# mtu = 14865
# uv = 14870
# Smoon = 8406
# 19 4 2035 1 : 10
# MTS = -85 adjust to 21515
# SMercury = 22774 adjust to 1174
# SVenus = -1631 adjust to 19969
# au_ = 2225
# mtu = 14865
# uv = 14870
# Smoon = 8406
# 19 4 2035 1 : 11
# MTS = -84 adjust to 21516
# SMercury = 22776 adjust to 1176
# SVenus = -1628 adjust to 19972
# au_ = 2225
# mtu = 14865
# uv = 14872
# Smoon = 8408
# 19 4 2035 1 : 12
# MTS = -84 adjust to 21516
# SMercury = 22776 adjust to 1176
# SVenus = -1628 adjust to 19972
# au_ = 2225
# mtu = 14865
# uv = 14872
# Smoon = 8408
# 19 4 2035 1 : 13
# MTS = -84 adjust to 21516
# SMercury = 22776 adjust to 1176
# SVenus = -1628 adjust to 19972
# au_ = 2225
# mtu = 14865
# uv = 14873
# Smoon = 8409
# 19 4 2035 1 : 14
# MTS = -84 adjust to 21516
# SMercury = 22776 adjust to 1176
# SVenus = -1628 adjust to 19972
# au_ = 2225
# mtu = 14865
# uv = 14873
# Smoon = 8409
# 19 4 2035 1 : 15
# MTS = -84 adjust to 21516
# SMercury = 22776 adjust to 1176
# SVenus = -1628 adjust to 19972
# au_ = 2225
# mtu = 14865
# uv = 14874
# Smoon = 8410
# 19 4 2035 1 : 16
# MTS = -84 adjust to 21516
# SMercury = 22776 adjust to 1176
# SVenus = -1628 adjust to 19972
# au_ = 2225
# mtu = 14865
# uv = 14874
# Smoon = 8410
# 19 4 2035 1 : 17
# MTS = -84 adjust to 21516
# SMercury = 22776 adjust to 1176
# SVenus = -1628 adjust to 19972
# au_ = 2225
# mtu = 14865
# uv = 14875
# Smoon = 8411
# 19 4 2035 1 : 18
# MTS = -84 adjust to 21516
# SMercury = 22776 adjust to 1176
# SVenus = -1628 adjust to 19972
# au_ = 2225
# mtu = 14865
# uv = 14875
# Smoon = 8411
# 19 4 2035 1 : 19
# MTS = -84 adjust to 21516
# SMercury = 22776 adjust to 1176
# SVenus = -1628 adjust to 19972
# au_ = 2225
# mtu = 14865
# uv = 14876
# Smoon = 8412
# 19 4 2035 1 : 20
# MTS = -84 adjust to 21516
# SMercury = 22776 adjust to 1176
# SVenus = -1628 adjust to 19972
# au_ = 2225
# mtu = 14865
# uv = 14876
# Smoon = 8412
# 19 4 2035 1 : 21
# MTS = -84 adjust to 21516
# SMercury = 22776 adjust to 1176
# SVenus = -1628 adjust to 19972
# au_ = 2225
# mtu = 14865
# uv = 14877
# Smoon = 8413
# 19 4 2035 1 : 22
# MTS = -84 adjust to 21516
# SMercury = 22776 adjust to 1176
# SVenus = -1628 adjust to 19972
# au_ = 2225
# mtu = 14865
# uv = 14877
# Smoon = 8413
# 19 4 2035 1 : 23
# MTS = -84 adjust to 21516
# SMercury = 22776 adjust to 1176
# SVenus = -1628 adjust to 19972
# au_ = 2225
# mtu = 14865
# uv = 14878
# Smoon = 8414
# 19 4 2035 1 : 24
# MTS = -84 adjust to 21516
# SMercury = 22776 adjust to 1176
# SVenus = -1628 adjust to 19972
# au_ = 2225
# mtu = 14865
# uv = 14878
# Smoon = 8414
# 19 4 2035 1 : 25
# MTS = -84 adjust to 21516
# SMercury = 22776 adjust to 1176
# SVenus = -1628 adjust to 19972
# au_ = 2225
# mtu = 14865
# uv = 14879
# Smoon = 8415
# 19 4 2035 1 : 26
# MTS = -84 adjust to 21516
# SMercury = 22776 adjust to 1176
# SVenus = -1628 adjust to 19972
# au_ = 2225
# mtu = 14865
# uv = 14879
# Smoon = 8415
# 19 4 2035 1 : 27
# MTS = -84 adjust to 21516
# SMercury = 22776 adjust to 1176
# SVenus = -1628 adjust to 19972
# au_ = 2225
# mtu = 14865
# uv = 14880
# Smoon = 8417
# 19 4 2035 1 : 28
# MTS = -84 adjust to 21516
# SMercury = 22776 adjust to 1176
# SVenus = -1628 adjust to 19972
# au_ = 2225
# mtu = 14865
# uv = 14880
# Smoon = 8417
# 19 4 2035 1 : 29
# MTS = -84 adjust to 21516
# SMercury = 22776 adjust to 1176
# SVenus = -1628 adjust to 19972
# au_ = 2225
# mtu = 14865
# uv = 14881
# Smoon = 8418
# 19 4 2035 1 : 30
# MTS = -84 adjust to 21516
# SMercury = 22776 adjust to 1176
# SVenus = -1628 adjust to 19972
# au_ = 2225
# mtu = 14865
# uv = 14881
# Smoon = 8418
# 19 4 2035 1 : 31
# MTS = -84 adjust to 21516
# SMercury = 22776 adjust to 1176
# SVenus = -1628 adjust to 19972
# au_ = 2225
# mtu = 14865
# uv = 14882
# Smoon = 8419
# 19 4 2035 1 : 32
# MTS = -84 adjust to 21516
# SMercury = 22776 adjust to 1176
# SVenus = -1628 adjust to 19972
# au_ = 2225
# mtu = 14865
# uv = 14882
# Smoon = 8419
# 19 4 2035 1 : 33
# MTS = -84 adjust to 21516
# SMercury = 22776 adjust to 1176
# SVenus = -1628 adjust to 19972
# au_ = 2225
# mtu = 14865
# uv = 14883
# Smoon = 8420
# 19 4 2035 1 : 34
# MTS = -84 adjust to 21516
# SMercury = 22776 adjust to 1176
# SVenus = -1628 adjust to 19972
# au_ = 2225
# mtu = 14865
# uv = 14883
# Smoon = 8420
# 19 4 2035 1 : 35
# MTS = -84 adjust to 21516
# SMercury = 22776 adjust to 1176
# SVenus = -1628 adjust to 19972
# au_ = 2225
# mtu = 14865
# uv = 14884
# Smoon = 8421
# 19 4 2035 1 : 36
# MTS = -84 adjust to 21516
# SMercury = 22776 adjust to 1176
# SVenus = -1628 adjust to 19972
# au_ = 2225
# mtu = 14865
# uv = 14884
# Smoon = 8421
# 19 4 2035 1 : 37
# MTS = -83 adjust to 21517
# SMercury = 22777 adjust to 1177
# SVenus = -1627 adjust to 19973
# au_ = 2225
# mtu = 14865
# uv = 14886
# Smoon = 8423
# 19 4 2035 1 : 38
# MTS = -83 adjust to 21517
# SMercury = 22777 adjust to 1177
# SVenus = -1627 adjust to 19973
# au_ = 2225
# mtu = 14865
# uv = 14886
# Smoon = 8423
# 19 4 2035 1 : 39
# MTS = -83 adjust to 21517
# SMercury = 22777 adjust to 1177
# SVenus = -1627 adjust to 19973
# au_ = 2225
# mtu = 14865
# uv = 14887
# Smoon = 8424
# 19 4 2035 1 : 40
# MTS = -83 adjust to 21517
# SMercury = 22777 adjust to 1177
# SVenus = -1627 adjust to 19973
# au_ = 2225
# mtu = 14865
# uv = 14887
# Smoon = 8424
# 19 4 2035 1 : 41
# MTS = -83 adjust to 21517
# SMercury = 22777 adjust to 1177
# SVenus = -1627 adjust to 19973
# au_ = 2225
# mtu = 14865
# uv = 14888
# Smoon = 8425
# 19 4 2035 1 : 42
# MTS = -83 adjust to 21517
# SMercury = 22777 adjust to 1177
# SVenus = -1627 adjust to 19973
# au_ = 2225
# mtu = 14865
# uv = 14888
# Smoon = 8425
# 19 4 2035 1 : 43
# MTS = -83 adjust to 21517
# SMercury = 22777 adjust to 1177
# SVenus = -1627 adjust to 19973
# au_ = 2225
# mtu = 14865
# uv = 14888
# Smoon = 8425
# 19 4 2035 1 : 44
# MTS = -83 adjust to 21517
# SMercury = 22777 adjust to 1177
# SVenus = -1627 adjust to 19973
# au_ = 2225
# mtu = 14865
# uv = 14889
# Smoon = 8426
# 19 4 2035 1 : 45
# MTS = -83 adjust to 21517
# SMercury = 22777 adjust to 1177
# SVenus = -1627 adjust to 19973
# au_ = 2225
# mtu = 14865
# uv = 14889
# Smoon = 8426
# 19 4 2035 1 : 46
# MTS = -83 adjust to 21517
# SMercury = 22777 adjust to 1177
# SVenus = -1627 adjust to 19973
# au_ = 2225
# mtu = 14865
# uv = 14890
# Smoon = 8427
# 19 4 2035 1 : 47
# MTS = -83 adjust to 21517
# SMercury = 22777 adjust to 1177
# SVenus = -1627 adjust to 19973
# au_ = 2225
# mtu = 14865
# uv = 14890
# Smoon = 8427
# 19 4 2035 1 : 48
# MTS = -83 adjust to 21517
# SMercury = 22777 adjust to 1177
# SVenus = -1627 adjust to 19973
# au_ = 2225
# mtu = 14865
# uv = 14891
# Smoon = 8428
# 19 4 2035 1 : 49
# MTS = -83 adjust to 21517
# SMercury = 22777 adjust to 1177
# SVenus = -1627 adjust to 19973
# au_ = 2225
# mtu = 14865
# uv = 14891
# Smoon = 8428
# 19 4 2035 1 : 50
# MTS = -83 adjust to 21517
# SMercury = 22777 adjust to 1177
# SVenus = -1627 adjust to 19973
# au_ = 2225
# mtu = 14865
# uv = 14893
# Smoon = 8430
# 19 4 2035 1 : 51
# MTS = -83 adjust to 21517
# SMercury = 22777 adjust to 1177
# SVenus = -1627 adjust to 19973
# au_ = 2225
# mtu = 14865
# uv = 14893
# Smoon = 8430
# 19 4 2035 1 : 52
# MTS = -83 adjust to 21517
# SMercury = 22777 adjust to 1177
# SVenus = -1627 adjust to 19973
# au_ = 2225
# mtu = 14865
# uv = 14894
# Smoon = 8431
# 19 4 2035 1 : 53
# MTS = -83 adjust to 21517
# SMercury = 22777 adjust to 1177
# SVenus = -1627 adjust to 19973
# au_ = 2225
# mtu = 14865
# uv = 14894
# Smoon = 8431
# 19 4 2035 1 : 54
# MTS = -83 adjust to 21517
# SMercury = 22777 adjust to 1177
# SVenus = -1627 adjust to 19973
# au_ = 2225
# mtu = 14865
# uv = 14895
# Smoon = 8432
# 19 4 2035 1 : 55
# MTS = -83 adjust to 21517
# SMercury = 22777 adjust to 1177
# SVenus = -1627 adjust to 19973
# au_ = 2225
# mtu = 14865
# uv = 14895
# Smoon = 8432
# 19 4 2035 1 : 56
# MTS = -83 adjust to 21517
# SMercury = 22777 adjust to 1177
# SVenus = -1627 adjust to 19973
# au_ = 2225
# mtu = 14865
# uv = 14896
# Smoon = 8433
# 19 4 2035 1 : 57
# MTS = -83 adjust to 21517
# SMercury = 22777 adjust to 1177
# SVenus = -1627 adjust to 19973
# au_ = 2225
# mtu = 14865
# uv = 14896
# Smoon = 8433
# 19 4 2035 1 : 58
# MTS = -83 adjust to 21517
# SMercury = 22777 adjust to 1177
# SVenus = -1627 adjust to 19973
# au_ = 2225
# mtu = 14865
# uv = 14897
# Smoon = 8434
# 19 4 2035 1 : 59
# MTS = -83 adjust to 21517
# SMercury = 22777 adjust to 1177
# SVenus = -1627 adjust to 19973
# au_ = 2225
# mtu = 14865
# uv = 14897
# Smoon = 8434
# 19 4 2035 2 : 0
# MTS = -83 adjust to 21517
# SMercury = 22777 adjust to 1177
# SVenus = -1627 adjust to 19973
# au_ = 2225
# mtu = 14865
# uv = 14898
# Smoon = 8435
# 19 4 2035 2 : 1
# MTS = -83 adjust to 21517
# SMercury = 22777 adjust to 1177
# SVenus = -1627 adjust to 19973
# au_ = 2225
# mtu = 14865
# uv = 14898
# Smoon = 8435
# 19 4 2035 2 : 2
# MTS = -82 adjust to 21518
# SMercury = 22778 adjust to 1178
# SVenus = -1626 adjust to 19974
# au_ = 2225
# mtu = 14865
# uv = 14900
# Smoon = 8437
# 19 4 2035 2 : 3
# MTS = -82 adjust to 21518
# SMercury = 22778 adjust to 1178
# SVenus = -1626 adjust to 19974
# au_ = 2225
# mtu = 14865
# uv = 14900
# Smoon = 8437
# 19 4 2035 2 : 4
# MTS = -82 adjust to 21518
# SMercury = 22778 adjust to 1178
# SVenus = -1626 adjust to 19974
# au_ = 2225
# mtu = 14865
# uv = 14901
# Smoon = 8438
# 19 4 2035 2 : 5
# MTS = -82 adjust to 21518
# SMercury = 22778 adjust to 1178
# SVenus = -1626 adjust to 19974
# au_ = 2225
# mtu = 14865
# uv = 14901
# Smoon = 8438
# 19 4 2035 2 : 6
# MTS = -82 adjust to 21518
# SMercury = 22778 adjust to 1178
# SVenus = -1626 adjust to 19974
# au_ = 2225
# mtu = 14865
# uv = 14902
# Smoon = 8439
# 19 4 2035 2 : 7
# MTS = -82 adjust to 21518
# SMercury = 22778 adjust to 1178
# SVenus = -1626 adjust to 19974
# au_ = 2225
# mtu = 14865
# uv = 14902
# Smoon = 8439
# 19 4 2035 2 : 8
# MTS = -82 adjust to 21518
# SMercury = 22778 adjust to 1178
# SVenus = -1626 adjust to 19974
# au_ = 2225
# mtu = 14865
# uv = 14903
# Smoon = 8440
# 19 4 2035 2 : 9
# MTS = -82 adjust to 21518
# SMercury = 22778 adjust to 1178
# SVenus = -1626 adjust to 19974
# au_ = 2225
# mtu = 14865
# uv = 14903
# Smoon = 8440
# 19 4 2035 2 : 10
# MTS = -82 adjust to 21518
# SMercury = 22778 adjust to 1178
# SVenus = -1626 adjust to 19974
# au_ = 2225
# mtu = 14865
# uv = 14904
# Smoon = 8441
# 19 4 2035 2 : 11
# MTS = -82 adjust to 21518
# SMercury = 22778 adjust to 1178
# SVenus = -1626 adjust to 19974
# au_ = 2225
# mtu = 14865
# uv = 14904
# Smoon = 8441
# 19 4 2035 2 : 12
# MTS = -82 adjust to 21518
# SMercury = 22778 adjust to 1178
# SVenus = -1626 adjust to 19974
# au_ = 2225
# mtu = 14865
# uv = 14905
# Smoon = 8442
# 19 4 2035 2 : 13
# MTS = -82 adjust to 21518
# SMercury = 22778 adjust to 1178
# SVenus = -1626 adjust to 19974
# au_ = 2225
# mtu = 14865
# uv = 14905
# Smoon = 8442
# 19 4 2035 2 : 14
# MTS = -82 adjust to 21518
# SMercury = 22778 adjust to 1178
# SVenus = -1626 adjust to 19974
# au_ = 2225
# mtu = 14865
# uv = 14906
# Smoon = 8443
# 19 4 2035 2 : 15
# MTS = -82 adjust to 21518
# SMercury = 22778 adjust to 1178
# SVenus = -1626 adjust to 19974
# au_ = 2225
# mtu = 14865
# uv = 14906
# Smoon = 8443
# 19 4 2035 2 : 16
# MTS = -82 adjust to 21518
# SMercury = 22778 adjust to 1178
# SVenus = -1626 adjust to 19974
# au_ = 2225
# mtu = 14865
# uv = 14907
# Smoon = 8444
# 19 4 2035 2 : 17
# MTS = -82 adjust to 21518
# SMercury = 22778 adjust to 1178
# SVenus = -1626 adjust to 19974
# au_ = 2225
# mtu = 14865
# uv = 14907
# Smoon = 8444
# 19 4 2035 2 : 18
# MTS = -82 adjust to 21518
# SMercury = 22778 adjust to 1178
# SVenus = -1626 adjust to 19974
# au_ = 2225
# mtu = 14865
# uv = 14908
# Smoon = 8445
# 19 4 2035 2 : 19
# MTS = -82 adjust to 21518
# SMercury = 22778 adjust to 1178
# SVenus = -1626 adjust to 19974
# au_ = 2225
# mtu = 14865
# uv = 14908
# Smoon = 8445
# 19 4 2035 2 : 20
# MTS = -82 adjust to 21518
# SMercury = 22778 adjust to 1178
# SVenus = -1626 adjust to 19974
# au_ = 2225
# mtu = 14865
# uv = 14909
# Smoon = 8446
# 19 4 2035 2 : 21
# MTS = -82 adjust to 21518
# SMercury = 22778 adjust to 1178
# SVenus = -1626 adjust to 19974
# au_ = 2225
# mtu = 14865
# uv = 14909
# Smoon = 8446
# 19 4 2035 2 : 22
# MTS = -82 adjust to 21518
# SMercury = 22778 adjust to 1178
# SVenus = -1626 adjust to 19974
# au_ = 2225
# mtu = 14865
# uv = 14910
# Smoon = 8448
# 19 4 2035 2 : 23
# MTS = -82 adjust to 21518
# SMercury = 22778 adjust to 1178
# SVenus = -1626 adjust to 19974
# au_ = 2225
# mtu = 14865
# uv = 14910
# Smoon = 8448
# 19 4 2035 2 : 24
# MTS = -82 adjust to 21518
# SMercury = 22778 adjust to 1178
# SVenus = -1626 adjust to 19974
# au_ = 2225
# mtu = 14865
# uv = 14911
# Smoon = 8449
# 19 4 2035 2 : 25
# MTS = -82 adjust to 21518
# SMercury = 22778 adjust to 1178
# SVenus = -1626 adjust to 19974
# au_ = 2225
# mtu = 14865
# uv = 14911
# Smoon = 8449
# 19 4 2035 2 : 26
# MTS = -82 adjust to 21518
# SMercury = 22778 adjust to 1178
# SVenus = -1626 adjust to 19974
# au_ = 2225
# mtu = 14865
# uv = 14911
# Smoon = 8449
# 19 4 2035 2 : 27
# MTS = -81 adjust to 21519
# SMercury = 22779 adjust to 1179
# SVenus = -1624 adjust to 19976
# au_ = 2225
# mtu = 14865
# uv = 14913
# Smoon = 8451
# 19 4 2035 2 : 28
# MTS = -81 adjust to 21519
# SMercury = 22779 adjust to 1179
# SVenus = -1624 adjust to 19976
# au_ = 2225
# mtu = 14865
# uv = 14913
# Smoon = 8451
# 19 4 2035 2 : 29
# MTS = -81 adjust to 21519
# SMercury = 22779 adjust to 1179
# SVenus = -1624 adjust to 19976
# au_ = 2225
# mtu = 14865
# uv = 14914
# Smoon = 8452
# 19 4 2035 2 : 30
# MTS = -81 adjust to 21519
# SMercury = 22779 adjust to 1179
# SVenus = -1624 adjust to 19976
# au_ = 2225
# mtu = 14865
# uv = 14914
# Smoon = 8452
# 19 4 2035 2 : 31
# MTS = -81 adjust to 21519
# SMercury = 22779 adjust to 1179
# SVenus = -1624 adjust to 19976
# au_ = 2225
# mtu = 14865
# uv = 14915
# Smoon = 8453
# 19 4 2035 2 : 32
# MTS = -81 adjust to 21519
# SMercury = 22779 adjust to 1179
# SVenus = -1624 adjust to 19976
# au_ = 2225
# mtu = 14865
# uv = 14915
# Smoon = 8453
# 19 4 2035 2 : 33
# MTS = -81 adjust to 21519
# SMercury = 22779 adjust to 1179
# SVenus = -1624 adjust to 19976
# au_ = 2225
# mtu = 14865
# uv = 14916
# Smoon = 8454
# 19 4 2035 2 : 34
# MTS = -81 adjust to 21519
# SMercury = 22779 adjust to 1179
# SVenus = -1624 adjust to 19976
# au_ = 2225
# mtu = 14866
# uv = 14915
# Smoon = 8454
# 19 4 2035 2 : 35
# MTS = -81 adjust to 21519
# SMercury = 22779 adjust to 1179
# SVenus = -1624 adjust to 19976
# au_ = 2225
# mtu = 14866
# uv = 14916
# Smoon = 8455
# 19 4 2035 2 : 36
# MTS = -81 adjust to 21519
# SMercury = 22779 adjust to 1179
# SVenus = -1624 adjust to 19976
# au_ = 2225
# mtu = 14866
# uv = 14916
# Smoon = 8455
# 19 4 2035 2 : 37
# MTS = -81 adjust to 21519
# SMercury = 22779 adjust to 1179
# SVenus = -1624 adjust to 19976
# au_ = 2225
# mtu = 14866
# uv = 14917
# Smoon = 8456
# 19 4 2035 2 : 38
# MTS = -81 adjust to 21519
# SMercury = 22779 adjust to 1179
# SVenus = -1624 adjust to 19976
# au_ = 2225
# mtu = 14866
# uv = 14917
# Smoon = 8456
# 19 4 2035 2 : 39
# MTS = -81 adjust to 21519
# SMercury = 22779 adjust to 1179
# SVenus = -1624 adjust to 19976
# au_ = 2225
# mtu = 14866
# uv = 14918
# Smoon = 8457
# 19 4 2035 2 : 40
# MTS = -81 adjust to 21519
# SMercury = 22779 adjust to 1179
# SVenus = -1624 adjust to 19976
# au_ = 2225
# mtu = 14866
# uv = 14918
# Smoon = 8457
# 19 4 2035 2 : 41
# MTS = -81 adjust to 21519
# SMercury = 22779 adjust to 1179
# SVenus = -1624 adjust to 19976
# au_ = 2225
# mtu = 14866
# uv = 14920
# Smoon = 8459
# 19 4 2035 2 : 42
# MTS = -81 adjust to 21519
# SMercury = 22779 adjust to 1179
# SVenus = -1624 adjust to 19976
# au_ = 2225
# mtu = 14866
# uv = 14920
# Smoon = 8459
# 19 4 2035 2 : 43
# MTS = -81 adjust to 21519
# SMercury = 22779 adjust to 1179
# SVenus = -1624 adjust to 19976
# au_ = 2225
# mtu = 14866
# uv = 14921
# Smoon = 8460
# 19 4 2035 2 : 44
# MTS = -81 adjust to 21519
# SMercury = 22779 adjust to 1179
# SVenus = -1624 adjust to 19976
# au_ = 2225
# mtu = 14866
# uv = 14921
# Smoon = 8460
# 19 4 2035 2 : 45
# MTS = -81 adjust to 21519
# SMercury = 22779 adjust to 1179
# SVenus = -1624 adjust to 19976
# au_ = 2225
# mtu = 14866
# uv = 14922
# Smoon = 8461
# 19 4 2035 2 : 46
# MTS = -81 adjust to 21519
# SMercury = 22779 adjust to 1179
# SVenus = -1624 adjust to 19976
# au_ = 2225
# mtu = 14866
# uv = 14922
# Smoon = 8461
# 19 4 2035 2 : 47
# MTS = -81 adjust to 21519
# SMercury = 22779 adjust to 1179
# SVenus = -1624 adjust to 19976
# au_ = 2225
# mtu = 14866
# uv = 14923
# Smoon = 8462
# 19 4 2035 2 : 48
# MTS = -81 adjust to 21519
# SMercury = 22779 adjust to 1179
# SVenus = -1624 adjust to 19976
# au_ = 2225
# mtu = 14866
# uv = 14923
# Smoon = 8462
# 19 4 2035 2 : 49
# MTS = -81 adjust to 21519
# SMercury = 22779 adjust to 1179
# SVenus = -1624 adjust to 19976
# au_ = 2225
# mtu = 14866
# uv = 14924
# Smoon = 8463
# 19 4 2035 2 : 50
# MTS = -81 adjust to 21519
# SMercury = 22779 adjust to 1179
# SVenus = -1624 adjust to 19976
# au_ = 2225
# mtu = 14866
# uv = 14924
# Smoon = 8463
# 19 4 2035 2 : 51
# MTS = -81 adjust to 21519
# SMercury = 22779 adjust to 1179
# SVenus = -1624 adjust to 19976
# au_ = 2225
# mtu = 14866
# uv = 14925
# Smoon = 8464
# 19 4 2035 2 : 52
# MTS = -80 adjust to 21520
# SMercury = 22781 adjust to 1181
# SVenus = -1623 adjust to 19977
# au_ = 2225
# mtu = 14866
# uv = 14926
# Smoon = 8465
# 19 4 2035 2 : 53
# MTS = -80 adjust to 21520
# SMercury = 22781 adjust to 1181
# SVenus = -1623 adjust to 19977
# au_ = 2225
# mtu = 14866
# uv = 14927
# Smoon = 8466
# 19 4 2035 2 : 54
# MTS = -80 adjust to 21520
# SMercury = 22781 adjust to 1181
# SVenus = -1623 adjust to 19977
# au_ = 2225
# mtu = 14866
# uv = 14927
# Smoon = 8466
# 19 4 2035 2 : 55
# MTS = -80 adjust to 21520
# SMercury = 22781 adjust to 1181
# SVenus = -1623 adjust to 19977
# au_ = 2225
# mtu = 14866
# uv = 14928
# Smoon = 8467
# 19 4 2035 2 : 56
# MTS = -80 adjust to 21520
# SMercury = 22781 adjust to 1181
# SVenus = -1623 adjust to 19977
# au_ = 2225
# mtu = 14866
# uv = 14928
# Smoon = 8467
# 19 4 2035 2 : 57
# MTS = -80 adjust to 21520
# SMercury = 22781 adjust to 1181
# SVenus = -1623 adjust to 19977
# au_ = 2225
# mtu = 14866
# uv = 14929
# Smoon = 8468
# 19 4 2035 2 : 58
# MTS = -80 adjust to 21520
# SMercury = 22781 adjust to 1181
# SVenus = -1623 adjust to 19977
# au_ = 2225
# mtu = 14866
# uv = 14929
# Smoon = 8468
# 19 4 2035 2 : 59
# MTS = -80 adjust to 21520
# SMercury = 22781 adjust to 1181
# SVenus = -1623 adjust to 19977
# au_ = 2225
# mtu = 14866
# uv = 14930
# Smoon = 8469
# 19 4 2035 3 : 0
# MTS = -80 adjust to 21520
# SMercury = 22781 adjust to 1181
# SVenus = -1623 adjust to 19977
# au_ = 2225
# mtu = 14866
# uv = 14930
# Smoon = 8469
# 19 4 2035 3 : 1
# MTS = -80 adjust to 21520
# SMercury = 22781 adjust to 1181
# SVenus = -1623 adjust to 19977
# au_ = 2225
# mtu = 14866
# uv = 14931
# Smoon = 8470
# 19 4 2035 3 : 2
# MTS = -80 adjust to 21520
# SMercury = 22781 adjust to 1181
# SVenus = -1623 adjust to 19977
# au_ = 2225
# mtu = 14866
# uv = 14931
# Smoon = 8470
# 19 4 2035 3 : 3
# MTS = -80 adjust to 21520
# SMercury = 22781 adjust to 1181
# SVenus = -1623 adjust to 19977
# au_ = 2225
# mtu = 14866
# uv = 14932
# Smoon = 8471
# 19 4 2035 3 : 4
# MTS = -80 adjust to 21520
# SMercury = 22781 adjust to 1181
# SVenus = -1623 adjust to 19977
# au_ = 2225
# mtu = 14866
# uv = 14932
# Smoon = 8471
# 19 4 2035 3 : 5
# MTS = -80 adjust to 21520
# SMercury = 22781 adjust to 1181
# SVenus = -1623 adjust to 19977
# au_ = 2225
# mtu = 14866
# uv = 14933
# Smoon = 8472
# 19 4 2035 3 : 6
# MTS = -80 adjust to 21520
# SMercury = 22781 adjust to 1181
# SVenus = -1623 adjust to 19977
# au_ = 2225
# mtu = 14866
# uv = 14933
# Smoon = 8472
# 19 4 2035 3 : 7
# MTS = -80 adjust to 21520
# SMercury = 22781 adjust to 1181
# SVenus = -1623 adjust to 19977
# au_ = 2225
# mtu = 14866
# uv = 14933
# Smoon = 8472
# 19 4 2035 3 : 8
# MTS = -80 adjust to 21520
# SMercury = 22781 adjust to 1181
# SVenus = -1623 adjust to 19977
# au_ = 2225
# mtu = 14866
# uv = 14934
# Smoon = 8473
# 19 4 2035 3 : 9
# MTS = -80 adjust to 21520
# SMercury = 22781 adjust to 1181
# SVenus = -1623 adjust to 19977
# au_ = 2225
# mtu = 14866
# uv = 14934
# Smoon = 8473
# 19 4 2035 3 : 10
# MTS = -80 adjust to 21520
# SMercury = 22781 adjust to 1181
# SVenus = -1623 adjust to 19977
# au_ = 2225
# mtu = 14866
# uv = 14935
# Smoon = 8474
# 19 4 2035 3 : 11
# MTS = -80 adjust to 21520
# SMercury = 22781 adjust to 1181
# SVenus = -1623 adjust to 19977
# au_ = 2225
# mtu = 14866
# uv = 14935
# Smoon = 8474
# 19 4 2035 3 : 12
# MTS = -80 adjust to 21520
# SMercury = 22781 adjust to 1181
# SVenus = -1623 adjust to 19977
# au_ = 2225
# mtu = 14866
# uv = 14936
# Smoon = 8475
# 19 4 2035 3 : 13
# MTS = -80 adjust to 21520
# SMercury = 22781 adjust to 1181
# SVenus = -1623 adjust to 19977
# au_ = 2225
# mtu = 14866
# uv = 14936
# Smoon = 8475
# 19 4 2035 3 : 14
# MTS = -80 adjust to 21520
# SMercury = 22781 adjust to 1181
# SVenus = -1623 adjust to 19977
# au_ = 2225
# mtu = 14866
# uv = 14937
# Smoon = 8476
# 19 4 2035 3 : 15
# MTS = -80 adjust to 21520
# SMercury = 22781 adjust to 1181
# SVenus = -1623 adjust to 19977
# au_ = 2225
# mtu = 14866
# uv = 14937
# Smoon = 8476
# 19 4 2035 3 : 16
# MTS = -80 adjust to 21520
# SMercury = 22781 adjust to 1181
# SVenus = -1623 adjust to 19977
# au_ = 2225
# mtu = 14866
# uv = 14938
# Smoon = 8477
# 19 4 2035 3 : 17
# MTS = -79 adjust to 21521
# SMercury = 22781 adjust to 1181
# SVenus = -1622 adjust to 19978
# au_ = 2225
# mtu = 14866
# uv = 14939
# Smoon = 8478
# 19 4 2035 3 : 18
# MTS = -79 adjust to 21521
# SMercury = 22781 adjust to 1181
# SVenus = -1622 adjust to 19978
# au_ = 2225
# mtu = 14866
# uv = 14940
# Smoon = 8480
# 19 4 2035 3 : 19
# MTS = -79 adjust to 21521
# SMercury = 22781 adjust to 1181
# SVenus = -1622 adjust to 19978
# au_ = 2225
# mtu = 14866
# uv = 14940
# Smoon = 8480
# 19 4 2035 3 : 20
# MTS = -79 adjust to 21521
# SMercury = 22781 adjust to 1181
# SVenus = -1622 adjust to 19978
# au_ = 2225
# mtu = 14866
# uv = 14941
# Smoon = 8481
# 19 4 2035 3 : 21
# MTS = -79 adjust to 21521
# SMercury = 22781 adjust to 1181
# SVenus = -1622 adjust to 19978
# au_ = 2225
# mtu = 14866
# uv = 14941
# Smoon = 8481
# 19 4 2035 3 : 22
# MTS = -79 adjust to 21521
# SMercury = 22781 adjust to 1181
# SVenus = -1622 adjust to 19978
# au_ = 2225
# mtu = 14866
# uv = 14942
# Smoon = 8482
# 19 4 2035 3 : 23
# MTS = -79 adjust to 21521
# SMercury = 22781 adjust to 1181
# SVenus = -1622 adjust to 19978
# au_ = 2225
# mtu = 14866
# uv = 14942
# Smoon = 8482
# 19 4 2035 3 : 24
# MTS = -79 adjust to 21521
# SMercury = 22781 adjust to 1181
# SVenus = -1622 adjust to 19978
# au_ = 2225
# mtu = 14866
# uv = 14943
# Smoon = 8483
# 19 4 2035 3 : 25
# MTS = -79 adjust to 21521
# SMercury = 22781 adjust to 1181
# SVenus = -1622 adjust to 19978
# au_ = 2225
# mtu = 14866
# uv = 14943
# Smoon = 8483
# 19 4 2035 3 : 26
# MTS = -79 adjust to 21521
# SMercury = 22781 adjust to 1181
# SVenus = -1622 adjust to 19978
# au_ = 2225
# mtu = 14866
# uv = 14944
# Smoon = 8484
# 19 4 2035 3 : 27
# MTS = -79 adjust to 21521
# SMercury = 22781 adjust to 1181
# SVenus = -1622 adjust to 19978
# au_ = 2225
# mtu = 14866
# uv = 14944
# Smoon = 8484
# 19 4 2035 3 : 28
# MTS = -79 adjust to 21521
# SMercury = 22781 adjust to 1181
# SVenus = -1622 adjust to 19978
# au_ = 2225
# mtu = 14866
# uv = 14945
# Smoon = 8485
# 19 4 2035 3 : 29
# MTS = -79 adjust to 21521
# SMercury = 22781 adjust to 1181
# SVenus = -1622 adjust to 19978
# au_ = 2225
# mtu = 14866
# uv = 14945
# Smoon = 8485
# 19 4 2035 3 : 30
# MTS = -79 adjust to 21521
# SMercury = 22781 adjust to 1181
# SVenus = -1622 adjust to 19978
# au_ = 2225
# mtu = 14866
# uv = 14946
# Smoon = 8486
# 19 4 2035 3 : 31
# MTS = -79 adjust to 21521
# SMercury = 22781 adjust to 1181
# SVenus = -1622 adjust to 19978
# au_ = 2225
# mtu = 14866
# uv = 14946
# Smoon = 8486
# 19 4 2035 3 : 32
# MTS = -79 adjust to 21521
# SMercury = 22781 adjust to 1181
# SVenus = -1622 adjust to 19978
# au_ = 2225
# mtu = 14866
# uv = 14948
# Smoon = 8488
# 19 4 2035 3 : 33
# MTS = -79 adjust to 21521
# SMercury = 22781 adjust to 1181
# SVenus = -1622 adjust to 19978
# au_ = 2225
# mtu = 14866
# uv = 14948
# Smoon = 8488
# 19 4 2035 3 : 34
# MTS = -79 adjust to 21521
# SMercury = 22781 adjust to 1181
# SVenus = -1622 adjust to 19978
# au_ = 2225
# mtu = 14866
# uv = 14949
# Smoon = 8489
# 19 4 2035 3 : 35
# MTS = -79 adjust to 21521
# SMercury = 22781 adjust to 1181
# SVenus = -1622 adjust to 19978
# au_ = 2225
# mtu = 14866
# uv = 14949
# Smoon = 8489
# 19 4 2035 3 : 36
# MTS = -79 adjust to 21521
# SMercury = 22781 adjust to 1181
# SVenus = -1622 adjust to 19978
# au_ = 2225
# mtu = 14866
# uv = 14950
# Smoon = 8490
# 19 4 2035 3 : 37
# MTS = -79 adjust to 21521
# SMercury = 22781 adjust to 1181
# SVenus = -1622 adjust to 19978
# au_ = 2225
# mtu = 14866
# uv = 14950
# Smoon = 8490
# 19 4 2035 3 : 38
# MTS = -79 adjust to 21521
# SMercury = 22781 adjust to 1181
# SVenus = -1622 adjust to 19978
# au_ = 2225
# mtu = 14866
# uv = 14951
# Smoon = 8491
# 19 4 2035 3 : 39
# MTS = -79 adjust to 21521
# SMercury = 22781 adjust to 1181
# SVenus = -1622 adjust to 19978
# au_ = 2225
# mtu = 14866
# uv = 14951
# Smoon = 8491
# 19 4 2035 3 : 40
# MTS = -79 adjust to 21521
# SMercury = 22781 adjust to 1181
# SVenus = -1622 adjust to 19978
# au_ = 2225
# mtu = 14866
# uv = 14952
# Smoon = 8492
# 19 4 2035 3 : 41
# MTS = -79 adjust to 21521
# SMercury = 22781 adjust to 1181
# SVenus = -1622 adjust to 19978
# au_ = 2225
# mtu = 14866
# uv = 14952
# Smoon = 8492
# 19 4 2035 3 : 42
# MTS = -79 adjust to 21521
# SMercury = 22781 adjust to 1181
# SVenus = -1622 adjust to 19978
# au_ = 2225
# mtu = 14866
# uv = 14953
# Smoon = 8493
# 19 4 2035 3 : 43
# MTS = -78 adjust to 21522
# SMercury = 22782 adjust to 1182
# SVenus = -1621 adjust to 19979
# au_ = 2225
# mtu = 14866
# uv = 14954
# Smoon = 8494
# 19 4 2035 3 : 44
# MTS = -78 adjust to 21522
# SMercury = 22782 adjust to 1182
# SVenus = -1621 adjust to 19979
# au_ = 2225
# mtu = 14866
# uv = 14955
# Smoon = 8495
# 19 4 2035 3 : 45
# MTS = -78 adjust to 21522
# SMercury = 22782 adjust to 1182
# SVenus = -1621 adjust to 19979
# au_ = 2225
# mtu = 14866
# uv = 14955
# Smoon = 8495
# 19 4 2035 3 : 46
# MTS = -78 adjust to 21522
# SMercury = 22782 adjust to 1182
# SVenus = -1621 adjust to 19979
# au_ = 2225
# mtu = 14866
# uv = 14956
# Smoon = 8496
# 19 4 2035 3 : 47
# MTS = -78 adjust to 21522
# SMercury = 22782 adjust to 1182
# SVenus = -1621 adjust to 19979
# au_ = 2225
# mtu = 14866
# uv = 14956
# Smoon = 8496
# 19 4 2035 3 : 48
# MTS = -78 adjust to 21522
# SMercury = 22782 adjust to 1182
# SVenus = -1621 adjust to 19979
# au_ = 2225
# mtu = 14866
# uv = 14957
# Smoon = 8497
# 19 4 2035 3 : 49
# MTS = -78 adjust to 21522
# SMercury = 22782 adjust to 1182
# SVenus = -1621 adjust to 19979
# au_ = 2225
# mtu = 14866
# uv = 14957
# Smoon = 8497
# 19 4 2035 3 : 50
# MTS = -78 adjust to 21522
# SMercury = 22782 adjust to 1182
# SVenus = -1621 adjust to 19979
# au_ = 2225
# mtu = 14866
# uv = 14957
# Smoon = 8497
# 19 4 2035 3 : 51
# MTS = -78 adjust to 21522
# SMercury = 22782 adjust to 1182
# SVenus = -1621 adjust to 19979
# au_ = 2225
# mtu = 14866
# uv = 14958
# Smoon = 8498
# 19 4 2035 3 : 52
# MTS = -78 adjust to 21522
# SMercury = 22782 adjust to 1182
# SVenus = -1621 adjust to 19979
# au_ = 2225
# mtu = 14866
# uv = 14958
# Smoon = 8498
# 19 4 2035 3 : 53
# MTS = -78 adjust to 21522
# SMercury = 22782 adjust to 1182
# SVenus = -1621 adjust to 19979
# au_ = 2225
# mtu = 14866
# uv = 14959
# Smoon = 8499
# 19 4 2035 3 : 54
# MTS = -78 adjust to 21522
# SMercury = 22782 adjust to 1182
# SVenus = -1621 adjust to 19979
# au_ = 2225
# mtu = 14866
# uv = 14959
# Smoon = 8499
# 19 4 2035 3 : 55
# MTS = -78 adjust to 21522
# SMercury = 22782 adjust to 1182
# SVenus = -1621 adjust to 19979
# au_ = 2225
# mtu = 14866
# uv = 14960
# Smoon = 8500
# 19 4 2035 3 : 56
# MTS = -78 adjust to 21522
# SMercury = 22782 adjust to 1182
# SVenus = -1621 adjust to 19979
# au_ = 2225
# mtu = 14866
# uv = 14960
# Smoon = 8500
# 19 4 2035 3 : 57
# MTS = -78 adjust to 21522
# SMercury = 22782 adjust to 1182
# SVenus = -1621 adjust to 19979
# au_ = 2225
# mtu = 14866
# uv = 14961
# Smoon = 8501
# 19 4 2035 3 : 58
# MTS = -78 adjust to 21522
# SMercury = 22782 adjust to 1182
# SVenus = -1621 adjust to 19979
# au_ = 2225
# mtu = 14866
# uv = 14961
# Smoon = 8501
# 19 4 2035 3 : 59
# MTS = -78 adjust to 21522
# SMercury = 22782 adjust to 1182
# SVenus = -1621 adjust to 19979
# au_ = 2225
# mtu = 14866
# uv = 14962
# Smoon = 8502
# 19 4 2035 4 : 0
# MTS = -78 adjust to 21522
# SMercury = 22782 adjust to 1182
# SVenus = -1621 adjust to 19979
# au_ = 2225
# mtu = 14866
# uv = 14962
# Smoon = 8502
# 19 4 2035 4 : 1
# MTS = -78 adjust to 21522
# SMercury = 22782 adjust to 1182
# SVenus = -1621 adjust to 19979
# au_ = 2225
# mtu = 14866
# uv = 14963
# Smoon = 8503
# 19 4 2035 4 : 2
# MTS = -78 adjust to 21522
# SMercury = 22782 adjust to 1182
# SVenus = -1621 adjust to 19979
# au_ = 2225
# mtu = 14866
# uv = 14963
# Smoon = 8503
# 19 4 2035 4 : 3
# MTS = -78 adjust to 21522
# SMercury = 22782 adjust to 1182
# SVenus = -1621 adjust to 19979
# au_ = 2225
# mtu = 14866
# uv = 14964
# Smoon = 8504
# 19 4 2035 4 : 4
# MTS = -78 adjust to 21522
# SMercury = 22782 adjust to 1182
# SVenus = -1621 adjust to 19979
# au_ = 2225
# mtu = 14866
# uv = 14964
# Smoon = 8504
# 19 4 2035 4 : 5
# MTS = -78 adjust to 21522
# SMercury = 22782 adjust to 1182
# SVenus = -1621 adjust to 19979
# au_ = 2225
# mtu = 14866
# uv = 14965
# Smoon = 8505
# 19 4 2035 4 : 6
# MTS = -78 adjust to 21522
# SMercury = 22782 adjust to 1182
# SVenus = -1621 adjust to 19979
# au_ = 2225
# mtu = 14866
# uv = 14965
# Smoon = 8505
# 19 4 2035 4 : 7
# MTS = -78 adjust to 21522
# SMercury = 22782 adjust to 1182
# SVenus = -1621 adjust to 19979
# au_ = 2225
# mtu = 14866
# uv = 14966
# Smoon = 8506
# 19 4 2035 4 : 8
# MTS = -77 adjust to 21523
# SMercury = 22784 adjust to 1184
# SVenus = -1620 adjust to 19980
# au_ = 2225
# mtu = 14866
# uv = 14967
# Smoon = 8507
# 19 4 2035 4 : 9
# MTS = -77 adjust to 21523
# SMercury = 22784 adjust to 1184
# SVenus = -1620 adjust to 19980
# au_ = 2225
# mtu = 14866
# uv = 14968
# Smoon = 8508
# 19 4 2035 4 : 10
# MTS = -77 adjust to 21523
# SMercury = 22784 adjust to 1184
# SVenus = -1620 adjust to 19980
# au_ = 2225
# mtu = 14866
# uv = 14968
# Smoon = 8508
# 19 4 2035 4 : 11
# MTS = -77 adjust to 21523
# SMercury = 22784 adjust to 1184
# SVenus = -1620 adjust to 19980
# au_ = 2225
# mtu = 14866
# uv = 14969
# Smoon = 8509
# 19 4 2035 4 : 12
# MTS = -77 adjust to 21523
# SMercury = 22784 adjust to 1184
# SVenus = -1620 adjust to 19980
# au_ = 2225
# mtu = 14866
# uv = 14969
# Smoon = 8509
# 19 4 2035 4 : 13
# MTS = -77 adjust to 21523
# SMercury = 22784 adjust to 1184
# SVenus = -1620 adjust to 19980
# au_ = 2225
# mtu = 14866
# uv = 14970
# Smoon = 8511
# 19 4 2035 4 : 14
# MTS = -77 adjust to 21523
# SMercury = 22784 adjust to 1184
# SVenus = -1620 adjust to 19980
# au_ = 2225
# mtu = 14866
# uv = 14970
# Smoon = 8511
# 19 4 2035 4 : 15
# MTS = -77 adjust to 21523
# SMercury = 22784 adjust to 1184
# SVenus = -1620 adjust to 19980
# au_ = 2225
# mtu = 14866
# uv = 14971
# Smoon = 8512
# 19 4 2035 4 : 16
# MTS = -77 adjust to 21523
# SMercury = 22784 adjust to 1184
# SVenus = -1620 adjust to 19980
# au_ = 2225
# mtu = 14866
# uv = 14971
# Smoon = 8512
# 19 4 2035 4 : 17
# MTS = -77 adjust to 21523
# SMercury = 22784 adjust to 1184
# SVenus = -1620 adjust to 19980
# au_ = 2225
# mtu = 14866
# uv = 14972
# Smoon = 8513
# 19 4 2035 4 : 18
# MTS = -77 adjust to 21523
# SMercury = 22784 adjust to 1184
# SVenus = -1620 adjust to 19980
# au_ = 2225
# mtu = 14866
# uv = 14972
# Smoon = 8513
# 19 4 2035 4 : 19
# MTS = -77 adjust to 21523
# SMercury = 22784 adjust to 1184
# SVenus = -1620 adjust to 19980
# au_ = 2225
# mtu = 14866
# uv = 14973
# Smoon = 8514
# 19 4 2035 4 : 20
# MTS = -77 adjust to 21523
# SMercury = 22784 adjust to 1184
# SVenus = -1620 adjust to 19980
# au_ = 2225
# mtu = 14866
# uv = 14973
# Smoon = 8514
# 19 4 2035 4 : 21
# MTS = -77 adjust to 21523
# SMercury = 22784 adjust to 1184
# SVenus = -1620 adjust to 19980
# au_ = 2225
# mtu = 14866
# uv = 14974
# Smoon = 8515
# 19 4 2035 4 : 22
# MTS = -77 adjust to 21523
# SMercury = 22784 adjust to 1184
# SVenus = -1620 adjust to 19980
# au_ = 2225
# mtu = 14866
# uv = 14974
# Smoon = 8515
# 19 4 2035 4 : 23
# MTS = -77 adjust to 21523
# SMercury = 22784 adjust to 1184
# SVenus = -1620 adjust to 19980
# au_ = 2225
# mtu = 14866
# uv = 14976
# Smoon = 8517
# 19 4 2035 4 : 24
# MTS = -77 adjust to 21523
# SMercury = 22784 adjust to 1184
# SVenus = -1620 adjust to 19980
# au_ = 2225
# mtu = 14866
# uv = 14976
# Smoon = 8517
# 19 4 2035 4 : 25
# MTS = -77 adjust to 21523
# SMercury = 22784 adjust to 1184
# SVenus = -1620 adjust to 19980
# au_ = 2225
# mtu = 14866
# uv = 14977
# Smoon = 8518
# 19 4 2035 4 : 26
# MTS = -77 adjust to 21523
# SMercury = 22784 adjust to 1184
# SVenus = -1620 adjust to 19980
# au_ = 2225
# mtu = 14866
# uv = 14977
# Smoon = 8518
# 19 4 2035 4 : 27
# MTS = -77 adjust to 21523
# SMercury = 22784 adjust to 1184
# SVenus = -1620 adjust to 19980
# au_ = 2225
# mtu = 14866
# uv = 14978
# Smoon = 8519
# 19 4 2035 4 : 28
# MTS = -77 adjust to 21523
# SMercury = 22784 adjust to 1184
# SVenus = -1620 adjust to 19980
# au_ = 2225
# mtu = 14866
# uv = 14978
# Smoon = 8519
# 19 4 2035 4 : 29
# MTS = -77 adjust to 21523
# SMercury = 22784 adjust to 1184
# SVenus = -1620 adjust to 19980
# au_ = 2225
# mtu = 14866
# uv = 14979
# Smoon = 8520
# 19 4 2035 4 : 30
# MTS = -77 adjust to 21523
# SMercury = 22784 adjust to 1184
# SVenus = -1620 adjust to 19980
# au_ = 2225
# mtu = 14866
# uv = 14979
# Smoon = 8520
# 19 4 2035 4 : 31
# MTS = -77 adjust to 21523
# SMercury = 22784 adjust to 1184
# SVenus = -1620 adjust to 19980
# au_ = 2225
# mtu = 14866
# uv = 14980
# Smoon = 8521
# 19 4 2035 4 : 32
# MTS = -77 adjust to 21523
# SMercury = 22784 adjust to 1184
# SVenus = -1620 adjust to 19980
# au_ = 2225
# mtu = 14866
# uv = 14980
# Smoon = 8521
# 19 4 2035 4 : 33
# MTS = -76 adjust to 21524
# SMercury = 22784 adjust to 1184
# SVenus = -1619 adjust to 19981
# au_ = 2225
# mtu = 14866
# uv = 14981
# Smoon = 8522
# 19 4 2035 4 : 34
# MTS = -76 adjust to 21524
# SMercury = 22784 adjust to 1184
# SVenus = -1619 adjust to 19981
# au_ = 2225
# mtu = 14866
# uv = 14982
# Smoon = 8523
# 19 4 2035 4 : 35
# MTS = -76 adjust to 21524
# SMercury = 22784 adjust to 1184
# SVenus = -1619 adjust to 19981
# au_ = 2225
# mtu = 14866
# uv = 14982
# Smoon = 8523
# 19 4 2035 4 : 36
# MTS = -76 adjust to 21524
# SMercury = 22784 adjust to 1184
# SVenus = -1619 adjust to 19981
# au_ = 2225
# mtu = 14866
# uv = 14983
# Smoon = 8524
# 19 4 2035 4 : 37
# MTS = -76 adjust to 21524
# SMercury = 22784 adjust to 1184
# SVenus = -1619 adjust to 19981
# au_ = 2225
# mtu = 14866
# uv = 14983
# Smoon = 8524
# 19 4 2035 4 : 38
# MTS = -76 adjust to 21524
# SMercury = 22784 adjust to 1184
# SVenus = -1619 adjust to 19981
# au_ = 2225
# mtu = 14866
# uv = 14984
# Smoon = 8525
# 19 4 2035 4 : 39
# MTS = -76 adjust to 21524
# SMercury = 22784 adjust to 1184
# SVenus = -1619 adjust to 19981
# au_ = 2225
# mtu = 14866
# uv = 14984
# Smoon = 8525
# 19 4 2035 4 : 40
# MTS = -76 adjust to 21524
# SMercury = 22784 adjust to 1184
# SVenus = -1619 adjust to 19981
# au_ = 2225
# mtu = 14866
# uv = 14985
# Smoon = 8526
# 19 4 2035 4 : 41
# MTS = -76 adjust to 21524
# SMercury = 22784 adjust to 1184
# SVenus = -1619 adjust to 19981
# au_ = 2225
# mtu = 14866
# uv = 14985
# Smoon = 8526
# 19 4 2035 4 : 42
# MTS = -76 adjust to 21524
# SMercury = 22784 adjust to 1184
# SVenus = -1619 adjust to 19981
# au_ = 2225
# mtu = 14866
# uv = 14986
# Smoon = 8527
# 19 4 2035 4 : 43
# MTS = -76 adjust to 21524
# SMercury = 22784 adjust to 1184
# SVenus = -1619 adjust to 19981
# au_ = 2225
# mtu = 14866
# uv = 14986
# Smoon = 8527
# 19 4 2035 4 : 44
# MTS = -76 adjust to 21524
# SMercury = 22784 adjust to 1184
# SVenus = -1619 adjust to 19981
# au_ = 2225
# mtu = 14866
# uv = 14987
# Smoon = 8528
# 19 4 2035 4 : 45
# MTS = -76 adjust to 21524
# SMercury = 22784 adjust to 1184
# SVenus = -1619 adjust to 19981
# au_ = 2225
# mtu = 14866
# uv = 14987
# Smoon = 8528
# 19 4 2035 4 : 46
# MTS = -76 adjust to 21524
# SMercury = 22784 adjust to 1184
# SVenus = -1619 adjust to 19981
# au_ = 2225
# mtu = 14866
# uv = 14988
# Smoon = 8529
# 19 4 2035 4 : 47
# MTS = -76 adjust to 21524
# SMercury = 22784 adjust to 1184
# SVenus = -1619 adjust to 19981
# au_ = 2225
# mtu = 14866
# uv = 14988
# Smoon = 8529
# 19 4 2035 4 : 48
# MTS = -76 adjust to 21524
# SMercury = 22784 adjust to 1184
# SVenus = -1619 adjust to 19981
# au_ = 2225
# mtu = 14866
# uv = 14989
# Smoon = 8530
# 19 4 2035 4 : 49
# MTS = -76 adjust to 21524
# SMercury = 22784 adjust to 1184
# SVenus = -1619 adjust to 19981
# au_ = 2225
# mtu = 14866
# uv = 14989
# Smoon = 8530
# 19 4 2035 4 : 50
# MTS = -76 adjust to 21524
# SMercury = 22784 adjust to 1184
# SVenus = -1619 adjust to 19981
# au_ = 2225
# mtu = 14866
# uv = 14990
# Smoon = 8531
# 19 4 2035 4 : 51
# MTS = -76 adjust to 21524
# SMercury = 22784 adjust to 1184
# SVenus = -1619 adjust to 19981
# au_ = 2225
# mtu = 14866
# uv = 14990
# Smoon = 8531
# 19 4 2035 4 : 52
# MTS = -76 adjust to 21524
# SMercury = 22784 adjust to 1184
# SVenus = -1619 adjust to 19981
# au_ = 2225
# mtu = 14866
# uv = 14991
# Smoon = 8532
# 19 4 2035 4 : 53
# MTS = -76 adjust to 21524
# SMercury = 22784 adjust to 1184
# SVenus = -1619 adjust to 19981
# au_ = 2225
# mtu = 14866
# uv = 14991
# Smoon = 8532
# 19 4 2035 4 : 54
# MTS = -76 adjust to 21524
# SMercury = 22784 adjust to 1184
# SVenus = -1619 adjust to 19981
# au_ = 2225
# mtu = 14866
# uv = 14992
# Smoon = 8533
# 19 4 2035 4 : 55
# MTS = -76 adjust to 21524
# SMercury = 22784 adjust to 1184
# SVenus = -1619 adjust to 19981
# au_ = 2225
# mtu = 14866
# uv = 14992
# Smoon = 8533
# 19 4 2035 4 : 56
# MTS = -76 adjust to 21524
# SMercury = 22784 adjust to 1184
# SVenus = -1619 adjust to 19981
# au_ = 2225
# mtu = 14866
# uv = 14993
# Smoon = 8534
# 19 4 2035 4 : 57
# MTS = -76 adjust to 21524
# SMercury = 22784 adjust to 1184
# SVenus = -1619 adjust to 19981
# au_ = 2225
# mtu = 14866
# uv = 14993
# Smoon = 8534
# 19 4 2035 4 : 58
# MTS = -75 adjust to 21525
# SMercury = 22786 adjust to 1186
# SVenus = -1618 adjust to 19982
# au_ = 2225
# mtu = 14866
# uv = 14995
# Smoon = 8536
# 19 4 2035 4 : 59
# MTS = -75 adjust to 21525
# SMercury = 22786 adjust to 1186
# SVenus = -1618 adjust to 19982
# au_ = 2225
# mtu = 14866
# uv = 14995
# Smoon = 8536
# 19 4 2035 5 : 0
# MTS = -75 adjust to 21525
# SMercury = 22786 adjust to 1186
# SVenus = -1618 adjust to 19982
# au_ = 2225
# mtu = 14866
# uv = 14996
# Smoon = 8537
# 19 4 2035 5 : 1
# MTS = -75 adjust to 21525
# SMercury = 22786 adjust to 1186
# SVenus = -1618 adjust to 19982
# au_ = 2225
# mtu = 14866
# uv = 14996
# Smoon = 8537
# 19 4 2035 5 : 2
# MTS = -75 adjust to 21525
# SMercury = 22786 adjust to 1186
# SVenus = -1618 adjust to 19982
# au_ = 2225
# mtu = 14866
# uv = 14997
# Smoon = 8538
# 19 4 2035 5 : 3
# MTS = -75 adjust to 21525
# SMercury = 22786 adjust to 1186
# SVenus = -1618 adjust to 19982
# au_ = 2225
# mtu = 14866
# uv = 14997
# Smoon = 8538
# 19 4 2035 5 : 4
# MTS = -75 adjust to 21525
# SMercury = 22786 adjust to 1186
# SVenus = -1618 adjust to 19982
# au_ = 2225
# mtu = 14866
# uv = 14998
# Smoon = 8539
# 19 4 2035 5 : 5
# MTS = -75 adjust to 21525
# SMercury = 22786 adjust to 1186
# SVenus = -1618 adjust to 19982
# au_ = 2225
# mtu = 14866
# uv = 14998
# Smoon = 8539
# 19 4 2035 5 : 6
# MTS = -75 adjust to 21525
# SMercury = 22786 adjust to 1186
# SVenus = -1618 adjust to 19982
# au_ = 2225
# mtu = 14866
# uv = 14999
# Smoon = 8540
# 19 4 2035 5 : 7
# MTS = -75 adjust to 21525
# SMercury = 22786 adjust to 1186
# SVenus = -1618 adjust to 19982
# au_ = 2225
# mtu = 14866
# uv = 14999
# Smoon = 8540
# 19 4 2035 5 : 8
# MTS = -75 adjust to 21525
# SMercury = 22786 adjust to 1186
# SVenus = -1618 adjust to 19982
# au_ = 2225
# mtu = 14866
# uv = 15000
# Smoon = 8542
# 19 4 2035 5 : 9
# MTS = -75 adjust to 21525
# SMercury = 22786 adjust to 1186
# SVenus = -1618 adjust to 19982
# au_ = 2225
# mtu = 14866
# uv = 15000
# Smoon = 8542
# 19 4 2035 5 : 10
# MTS = -75 adjust to 21525
# SMercury = 22786 adjust to 1186
# SVenus = -1618 adjust to 19982
# au_ = 2225
# mtu = 14866
# uv = 15001
# Smoon = 8543
# 19 4 2035 5 : 11
# MTS = -75 adjust to 21525
# SMercury = 22786 adjust to 1186
# SVenus = -1618 adjust to 19982
# au_ = 2225
# mtu = 14866
# uv = 15001
# Smoon = 8543
# 19 4 2035 5 : 12
# MTS = -75 adjust to 21525
# SMercury = 22786 adjust to 1186
# SVenus = -1618 adjust to 19982
# au_ = 2225
# mtu = 14866
# uv = 15002
# Smoon = 8544
# 19 4 2035 5 : 13
# ...
# uv = 15211
# Smoon = 8762
# 19 4 2035 11 : 39
# MTS = -59 adjust to 21541
# SMercury = 22804 adjust to 1204
# SVenus = -1598 adjust to 20002
# au_ = 2225
# mtu = 14868
# uv = 15211
# Smoon = 8762
# 19 4 2035 11 : 40
# MTS = -59 adjust to 21541
# SMercury = 22804 adjust to 1204
# SVenus = -1598 adjust to 20002
# au_ = 2225
# mtu = 14868
# uv = 15212
# Smoon = 8763
# 19 4 2035 11 : 41
# MTS = -58 adjust to 21542
# SMercury = 22805 adjust to 1205
# SVenus = -1597 adjust to 20003
# au_ = 2225
# mtu = 14868
# uv = 15213
# Smoon = 8764
# 19 4 2035 11 : 42
# MTS = -58 adjust to 21542
# SMercury = 22805 adjust to 1205
# SVenus = -1597 adjust to 20003
# au_ = 2225
# mtu = 14868
# uv = 15214
# Smoon = 8765
# 19 4 2035 11 : 43
# MTS = -58 adjust to 21542
# SMercury = 22805 adjust to 1205
# SVenus = -1597 adjust to 20003
# au_ = 2225
# mtu = 14868
# uv = 15214
# Smoon = 8765
# 19 4 2035 11 : 44
# MTS = -58 adjust to 21542
# SMercury = 22805 adjust to 1205
# SVenus = -1597 adjust to 20003
# au_ = 2225
# mtu = 14868
# uv = 15215
# Smoon = 8766
# 19 4 2035 11 : 45
# MTS = -58 adjust to 21542
# SMercury = 22805 adjust to 1205
# SVenus = -1597 adjust to 20003
# au_ = 2225
# mtu = 14868
# uv = 15215
# Smoon = 8766
# 19 4 2035 11 : 46
# MTS = -58 adjust to 21542
# SMercury = 22805 adjust to 1205
# SVenus = -1597 adjust to 20003
# au_ = 2225
# mtu = 14868
# uv = 15216
# Smoon = 8767
# 19 4 2035 11 : 47
# MTS = -58 adjust to 21542
# SMercury = 22805 adjust to 1205
# SVenus = -1597 adjust to 20003
# au_ = 2225
# mtu = 14868
# uv = 15216
# Smoon = 8767
# 19 4 2035 11 : 48
# MTS = -58 adjust to 21542
# SMercury = 22805 adjust to 1205
# SVenus = -1597 adjust to 20003
# au_ = 2225
# mtu = 14868
# uv = 15217
# Smoon = 8768
# 19 4 2035 11 : 49
# MTS = -58 adjust to 21542
# SMercury = 22805 adjust to 1205
# SVenus = -1597 adjust to 20003
# au_ = 2225
# mtu = 14868
# uv = 15217
# Smoon = 8768
# 19 4 2035 11 : 50
# MTS = -58 adjust to 21542
# SMercury = 22805 adjust to 1205
# SVenus = -1597 adjust to 20003
# au_ = 2225
# mtu = 14868
# uv = 15218
# Smoon = 8769
# 19 4 2035 11 : 51
# MTS = -58 adjust to 21542
# SMercury = 22805 adjust to 1205
# SVenus = -1597 adjust to 20003
# au_ = 2225
# mtu = 14868
# uv = 15218
# Smoon = 8769
# 19 4 2035 11 : 52
# MTS = -58 adjust to 21542
# SMercury = 22805 adjust to 1205
# SVenus = -1597 adjust to 20003
# au_ = 2225
# mtu = 14868
# uv = 15219
# Smoon = 8770
# 19 4 2035 11 : 53
# MTS = -58 adjust to 21542
# SMercury = 22805 adjust to 1205
# SVenus = -1597 adjust to 20003
# au_ = 2225
# mtu = 14868
# uv = 15219
# Smoon = 8770
# 19 4 2035 11 : 54
# MTS = -58 adjust to 21542
# SMercury = 22805 adjust to 1205
# SVenus = -1597 adjust to 20003
# au_ = 2225
# mtu = 14868
# uv = 15220
# Smoon = 8771
# 19 4 2035 11 : 55
# MTS = -58 adjust to 21542
# SMercury = 22805 adjust to 1205
# SVenus = -1597 adjust to 20003
# au_ = 2225
# mtu = 14868
# uv = 15220
# Smoon = 8771
# 19 4 2035 11 : 56
# MTS = -58 adjust to 21542
# SMercury = 22805 adjust to 1205
# SVenus = -1597 adjust to 20003
# au_ = 2225
# mtu = 14868
# uv = 15221
# Smoon = 8772
# 19 4 2035 11 : 57
# MTS = -58 adjust to 21542
# SMercury = 22805 adjust to 1205
# SVenus = -1597 adjust to 20003
# au_ = 2225
# mtu = 14868
# uv = 15221
# Smoon = 8772
# 19 4 2035 11 : 58
# MTS = -58 adjust to 21542
# SMercury = 22805 adjust to 1205
# SVenus = -1597 adjust to 20003
# au_ = 2225
# mtu = 14868
# uv = 15222
# Smoon = 8773
# 19 4 2035 11 : 59
# MTS = -58 adjust to 21542
# SMercury = 22805 adjust to 1205
# SVenus = -1597 adjust to 20003
# au_ = 2225
# mtu = 14868
# uv = 15222
# Smoon = 8773
# 19 4 2035 12 : 0
# MTS = -58 adjust to 21542
# SMercury = 22805 adjust to 1205
# SVenus = -1597 adjust to 20003
# au_ = 2225
# mtu = 14868
# uv = 15223
# Smoon = 8774
# 19 4 2035 12 : 1
# MTS = -58 adjust to 21542
# SMercury = 22805 adjust to 1205
# SVenus = -1597 adjust to 20003
# au_ = 2225
# mtu = 14868
# uv = 15223
# Smoon = 8774
# 19 4 2035 12 : 2
# MTS = -58 adjust to 21542
# SMercury = 22805 adjust to 1205
# SVenus = -1597 adjust to 20003
# au_ = 2225
# mtu = 14868
# uv = 15224
# Smoon = 8775
# 19 4 2035 12 : 3
# MTS = -58 adjust to 21542
# SMercury = 22805 adjust to 1205
# SVenus = -1597 adjust to 20003
# au_ = 2225
# mtu = 14868
# uv = 15224
# Smoon = 8775
# 19 4 2035 12 : 4
# MTS = -58 adjust to 21542
# SMercury = 22805 adjust to 1205
# SVenus = -1597 adjust to 20003
# au_ = 2225
# mtu = 14868
# uv = 15226
# Smoon = 8777
# 19 4 2035 12 : 5
# MTS = -58 adjust to 21542
# SMercury = 22805 adjust to 1205
# SVenus = -1597 adjust to 20003
# au_ = 2225
# mtu = 14868
# uv = 15226
# Smoon = 8777
# 19 4 2035 12 : 6
# MTS = -58 adjust to 21542
# SMercury = 22805 adjust to 1205
# SVenus = -1597 adjust to 20003
# au_ = 2225
# mtu = 14868
# uv = 15227
# Smoon = 8778
# 19 4 2035 12 : 7
# MTS = -57 adjust to 21543
# SMercury = 22807 adjust to 1207
# SVenus = -1596 adjust to 20004
# au_ = 2225
# mtu = 14868
# uv = 15228
# Smoon = 8779
# 19 4 2035 12 : 8
# MTS = -57 adjust to 21543
# SMercury = 22807 adjust to 1207
# SVenus = -1596 adjust to 20004
# au_ = 2225
# mtu = 14868
# uv = 15229
# Smoon = 8780
# 19 4 2035 12 : 9
# MTS = -57 adjust to 21543
# SMercury = 22807 adjust to 1207
# SVenus = -1596 adjust to 20004
# au_ = 2225
# mtu = 14868
# uv = 15229
# Smoon = 8780
# 19 4 2035 12 : 10
# MTS = -57 adjust to 21543
# SMercury = 22807 adjust to 1207
# SVenus = -1596 adjust to 20004
# au_ = 2225
# mtu = 14868
# uv = 15230
# Smoon = 8781
# 19 4 2035 12 : 11
# MTS = -57 adjust to 21543
# SMercury = 22807 adjust to 1207
# SVenus = -1596 adjust to 20004
# au_ = 2225
# mtu = 14868
# uv = 15230
# Smoon = 8781
# 19 4 2035 12 : 12
# MTS = -57 adjust to 21543
# SMercury = 22807 adjust to 1207
# SVenus = -1596 adjust to 20004
# au_ = 2225
# mtu = 14868
# uv = 15231
# Smoon = 8782
# 19 4 2035 12 : 13
# MTS = -57 adjust to 21543
# SMercury = 22807 adjust to 1207
# SVenus = -1596 adjust to 20004
# au_ = 2225
# mtu = 14868
# uv = 15231
# Smoon = 8782
# 19 4 2035 12 : 14
# MTS = -57 adjust to 21543
# SMercury = 22807 adjust to 1207
# SVenus = -1596 adjust to 20004
# au_ = 2225
# mtu = 14868
# uv = 15232
# Smoon = 8783
# 19 4 2035 12 : 15
# MTS = -57 adjust to 21543
# SMercury = 22807 adjust to 1207
# SVenus = -1596 adjust to 20004
# au_ = 2225
# mtu = 14868
# uv = 15232
# Smoon = 8783
# 19 4 2035 12 : 16
# MTS = -57 adjust to 21543
# SMercury = 22807 adjust to 1207
# SVenus = -1596 adjust to 20004
# au_ = 2225
# mtu = 14868
# uv = 15233
# Smoon = 8784
# 19 4 2035 12 : 17
# MTS = -57 adjust to 21543
# SMercury = 22807 adjust to 1207
# SVenus = -1596 adjust to 20004
# au_ = 2225
# mtu = 14868
# uv = 15233
# Smoon = 8784
# 19 4 2035 12 : 18
# MTS = -57 adjust to 21543
# SMercury = 22807 adjust to 1207
# SVenus = -1596 adjust to 20004
# au_ = 2225
# mtu = 14868
# uv = 15233
# Smoon = 8784
# 19 4 2035 12 : 19
# MTS = -57 adjust to 21543
# SMercury = 22807 adjust to 1207
# SVenus = -1596 adjust to 20004
# au_ = 2225
# mtu = 14868
# uv = 15234
# Smoon = 8785
# 19 4 2035 12 : 20
# MTS = -57 adjust to 21543
# SMercury = 22807 adjust to 1207
# SVenus = -1596 adjust to 20004
# au_ = 2225
# mtu = 14868
# uv = 15234
# Smoon = 8785
# 19 4 2035 12 : 21
# MTS = -57 adjust to 21543
# SMercury = 22807 adjust to 1207
# SVenus = -1596 adjust to 20004
# au_ = 2225
# mtu = 14868
# uv = 15235
# Smoon = 8786
# 19 4 2035 12 : 22
# MTS = -57 adjust to 21543
# SMercury = 22807 adjust to 1207
# SVenus = -1596 adjust to 20004
# au_ = 2225
# mtu = 14868
# uv = 15235
# Smoon = 8786
# 19 4 2035 12 : 23
# MTS = -57 adjust to 21543
# SMercury = 22807 adjust to 1207
# SVenus = -1596 adjust to 20004
# au_ = 2225
# mtu = 14868
# uv = 15236
# Smoon = 8787
# 19 4 2035 12 : 24
# MTS = -57 adjust to 21543
# SMercury = 22807 adjust to 1207
# SVenus = -1596 adjust to 20004
# au_ = 2225
# mtu = 14868
# uv = 15236
# Smoon = 8787
# 19 4 2035 12 : 25
# MTS = -57 adjust to 21543
# SMercury = 22807 adjust to 1207
# SVenus = -1596 adjust to 20004
# au_ = 2225
# mtu = 14868
# uv = 15237
# Smoon = 8788
# 19 4 2035 12 : 26
# MTS = -57 adjust to 21543
# SMercury = 22807 adjust to 1207
# SVenus = -1596 adjust to 20004
# au_ = 2225
# mtu = 14868
# uv = 15237
# Smoon = 8788
# 19 4 2035 12 : 27
# MTS = -57 adjust to 21543
# SMercury = 22807 adjust to 1207
# SVenus = -1596 adjust to 20004
# au_ = 2225
# mtu = 14868
# uv = 15238
# Smoon = 8789
# 19 4 2035 12 : 28
# MTS = -57 adjust to 21543
# SMercury = 22807 adjust to 1207
# SVenus = -1596 adjust to 20004
# au_ = 2225
# mtu = 14868
# uv = 15238
# Smoon = 8789
# 19 4 2035 12 : 29
# MTS = -57 adjust to 21543
# SMercury = 22807 adjust to 1207
# SVenus = -1596 adjust to 20004
# au_ = 2225
# mtu = 14868
# uv = 15239
# Smoon = 8790
# 19 4 2035 12 : 30
# MTS = -57 adjust to 21543
# SMercury = 22807 adjust to 1207
# SVenus = -1596 adjust to 20004
# au_ = 2225
# mtu = 14868
# uv = 15239
# Smoon = 8790
# 19 4 2035 12 : 31
# MTS = -57 adjust to 21543
# SMercury = 22807 adjust to 1207
# SVenus = -1596 adjust to 20004
# au_ = 2225
# mtu = 14868
# uv = 15240
# Smoon = 8792
# 19 4 2035 12 : 32
# MTS = -56 adjust to 21544
# SMercury = 22808 adjust to 1208
# SVenus = -1594 adjust to 20006
# au_ = 2225
# mtu = 14868
# uv = 15241
# Smoon = 8793
# 19 4 2035 12 : 33
# MTS = -56 adjust to 21544
# SMercury = 22808 adjust to 1208
# SVenus = -1594 adjust to 20006
# au_ = 2225
# mtu = 14868
# uv = 15242
# Smoon = 8794
# 19 4 2035 12 : 34
# MTS = -56 adjust to 21544
# SMercury = 22808 adjust to 1208
# SVenus = -1594 adjust to 20006
# au_ = 2225
# mtu = 14868
# uv = 15242
# Smoon = 8794
# 19 4 2035 12 : 35
# MTS = -56 adjust to 21544
# SMercury = 22808 adjust to 1208
# SVenus = -1594 adjust to 20006
# au_ = 2225
# mtu = 14868
# uv = 15243
# Smoon = 8795
# 19 4 2035 12 : 36
# MTS = -56 adjust to 21544
# SMercury = 22808 adjust to 1208
# SVenus = -1594 adjust to 20006
# au_ = 2225
# mtu = 14868
# uv = 15243
# Smoon = 8795
# 19 4 2035 12 : 37
# MTS = -56 adjust to 21544
# SMercury = 22808 adjust to 1208
# SVenus = -1594 adjust to 20006
# au_ = 2225
# mtu = 14868
# uv = 15244
# Smoon = 8796
# 19 4 2035 12 : 38
# MTS = -56 adjust to 21544
# SMercury = 22808 adjust to 1208
# SVenus = -1594 adjust to 20006
# au_ = 2225
# mtu = 14868
# uv = 15244
# Smoon = 8796
# 19 4 2035 12 : 39
# MTS = -56 adjust to 21544
# SMercury = 22808 adjust to 1208
# SVenus = -1594 adjust to 20006
# au_ = 2225
# mtu = 14868
# uv = 15245
# Smoon = 8797
# 19 4 2035 12 : 40
# MTS = -56 adjust to 21544
# SMercury = 22808 adjust to 1208
# SVenus = -1594 adjust to 20006
# au_ = 2225
# mtu = 14868
# uv = 15245
# Smoon = 8797
# 19 4 2035 12 : 41
# MTS = -56 adjust to 21544
# SMercury = 22808 adjust to 1208
# SVenus = -1594 adjust to 20006
# au_ = 2225
# mtu = 14868
# uv = 15246
# Smoon = 8798
# 19 4 2035 12 : 42
# MTS = -56 adjust to 21544
# SMercury = 22808 adjust to 1208
# SVenus = -1594 adjust to 20006
# au_ = 2225
# mtu = 14868
# uv = 15246
# Smoon = 8798
# 19 4 2035 12 : 43
# MTS = -56 adjust to 21544
# SMercury = 22808 adjust to 1208
# SVenus = -1594 adjust to 20006
# au_ = 2225
# mtu = 14868
# uv = 15247
# Smoon = 8799
# 19 4 2035 12 : 44
# MTS = -56 adjust to 21544
# SMercury = 22808 adjust to 1208
# SVenus = -1594 adjust to 20006
# au_ = 2225
# mtu = 14868
# uv = 15247
# Smoon = 8799
# 19 4 2035 12 : 45
# MTS = -56 adjust to 21544
# SMercury = 22808 adjust to 1208
# SVenus = -1594 adjust to 20006
# au_ = 2225
# mtu = 14868
# uv = 15248
# Smoon = 8800
# 19 4 2035 12 : 46
# MTS = -56 adjust to 21544
# SMercury = 22808 adjust to 1208
# SVenus = -1594 adjust to 20006
# au_ = 2225
# mtu = 14868
# uv = 15248
# Smoon = 8800
# 19 4 2035 12 : 47
# MTS = -56 adjust to 21544
# SMercury = 22808 adjust to 1208
# SVenus = -1594 adjust to 20006
# au_ = 2225
# mtu = 14868
# uv = 15249
# Smoon = 8801
# 19 4 2035 12 : 48
# MTS = -56 adjust to 21544
# SMercury = 22808 adjust to 1208
# SVenus = -1594 adjust to 20006
# au_ = 2225
# mtu = 14868
# uv = 15249
# Smoon = 8801
# 19 4 2035 12 : 49
# MTS = -56 adjust to 21544
# SMercury = 22808 adjust to 1208
# SVenus = -1594 adjust to 20006
# au_ = 2225
# mtu = 14868
# uv = 15250
# Smoon = 8802
# 19 4 2035 12 : 50
# MTS = -56 adjust to 21544
# SMercury = 22808 adjust to 1208
# SVenus = -1594 adjust to 20006
# au_ = 2225
# mtu = 14868
# uv = 15250
# Smoon = 8802
# 19 4 2035 12 : 51
# MTS = -56 adjust to 21544
# SMercury = 22808 adjust to 1208
# SVenus = -1594 adjust to 20006
# au_ = 2225
# mtu = 14868
# uv = 15251
# Smoon = 8803
# 19 4 2035 12 : 52
# MTS = -56 adjust to 21544
# SMercury = 22808 adjust to 1208
# SVenus = -1594 adjust to 20006
# au_ = 2225
# mtu = 14868
# uv = 15251
# Smoon = 8803
# 19 4 2035 12 : 53
# MTS = -56 adjust to 21544
# SMercury = 22808 adjust to 1208
# SVenus = -1594 adjust to 20006
# au_ = 2225
# mtu = 14868
# uv = 15252
# Smoon = 8804
# 19 4 2035 12 : 54
# MTS = -56 adjust to 21544
# SMercury = 22808 adjust to 1208
# SVenus = -1594 adjust to 20006
# au_ = 2225
# mtu = 14868
# uv = 15252
# Smoon = 8804
# 19 4 2035 12 : 55
# MTS = -56 adjust to 21544
# SMercury = 22808 adjust to 1208
# SVenus = -1594 adjust to 20006
# au_ = 2225
# mtu = 14868
# uv = 15254
# Smoon = 8806
# 19 4 2035 12 : 56
# MTS = -56 adjust to 21544
# SMercury = 22808 adjust to 1208
# SVenus = -1594 adjust to 20006
# au_ = 2225
# mtu = 14868
# uv = 15254
# Smoon = 8806
# 19 4 2035 12 : 57
# MTS = -55 adjust to 21545
# SMercury = 22809 adjust to 1209
# SVenus = -1595 adjust to 20005
# au_ = 2225
# mtu = 14868
# uv = 15256
# Smoon = 8808
# 19 4 2035 12 : 58
# MTS = -55 adjust to 21545
# SMercury = 22809 adjust to 1209
# SVenus = -1595 adjust to 20005
# au_ = 2225
# mtu = 14868
# uv = 15256
# Smoon = 8808
# 19 4 2035 12 : 59
# MTS = -55 adjust to 21545
# SMercury = 22809 adjust to 1209
# SVenus = -1595 adjust to 20005
# au_ = 2225
# mtu = 14868
# uv = 15257
# Smoon = 8809
# 19 4 2035 13 : 0
# MTS = -55 adjust to 21545
# SMercury = 22809 adjust to 1209
# SVenus = -1595 adjust to 20005
# au_ = 2225
# mtu = 14868
# uv = 15257
# Smoon = 8809
# 19 4 2035 13 : 1
# MTS = -55 adjust to 21545
# SMercury = 22809 adjust to 1209
# SVenus = -1595 adjust to 20005
# au_ = 2225
# mtu = 14868
# uv = 15257
# Smoon = 8809
# 19 4 2035 13 : 2
# MTS = -55 adjust to 21545
# SMercury = 22809 adjust to 1209
# SVenus = -1595 adjust to 20005
# au_ = 2225
# mtu = 14868
# uv = 15258
# Smoon = 8810
# 19 4 2035 13 : 3
# MTS = -55 adjust to 21545
# SMercury = 22809 adjust to 1209
# SVenus = -1595 adjust to 20005
# au_ = 2225
# mtu = 14868
# uv = 15258
# Smoon = 8810
# 19 4 2035 13 : 4
# MTS = -55 adjust to 21545
# SMercury = 22809 adjust to 1209
# SVenus = -1595 adjust to 20005
# au_ = 2225
# mtu = 14868
# uv = 15259
# Smoon = 8811
# 19 4 2035 13 : 5
# MTS = -55 adjust to 21545
# SMercury = 22809 adjust to 1209
# SVenus = -1595 adjust to 20005
# au_ = 2225
# mtu = 14868
# uv = 15259
# Smoon = 8811
# 19 4 2035 13 : 6
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-41-5a11a884b30f> in <module>
#      56     print(dt.day,dt.month,dt.year,dt.hour,':',dt.minute)
#      57     #df = pd.DataFrame(data)
# ---> 58     df = df.append(data , ignore_index=True)
#      59
#      60
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in append(self, other, ignore_index, verify_integrity, sort)
#    6675                               index=index,
#    6676                               columns=combined_columns)
# -> 6677             other = other._convert(datetime=True, timedelta=True)
#    6678             if not self.columns.equals(combined_columns):
#    6679                 self = self.reindex(columns=combined_columns)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _convert(self, datetime, numeric, timedelta, coerce, copy)
#    5848             self._data.convert(datetime=datetime, numeric=numeric,
#    5849                                timedelta=timedelta, coerce=coerce,
# -> 5850                                copy=copy)).__finalize__(self)
#    5851
#    5852     def convert_objects(self, convert_dates=True, convert_numeric=False,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in convert(self, **kwargs)
#     532
#     533     def convert(self, **kwargs):
# --> 534         return self.apply('convert', **kwargs)
#     535
#     536     def replace(self, **kwargs):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#     399             return self.make_empty(axes or self.axes)
#     400         bm = self.__class__(result_blocks, axes or self.axes,
# --> 401                             do_integrity_check=do_integrity_check)
#     402         bm._consolidate_inplace()
#     403         return bm
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in __init__(self, blocks, axes, do_integrity_check)
#     116         self._consolidate_check()
#     117
# --> 118         self._rebuild_blknos_and_blklocs()
#     119
#     120     def make_empty(self, axes=None):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in _rebuild_blknos_and_blklocs(self)
#     196             rl = blk.mgr_locs
#     197             new_blknos[rl.indexer] = blkno
# --> 198             new_blklocs[rl.indexer] = np.arange(len(rl))
#     199
#     200         if (new_blknos == -1).any():
#
# KeyboardInterrupt:

# %%
df = df[['dt','dtny','ahra','jultin','kj','aw','masG','dT','au','van',
         'stin','sec','ahra_','kj_','aw_','masG_','dT_','au_','van_',
         'sun','moon','rahu','geth','mars','mercury','venus','jupiter','saturn','uranus',
         'sun_Z','sun_D','sun_M',
         'moon_Z','moon_D','moon_M',
         'rahu_Z','rahu_D','rahu_M',
         'geth_Z','geth_D','geth_M',
         'mars_Z','mars_D','mars_M',
         'mercury_Z','mercury_D','mercury_M',
         'venus_Z','venus_D','venus_M',
         'jupiter_Z','jupiter_D','jupiter_M',
         'saturn_Z','saturn_D','saturn_M',
         'uranus_Z','uranus_D','uranus_M'
        ]]
df.to_csv(r"C:\Users\JACK\Desktop\S_out.csv")

# %%
dt1= datetime(2019,1,1,0,0)
dt2= datetime(1943,4,17,9,49)
dt3= datetime(2019,1,2,22,45)


test1= hora(dt1)
test2= hora(dt2)
test3= hora(dt3)

#Create dataframe
#Method1
data = {
    'dt': [dt1,dt2,dt3],
    'sun' : [test1.sun,test2.sun,test3.sun],
    'moon': [test1.moon,test2.moon,test3.moon],
    'rahu' : [test1.rahu,test2.rahu,test3.rahu],
    'geth' : [test1.geth,test2.geth,test3.geth],
    'mars' : [test1.mars,test2.mars,test3.mars],
    'mercury' : [test1.mercury,test2.mercury,test3.mercury],
    'venus' : [test1.venus,test2.venus,test3.venus],
    'jupiter' : [test1.jupiter,test2.jupiter,test3.jupiter],
    'saturn' : [test1.saturn,test2.saturn,test3.saturn],
    'uranus' : [test1.uranus,test2.uranus,test3.uranus]
}


#Method2
# data = [
#     {'dt': dt1, 'ssun': test1.sun, 'smoon': test1.moon},
#     {'dt': dt2, 'ssun': test2.sun, 'smoon': test2.moon},
#     {'dt': dt3, 'ssun': test3.sun, 'smoon': test3.moon},
# ]

df = pd.DataFrame(data)


loops = ['sun','moon','rahu','geth','mars','mercury','venus','jupiter','saturn','uranus'] 

for planet in loops:
    zodiac = planet+"_Z"
    degree = planet+"_D"
    minute = planet+"_M"
    df[zodiac] =  df[planet]//1800 
    df[degree] =  (df[planet]%1800)//60 
    df[minute] =  (df[planet]%1800)%60

# df['sun_Z'] =  df['ssun']//1800 
# df['sun_D'] =  (df['ssun']%1800)//60 
# df['sun_M'] =  (df['ssun']%1800)%60

df[['sun_Z','sun_D','sun_M','moon_Z','moon_D','moon_M','rahu_Z','rahu_D','rahu_M','geth_Z','geth_D','geth_M']]
#df[['mercury_Z','mercury_D','mercury_M','venus_Z','venus_D','venus_M']]
#df[['mars_Z','mars_D','mars_M','jupiter_Z','jupiter_D','jupiter_M','saturn_Z','saturn_D','saturn_M','uranus_Z','uranus_D','uranus_M']]
# Out:
# Smars = -1498 adjust to 20102
# MTS = -137 adjust to 21463
# SMercury = 22715 adjust to 1115
# Smars = -1431 adjust to 20169
#    sun_Z  sun_D  sun_M  moon_Z  moon_D  moon_M  rahu_Z  rahu_D  rahu_M  \
# 0      8     15     29       6      13      42       3       2      45
# 1      0      3     21       4      25      31       3      28      19
# 2      8     17     29       7       9      51       3       2      39
#
#    geth_Z  geth_D  geth_M
# 0       9       7      50
# 1       5      29       0
# 2       9       6      48

# %%
dt1= datetime(1984,1,27,9,49)
dt2= datetime(2007,3,30,8,55)
dt3= datetime(2010,1,27,22,52)


test1= hora(dt1)
test2= hora(dt2)
test3= hora(dt3)

#Create dataframe
#Method1
data = {
    'dt': [dt1,dt2,dt3],
    'ssun' : [test1.sun,test2.sun,test3.sun],
    'smoon': [test1.moon,test2.moon,test3.moon],
    'srahu' : [test1.rahu,test2.rahu,test3.rahu],
    'sgeth' : [test1.geth,test2.geth,test3.geth],
    'smars' : [test1.mars,test2.mars,test3.mars],
    'smercury' : [test1.mercury,test2.mercury,test3.mercury],
    'svenus' : [test1.venus,test2.venus,test3.venus],
    'jupiter' : [test1.jupiter,test2.jupiter,test3.jupiter],
    'ssaturn' : [test1.saturn,test2.saturn,test3.saturn],
    'suranus' : [test1.uranus,test2.uranus,test3.uranus]
}


#Method2
# data = [
#     {'dt': dt1, 'ssun': test1.sun, 'smoon': test1.moon},
#     {'dt': dt2, 'ssun': test2.sun, 'smoon': test2.moon},
#     {'dt': dt3, 'ssun': test3.sun, 'smoon': test3.moon},
# ]

df = pd.DataFrame(data)



#Add row to DataFrame
#METHOD1: add or update specify by row name 
#df.loc[2] = [dt3,10,20]
#df.loc[3] = [dt3,10,20]

#METHOD1.1: Add row to the end of dataframe 
#df.loc[len(df.index)] = [dt3,10,20]
#df.loc[len(df.index)] = [dt3,10,20]
# df.loc[len(df.index)] = [dt3,10,20]


#METHOD2: Add row to some columns
#df = df.append({'dt' : 'dateadded' , 'ssun' : 2222} , ignore_index=True)

#print(len(df.index))


#Change column name
#df.columns = 'a','b','c'

#create new column and data
#method1
#df['newcolumn1'] = ''
#df['newcolumn1'] = [1,2,3,4,5]

#Method2
#df.insert(4, "newcolumn2", [21, 23, 24, 21, 20], True) 
#df.insert(len(df.columns), "newcolumn2", [21, 23, 24, 21, 20], True) 

#Method3-Create new 
#df2 = df.assign(address = ['Delhi', 'Bangalore', 'Chennai', 'Patna', 'ddd']) 
#df2


#Drop column 
#df = df.drop(columns=['newcolumn1','newcolumn2'])


# df['sun_Z'] =  df['ssun']//1800 
# df['sun_D'] =  (df['ssun']%1800)//60 
# df['sun_M'] =  (df['ssun']%1800)%60

# df['moon_Z'] =  df['smoon']//1800 
# df['moon_D'] =  (df['smoon']%1800)//60 
# df['moon_M'] =  (df['smoon']%1800)%60

# df['rahu_Z'] =  df['srahu']//1800 
# df['rahu_D'] =  (df['srahu']%1800)//60 
# df['rahu_M'] =  (df['srahu']%1800)%60

# df['geth_Z'] =  df['sgeth']//1800 
# df['geth_D'] =  (df['sgeth']%1800)//60 
# df['geth_M'] =  (df['sgeth']%1800)%60

# df['mars_Z'] =  df['smars']//1800 
# df['mars_D'] =  (df['smars']%1800)//60 
# df['mars_M'] =  (df['smars']%1800)%60



# df[0:]




#sliding rows 
#df[2:3]

#sliding columns 
# df[['dt','ssun','smoon']]

#sliding rows and columns 
#df.loc[row,colmm]
# df.loc[:,:]
# df.loc[1,['dt']]
# df.loc[1:3,['dt','ssun','smoon']]
# df.loc[1:3,'dt':'ssun']

#Change index
# df.set_index("dt", inplace=True)
# df.loc[:,:]
# df.loc[dt1,:]
# df.loc[dt1:dt3,['ssun','smoon']]
# df.loc[dt1:dt3,'ssun':'ssun_m']

#boolean
# df.loc[df['smoon'] >= 7000,'ssun':'ssun_m']

df



#df.loc[0:3,'dt']>dt1
#df.loc[0:3,'dt']>dt1
#data.set_index("last_name", inplace=True)
# Out:
# uv = 14819
# pholGA = 4019
# khan = 4
# SVenus = 22652 adjust to 1052
# uv = 17719
# pholGA = 3881
# khan = 4
# uv = 7926
# pholGA = 2874
# khan = 3
#                    dt   ssun  smoon  srahu  sgeth  smars  smercury  svenus  \
# 0 1984-01-27 09:49:00  16953  12913   2933  12108  11722     15638   14765
# 1 2007-03-30 08:55:00  20702   7569  19222   2089  18000     19459    1052
# 2 2010-01-27 22:52:00  17003   4207  15932  12377   6532     15557   17071
#
#    jupiter  ssaturn  suranus
# 0    14973    11999    13324
# 1    14290     6638    19352
# 2    18534     9464    19983

# %%
#df[['dt','ssun','sun_Z','sun_D','sun_M','smoon','moon_Z','moon_D','moon_M']]

# %%
# s_ravi = {
#     'jya': [35,32,27,22,13,5],
#     'ravi': [0,35,67,94,116,129]
# }
# #df = pd.DataFrame(s_ravi)
# df = pd.DataFrame(s_ravi)
# #df.iloc[1] = [kj,Ssun]
# #df.append(data)
# df = df.append({'kj' : 'Sahil' , 'sun' : 22} , ignore_index=True)
# df = df.append({'kj' : 'Sahil' , 'sun' : 22} , ignore_index=True)

# df = df.append({'kj' : 'Sahil' , 'sun' : 22 , 'datetime' : dt} , ignore_index=True)
# df = df.append({'kj' : 'Sahil' , 'sun' : 22 , 'datetime' : dtny} , ignore_index=True)


#Create dataframe
df = pd.DataFrame()

# Creating an empty Dataframe with column names only
df = pd.DataFrame(columns=['User_ID', 'UserName', 'Action'])

# Create an empty Dataframe with columns or indices
#df = pd.DataFrame(columns=['User_ID', 'UserName', 'Action'], index=['a', 'b', 'c'])

print(df.head(5))
print(df.tail())

print(df.dtypes)
print(df.index)
print(df.columns)
print(df.values)

#for index,row in df.iterrows():
#    print (index, row['ssun'], row['smoon'])
# Out:
# Empty DataFrame
# Columns: [User_ID, UserName, Action]
# Index: []
# Empty DataFrame
# Columns: [User_ID, UserName, Action]
# Index: []
# User_ID     object
# UserName    object
# Action      object
# dtype: object
# Index([], dtype='object')
# Index(['User_ID', 'UserName', 'Action'], dtype='object')
# []

# %%
day,month,year,hour,minute = 27,1,2527,9,49
christ_year = year-543

dt= datetime(christ_year,month,day,hour,minute)

a = hora(dt)  
print('dt =', a.dt)
print('dtnt =', a.dtny)
print('ahra =', a.ahra)
print('jultin =', a.jultin)
print('kj =', a.kj)
print('aw =', a.aw)
print('masG =', a.masG)
print('dT =', a.dT)
print('au =', a.au)
print('van =', a.van)

print('stin =', a.stin)
print('sec =', a.sec)
print('ahra_ =', a.ahra_)
print('kj_ =', a.kj_)
print('aw_ =', a.aw_)
print('masG_ =', a.masG_)
print('dT_ =', a.dT_)
print('au_ =', a.au_)
print('van_ =', a.van_)

print('sun =', a.sun)
print('moon =', a.moon)
print('rahu =', a.rahu)
print('geth =', a.geth)
print('mars =', a.mars)
print('mercury =', a.mercury)
print('venus =', a.venus)
print('jupiter =', a.jupiter)
print('saturn =', a.saturn)
print('uranus =', a.uranus)
# Out:
# dt = 1984-01-27 09:31:00
# dtnt = 1983-04-16 11:38:24
# ahra = 491274
# jultin = 388
# kj = 412
# aw = 144
# masG = 16636
# dT = 4
# au = 2621
# van = 0
# stin = 286
# sec = 34260
# ahra_ = 491560
# kj_ = 228729
# aw_ = 97
# masG_ = 16645
# dT_ = 24
# au_ = 2907
# van_ = 6
# sun = 16953
# moon = 12913
# rahu = 2933
# geth = 12108
# mars = 11722
# mercury = 15638
# venus = 14765
# jupiter = 14973
# saturn = 11999
# uranus = 13324

# %% [markdown]
# #
