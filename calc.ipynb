# %%
import math
from datetime import date
from datetime import datetime
from datetime import timedelta
import pandas as pd

# %%
def NYdate(jula_year):
    ny = jula_year*0.25875-int(jula_year/4 +0.5)+int(jula_year/100 +0.38)-int(jula_year/400 +0.595)-5.53375
    jultin =  ((jula_year*292207)+373)%800
    hour,frac = divmod(jultin*24,800)
    minute,frac = divmod(frac*60,800)
    second,frac = divmod(frac*60,800)
    christ_year = jula_year+638
    dtny = datetime(christ_year, 4, int(ny), hour , minute, second)
    return dtny;

# %%
class hora:
    def __init__(self,dt):
        offset = timedelta(minutes=18)
        dt= dt-offset
        jula_year = dt.year-638    
        d = date(dt.year,dt.month,dt.day)
        dtf= datetime(dt.year,dt.month,dt.day,0,0)        
        dtny = NYdate(jula_year)
        dny = date(dtny.year,dtny.month,dtny.day)
        
        if (dt>=dtny):
            jula_newyear = jula_year
        elif (dt<dtny):
            jula_newyear = jula_year-1
            dtny = NYdate(jula_newyear)
            dny = date(dtny.year,dtny.month,dtny.day)

            
        temp = (jula_newyear*292207)+373
        ahra = (temp//800)+1
        jultin =  temp%800

        kj = 800-jultin
        temp,aw= divmod((ahra*11)+650,692)
        masG,dT=divmod((ahra+temp),30)

        au = (ahra-621)%3232
        van = ahra%7

        stin = (d-dny).days
        sec = (dt-dtf).seconds

        ahra_ = ahra+stin
        stkm = (stin-1)*800
        kj_ = kj + stkm + sec//108

        awjt = (stin-1)*703+aw
        aws = awjt+(sec*703)//86400
        awdT,aw_=divmod(aws,692)
        temp,dT_=divmod((awdT+dT),30)
        masG_ = masG+temp
        van_=ahra_%7

        if (au+stin > 3232):
            au_ = au+stin-3232
        else: au_= au+stin        
        
        
##########################SUN###############################
        sun_table = [[35,32,27,22,13,5,0],
                     [0,35,67,94,116,129,134]]

        z = kj_ // 24350
        z_remainder = kj_ % 24350
        degree = z_remainder//811
        d_remainder = z_remainder % 811
        minute = d_remainder//14

        d_total = z*30+degree
        mathasun = d_total*60+minute-3
        
        
        if mathasun < 0:
            mathasun = mathasun+21600     
        if mathasun >= 21600:
            raise Exception('mathasun exceed or equal 21600')      
            
        if mathasun < 4800:
            pholsun = 21600+mathasun-4800
        else:
            pholsun = mathasun-4800


        if pholsun >= 21600:
            raise Exception('pholsun exceed or equal 21600')
        elif pholsun < 0:
            raise Exception('pholsun below 0')
        elif pholsun >= 0 and pholsun <5400:
            pholGA = pholsun

        elif pholsun >= 5400 and pholsun <10800:
            pholGA = 10800-pholsun

        elif pholsun >= 10800 and pholsun <16200:
            pholGA = pholsun-10800

        elif pholsun >= 16200:
            pholGA = 21600-pholsun


        khan = pholGA // 900
        pushlip = pholGA % 900


        jyaGA = (sun_table[0][khan]*pushlip) // 900
        ravipphol = sun_table[1][khan]+jyaGA


        if pholsun < 10800:
            Ssun = mathasun-ravipphol
        elif pholsun > 10800:
            Ssun= mathasun+ravipphol
        elif pholsun == 10800:
            if(ravipphol != 0):raise Exception('pholsun=10800 but ravipphol not 0')
            Ssun= mathasun

        if Ssun < 0:
            Ssun = Ssun+21600
        elif Ssun > 21600:
            Ssun= Ssun-21600

        #parameter for sun calculation
        self.mathasun = mathasun
        self.pholsun = pholsun
        self.SPholGA = pholGA
        self.SKhan = khan
        self.SPushlip = pushlip
        self.SJyaGA = jyaGA
        self.ravipphol = ravipphol               

        #zodiac,frac = divmod(Ssun,1800)
        #degree,minute = divmod(frac,60)    

#         print('pholGA =',pholGA)
#         print('khan =',khan)
#         print('kj_ =',kj_)
#         print('mathasun =',mathasun)
#         print('Ssun =',Ssun)

##########################MOON###############################

        moon_table = [[77,71,61,47,30,10,0],
                     [0,77,148,209,256,286,296]]

        temp = (au_-1)*86400+sec

        #zodiac,frac = divmod(x,23270400)
        #degree,frac = divmod(frac,775680)
        #minute = frac // 12928

        zodiac = temp//23270400
        degree = (temp%23270400)//775680
        minute = ((temp%23270400)%775680)//12928
        d_total = zodiac*30+degree
        mtu = d_total*60+minute+2


        mathamoon = mathasun + aw_ +(aw_//25)+(dT_*720)-40
        if mathamoon >= 21600: 
            mathamoon = mathamoon-21600
        if mtu >= 21600: 
            mtu = mtu-21600

#        if mathamoon >= 21600:
#            raise Exception('mathamoon exceed or equal 21600')
#        if mtu >= 21600:
#            raise Exception('mtu exceed or equal 21600')
        if mathamoon < 0:
            raise Exception('mathamoon below 0')
        elif mtu < 0:
            raise Exception('mtu below 0')
        elif mathamoon>=mtu:
            uv =  mathamoon-mtu
        elif mathamoon<mtu:
            uv = 21600+mathamoon-mtu


        if uv >= 21600:
            raise Exception('uv exceed or equal 21600')
        elif uv < 0:
            raise Exception('uv below 0')
        elif uv >= 0 and uv <5400:
            pholGA = uv
        elif uv >= 5400 and uv <10800:
            pholGA = 10800-uv
        elif uv >= 10800 and uv <16200:
            pholGA = uv-10800
        elif uv >= 16200:
            pholGA = 21600-uv


        khan = pholGA // 900
        pushlip = pholGA % 900

        jyaGA = (moon_table[0][khan]*pushlip) // 900
        chandraphol = moon_table[1][khan]+jyaGA

        if uv < 10800:
            Smoon = mathamoon-chandraphol
        elif uv > 10800:
            Smoon= mathamoon+chandraphol
        elif uv == 10800:
            if(chandraphol != 0):raise Exception('uv=10800 but chandraphol not 0')
            Smoon= mathamoon

        if Smoon < 0:
            Smoon = Smoon+21600
        elif Smoon > 21600:
            Smoon= Smoon-21600

        #moon parameters 
        self.mtu = mtu
        self.mathamoon = mathamoon
        self.uv = uv
        self.MPholGA = pholGA
        self.MKhan = khan
        self.MPushlip = pushlip
        self.MJyaGA = jyaGA
        self.chandraphol = chandraphol
    
    
##########################RAHU###############################
        matharavi = mathasun-23
        if matharavi <0:
            matharavi=matharavi+21600
    
    
        srb = jula_newyear-610
        manut = (srb*21600)+ matharavi

        a = manut//20
        b = manut//265
        pmt = (a+b)%21600

        Srahu = 15150-pmt
        if Srahu<0:
            Srahu = Srahu+21600
            
        #rahu parameters
        self.matharavi = matharavi
        self.srb = srb
        self.manut = manut
        self.a = a
        self.b = b
        self.pmt = pmt  

##########################GETH###############################
        pholgt = (ahra_-345)%679
        mathageth = (pholgt*21600 + (sec*21600)//86400)//679
        Sgeth = 21600-mathageth
#         zodiac,frac = divmod(Sgeth,1800)
#         degree,minute = divmod(frac,60)

        #geth parameters
        self.pholgt = pholgt
        self.mathageth = mathageth           


                
##########################Inner Plannets##################################
        plannet = ['mercury','venus']
        for plannet in plannet: 
            if plannet  == 'mercury':
                matha = ((manut*7)//46 + (manut*4)//1 + 10642)%21600
                pholPK = matharavi-13200
            elif plannet == 'venus':
                matha = ((manut*5)//3 - (manut*10)//243 + 10944)%21600
                pholPK = matharavi-4800
                
            if pholPK<0:
                pholPK = pholPK+21600

            ptma = (pholPK//5400)+1
            if ptma == 1:
                puchaPT = pholPK
                khotiPT = 5400-pholPK
            elif ptma == 2:
                puchaPT = 10800-pholPK
                khotiPT = pholPK-5400
            elif ptma == 3:
                puchaPT = pholPK-10800
                khotiPT = 16200-pholPK
            elif ptma == 4:
                puchaPT = 21600-pholPK
                khotiPT = pholPK-16200

            # puchaPT = 1064
            # khotiPT = 4336

            if puchaPT < 0:
                raise Exception('puchaPT is below 0')
            elif puchaPT > 5400:
                raise Exception('puchaPT is greater than 5400')
            elif puchaPT < 1800:
                MTpucha = (puchaPT*14640)//1800
            elif (puchaPT >= 1800) and (puchaPT < 3600) :
                MTpucha = (((puchaPT-1800)*10980)//1800)+14640
            elif puchaPT >= 3600 :
                MTpucha = (((puchaPT-3600)*3660)//1800)+25620

            if khotiPT < 0:
                raise Exception('khotiPT is below 0')
            elif khotiPT > 5400:
                raise Exception('khotiPT is greater than 5400')
            elif khotiPT < 1800:
                MTKhoti = (khotiPT*14640)//1800
            elif (khotiPT >= 1800) and (khotiPT < 3600) :
                MTKhoti = (((khotiPT-1800)*10980)//1800)+14640
            elif khotiPT >= 3600 :
                MTKhoti = (((khotiPT-3600)*3660)//1800)+25620

            MTKhoti = (MTKhoti+30)//60
            khotiphol = MTKhoti//2


            if plannet == 'mercury':
                if (ptma ==1) or (ptma ==4):
                    MTcheta = 100*60 + khotiphol
                elif (ptma ==2) or (ptma ==3):
                    MTcheta=  100*60 - khotiphol
            elif plannet == 'venus':
                if (ptma ==1) or (ptma ==4):
                    MTcheta = 320*60 + khotiphol
                elif (ptma ==2) or (ptma ==3):
                    MTcheta=  320*60 - khotiphol          
            
            

            MTphol = (MTpucha*60)//MTcheta


            if (ptma ==1) or (ptma ==2):
                if (matharavi  - MTphol)>=0:
                    MTS = matharavi  - MTphol
                elif (matharavi  - MTphol)<0:
                    MTS =  matharavi  - MTphol + 21600
                    print('MTS =',matharavi  - MTphol,'adjust to',MTS)          

            elif (ptma ==3) or (ptma ==4):
                if (matharavi  + MTphol)>=21600:
                    MTS = matharavi  + MTphol - 21600
                    print('MTS =',matharavi  + MTphol,'adjust to',MTS)
                elif(matharavi  + MTphol)<21600:
                    MTS = matharavi  + MTphol


            pholMT = MTS-matha
            if pholMT<0:
                pholMT=pholMT+21600

            ptnd = (pholMT//5400)+1
            if ptnd == 1:
                puchaTY = pholMT
                khotiTY = 5400-pholMT
            elif ptnd == 2:
                puchaTY = 10800-pholMT
                khotiTY = pholMT-5400
            elif ptnd == 3:
                puchaTY = pholMT-10800
                khotiTY = 16200-pholMT
            elif ptnd == 4:
                puchaTY = 21600-pholMT
                khotiTY = pholMT-16200

            if puchaTY < 0:
                raise Exception('puchaTY is below 0')
            elif puchaTY > 5400:
                raise Exception('puchaTY is greater than 5400')
            elif puchaTY < 1800:
                SGPucha = (puchaTY*14640)//1800
            elif (puchaTY >= 1800) and (puchaTY < 3600) :
                SGPucha = (((puchaTY-1800)*10980)//1800)+14640
            elif puchaTY >= 3600 :
                SGPucha = (((puchaTY-3600)*3660)//1800)+25620

            if khotiTY < 0:
                raise Exception('khotiTY is below 0')
            elif khotiTY > 5400:
                raise Exception('khotiTY is greater than 5400')
            elif khotiTY < 1800:
                SGKhoti = (khotiTY*14640)//1800
            elif (khotiTY >= 1800) and (khotiTY < 3600) :
                SGKhoti = (((khotiTY-1800)*10980)//1800)+14640
            elif khotiTY >= 3600 :
                SGKhoti = (((khotiTY-3600)*3660)//1800)+25620

            SGKhoti = (SGKhoti+30)//60
            SGphol = ((SGPucha+30)//60)//3


            if plannet == 'mercury': p= 21*60
            elif plannet == 'venus': p= 11*60            
            
            
            sp = p+SGphol

            if (ptnd ==1) or (ptnd ==4):
                SGcheta = sp + SGKhoti
            elif (ptnd ==2) or (ptnd ==3):
                SGcheta = sp - SGKhoti

            if SGcheta < 0:
                raise Exception('SGcheta < 0')
            elif khotiTY > 21600:
                raise Exception('SGcheta > SGcheta')

            mahaphol = (SGPucha*60)//SGcheta
            
            
            
            if plannet == 'mercury': 
                if (ptnd ==1) or (ptnd ==2):
                    if (MTS - mahaphol)>=0:
                        SMercury = MTS - mahaphol
                    elif (MTS - mahaphol)<0:
                        SMercury =  MTS - mahaphol + 21600
                        print('Smercury =',MTS - mahaphol,'adjust to',SMercury)          

                elif (ptnd ==3) or (ptnd ==4):
                    if (MTS + mahaphol)>=21600:
                        SMercury = MTS + mahaphol - 21600
                        print('SMercury =',MTS + mahaphol,'adjust to',SMercury)
                    elif(MTS + mahaphol)<21600:
                        SMercury = MTS + mahaphol               
                self.matha_mecury = matha
                self.pholPK_mecury  = pholPK
                self.ptma_mecury = ptma
                self.puchaPT_mecury = puchaPT
                self.khotiPT_mecury = khotiPT
                self.MTpucha_mecury = MTpucha
                self.MTKhoti_mecury = MTKhoti
                self.khotiphol_mecury = khotiphol
                self.MTcheta_mecury = MTcheta
                self.MTphol_mecury = MTphol
                self.MTS_mecury = MTS
                self.pholMT_mecury = pholMT
                self.ptnd_mecury = ptnd
                self.puchaTY_mecury = puchaTY
                self.khotiTY_mecury = khotiTY
                self.SGPucha_mecury = SGPucha
                self.SGKhoti_mecury = SGKhoti
                self.SGphol_mecury = SGphol
                self.p_mecury = p
                self.sp_mecury = sp
                self.SGcheta_mecury = SGcheta
                self.mahaphol_mecury = mahaphol
                        
                        
            elif plannet == 'venus': 
                if (ptnd ==1) or (ptnd ==2):
                    if (MTS - mahaphol)>=0:
                        SVenus = MTS - mahaphol
                    elif (MTS - mahaphol)<0:
                        SVenus =  MTS - mahaphol + 21600
                        print('SVenus =',MTS - mahaphol,'adjust to',SVenus)          

                elif (ptnd ==3) or (ptnd ==4):
                    if (MTS + mahaphol)>=21600:
                        SVenus = MTS + mahaphol - 21600
                        print('SVenus =',MTS + mahaphol,'adjust to',SVenus)
                    elif(MTS + mahaphol)<21600:
                        SVenus = MTS + mahaphol      
                self.matha_venus = matha
                self.pholPK_venus  = pholPK
                self.ptma_venus = ptma
                self.puchaPT_venus = puchaPT
                self.khotiPT_venus = khotiPT
                self.MTpucha_venus = MTpucha
                self.MTKhoti_venus = MTKhoti
                self.khotiphol_venus = khotiphol
                self.MTcheta_venus = MTcheta
                self.MTphol_venus = MTphol
                self.MTS_venus = MTS
                self.pholMT_venus = pholMT
                self.ptnd_venus = ptnd
                self.puchaTY_venus = puchaTY
                self.khotiTY_venus = khotiTY
                self.SGPucha_venus = SGPucha
                self.SGKhoti_venus = SGKhoti
                self.SGphol_venus = SGphol
                self.p_venus = p
                self.sp_venus = sp
                self.SGcheta_venus = SGcheta
                self.mahaphol_venus = mahaphol





                
##########################Other Plannets####################################

        plannet = ['mars','jupiter','saturn','uranus']
        for plannet in plannet: 
 
            if plannet  == 'mars':
                matha  =  ((manut*1)//2 + (manut*16)//505 + 5420)%21600         
                pholPK = matha-7620
            elif plannet == 'jupiter':
                matha  = ((manut*1)//12 + (manut*1)//1032 + 14297)%21600
                pholPK = matha-10320
            elif plannet == 'saturn':
                matha  = ((manut*1)//30 + (manut*6)//10000 + 11944)%21600
                pholPK = matha-14820
            elif plannet == 'uranus':
                matha  = ((manut*1)//84 + (manut*1)//7224 + 16277)%21600
                pholPK = matha-7440        

            if pholPK<0:
                pholPK = pholPK+21600


            ptma = (pholPK//5400)+1
            if ptma == 1:
                puchaPT = pholPK
                khotiPT = 5400-pholPK
            elif ptma == 2:
                puchaPT = 10800-pholPK
                khotiPT = pholPK-5400
            elif ptma == 3:
                puchaPT = pholPK-10800
                khotiPT = 16200-pholPK
            elif ptma == 4:
                puchaPT = 21600-pholPK
                khotiPT = pholPK-16200

            # puchaPT = 1064
            # khotiPT = 4336

            if puchaPT < 0:
                raise Exception('puchaPT is below 0')
            elif puchaPT > 5400:
                raise Exception('puchaPT is greater than 5400')
            elif puchaPT < 1800:
                MTpucha = (puchaPT*14640)//1800
            elif (puchaPT >= 1800) and (puchaPT < 3600) :
                MTpucha = (((puchaPT-1800)*10980)//1800)+14640
            elif puchaPT >= 3600 :
                MTpucha = (((puchaPT-3600)*3660)//1800)+25620

            if khotiPT < 0:
                raise Exception('khotiPT is below 0')
            elif khotiPT > 5400:
                raise Exception('khotiPT is greater than 5400')
            elif khotiPT < 1800:
                MTKhoti = (khotiPT*14640)//1800
            elif (khotiPT >= 1800) and (khotiPT < 3600) :
                MTKhoti = (((khotiPT-1800)*10980)//1800)+14640
            elif khotiPT >= 3600 :
                MTKhoti = (((khotiPT-3600)*3660)//1800)+25620

            MTKhoti = (MTKhoti+30)//60
            khotiphol = MTKhoti//2


            if plannet == 'mars':
                if (ptma ==1) or (ptma ==4):
                    MTcheta = 45*60 + khotiphol
                elif (ptma ==2) or (ptma ==3):
                    MTcheta=  45*60 - khotiphol
            elif plannet == 'jupiter':
                if (ptma ==1) or (ptma ==4):
                    MTcheta = 92*60 + khotiphol
                elif (ptma ==2) or (ptma ==3):
                    MTcheta=  92*60 - khotiphol
            elif plannet == 'saturn':
                if (ptma ==1) or (ptma ==4):
                    MTcheta = 63*60 + khotiphol
                elif (ptma ==2) or (ptma ==3):
                    MTcheta=  63*60 - khotiphol
            elif plannet == 'uranus':
                if (ptma ==1) or (ptma ==4):
                    MTcheta = 644*60 + khotiphol
                elif (ptma ==2) or (ptma ==3):
                    MTcheta=  644*60 - khotiphol  



            MTphol = (MTpucha*60)//MTcheta


            if (ptma ==1) or (ptma ==2):
                if (matha - MTphol)>=0:
                    MTS = matha - MTphol
                elif (matha - MTphol)<0:
                    MTS =  matha - MTphol + 21600
                    print('MTS =',matha - MTphol,'adjust to',MTS)          

            elif (ptma ==3) or (ptma ==4):
                if (matha + MTphol)>=21600:
                    MTS = matha + MTphol - 21600
                    print('MTS =',matha + MTphol,'adjust to',MTS)
                elif(matha + MTphol)<21600:
                    MTS = matha + MTphol


            pholMT = MTS-matharavi
            if pholMT<0:
                pholMT=pholMT+21600
#             elif pholMT>=21600:
#                 pholMT = pholMT - 21600
#                 print('pholMT =',pholMT + 21600,'adjust to',pholMT)

            ptnd = (pholMT//5400)+1
            if ptnd == 1:
                puchaTY = pholMT
                khotiTY = 5400-pholMT
            elif ptnd == 2:
                puchaTY = 10800-pholMT
                khotiTY = pholMT-5400
            elif ptnd == 3:
                puchaTY = pholMT-10800
                khotiTY = 16200-pholMT
            elif ptnd == 4:
                puchaTY = 21600-pholMT
                khotiTY = pholMT-16200

            if puchaTY < 0:
                raise Exception('puchaTY is below 0')
            elif puchaTY > 5400:
                raise Exception('puchaTY is greater than 5400')
            elif puchaTY < 1800:
                SGPucha = (puchaTY*14640)//1800
            elif (puchaTY >= 1800) and (puchaTY < 3600) :
                SGPucha = (((puchaTY-1800)*10980)//1800)+14640
            elif puchaTY >= 3600 :
                SGPucha = (((puchaTY-3600)*3660)//1800)+25620

            if khotiTY < 0:
                raise Exception('khotiTY is below 0')
            elif khotiTY > 5400:
                raise Exception('khotiTY is greater than 5400')
            elif khotiTY < 1800:
                SGKhoti = (khotiTY*14640)//1800
            elif (khotiTY >= 1800) and (khotiTY < 3600) :
                SGKhoti = (((khotiTY-1800)*10980)//1800)+14640
            elif khotiTY >= 3600 :
                SGKhoti = (((khotiTY-3600)*3660)//1800)+25620

            SGKhoti = (SGKhoti+30)//60
            SGphol = ((SGPucha+30)//60)//3

            
            if plannet == 'mars': p= (4*MTcheta)//15 
            elif plannet == 'jupiter': p= (3*MTcheta)//7
            elif plannet == 'saturn': 
                p= (7*MTcheta)//6 
                #print('ptnd = ',ptnd)
            elif plannet == 'uranus':p= (3*MTcheta)//7 
    

            sp = p+SGphol
            if (ptnd ==1) or (ptnd ==4):
                SGcheta = sp + SGKhoti
            elif (ptnd ==2) or (ptnd ==3):
                SGcheta = sp - SGKhoti

            if SGcheta < 0:
                raise Exception('SGcheta < 0')
            elif khotiTY > 21600:
                raise Exception('SGcheta > SGcheta')

            mahaphol = (SGPucha*60)//SGcheta

            

            if plannet == 'mars':
                if (ptnd ==1) or (ptnd ==2):
                    if (MTS - mahaphol)>=0:
                        Smars = MTS - mahaphol
                    elif (MTS - mahaphol)<0:
                        Smars =  MTS - mahaphol + 21600
                        print('Smars =',MTS - mahaphol,'adjust to',Smars)          
                elif (ptnd ==3) or (ptnd ==4):
                    if (MTS + mahaphol)>=21600:
                        Smars = MTS + mahaphol - 21600
                        print('Smars =',MTS + mahaphol,'adjust to',Smars)
                    elif(MTS + mahaphol)<21600:
                        Smars = MTS + mahaphol 
                self.matha_mars = matha
                self.pholPK_mars  = pholPK
                self.ptma_mars = ptma
                self.puchaPT_mars = puchaPT
                self.khotiPT_mars = khotiPT
                self.MTpucha_mars = MTpucha
                self.MTKhoti_mars = MTKhoti
                self.khotiphol_mars = khotiphol
                self.MTcheta_mars = MTcheta
                self.MTphol_mars = MTphol
                self.MTS_mars = MTS
                self.pholMT_mars = pholMT
                self.ptnd_mars = ptnd
                self.puchaTY_mars = puchaTY
                self.khotiTY_mars = khotiTY
                self.SGPucha_mars = SGPucha
                self.SGKhoti_mars = SGKhoti
                self.SGphol_mars = SGphol
                self.p_mars = p
                self.sp_mars = sp
                self.SGcheta_mars = SGcheta
                self.mahaphol_mars = mahaphol
                        
            elif plannet == 'jupiter':
                if (ptnd ==1) or (ptnd ==2):
                    if (MTS - mahaphol)>=0:
                        Jupiter = MTS - mahaphol
                    elif (MTS - mahaphol)<0:
                        Jupiter =  MTS - mahaphol + 21600
                        print('Jupiter =',MTS - mahaphol,'adjust to',Jupiter)          

                elif (ptnd ==3) or (ptnd ==4):
                    if (MTS + mahaphol)>=21600:
                        Jupiter = MTS + mahaphol - 21600
                        print('Jupiter =',MTS + mahaphol,'adjust to',Jupiter)
                    elif(MTS + mahaphol)<21600:
                        Jupiter = MTS + mahaphol 
                self.matha_jupiter = matha
                self.pholPK_jupiter  = pholPK
                self.ptma_jupiter = ptma
                self.puchaPT_jupiter = puchaPT
                self.khotiPT_jupiter = khotiPT
                self.MTpucha_jupiter = MTpucha
                self.MTKhoti_jupiter = MTKhoti
                self.khotiphol_jupiter = khotiphol
                self.MTcheta_jupiter = MTcheta
                self.MTphol_jupiter = MTphol
                self.MTS_jupiter = MTS
                self.pholMT_jupiter = pholMT
                self.ptnd_jupiter = ptnd
                self.puchaTY_jupiter = puchaTY
                self.khotiTY_jupiter = khotiTY
                self.SGPucha_jupiter = SGPucha
                self.SGKhoti_jupiter = SGKhoti
                self.SGphol_jupiter = SGphol
                self.p_jupiter = p
                self.sp_jupiter = sp
                self.SGcheta_jupiter = SGcheta
                self.mahaphol_jupiter = mahaphol                        
                        
            elif plannet == 'saturn':
                if (ptnd ==1) or (ptnd ==2):
                    if (MTS - mahaphol)>=0:
                        SSaturn = MTS - mahaphol
                    elif (MTS - mahaphol)<0:
                        SSaturn =  MTS - mahaphol + 21600
                        print('SSaturn =',MTS - mahaphol,'adjust to',SSaturn)          

                elif (ptnd ==3) or (ptnd ==4):
                    if (MTS + mahaphol)>=21600:
                        SSaturn = MTS + mahaphol - 21600
                        print('SSaturn =',MTS + mahaphol,'adjust to',SSaturn)
                    elif(MTS + mahaphol)<21600:
                        SSaturn = MTS + mahaphol
                        
                self.matha_saturn = matha
                self.pholPK_saturn  = pholPK
                self.ptma_saturn = ptma
                self.puchaPT_saturn = puchaPT
                self.khotiPT_saturn = khotiPT
                self.MTpucha_saturn = MTpucha
                self.MTKhoti_saturn = MTKhoti
                self.khotiphol_saturn = khotiphol
                self.MTcheta_saturn = MTcheta
                self.MTphol_saturn = MTphol
                self.MTS_saturn = MTS
                self.pholMT_saturn = pholMT
                self.ptnd_saturn = ptnd
                self.puchaTY_saturn = puchaTY
                self.khotiTY_saturn = khotiTY
                self.SGPucha_saturn = SGPucha
                self.SGKhoti_saturn = SGKhoti
                self.SGphol_saturn = SGphol
                self.p_saturn = p
                self.sp_saturn = sp
                self.SGcheta_saturn = SGcheta
                self.mahaphol_saturn = mahaphol  
                
            elif plannet == 'uranus':
                if (ptnd ==1) or (ptnd ==2):
                    if (MTS - mahaphol)>=0:
                        SUranus = MTS - mahaphol
                    elif (MTS - mahaphol)<0:
                        SUranus =  MTS - mahaphol + 21600
                        print('SUranus =',MTS - mahaphol,'adjust to',SUranus)          

                elif (ptnd ==3) or (ptnd ==4):
                    if (MTS + mahaphol)>=21600:
                        SUranus = MTS + mahaphol - 21600
                        print('SUranus =',MTS + mahaphol,'adjust to',SUranus)
                    elif(MTS + mahaphol)<21600:
                        SUranus = MTS + mahaphol 
                self.matha_uranus = matha
                self.pholPK_uranus  = pholPK
                self.ptma_uranus = ptma
                self.puchaPT_uranus = puchaPT
                self.khotiPT_uranus = khotiPT
                self.MTpucha_uranus = MTpucha
                self.MTKhoti_uranus = MTKhoti
                self.khotiphol_uranus = khotiphol
                self.MTcheta_uranus = MTcheta
                self.MTphol_uranus = MTphol
                self.MTS_uranus = MTS
                self.pholMT_uranus = pholMT
                self.ptnd_uranus = ptnd
                self.puchaTY_uranus = puchaTY
                self.khotiTY_uranus = khotiTY
                self.SGPucha_uranus = SGPucha
                self.SGKhoti_uranus = SGKhoti
                self.SGphol_uranus = SGphol
                self.p_uranus = p
                self.sp_uranus = sp
                self.SGcheta_uranus = SGcheta
                self.mahaphol_uranus = mahaphol    



        

#         print('uv =',uv)
#         print('pholGA =',pholGA)
#         print('khan =',khan)
#         print('Smoon =',Smoon)

#         print('au_ =',au_)
#         print('mtu =',mtu)
#         print('uv =',uv)
#         print('Smoon =',Smoon)

        #TS Parameter (yearly parameter) 
        self.dt = dt  
        self.dtny = dtny 
        self.dny = dny 
        self.ahra = ahra 
        self.jultin = jultin 
        self.kj = kj 
        self.aw = aw 
        self.masG = masG 
        self.dT = dT
        self.au = au 
        self.van = van 
        
        #Given Datetime parameter
        self.stin = stin 
        self.sec = sec 
        self.ahra_ = ahra_ 
        self.kj_ = kj_ 
        self.aw_ = aw_ 
        self.masG_ = masG_ 
        self.dT_ = dT_
        self.au_ = au_ 
        self.van_ = van_
    
        
        ##locations in zodiac (minutes maximum = 21600)         
        self.sun = Ssun
        self.moon = Smoon
        self.rahu = Srahu
        self.geth = Sgeth
        self.mars = Smars
        self.mercury = SMercury
        self.venus = SVenus
        self.jupiter = Jupiter
        self.saturn = SSaturn
        self.uranus = SUranus

# %%
#startdate = datetime(1969,4,15,16,0)
#startdate = datetime(2019,4,16,8,0)
startdate = datetime(1919,1,1,0,0)
df = pd.DataFrame()
#count = 108000
count = 75000
#count = 1000
#select timeframe
interval = 'day'
#interval = 'minutes'
start = datetime.now()

for i in range(0,count):
    
    if interval=='minutes':
        diff = timedelta(minutes=i)
    elif interval=='day':
        diff = timedelta(days=i)
        
    dt = startdate+diff
    h = hora(dt)    
    data = {
        #'dt': dt,
        #'dtny': h.dtny,        
        'dt': str(dt.day)+'/'+str(dt.month)+'/'+str(dt.year+543)+' '+str(dt.hour)+':'+str(dt.minute),
        'dtny': str(h.dtny.day)+'/'+str(h.dtny.month)+'/'+str(h.dtny.year+543)+' '+str(h.dtny.hour)+':'+str(h.dtny.minute)+':'+str(h.dtny.second),
        
        #TS parameter
        'ahra' : h.ahra, 'jultin': h.jultin, 'kj' : h.kj, 'aw' : h.aw, 'masG' : h.masG, 'dT' : h.dT, 
        'au' : h.au, 'van' : h.van,
        
        #GivenDT parameter
        'stin' : h.stin, 'sec': h.sec, 'ahra_' : h.ahra_, 'kj_' : h.kj_, 'aw_' : h.aw_, 
        'masG_' : h.masG_, 'dT_' : h.dT_, 'au_' : h.au_, 'van_' : h.van_,
        
        #parameter for sun and moon calculation  
        #Sun
        'mathasun' : h.mathasun, 'pholsun': h.pholsun, 'SPholGA' : h.SPholGA, 'SKhan': h.SKhan, 'SPushlip' : h.SPushlip,'SJyaGA' : h.SJyaGA, 'ravipphol': h.ravipphol,        
        #Moon
        'mtu' : h.mtu, 'mathamoon': h.mathamoon, 'uv' : h.uv, 'MPholGA' : h.MPholGA, 'MKhan': h.MKhan, 'MPushlip' : h.MPushlip,'MJyaGA' : h.MJyaGA, 'chandraphol': h.chandraphol,
        #rahu
       'matharavi' : h.matharavi, 'srb': h.srb, 'manut' : h.manut, 'a': h.a, 'b' : h.b, 'pmt' : h.pmt,
        #geht
        'pholgt' : h.pholgt,
          
        #Mercury
        'matha_mecury' : h.matha_mecury, 'pholPK_mecury': h.pholPK_mecury, 'ptma_mecury' : h.ptma_mecury, 
        'puchaPT_mecury' : h.puchaPT_mecury, 'khotiPT_mecury': h.khotiPT_mecury, 'MTpucha_mecury' : h.MTpucha_mecury, 
        'MTKhoti_mecury' : h.MTKhoti_mecury, 'khotiphol_mecury': h.khotiphol_mecury,
        'MTcheta_mecury' : h.MTcheta_mecury, 'MTphol_mecury': h.MTphol_mecury, 'MTS_mecury' : h.MTS_mecury,      
        'pholMT_mecury' : h.pholMT_mecury, 'ptnd_mecury': h.ptnd_mecury, 'puchaTY_mecury' : h.puchaTY_mecury, 
        'khotiTY_mecury' : h.khotiTY_mecury, 'SGPucha_mecury': h.SGPucha_mecury, 'SGKhoti_mecury': h.SGKhoti_mecury,
        'SGphol_mecury' : h.SGphol_mecury, 'p_mecury': h.p_mecury, 'sp_mecury': h.sp_mecury, 'SGcheta_mecury': h.SGcheta_mecury,
        'mahaphol_mecury' : h.mahaphol_mecury,
        
        #Venus
        'matha_venus' : h.matha_venus, 'pholPK_venus': h.pholPK_venus, 'ptma_venus' : h.ptma_venus, 
        'puchaPT_venus' : h.puchaPT_venus, 'khotiPT_venus': h.khotiPT_venus, 'MTpucha_venus' : h.MTpucha_venus, 
        'MTKhoti_venus' : h.MTKhoti_venus, 'khotiphol_venus': h.khotiphol_venus,
        'MTcheta_venus' : h.MTcheta_venus, 'MTphol_venus': h.MTphol_venus, 'MTS_venus' : h.MTS_venus,      
        'pholMT_venus' : h.pholMT_venus, 'ptnd_venus': h.ptnd_venus, 'puchaTY_venus' : h.puchaTY_venus, 
        'khotiTY_venus' : h.khotiTY_venus, 'SGPucha_venus': h.SGPucha_venus, 'SGKhoti_venus': h.SGKhoti_venus,
        'SGphol_venus' : h.SGphol_venus, 'p_venus': h.p_venus, 'sp_venus': h.sp_venus, 'SGcheta_venus': h.SGcheta_venus,
        'mahaphol_venus' : h.mahaphol_venus,  
        
        #mars
        'matha_mars' : h.matha_mars, 'pholPK_mars': h.pholPK_mars, 'ptma_mars' : h.ptma_mars, 
        'puchaPT_mars' : h.puchaPT_mars, 'khotiPT_mars': h.khotiPT_mars, 'MTpucha_mars' : h.MTpucha_mars, 
        'MTKhoti_mars' : h.MTKhoti_mars, 'khotiphol_mars': h.khotiphol_mars,
        'MTcheta_mars' : h.MTcheta_mars, 'MTphol_mars': h.MTphol_mars, 'MTS_mars' : h.MTS_mars,      
        'pholMT_mars' : h.pholMT_mars, 'ptnd_mars': h.ptnd_mars, 'puchaTY_mars' : h.puchaTY_mars, 
        'khotiTY_mars' : h.khotiTY_mars, 'SGPucha_mars': h.SGPucha_mars, 'SGKhoti_mars': h.SGKhoti_mars,
        'SGphol_mars' : h.SGphol_mars, 'p_mars': h.p_mars, 'sp_mars': h.sp_mars, 'SGcheta_mars': h.SGcheta_mars,
        'mahaphol_mars' : h.mahaphol_mars,          

        #jupiter
        'matha_jupiter' : h.matha_jupiter, 'pholPK_jupiter': h.pholPK_jupiter, 'ptma_jupiter' : h.ptma_jupiter, 
        'puchaPT_jupiter' : h.puchaPT_jupiter, 'khotiPT_jupiter': h.khotiPT_jupiter, 'MTpucha_jupiter' : h.MTpucha_jupiter, 
        'MTKhoti_jupiter' : h.MTKhoti_jupiter, 'khotiphol_jupiter': h.khotiphol_jupiter,
        'MTcheta_jupiter' : h.MTcheta_jupiter, 'MTphol_jupiter': h.MTphol_jupiter, 'MTS_jupiter' : h.MTS_jupiter,      
        'pholMT_jupiter' : h.pholMT_jupiter, 'ptnd_jupiter': h.ptnd_jupiter, 'puchaTY_jupiter' : h.puchaTY_jupiter, 
        'khotiTY_jupiter' : h.khotiTY_jupiter, 'SGPucha_jupiter': h.SGPucha_jupiter, 'SGKhoti_jupiter': h.SGKhoti_jupiter,
        'SGphol_jupiter' : h.SGphol_jupiter, 'p_jupiter': h.p_jupiter, 'sp_jupiter': h.sp_jupiter, 'SGcheta_jupiter': h.SGcheta_jupiter,
        'mahaphol_jupiter' : h.mahaphol_jupiter,  
        
        #saturn
        'matha_saturn' : h.matha_saturn, 'pholPK_saturn': h.pholPK_saturn, 'ptma_saturn' : h.ptma_saturn, 
        'puchaPT_saturn' : h.puchaPT_saturn, 'khotiPT_saturn': h.khotiPT_saturn, 'MTpucha_saturn' : h.MTpucha_saturn, 
        'MTKhoti_saturn' : h.MTKhoti_saturn, 'khotiphol_saturn': h.khotiphol_saturn,
        'MTcheta_saturn' : h.MTcheta_saturn, 'MTphol_saturn': h.MTphol_saturn, 'MTS_saturn' : h.MTS_saturn,      
        'pholMT_saturn' : h.pholMT_saturn, 'ptnd_saturn': h.ptnd_saturn, 'puchaTY_saturn' : h.puchaTY_saturn, 
        'khotiTY_saturn' : h.khotiTY_saturn, 'SGPucha_saturn': h.SGPucha_saturn, 'SGKhoti_saturn': h.SGKhoti_saturn,
        'SGphol_saturn' : h.SGphol_saturn, 'p_saturn': h.p_saturn, 'sp_saturn': h.sp_saturn, 'SGcheta_saturn': h.SGcheta_saturn,
        'mahaphol_saturn' : h.mahaphol_saturn, 
        
        #uranus
        'matha_uranus' : h.matha_uranus, 'pholPK_uranus': h.pholPK_uranus, 'ptma_uranus' : h.ptma_uranus, 
        'puchaPT_uranus' : h.puchaPT_uranus, 'khotiPT_uranus': h.khotiPT_uranus, 'MTpucha_uranus' : h.MTpucha_uranus, 
        'MTKhoti_uranus' : h.MTKhoti_uranus, 'khotiphol_uranus': h.khotiphol_uranus,
        'MTcheta_uranus' : h.MTcheta_uranus, 'MTphol_uranus': h.MTphol_uranus, 'MTS_uranus' : h.MTS_uranus,      
        'pholMT_uranus' : h.pholMT_uranus, 'ptnd_uranus': h.ptnd_uranus, 'puchaTY_uranus' : h.puchaTY_uranus, 
        'khotiTY_uranus' : h.khotiTY_uranus, 'SGPucha_uranus': h.SGPucha_uranus, 'SGKhoti_uranus': h.SGKhoti_uranus,
        'SGphol_uranus' : h.SGphol_uranus, 'p_uranus': h.p_uranus, 'sp_uranus': h.sp_uranus, 'SGcheta_uranus': h.SGcheta_uranus,
        'mahaphol_uranus' : h.mahaphol_uranus, 
        
        #Constellation 
        'sun' : h.sun, 'moon': h.moon, 'rahu' : h.rahu, 'geth' : h.geth, 'mars' : h.mars, 'mercury' : h.mercury, 'venus' : h.venus, 'jupiter' : h.jupiter, 'saturn' : h.saturn, 'uranus' : h.uranus
              
    }


    print(dt.day,dt.month,dt.year,dt.hour,':',dt.minute)
    #df = pd.DataFrame(data)
    df = df.append(data , ignore_index=True)

finish = datetime.now()
duration = finish-start

ListofPlannets = ['sun','moon','rahu','geth','mars','mercury','venus','jupiter','saturn','uranus'] 
for planet in ListofPlannets:
    zodiac = planet+"_Z"
    degree = planet+"_D"
    minute = planet+"_M"
    diff = planet+"_diff"
    df[zodiac] =  df[planet]//1800 
    df[degree] =  (df[planet]%1800)//60 
    df[minute] =  (df[planet]%1800)%60    
    df[diff] = df[planet]-df[planet].shift(1)

print(duration)
#df['sun_delta'] = df['sun'] 


#df.to_csv(r"C:\Users\JACK\Desktop\S_out.csv")

#df.dtypes

# data = {
#     'dt': [startdate],
#     'sun' : [h.sun],
#     'moon': [h.moon],
#     'rahu' : [h.rahu],
#     'geth' : [h.geth],
#     'mars' : [h.mars],
#     'mercury' : [h.mercury],
#     'venus' : [h.venus],
#     'jupiter' : [h.jupiter],
#     'saturn' : [h.saturn],
#     'uranus' : [h.uranus]
# }
#startdate = datetime(2019,4,16,0,0) mathasun-
# Out:
# 1 1 1919 0 : 0
# 2 1 1919 0 : 0
# 3 1 1919 0 : 0
# 4 1 1919 0 : 0
# 5 1 1919 0 : 0
# 6 1 1919 0 : 0
# 7 1 1919 0 : 0
# 8 1 1919 0 : 0
# 9 1 1919 0 : 0
# 10 1 1919 0 : 0
# 11 1 1919 0 : 0
# 12 1 1919 0 : 0
# 13 1 1919 0 : 0
# 14 1 1919 0 : 0
# 15 1 1919 0 : 0
# 16 1 1919 0 : 0
# 17 1 1919 0 : 0
# 18 1 1919 0 : 0
# 19 1 1919 0 : 0
# 20 1 1919 0 : 0
# 21 1 1919 0 : 0
# 22 1 1919 0 : 0
# 23 1 1919 0 : 0
# 24 1 1919 0 : 0
# 25 1 1919 0 : 0
# 26 1 1919 0 : 0
# 27 1 1919 0 : 0
# 28 1 1919 0 : 0
# 29 1 1919 0 : 0
# 30 1 1919 0 : 0
# 31 1 1919 0 : 0
# 1 2 1919 0 : 0
# 2 2 1919 0 : 0
# 3 2 1919 0 : 0
# 4 2 1919 0 : 0
# 5 2 1919 0 : 0
# 6 2 1919 0 : 0
# 7 2 1919 0 : 0
# 8 2 1919 0 : 0
# 9 2 1919 0 : 0
# 10 2 1919 0 : 0
# 11 2 1919 0 : 0
# 12 2 1919 0 : 0
# 13 2 1919 0 : 0
# 14 2 1919 0 : 0
# 15 2 1919 0 : 0
# 16 2 1919 0 : 0
# 17 2 1919 0 : 0
# 18 2 1919 0 : 0
# 19 2 1919 0 : 0
# 20 2 1919 0 : 0
# 21 2 1919 0 : 0
# 22 2 1919 0 : 0
# 23 2 1919 0 : 0
# 24 2 1919 0 : 0
# 25 2 1919 0 : 0
# 26 2 1919 0 : 0
# 27 2 1919 0 : 0
# 28 2 1919 0 : 0
# 1 3 1919 0 : 0
# 2 3 1919 0 : 0
# 3 3 1919 0 : 0
# 4 3 1919 0 : 0
# 5 3 1919 0 : 0
# 6 3 1919 0 : 0
# 7 3 1919 0 : 0
# 8 3 1919 0 : 0
# 9 3 1919 0 : 0
# 10 3 1919 0 : 0
# 11 3 1919 0 : 0
# 12 3 1919 0 : 0
# 13 3 1919 0 : 0
# 14 3 1919 0 : 0
# 15 3 1919 0 : 0
# 16 3 1919 0 : 0
# 17 3 1919 0 : 0
# 18 3 1919 0 : 0
# 19 3 1919 0 : 0
# 20 3 1919 0 : 0
# SVenus = 21664 adjust to 64
# 21 3 1919 0 : 0
# SVenus = 21737 adjust to 137
# 22 3 1919 0 : 0
# SVenus = 21806 adjust to 206
# 23 3 1919 0 : 0
# SVenus = 21878 adjust to 278
# 24 3 1919 0 : 0
# SVenus = 21950 adjust to 350
# 25 3 1919 0 : 0
# SVenus = 22021 adjust to 421
# MTS = 21632 adjust to 32
# Smars = -505 adjust to 21095
# 26 3 1919 0 : 0
# SVenus = 22092 adjust to 492
# MTS = 21666 adjust to 66
# Smars = -460 adjust to 21140
# 27 3 1919 0 : 0
# SVenus = 22163 adjust to 563
# MTS = 21702 adjust to 102
# Smars = -414 adjust to 21186
# 28 3 1919 0 : 0
# SVenus = 22235 adjust to 635
# MTS = 21737 adjust to 137
# Smars = -369 adjust to 21231
# 29 3 1919 0 : 0
# SVenus = 22307 adjust to 707
# MTS = 21773 adjust to 173
# Smars = -324 adjust to 21276
# 30 3 1919 0 : 0
# SVenus = 22380 adjust to 780
# MTS = 21810 adjust to 210
# Smars = -277 adjust to 21323
# 31 3 1919 0 : 0
# SVenus = 22452 adjust to 852
# MTS = 21845 adjust to 245
# Smars = -232 adjust to 21368
# 1 4 1919 0 : 0
# SVenus = 22522 adjust to 922
# MTS = 21881 adjust to 281
# Smars = -187 adjust to 21413
# 2 4 1919 0 : 0
# SVenus = 22596 adjust to 996
# MTS = 21916 adjust to 316
# Smars = -142 adjust to 21458
# 3 4 1919 0 : 0
# SVenus = 22669 adjust to 1069
# MTS = 21951 adjust to 351
# Smars = -97 adjust to 21503
# 4 4 1919 0 : 0
# SVenus = 22742 adjust to 1142
# MTS = 21988 adjust to 388
# Smars = -50 adjust to 21550
# 5 4 1919 0 : 0
# SVenus = 22814 adjust to 1214
# MTS = 22023 adjust to 423
# Smars = -5 adjust to 21595
# 6 4 1919 0 : 0
# SVenus = 22886 adjust to 1286
# MTS = 22059 adjust to 459
# 7 4 1919 0 : 0
# SVenus = 22958 adjust to 1358
# MTS = 22094 adjust to 494
# 8 4 1919 0 : 0
# SVenus = 23030 adjust to 1430
# MTS = 22130 adjust to 530
# 9 4 1919 0 : 0
# SVenus = 23104 adjust to 1504
# 10 4 1919 0 : 0
# SVenus = 23177 adjust to 1577
# 11 4 1919 0 : 0
# SVenus = 23249 adjust to 1649
# 12 4 1919 0 : 0
# SVenus = 23321 adjust to 1721
# 13 4 1919 0 : 0
# SVenus = 23395 adjust to 1795
# 14 4 1919 0 : 0
# MTS = 21608 adjust to 8
# 15 4 1919 0 : 0
# MTS = 21664 adjust to 64
# SVenus = -1270 adjust to 20330
# 16 4 1919 0 : 0
# MTS = -150 adjust to 21450
# 17 4 1919 0 : 0
# MTS = -86 adjust to 21514
# 18 4 1919 0 : 0
# MTS = -24 adjust to 21576
# 19 4 1919 0 : 0
# Smercury = -1191 adjust to 20409
# 20 4 1919 0 : 0
# Smercury = -1163 adjust to 20437
# 21 4 1919 0 : 0
# Smercury = -1132 adjust to 20468
# 22 4 1919 0 : 0
# Smercury = -1099 adjust to 20501
# 23 4 1919 0 : 0
# 12 2 1920 0 : 0
# 13 2 1920 0 : 0
# 14 2 1920 0 : 0
# 15 2 1920 0 : 0
# 16 2 1920 0 : 0
# 17 2 1920 0 : 0
# 18 2 1920 0 : 0
# 19 2 1920 0 : 0
# 20 2 1920 0 : 0
# 21 2 1920 0 : 0
# 22 2 1920 0 : 0
# 23 2 1920 0 : 0
# 24 2 1920 0 : 0
# 25 2 1920 0 : 0
# 26 2 1920 0 : 0
# 27 2 1920 0 : 0
# 28 2 1920 0 : 0
# 29 2 1920 0 : 0
# 1 3 1920 0 : 0
# 2 3 1920 0 : 0
# 3 3 1920 0 : 0
# 4 3 1920 0 : 0
# 5 3 1920 0 : 0
# 6 3 1920 0 : 0
# 7 3 1920 0 : 0
# 8 3 1920 0 : 0
# 9 3 1920 0 : 0
# 10 3 1920 0 : 0
# 11 3 1920 0 : 0
# 12 3 1920 0 : 0
# 13 3 1920 0 : 0
# 14 3 1920 0 : 0
# 15 3 1920 0 : 0
# 16 3 1920 0 : 0
# 17 3 1920 0 : 0
# 18 3 1920 0 : 0
# 19 3 1920 0 : 0
# 20 3 1920 0 : 0
# 21 3 1920 0 : 0
# 22 3 1920 0 : 0
# 23 3 1920 0 : 0
# 24 3 1920 0 : 0
# 25 3 1920 0 : 0
# 26 3 1920 0 : 0
# 27 3 1920 0 : 0
# 28 3 1920 0 : 0
# 29 3 1920 0 : 0
# 30 3 1920 0 : 0
# 31 3 1920 0 : 0
# 1 4 1920 0 : 0
# 2 4 1920 0 : 0
# 3 4 1920 0 : 0
# 4 4 1920 0 : 0
# 5 4 1920 0 : 0
# 6 4 1920 0 : 0
# 7 4 1920 0 : 0
# 8 4 1920 0 : 0
# 9 4 1920 0 : 0
# 10 4 1920 0 : 0
# 11 4 1920 0 : 0
# 12 4 1920 0 : 0
# 13 4 1920 0 : 0
# 14 4 1920 0 : 0
# MTS = 21649 adjust to 49
# SVenus = -1288 adjust to 20312
# 15 4 1920 0 : 0
# MTS = -168 adjust to 21432
# SVenus = -1217 adjust to 20383
# 16 4 1920 0 : 0
# MTS = -104 adjust to 21496
# SVenus = -1142 adjust to 20458
# 17 4 1920 0 : 0
# MTS = -42 adjust to 21558
# SVenus = -1067 adjust to 20533
# 18 4 1920 0 : 0
# Smercury = -1057 adjust to 20543
# SVenus = -992 adjust to 20608
# 19 4 1920 0 : 0
# Smercury = -965 adjust to 20635
# SVenus = -918 adjust to 20682
# 20 4 1920 0 : 0
# Smercury = -871 adjust to 20729
# SVenus = -843 adjust to 20757
# 21 4 1920 0 : 0
# Smercury = -780 adjust to 20820
# SVenus = -768 adjust to 20832
# 22 4 1920 0 : 0
# Smercury = -690 adjust to 20910
# SVenus = -694 adjust to 20906
# 23 4 1920 0 : 0
# Smercury = -600 adjust to 21000
# SVenus = -621 adjust to 20979
# 24 4 1920 0 : 0
# Smercury = -492 adjust to 21108
# SVenus = -548 adjust to 21052
# 25 4 1920 0 : 0
# Smercury = -380 adjust to 21220
# SVenus = -472 adjust to 21128
# 26 4 1920 0 : 0
# Smercury = -271 adjust to 21329
# SVenus = -397 adjust to 21203
# 27 4 1920 0 : 0
# Smercury = -162 adjust to 21438
# SVenus = -325 adjust to 21275
# 28 4 1920 0 : 0
# Smercury = -53 adjust to 21547
# SVenus = -250 adjust to 21350
# 29 4 1920 0 : 0
# SVenus = -178 adjust to 21422
# 30 4 1920 0 : 0
# SVenus = -102 adjust to 21498
# 1 5 1920 0 : 0
# SVenus = -29 adjust to 21571
# 2 5 1920 0 : 0
# 3 5 1920 0 : 0
# 4 5 1920 0 : 0
# 5 5 1920 0 : 0
# 6 5 1920 0 : 0
# 7 5 1920 0 : 0
# 8 5 1920 0 : 0
# 9 5 1920 0 : 0
# 10 5 1920 0 : 0
# 11 5 1920 0 : 0
# 12 5 1920 0 : 0
# 13 5 1920 0 : 0
# 14 5 1920 0 : 0
# 15 5 1920 0 : 0
# 16 5 1920 0 : 0
# 17 5 1920 0 : 0
# 18 5 1920 0 : 0
# 19 5 1920 0 : 0
# 20 5 1920 0 : 0
# 21 5 1920 0 : 0
# 22 5 1920 0 : 0
# 23 5 1920 0 : 0
# 24 5 1920 0 : 0
# 25 5 1920 0 : 0
# 26 5 1920 0 : 0
# 27 5 1920 0 : 0
# 28 5 1920 0 : 0
# 29 5 1920 0 : 0
# 30 5 1920 0 : 0
# 31 5 1920 0 : 0
# 1 6 1920 0 : 0
# 2 6 1920 0 : 0
# 3 6 1920 0 : 0
# 4 6 1920 0 : 0
# 5 6 1920 0 : 0
# 6 6 1920 0 : 0
# 7 6 1920 0 : 0
# 8 6 1920 0 : 0
# 9 6 1920 0 : 0
# 10 6 1920 0 : 0
# 11 6 1920 0 : 0
# 12 6 1920 0 : 0
# 13 6 1920 0 : 0
# 14 6 1920 0 : 0
# 15 6 1920 0 : 0
# 16 6 1920 0 : 0
# 17 6 1920 0 : 0
# 18 6 1920 0 : 0
# 19 6 1920 0 : 0
# 20 6 1920 0 : 0
# 21 6 1920 0 : 0
# 22 6 1920 0 : 0
# 23 6 1920 0 : 0
# 24 6 1920 0 : 0
# 25 6 1920 0 : 0
# 26 6 1920 0 : 0
# 27 6 1920 0 : 0
# 28 6 1920 0 : 0
# 29 6 1920 0 : 0
# 30 6 1920 0 : 0
# 1 7 1920 0 : 0
# 2 7 1920 0 : 0
# 3 7 1920 0 : 0
# 4 7 1920 0 : 0
# 5 7 1920 0 : 0
# 6 7 1920 0 : 0
# 7 7 1920 0 : 0
# 8 7 1920 0 : 0
# 9 7 1920 0 : 0
# 10 7 1920 0 : 0
# 11 7 1920 0 : 0
# 12 7 1920 0 : 0
# 13 7 1920 0 : 0
# 14 7 1920 0 : 0
# 15 7 1920 0 : 0
# 16 7 1920 0 : 0
# 17 7 1920 0 : 0
# 18 7 1920 0 : 0
# 19 7 1920 0 : 0
# 20 7 1920 0 : 0
# 21 7 1920 0 : 0
# 22 7 1920 0 : 0
# 23 7 1920 0 : 0
# 24 7 1920 0 : 0
# 25 7 1920 0 : 0
# 26 7 1920 0 : 0
# 27 7 1920 0 : 0
# 28 7 1920 0 : 0
# 29 7 1920 0 : 0
# Smars = -1366 adjust to 20234
# 13 2 1921 0 : 0
# MTS = 21773 adjust to 173
# Smars = -1324 adjust to 20276
# 14 2 1921 0 : 0
# MTS = 21809 adjust to 209
# Smars = -1281 adjust to 20319
# 15 2 1921 0 : 0
# MTS = 21845 adjust to 245
# Smars = -1236 adjust to 20364
# 16 2 1921 0 : 0
# MTS = 21881 adjust to 281
# Smars = -1193 adjust to 20407
# 17 2 1921 0 : 0
# MTS = 21916 adjust to 316
# Smars = -1150 adjust to 20450
# 18 2 1921 0 : 0
# MTS = 21953 adjust to 353
# Smars = -1106 adjust to 20494
# 19 2 1921 0 : 0
# MTS = 21988 adjust to 388
# Smars = -1064 adjust to 20536
# 20 2 1921 0 : 0
# MTS = 22023 adjust to 423
# Smars = -1021 adjust to 20579
# 21 2 1921 0 : 0
# MTS = 22059 adjust to 459
# Smars = -977 adjust to 20623
# 22 2 1921 0 : 0
# MTS = 22094 adjust to 494
# Smars = -929 adjust to 20671
# 23 2 1921 0 : 0
# MTS = 22130 adjust to 530
# Smars = -884 adjust to 20716
# 24 2 1921 0 : 0
# Smars = -837 adjust to 20763
# 25 2 1921 0 : 0
# Smars = -791 adjust to 20809
# 26 2 1921 0 : 0
# SVenus = 21616 adjust to 16
# Smars = -745 adjust to 20855
# 27 2 1921 0 : 0
# SVenus = 21686 adjust to 86
# Smars = -698 adjust to 20902
# 28 2 1921 0 : 0
# SVenus = 21741 adjust to 141
# Smars = -653 adjust to 20947
# 1 3 1921 0 : 0
# SVenus = 21802 adjust to 202
# Smars = -606 adjust to 20994
# 2 3 1921 0 : 0
# SVenus = 21865 adjust to 265
# Smars = -561 adjust to 21039
# 3 3 1921 0 : 0
# SVenus = 21919 adjust to 319
# Smars = -513 adjust to 21087
# 4 3 1921 0 : 0
# SVenus = 21992 adjust to 392
# Smars = -467 adjust to 21133
# 5 3 1921 0 : 0
# SVenus = 22054 adjust to 454
# Smars = -422 adjust to 21178
# 6 3 1921 0 : 0
# SVenus = 22107 adjust to 507
# Smars = -376 adjust to 21224
# 7 3 1921 0 : 0
# SVenus = 22169 adjust to 569
# Smars = -331 adjust to 21269
# 8 3 1921 0 : 0
# SVenus = 22238 adjust to 638
# Smars = -284 adjust to 21316
# 9 3 1921 0 : 0
# SVenus = 22289 adjust to 689
# Smars = -239 adjust to 21361
# 10 3 1921 0 : 0
# SVenus = 22352 adjust to 752
# Smars = -196 adjust to 21404
# 11 3 1921 0 : 0
# SVenus = 22413 adjust to 813
# Smars = -151 adjust to 21449
# 12 3 1921 0 : 0
# SVenus = 22482 adjust to 882
# Smars = -107 adjust to 21493
# 13 3 1921 0 : 0
# SVenus = 22518 adjust to 918
# Smars = -62 adjust to 21538
# 14 3 1921 0 : 0
# SVenus = 22545 adjust to 945
# Smars = -20 adjust to 21580
# 15 3 1921 0 : 0
# SVenus = 22568 adjust to 968
# 16 3 1921 0 : 0
# SVenus = 22593 adjust to 993
# 17 3 1921 0 : 0
# SVenus = 22627 adjust to 1027
# 18 3 1921 0 : 0
# SVenus = 22647 adjust to 1047
# 19 3 1921 0 : 0
# SVenus = 22671 adjust to 1071
# 20 3 1921 0 : 0
# SVenus = 22695 adjust to 1095
# 21 3 1921 0 : 0
# SVenus = 22721 adjust to 1121
# 22 3 1921 0 : 0
# SVenus = 22743 adjust to 1143
# 23 3 1921 0 : 0
# SVenus = 22765 adjust to 1165
# 24 3 1921 0 : 0
# SVenus = 22778 adjust to 1178
# 25 3 1921 0 : 0
# SVenus = 22808 adjust to 1208
# 26 3 1921 0 : 0
# SVenus = 22822 adjust to 1222
# 27 3 1921 0 : 0
# SVenus = 22841 adjust to 1241
# 28 3 1921 0 : 0
# SVenus = 22856 adjust to 1256
# 29 3 1921 0 : 0
# SVenus = 22877 adjust to 1277
# 30 3 1921 0 : 0
# SVenus = 22892 adjust to 1292
# 31 3 1921 0 : 0
# SVenus = 22905 adjust to 1305
# 1 4 1921 0 : 0
# SVenus = 22914 adjust to 1314
# 2 4 1921 0 : 0
# SVenus = 22934 adjust to 1334
# 3 4 1921 0 : 0
# SVenus = 22947 adjust to 1347
# 4 4 1921 0 : 0
# SVenus = 22950 adjust to 1350
# 5 4 1921 0 : 0
# SVenus = 22961 adjust to 1361
# 6 4 1921 0 : 0
# SVenus = 22975 adjust to 1375
# 7 4 1921 0 : 0
# SVenus = 22973 adjust to 1373
# 8 4 1921 0 : 0
# SVenus = 22976 adjust to 1376
# 9 4 1921 0 : 0
# SVenus = 22976 adjust to 1376
# 10 4 1921 0 : 0
# SVenus = 22986 adjust to 1386
# 11 4 1921 0 : 0
# SVenus = 22980 adjust to 1380
# 12 4 1921 0 : 0
# SVenus = 22976 adjust to 1376
# 13 4 1921 0 : 0
# SVenus = 22973 adjust to 1373
# 14 4 1921 0 : 0
# MTS = 21634 adjust to 34
# 15 4 1921 0 : 0
# MTS = -183 adjust to 21417
# 16 4 1921 0 : 0
# MTS = -120 adjust to 21480
# 17 4 1921 0 : 0
# MTS = -58 adjust to 21542
# 18 4 1921 0 : 0
# Smercury = -351 adjust to 21249
# 19 4 1921 0 : 0
# Smercury = -236 adjust to 21364
# 20 4 1921 0 : 0
# Smercury = -123 adjust to 21477
# 21 4 1921 0 : 0
# Smercury = -10 adjust to 21590
# 22 4 1921 0 : 0
# 23 4 1921 0 : 0
# 24 4 1921 0 : 0
# 25 4 1921 0 : 0
# 26 4 1921 0 : 0
# 27 4 1921 0 : 0
# 28 4 1921 0 : 0
# 29 4 1921 0 : 0
# 30 4 1921 0 : 0
# 1 5 1921 0 : 0
# 2 5 1921 0 : 0
# 3 5 1921 0 : 0
# 4 5 1921 0 : 0
# 5 5 1921 0 : 0
# 6 5 1921 0 : 0
# 7 5 1921 0 : 0
# 8 5 1921 0 : 0
# 9 5 1921 0 : 0
# 10 5 1921 0 : 0
# 11 5 1921 0 : 0
# 12 5 1921 0 : 0
# 13 5 1921 0 : 0
# 14 5 1921 0 : 0
# 15 5 1921 0 : 0
# 16 5 1921 0 : 0
# 17 5 1921 0 : 0
# 18 5 1921 0 : 0
# 19 5 1921 0 : 0
# 20 5 1921 0 : 0
# 26 3 1922 0 : 0
# 27 3 1922 0 : 0
# 28 3 1922 0 : 0
# 29 3 1922 0 : 0
# 30 3 1922 0 : 0
# 31 3 1922 0 : 0
# 1 4 1922 0 : 0
# 2 4 1922 0 : 0
# SVenus = 21605 adjust to 5
# 3 4 1922 0 : 0
# SVenus = 21678 adjust to 78
# 4 4 1922 0 : 0
# SVenus = 21754 adjust to 154
# 5 4 1922 0 : 0
# SVenus = 21829 adjust to 229
# 6 4 1922 0 : 0
# SVenus = 21903 adjust to 303
# 7 4 1922 0 : 0
# SVenus = 21974 adjust to 374
# 8 4 1922 0 : 0
# SVenus = 22047 adjust to 447
# 9 4 1922 0 : 0
# SVenus = 22120 adjust to 520
# 10 4 1922 0 : 0
# SVenus = 22192 adjust to 592
# 11 4 1922 0 : 0
# SVenus = 22264 adjust to 664
# 12 4 1922 0 : 0
# SVenus = 22336 adjust to 736
# 13 4 1922 0 : 0
# SVenus = 22409 adjust to 809
# 14 4 1922 0 : 0
# SMercury = 21682 adjust to 82
# MTS = 21620 adjust to 20
# 15 4 1922 0 : 0
# SMercury = 22507 adjust to 907
# MTS = 21677 adjust to 77
# SVenus = -2200 adjust to 19400
# 16 4 1922 0 : 0
# MTS = -136 adjust to 21464
# SMercury = 21903 adjust to 303
# 17 4 1922 0 : 0
# MTS = -74 adjust to 21526
# SMercury = 22015 adjust to 415
# 18 4 1922 0 : 0
# MTS = -10 adjust to 21590
# SMercury = 22122 adjust to 522
# 19 4 1922 0 : 0
# 20 4 1922 0 : 0
# 21 4 1922 0 : 0
# 22 4 1922 0 : 0
# 23 4 1922 0 : 0
# 24 4 1922 0 : 0
# 25 4 1922 0 : 0
# 26 4 1922 0 : 0
# 27 4 1922 0 : 0
# 28 4 1922 0 : 0
# 29 4 1922 0 : 0
# 30 4 1922 0 : 0
# 1 5 1922 0 : 0
# 2 5 1922 0 : 0
# 3 5 1922 0 : 0
# 4 5 1922 0 : 0
# 5 5 1922 0 : 0
# 6 5 1922 0 : 0
# 7 5 1922 0 : 0
# 8 5 1922 0 : 0
# 9 5 1922 0 : 0
# 10 5 1922 0 : 0
# 11 5 1922 0 : 0
# 12 5 1922 0 : 0
# 13 5 1922 0 : 0
# 14 5 1922 0 : 0
# 15 5 1922 0 : 0
# 16 5 1922 0 : 0
# 17 5 1922 0 : 0
# 18 5 1922 0 : 0
# 19 5 1922 0 : 0
# 20 5 1922 0 : 0
# 21 5 1922 0 : 0
# 22 5 1922 0 : 0
# 23 5 1922 0 : 0
# 24 5 1922 0 : 0
# 25 5 1922 0 : 0
# 26 5 1922 0 : 0
# 27 5 1922 0 : 0
# 28 5 1922 0 : 0
# 29 5 1922 0 : 0
# 30 5 1922 0 : 0
# 31 5 1922 0 : 0
# 1 6 1922 0 : 0
# 2 6 1922 0 : 0
# 3 6 1922 0 : 0
# 4 6 1922 0 : 0
# 5 6 1922 0 : 0
# 6 6 1922 0 : 0
# 7 6 1922 0 : 0
# 8 6 1922 0 : 0
# 9 6 1922 0 : 0
# 10 6 1922 0 : 0
# 30 12 1922 0 : 0
# MTS = 21703 adjust to 103
# Smars = -2260 adjust to 19340
# 31 12 1922 0 : 0
# MTS = 21739 adjust to 139
# Smars = -2214 adjust to 19386
# 1 1 1923 0 : 0
# MTS = 21773 adjust to 173
# Smars = -2171 adjust to 19429
# 2 1 1923 0 : 0
# MTS = 21810 adjust to 210
# Smars = -2128 adjust to 19472
# 3 1 1923 0 : 0
# MTS = 21846 adjust to 246
# Smars = -2079 adjust to 19521
# 4 1 1923 0 : 0
# MTS = 21881 adjust to 281
# Smars = -2039 adjust to 19561
# 5 1 1923 0 : 0
# MTS = 21917 adjust to 317
# Smars = -1990 adjust to 19610
# 6 1 1923 0 : 0
# MTS = 21953 adjust to 353
# Smars = -1949 adjust to 19651
# 7 1 1923 0 : 0
# MTS = 21989 adjust to 389
# Smars = -1904 adjust to 19696
# 8 1 1923 0 : 0
# MTS = 22025 adjust to 425
# Smars = -1859 adjust to 19741
# 9 1 1923 0 : 0
# MTS = 22059 adjust to 459
# Smars = -1817 adjust to 19783
# 10 1 1923 0 : 0
# MTS = 22095 adjust to 495
# Smars = -1772 adjust to 19828
# 11 1 1923 0 : 0
# MTS = 22130 adjust to 530
# Smars = -1732 adjust to 19868
# 12 1 1923 0 : 0
# Smars = -1683 adjust to 19917
# 13 1 1923 0 : 0
# Smars = -1639 adjust to 19961
# 14 1 1923 0 : 0
# Smars = -1600 adjust to 20000
# 15 1 1923 0 : 0
# Smars = -1556 adjust to 20044
# 16 1 1923 0 : 0
# Smars = -1512 adjust to 20088
# 17 1 1923 0 : 0
# Smars = -1470 adjust to 20130
# 18 1 1923 0 : 0
# Smars = -1426 adjust to 20174
# 19 1 1923 0 : 0
# Smars = -1382 adjust to 20218
# 20 1 1923 0 : 0
# Smars = -1339 adjust to 20261
# 21 1 1923 0 : 0
# Smars = -1298 adjust to 20302
# 22 1 1923 0 : 0
# Smars = -1256 adjust to 20344
# 23 1 1923 0 : 0
# Smars = -1215 adjust to 20385
# 24 1 1923 0 : 0
# Smars = -1166 adjust to 20434
# 25 1 1923 0 : 0
# Smars = -1129 adjust to 20471
# 26 1 1923 0 : 0
# Smars = -1087 adjust to 20513
# 27 1 1923 0 : 0
# Smars = -1048 adjust to 20552
# 28 1 1923 0 : 0
# Smars = -1006 adjust to 20594
# 29 1 1923 0 : 0
# Smars = -964 adjust to 20636
# 30 1 1923 0 : 0
# Smars = -925 adjust to 20675
# 31 1 1923 0 : 0
# Smars = -883 adjust to 20717
# 1 2 1923 0 : 0
# Smars = -847 adjust to 20753
# 2 2 1923 0 : 0
# Smars = -807 adjust to 20793
# 3 2 1923 0 : 0
# Smars = -765 adjust to 20835
# 4 2 1923 0 : 0
# Smars = -727 adjust to 20873
# 5 2 1923 0 : 0
# Smars = -686 adjust to 20914
# 6 2 1923 0 : 0
# Smars = -645 adjust to 20955
# 7 2 1923 0 : 0
# Smars = -606 adjust to 20994
# 8 2 1923 0 : 0
# Smars = -568 adjust to 21032
# 9 2 1923 0 : 0
# Smars = -526 adjust to 21074
# 10 2 1923 0 : 0
# Smars = -481 adjust to 21119
# 11 2 1923 0 : 0
# Smars = -433 adjust to 21167
# 12 2 1923 0 : 0
# Smars = -392 adjust to 21208
# 13 2 1923 0 : 0
# Smars = -344 adjust to 21256
# 14 2 1923 0 : 0
# Smars = -299 adjust to 21301
# 15 2 1923 0 : 0
# Smars = -257 adjust to 21343
# 16 2 1923 0 : 0
# Smars = -209 adjust to 21391
# 17 2 1923 0 : 0
# Smars = -168 adjust to 21432
# 18 2 1923 0 : 0
# Smars = -123 adjust to 21477
# 19 2 1923 0 : 0
# Smars = -78 adjust to 21522
# 20 2 1923 0 : 0
# Smars = -34 adjust to 21566
# 21 2 1923 0 : 0
# 22 2 1923 0 : 0
# 23 2 1923 0 : 0
# 24 2 1923 0 : 0
# 25 2 1923 0 : 0
# 26 2 1923 0 : 0
# 27 2 1923 0 : 0
# 28 2 1923 0 : 0
# 1 3 1923 0 : 0
# 2 3 1923 0 : 0
# 3 3 1923 0 : 0
# 4 3 1923 0 : 0
# 5 3 1923 0 : 0
# 6 3 1923 0 : 0
# 7 3 1923 0 : 0
# 8 3 1923 0 : 0
# 9 3 1923 0 : 0
# 10 3 1923 0 : 0
# 11 3 1923 0 : 0
# 12 3 1923 0 : 0
# 13 3 1923 0 : 0
# 14 3 1923 0 : 0
# 15 3 1923 0 : 0
# 16 3 1923 0 : 0
# 17 3 1923 0 : 0
# 18 3 1923 0 : 0
# 19 3 1923 0 : 0
# 20 3 1923 0 : 0
# 21 3 1923 0 : 0
# 22 3 1923 0 : 0
# 23 3 1923 0 : 0
# 24 3 1923 0 : 0
# 25 3 1923 0 : 0
# 26 3 1923 0 : 0
# 27 3 1923 0 : 0
# 28 3 1923 0 : 0
# 29 3 1923 0 : 0
# 30 3 1923 0 : 0
# 31 3 1923 0 : 0
# 1 4 1923 0 : 0
# 2 4 1923 0 : 0
# 3 4 1923 0 : 0
# 4 4 1923 0 : 0
# 5 4 1923 0 : 0
# 6 4 1923 0 : 0
# SMercury = 21604 adjust to 4
# 7 4 1923 0 : 0
# SMercury = 21712 adjust to 112
# 8 4 1923 0 : 0
# SMercury = 21823 adjust to 223
# 9 4 1923 0 : 0
# SMercury = 21933 adjust to 333
# 10 4 1923 0 : 0
# SMercury = 22027 adjust to 427
# 11 4 1923 0 : 0
# SMercury = 22117 adjust to 517
# 12 4 1923 0 : 0
# SMercury = 22207 adjust to 607
# 13 4 1923 0 : 0
# SMercury = 22301 adjust to 701
# 14 4 1923 0 : 0
# SMercury = 22393 adjust to 793
# MTS = 21606 adjust to 6
# SVenus = -2285 adjust to 19315
# 15 4 1923 0 : 0
# SMercury = 22583 adjust to 983
# MTS = 21662 adjust to 62
# 16 4 1923 0 : 0
# MTS = -152 adjust to 21448
# SMercury = 22578 adjust to 978
# SVenus = -2151 adjust to 19449
# 17 4 1923 0 : 0
# MTS = -88 adjust to 21512
# SMercury = 22675 adjust to 1075
# SVenus = -2077 adjust to 19523
# 18 4 1923 0 : 0
# MTS = -28 adjust to 21572
# SMercury = 22767 adjust to 1167
# SVenus = -2014 adjust to 19586
# 19 4 1923 0 : 0
# SVenus = -1943 adjust to 19657
# 20 4 1923 0 : 0
# SVenus = -1877 adjust to 19723
# 21 4 1923 0 : 0
# SVenus = -1806 adjust to 19794
# 22 4 1923 0 : 0
# SVenus = -1736 adjust to 19864
# 23 4 1923 0 : 0
# SVenus = -1669 adjust to 19931
# 24 4 1923 0 : 0
# SVenus = -1599 adjust to 20001
# 25 4 1923 0 : 0
# SVenus = -1533 adjust to 20067
# 26 4 1923 0 : 0
# SVenus = -1463 adjust to 20137
# 27 4 1923 0 : 0
# SVenus = -1396 adjust to 20204
# 28 4 1923 0 : 0
# SVenus = -1327 adjust to 20273
# 29 4 1923 0 : 0
# SVenus = -1260 adjust to 20340
# 30 4 1923 0 : 0
# SVenus = -1194 adjust to 20406
# 1 5 1923 0 : 0
# SVenus = -1117 adjust to 20483
# 2 5 1923 0 : 0
# SVenus = -1041 adjust to 20559
# 3 5 1923 0 : 0
# SVenus = -965 adjust to 20635
# 4 5 1923 0 : 0
# SVenus = -888 adjust to 20712
# 5 5 1923 0 : 0
# SVenus = -813 adjust to 20787
# 6 5 1923 0 : 0
# SVenus = -735 adjust to 20865
# 7 5 1923 0 : 0
# SVenus = -663 adjust to 20937
# 8 5 1923 0 : 0
# SVenus = -588 adjust to 21012
# 9 5 1923 0 : 0
# SVenus = -516 adjust to 21084
# 10 5 1923 0 : 0
# SVenus = -441 adjust to 21159
# 11 5 1923 0 : 0
# SVenus = -363 adjust to 21237
# 12 5 1923 0 : 0
# SVenus = -291 adjust to 21309
# 13 5 1923 0 : 0
# SVenus = -217 adjust to 21383
# 14 5 1923 0 : 0
# SVenus = -145 adjust to 21455
# 15 5 1923 0 : 0
# SVenus = -71 adjust to 21529
# 16 5 1923 0 : 0
# SVenus = -1 adjust to 21599
# 17 5 1923 0 : 0
# 18 5 1923 0 : 0
# 19 5 1923 0 : 0
# 20 5 1923 0 : 0
# 21 5 1923 0 : 0
# 22 5 1923 0 : 0
# 23 5 1923 0 : 0
# 24 5 1923 0 : 0
# 25 5 1923 0 : 0
# 26 5 1923 0 : 0
# 27 5 1923 0 : 0
# 28 5 1923 0 : 0
# 29 5 1923 0 : 0
# 30 5 1923 0 : 0
# 31 5 1923 0 : 0
# 1 6 1923 0 : 0
# 2 6 1923 0 : 0
# 3 6 1923 0 : 0
# 4 6 1923 0 : 0
# 5 6 1923 0 : 0
# 6 6 1923 0 : 0
# 7 6 1923 0 : 0
# 8 6 1923 0 : 0
# 9 6 1923 0 : 0
# 10 6 1923 0 : 0
# 11 6 1923 0 : 0
# 12 6 1923 0 : 0
# 13 6 1923 0 : 0
# 14 6 1923 0 : 0
# 15 6 1923 0 : 0
# 16 6 1923 0 : 0
# 17 6 1923 0 : 0
# 18 6 1923 0 : 0
# 19 6 1923 0 : 0
# 20 6 1923 0 : 0
# 21 6 1923 0 : 0
# 22 6 1923 0 : 0
# 23 6 1923 0 : 0
# 24 6 1923 0 : 0
# 25 6 1923 0 : 0
# 26 6 1923 0 : 0
# 19 1 1924 0 : 0
# 20 1 1924 0 : 0
# 21 1 1924 0 : 0
# 22 1 1924 0 : 0
# 23 1 1924 0 : 0
# 24 1 1924 0 : 0
# 25 1 1924 0 : 0
# 26 1 1924 0 : 0
# 27 1 1924 0 : 0
# 28 1 1924 0 : 0
# 29 1 1924 0 : 0
# 30 1 1924 0 : 0
# 31 1 1924 0 : 0
# 1 2 1924 0 : 0
# 2 2 1924 0 : 0
# 3 2 1924 0 : 0
# 4 2 1924 0 : 0
# 5 2 1924 0 : 0
# 6 2 1924 0 : 0
# 7 2 1924 0 : 0
# 8 2 1924 0 : 0
# 9 2 1924 0 : 0
# 10 2 1924 0 : 0
# 11 2 1924 0 : 0
# 12 2 1924 0 : 0
# 13 2 1924 0 : 0
# 14 2 1924 0 : 0
# 15 2 1924 0 : 0
# 16 2 1924 0 : 0
# 17 2 1924 0 : 0
# 18 2 1924 0 : 0
# 19 2 1924 0 : 0
# 20 2 1924 0 : 0
# 21 2 1924 0 : 0
# 22 2 1924 0 : 0
# 23 2 1924 0 : 0
# 24 2 1924 0 : 0
# 25 2 1924 0 : 0
# 26 2 1924 0 : 0
# 27 2 1924 0 : 0
# 28 2 1924 0 : 0
# 29 2 1924 0 : 0
# 1 3 1924 0 : 0
# 2 3 1924 0 : 0
# 3 3 1924 0 : 0
# 4 3 1924 0 : 0
# 5 3 1924 0 : 0
# 6 3 1924 0 : 0
# SVenus = 21660 adjust to 60
# 7 3 1924 0 : 0
# SVenus = 21731 adjust to 131
# 8 3 1924 0 : 0
# SVenus = 21800 adjust to 200
# 9 3 1924 0 : 0
# SVenus = 21873 adjust to 273
# 10 3 1924 0 : 0
# SVenus = 21943 adjust to 343
# 11 3 1924 0 : 0
# SVenus = 22017 adjust to 417
# 12 3 1924 0 : 0
# SVenus = 22088 adjust to 488
# 13 3 1924 0 : 0
# SVenus = 22162 adjust to 562
# 14 3 1924 0 : 0
# SVenus = 22232 adjust to 632
# 15 3 1924 0 : 0
# SVenus = 22299 adjust to 699
# 16 3 1924 0 : 0
# SVenus = 22377 adjust to 777
# 17 3 1924 0 : 0
# SVenus = 22444 adjust to 844
# 18 3 1924 0 : 0
# SVenus = 22520 adjust to 920
# 19 3 1924 0 : 0
# SVenus = 22592 adjust to 992
# 20 3 1924 0 : 0
# SVenus = 22667 adjust to 1067
# 21 3 1924 0 : 0
# SVenus = 22740 adjust to 1140
# 22 3 1924 0 : 0
# SVenus = 22812 adjust to 1212
# 23 3 1924 0 : 0
# SVenus = 22890 adjust to 1290
# 24 3 1924 0 : 0
# SVenus = 22962 adjust to 1362
# 25 3 1924 0 : 0
# SVenus = 23038 adjust to 1438
# 26 3 1924 0 : 0
# SVenus = 23112 adjust to 1512
# 27 3 1924 0 : 0
# SVenus = 23185 adjust to 1585
# 28 3 1924 0 : 0
# SVenus = 23263 adjust to 1663
# 29 3 1924 0 : 0
# SVenus = 23338 adjust to 1738
# 30 3 1924 0 : 0
# SMercury = 21616 adjust to 16
# SVenus = 23416 adjust to 1816
# 31 3 1924 0 : 0
# SMercury = 21711 adjust to 111
# SVenus = 23489 adjust to 1889
# 1 4 1924 0 : 0
# SMercury = 21792 adjust to 192
# SVenus = 23564 adjust to 1964
# 2 4 1924 0 : 0
# SMercury = 21863 adjust to 263
# SVenus = 23644 adjust to 2044
# 3 4 1924 0 : 0
# SMercury = 21935 adjust to 335
# SVenus = 23719 adjust to 2119
# 4 4 1924 0 : 0
# SMercury = 22005 adjust to 405
# SVenus = 23800 adjust to 2200
# 5 4 1924 0 : 0
# SMercury = 22077 adjust to 477
# SVenus = 23873 adjust to 2273
# 6 4 1924 0 : 0
# SMercury = 22148 adjust to 548
# SVenus = 23926 adjust to 2326
# 7 4 1924 0 : 0
# SMercury = 22222 adjust to 622
# SVenus = 23991 adjust to 2391
# 8 4 1924 0 : 0
# SMercury = 22296 adjust to 696
# SVenus = 24051 adjust to 2451
# 9 4 1924 0 : 0
# SMercury = 22367 adjust to 767
# SVenus = 24109 adjust to 2509
# 10 4 1924 0 : 0
# SMercury = 22443 adjust to 843
# SVenus = 24173 adjust to 2573
# 11 4 1924 0 : 0
# SMercury = 22484 adjust to 884
# SVenus = 24231 adjust to 2631
# 12 4 1924 0 : 0
# SMercury = 22517 adjust to 917
# SVenus = 24286 adjust to 2686
# 13 4 1924 0 : 0
# SMercury = 22547 adjust to 947
# SVenus = 24345 adjust to 2745
# 14 4 1924 0 : 0
# SMercury = 22575 adjust to 975
# MTS = 21647 adjust to 47
# 15 4 1924 0 : 0
# MTS = -170 adjust to 21430
# SMercury = 22602 adjust to 1002
# 16 4 1924 0 : 0
# MTS = -107 adjust to 21493
# SMercury = 22628 adjust to 1028
# 17 4 1924 0 : 0
# MTS = -44 adjust to 21556
# SMercury = 22651 adjust to 1051
# 18 4 1924 0 : 0
# 19 4 1924 0 : 0
# 20 4 1924 0 : 0
# 21 4 1924 0 : 0
# 22 4 1924 0 : 0
# 23 4 1924 0 : 0
# 24 4 1924 0 : 0
# 25 4 1924 0 : 0
# 26 4 1924 0 : 0
# 27 4 1924 0 : 0
# 28 4 1924 0 : 0
# 29 4 1924 0 : 0
# 30 4 1924 0 : 0
# 1 5 1924 0 : 0
# 2 5 1924 0 : 0
# 3 5 1924 0 : 0
# 4 5 1924 0 : 0
# 5 5 1924 0 : 0
# 6 5 1924 0 : 0
# 7 5 1924 0 : 0
# 8 5 1924 0 : 0
# 9 5 1924 0 : 0
# 10 5 1924 0 : 0
# 11 5 1924 0 : 0
# 12 5 1924 0 : 0
# 13 5 1924 0 : 0
# 14 5 1924 0 : 0
# 15 5 1924 0 : 0
# 16 5 1924 0 : 0
# 17 5 1924 0 : 0
# 18 5 1924 0 : 0
# 19 5 1924 0 : 0
# 20 5 1924 0 : 0
# 21 5 1924 0 : 0
# 22 5 1924 0 : 0
# 23 5 1924 0 : 0
# 24 5 1924 0 : 0
# 25 5 1924 0 : 0
# 26 5 1924 0 : 0
# 27 5 1924 0 : 0
# 28 5 1924 0 : 0
# 29 5 1924 0 : 0
# 30 5 1924 0 : 0
# 31 5 1924 0 : 0
# 1 6 1924 0 : 0
# 13 9 1924 0 : 0
# 14 9 1924 0 : 0
# 15 9 1924 0 : 0
# 16 9 1924 0 : 0
# 17 9 1924 0 : 0
# 18 9 1924 0 : 0
# 19 9 1924 0 : 0
# 20 9 1924 0 : 0
# 21 9 1924 0 : 0
# 22 9 1924 0 : 0
# 23 9 1924 0 : 0
# 24 9 1924 0 : 0
# 25 9 1924 0 : 0
# 26 9 1924 0 : 0
# 27 9 1924 0 : 0
# 28 9 1924 0 : 0
# 29 9 1924 0 : 0
# 30 9 1924 0 : 0
# 1 10 1924 0 : 0
# 2 10 1924 0 : 0
# 3 10 1924 0 : 0
# 4 10 1924 0 : 0
# 5 10 1924 0 : 0
# 6 10 1924 0 : 0
# 7 10 1924 0 : 0
# 8 10 1924 0 : 0
# 9 10 1924 0 : 0
# 10 10 1924 0 : 0
# 11 10 1924 0 : 0
# 12 10 1924 0 : 0
# 13 10 1924 0 : 0
# 14 10 1924 0 : 0
# 15 10 1924 0 : 0
# 16 10 1924 0 : 0
# 17 10 1924 0 : 0
# 18 10 1924 0 : 0
# 19 10 1924 0 : 0
# 20 10 1924 0 : 0
# 21 10 1924 0 : 0
# 22 10 1924 0 : 0
# 23 10 1924 0 : 0
# 24 10 1924 0 : 0
# 25 10 1924 0 : 0
# 26 10 1924 0 : 0
# 27 10 1924 0 : 0
# 28 10 1924 0 : 0
# 29 10 1924 0 : 0
# 30 10 1924 0 : 0
# 31 10 1924 0 : 0
# 1 11 1924 0 : 0
# 2 11 1924 0 : 0
# 3 11 1924 0 : 0
# 4 11 1924 0 : 0
# 5 11 1924 0 : 0
# 6 11 1924 0 : 0
# 7 11 1924 0 : 0
# 8 11 1924 0 : 0
# 9 11 1924 0 : 0
# 10 11 1924 0 : 0
# 11 11 1924 0 : 0
# 12 11 1924 0 : 0
# 13 11 1924 0 : 0
# 14 11 1924 0 : 0
# MTS = 21632 adjust to 32
# Smars = -2627 adjust to 18973
# 15 11 1924 0 : 0
# MTS = 21667 adjust to 67
# Smars = -2593 adjust to 19007
# 16 11 1924 0 : 0
# MTS = 21703 adjust to 103
# Smars = -2558 adjust to 19042
# 17 11 1924 0 : 0
# MTS = 21739 adjust to 139
# Smars = -2517 adjust to 19083
# 18 11 1924 0 : 0
# MTS = 21775 adjust to 175
# Smars = -2474 adjust to 19126
# 19 11 1924 0 : 0
# MTS = 21810 adjust to 210
# Smars = -2449 adjust to 19151
# 20 11 1924 0 : 0
# MTS = 21845 adjust to 245
# Smars = -2401 adjust to 19199
# 21 11 1924 0 : 0
# MTS = 21881 adjust to 281
# Smars = -2367 adjust to 19233
# 22 11 1924 0 : 0
# MTS = 21917 adjust to 317
# Smars = -2326 adjust to 19274
# 23 11 1924 0 : 0
# MTS = 21953 adjust to 353
# Smars = -2284 adjust to 19316
# 24 11 1924 0 : 0
# MTS = 21989 adjust to 389
# Smars = -2249 adjust to 19351
# 25 11 1924 0 : 0
# MTS = 22024 adjust to 424
# Smars = -2209 adjust to 19391
# 26 11 1924 0 : 0
# MTS = 22060 adjust to 460
# Smars = -2175 adjust to 19425
# 27 11 1924 0 : 0
# MTS = 22095 adjust to 495
# Smars = -2136 adjust to 19464
# 28 11 1924 0 : 0
# MTS = 22130 adjust to 530
# Smars = -2096 adjust to 19504
# 29 11 1924 0 : 0
# Smars = -2060 adjust to 19540
# 30 11 1924 0 : 0
# Smars = -2027 adjust to 19573
# 1 12 1924 0 : 0
# Smars = -1987 adjust to 19613
# 2 12 1924 0 : 0
# Smars = -1945 adjust to 19655
# 3 12 1924 0 : 0
# Smars = -1906 adjust to 19694
# 4 12 1924 0 : 0
# Smars = -1871 adjust to 19729
# 5 12 1924 0 : 0
# Smars = -1834 adjust to 19766
# 6 12 1924 0 : 0
# Smars = -1792 adjust to 19808
# 7 12 1924 0 : 0
# Smars = -1758 adjust to 19842
# 8 12 1924 0 : 0
# Smars = -1719 adjust to 19881
# 9 12 1924 0 : 0
# Smars = -1684 adjust to 19916
# 10 12 1924 0 : 0
# ...
# Smars = 21951 adjust to 351
# 8 5 2122 0 : 0
# Smercury = -235 adjust to 21365
# Smars = 21997 adjust to 397
# 9 5 2122 0 : 0
# Smercury = -159 adjust to 21441
# Smars = 22043 adjust to 443
# 10 5 2122 0 : 0
# Smercury = -86 adjust to 21514
# Smars = 22086 adjust to 486
# 11 5 2122 0 : 0
# Smercury = -11 adjust to 21589
# Smars = 22132 adjust to 532
# 12 5 2122 0 : 0
# Smars = 22176 adjust to 576
# 13 5 2122 0 : 0
# MTS = 21615 adjust to 15
# 14 5 2122 0 : 0
# MTS = 21651 adjust to 51
# 15 5 2122 0 : 0
# MTS = 21686 adjust to 86
# 16 5 2122 0 : 0
# MTS = 21722 adjust to 122
# 17 5 2122 0 : 0
# MTS = 21757 adjust to 157
# 18 5 2122 0 : 0
# MTS = 21792 adjust to 192
# 19 5 2122 0 : 0
# MTS = 21828 adjust to 228
# 20 5 2122 0 : 0
# MTS = 21864 adjust to 264
# 21 5 2122 0 : 0
# MTS = 21899 adjust to 299
# 22 5 2122 0 : 0
# MTS = 21935 adjust to 335
# 23 5 2122 0 : 0
# MTS = 21971 adjust to 371
# 24 5 2122 0 : 0
# MTS = 22007 adjust to 407
# 25 5 2122 0 : 0
# MTS = 22043 adjust to 443
# 26 5 2122 0 : 0
# MTS = 22076 adjust to 476
# 27 5 2122 0 : 0
# MTS = 22112 adjust to 512
# 28 5 2122 0 : 0
# 29 5 2122 0 : 0
# 30 5 2122 0 : 0
# 31 5 2122 0 : 0
# 1 6 2122 0 : 0
# 2 6 2122 0 : 0
# 3 6 2122 0 : 0
# 4 6 2122 0 : 0
# 5 6 2122 0 : 0
# 6 6 2122 0 : 0
# 7 6 2122 0 : 0
# 8 6 2122 0 : 0
# 9 6 2122 0 : 0
# 10 6 2122 0 : 0
# 11 6 2122 0 : 0
# 12 6 2122 0 : 0
# 13 6 2122 0 : 0
# 14 6 2122 0 : 0
# 15 6 2122 0 : 0
# 16 6 2122 0 : 0
# 17 6 2122 0 : 0
# 18 6 2122 0 : 0
# 19 6 2122 0 : 0
# 20 6 2122 0 : 0
# MTS = -74 adjust to 21526
# SVenus = -1290 adjust to 20310
# 21 4 2123 0 : 0
# MTS = -11 adjust to 21589
# SVenus = -1221 adjust to 20379
# 22 4 2123 0 : 0
# Smercury = -1250 adjust to 20350
# SVenus = -1149 adjust to 20451
# 23 4 2123 0 : 0
# Smercury = -1178 adjust to 20422
# SVenus = -1073 adjust to 20527
# 24 4 2123 0 : 0
# Smercury = -1104 adjust to 20496
# SVenus = -995 adjust to 20605
# 25 4 2123 0 : 0
# Smercury = -1032 adjust to 20568
# SVenus = -922 adjust to 20678
# 26 4 2123 0 : 0
# Smercury = -960 adjust to 20640
# SVenus = -847 adjust to 20753
# 27 4 2123 0 : 0
# Smercury = -890 adjust to 20710
# SVenus = -772 adjust to 20828
# 28 4 2123 0 : 0
# Smercury = -817 adjust to 20783
# SVenus = -695 adjust to 20905
# 29 4 2123 0 : 0
# Smercury = -746 adjust to 20854
# SVenus = -621 adjust to 20979
# 30 4 2123 0 : 0
# Smercury = -663 adjust to 20937
# SVenus = -546 adjust to 21054
# 1 5 2123 0 : 0
# Smercury = -565 adjust to 21035
# SVenus = -472 adjust to 21128
# 2 5 2123 0 : 0
# Smercury = -468 adjust to 21132
# SVenus = -397 adjust to 21203
# 3 5 2123 0 : 0
# Smercury = -370 adjust to 21230
# SVenus = -322 adjust to 21278
# 4 5 2123 0 : 0
# Smercury = -275 adjust to 21325
# SVenus = -248 adjust to 21352
# 5 5 2123 0 : 0
# Smercury = -181 adjust to 21419
# SVenus = -173 adjust to 21427
# 6 5 2123 0 : 0
# Smercury = -88 adjust to 21512
# SVenus = -99 adjust to 21501
# 7 5 2123 0 : 0
# SVenus = -26 adjust to 21574
# 8 5 2123 0 : 0
# 9 5 2123 0 : 0
# 10 5 2123 0 : 0
# 11 5 2123 0 : 0
# 12 5 2123 0 : 0
# 13 5 2123 0 : 0
# 14 5 2123 0 : 0
# 15 5 2123 0 : 0
# 16 5 2123 0 : 0
# 17 5 2123 0 : 0
# 18 5 2123 0 : 0
# 19 5 2123 0 : 0
# 20 5 2123 0 : 0
# 21 5 2123 0 : 0
# 22 5 2123 0 : 0
# 23 5 2123 0 : 0
# 24 5 2123 0 : 0
# 25 5 2123 0 : 0
# 26 5 2123 0 : 0
# 27 5 2123 0 : 0
# 28 5 2123 0 : 0
# 29 5 2123 0 : 0
# 30 5 2123 0 : 0
# 31 5 2123 0 : 0
# 1 6 2123 0 : 0
# 2 6 2123 0 : 0
# 3 6 2123 0 : 0
# 4 6 2123 0 : 0
# 5 6 2123 0 : 0
# 6 6 2123 0 : 0
# 7 6 2123 0 : 0
# 8 6 2123 0 : 0
# 9 6 2123 0 : 0
# 10 6 2123 0 : 0
# 11 6 2123 0 : 0
# 12 6 2123 0 : 0
# 13 6 2123 0 : 0
# 14 6 2123 0 : 0
# 15 6 2123 0 : 0
# 16 6 2123 0 : 0
# 17 6 2123 0 : 0
# 18 6 2123 0 : 0
# 19 6 2123 0 : 0
# 20 6 2123 0 : 0
# 21 6 2123 0 : 0
# 22 6 2123 0 : 0
# 15 1 2124 0 : 0
# 16 1 2124 0 : 0
# 17 1 2124 0 : 0
# 18 1 2124 0 : 0
# 19 1 2124 0 : 0
# 20 1 2124 0 : 0
# 21 1 2124 0 : 0
# 22 1 2124 0 : 0
# 23 1 2124 0 : 0
# 24 1 2124 0 : 0
# 25 1 2124 0 : 0
# 26 1 2124 0 : 0
# 27 1 2124 0 : 0
# 28 1 2124 0 : 0
# 29 1 2124 0 : 0
# 30 1 2124 0 : 0
# 31 1 2124 0 : 0
# 1 2 2124 0 : 0
# 2 2 2124 0 : 0
# 3 2 2124 0 : 0
# 4 2 2124 0 : 0
# 5 2 2124 0 : 0
# 6 2 2124 0 : 0
# 7 2 2124 0 : 0
# 8 2 2124 0 : 0
# 9 2 2124 0 : 0
# 10 2 2124 0 : 0
# 11 2 2124 0 : 0
# 12 2 2124 0 : 0
# 13 2 2124 0 : 0
# 14 2 2124 0 : 0
# 15 2 2124 0 : 0
# 16 2 2124 0 : 0
# 17 2 2124 0 : 0
# 18 2 2124 0 : 0
# 19 2 2124 0 : 0
# 20 2 2124 0 : 0
# 21 2 2124 0 : 0
# 22 2 2124 0 : 0
# 23 2 2124 0 : 0
# 24 2 2124 0 : 0
# 25 2 2124 0 : 0
# 26 2 2124 0 : 0
# 27 2 2124 0 : 0
# 28 2 2124 0 : 0
# 29 2 2124 0 : 0
# 1 3 2124 0 : 0
# SVenus = 21640 adjust to 40
# 2 3 2124 0 : 0
# SVenus = 21697 adjust to 97
# 3 3 2124 0 : 0
# SVenus = 21759 adjust to 159
# 4 3 2124 0 : 0
# SVenus = 21814 adjust to 214
# 5 3 2124 0 : 0
# SVenus = 21882 adjust to 282
# 6 3 2124 0 : 0
# SVenus = 21944 adjust to 344
# 7 3 2124 0 : 0
# SVenus = 21999 adjust to 399
# 8 3 2124 0 : 0
# SVenus = 22061 adjust to 461
# 9 3 2124 0 : 0
# SVenus = 22128 adjust to 528
# 10 3 2124 0 : 0
# SVenus = 22183 adjust to 583
# 11 3 2124 0 : 0
# SVenus = 22243 adjust to 643
# 12 3 2124 0 : 0
# SVenus = 22305 adjust to 705
# 13 3 2124 0 : 0
# SVenus = 22372 adjust to 772
# 14 3 2124 0 : 0
# SVenus = 22432 adjust to 832
# 15 3 2124 0 : 0
# SVenus = 22488 adjust to 888
# 16 3 2124 0 : 0
# SVenus = 22547 adjust to 947
# 17 3 2124 0 : 0
# SVenus = 22615 adjust to 1015
# 18 3 2124 0 : 0
# SVenus = 22669 adjust to 1069
# 19 3 2124 0 : 0
# SVenus = 22730 adjust to 1130
# 20 3 2124 0 : 0
# SVenus = 22790 adjust to 1190
# 21 3 2124 0 : 0
# SVenus = 22844 adjust to 1244
# 22 3 2124 0 : 0
# SVenus = 22912 adjust to 1312
# 23 3 2124 0 : 0
# SVenus = 22975 adjust to 1375
# 24 3 2124 0 : 0
# SVenus = 23036 adjust to 1436
# 25 3 2124 0 : 0
# SVenus = 23088 adjust to 1488
# 26 3 2124 0 : 0
# SVenus = 23159 adjust to 1559
# 27 3 2124 0 : 0
# SVenus = 23219 adjust to 1619
# 28 3 2124 0 : 0
# SVenus = 23248 adjust to 1648
# 29 3 2124 0 : 0
# SVenus = 23269 adjust to 1669
# 30 3 2124 0 : 0
# SVenus = 23304 adjust to 1704
# MTS = 21615 adjust to 15
# Smars = -443 adjust to 21157
# 31 3 2124 0 : 0
# SVenus = 23332 adjust to 1732
# MTS = 21651 adjust to 51
# Smars = -397 adjust to 21203
# 1 4 2124 0 : 0
# SVenus = 23351 adjust to 1751
# MTS = 21686 adjust to 86
# Smars = -352 adjust to 21248
# 2 4 2124 0 : 0
# SVenus = 23376 adjust to 1776
# MTS = 21722 adjust to 122
# Smars = -307 adjust to 21293
# 3 4 2124 0 : 0
# SVenus = 23408 adjust to 1808
# MTS = 21759 adjust to 159
# Smars = -260 adjust to 21340
# 4 4 2124 0 : 0
# SVenus = 23427 adjust to 1827
# MTS = 21794 adjust to 194
# Smars = -215 adjust to 21385
# 5 4 2124 0 : 0
# SVenus = 23450 adjust to 1850
# MTS = 21829 adjust to 229
# Smars = -170 adjust to 21430
# 6 4 2124 0 : 0
# SVenus = 23464 adjust to 1864
# MTS = 21864 adjust to 264
# Smars = -125 adjust to 21475
# 7 4 2124 0 : 0
# SVenus = 23495 adjust to 1895
# MTS = 21900 adjust to 300
# Smars = -80 adjust to 21520
# 8 4 2124 0 : 0
# SVenus = 23515 adjust to 1915
# MTS = 21937 adjust to 337
# Smars = -33 adjust to 21567
# 9 4 2124 0 : 0
# SVenus = 23533 adjust to 1933
# MTS = 21972 adjust to 372
# 10 4 2124 0 : 0
# SVenus = 23542 adjust to 1942
# MTS = 22008 adjust to 408
# 11 4 2124 0 : 0
# SVenus = 23570 adjust to 1970
# MTS = 22043 adjust to 443
# 12 4 2124 0 : 0
# SVenus = 23584 adjust to 1984
# MTS = 22079 adjust to 479
# 13 4 2124 0 : 0
# SVenus = 23590 adjust to 1990
# MTS = 22116 adjust to 516
# 14 4 2124 0 : 0
# SVenus = 23610 adjust to 2010
# 15 4 2124 0 : 0
# SVenus = 23624 adjust to 2024
# 16 4 2124 0 : 0
# MTS = 21605 adjust to 5
# 17 4 2124 0 : 0
# MTS = 21662 adjust to 62
# 18 4 2124 0 : 0
# MTS = -152 adjust to 21448
# 19 4 2124 0 : 0
# MTS = -92 adjust to 21508
# 20 4 2124 0 : 0
# MTS = -29 adjust to 21571
# 21 4 2124 0 : 0
# Smercury = -887 adjust to 20713
# 22 4 2124 0 : 0
# Smercury = -776 adjust to 20824
# 23 4 2124 0 : 0
# Smercury = -667 adjust to 20933
# 24 4 2124 0 : 0
# Smercury = -558 adjust to 21042
# 25 4 2124 0 : 0
# Smercury = -451 adjust to 21149
# 26 4 2124 0 : 0
# Smercury = -344 adjust to 21256
# 27 4 2124 0 : 0
# Smercury = -235 adjust to 21365
# 28 4 2124 0 : 0
# Smercury = -129 adjust to 21471
# 29 4 2124 0 : 0
# Smercury = -23 adjust to 21577
# 30 4 2124 0 : 0
# 1 5 2124 0 : 0
# 2 5 2124 0 : 0
# 3 5 2124 0 : 0
# 4 5 2124 0 : 0
# 4:02:37.154112

# %%
#df[['sun_diff','moon_diff']].min()
df[['dt','sun','moon','saturn_diff','moon_diff']].to_csv(r"C:\Users\JACK\Desktop\S_out.csv")

# %%
df1 = df[['dt','dtny','ahra','jultin','kj','aw','masG','dT','au','van',
         'stin','sec','ahra_','kj_','aw_','masG_','dT_','au_','van_',
         'mathasun','pholsun','SPholGA','SKhan','SPushlip','SJyaGA','ravipphol','sun','sun_diff','sun_Z','sun_D','sun_M',
         'mtu','mathamoon','uv','MPholGA','MKhan','MPushlip','MJyaGA','chandraphol','moon','moon_diff','moon_Z','moon_D','moon_M', 
          'matharavi','srb','manut', 'a', 'b', 'pmt','rahu','rahu_diff','rahu_Z','rahu_D','rahu_M',
          'pholgt','geth','geth_diff','geth_Z','geth_D','geth_M',
          
          'matha_mecury','pholPK_mecury','ptma_mecury','puchaPT_mecury','khotiPT_mecury','MTpucha_mecury','MTKhoti_mecury',
          'khotiphol_mecury','MTcheta_mecury','MTphol_mecury','MTS_mecury','pholMT_mecury','ptnd_mecury','puchaTY_mecury',
          'khotiTY_mecury','SGPucha_mecury','SGKhoti_mecury','SGphol_mecury','p_mecury','sp_mecury','SGcheta_mecury',
          'mahaphol_mecury','mercury','mercury_diff','mercury_Z','mercury_D','mercury_M',
          
          'matha_venus','pholPK_venus','ptma_venus','puchaPT_venus','khotiPT_venus','MTpucha_venus','MTKhoti_venus',
          'khotiphol_venus','MTcheta_venus','MTphol_venus','MTS_venus','pholMT_venus','ptnd_venus','puchaTY_venus',
          'khotiTY_venus','SGPucha_venus','SGKhoti_venus','SGphol_venus','p_venus','sp_venus','SGcheta_venus',
          'mahaphol_venus','venus','venus_diff','venus_Z','venus_D','venus_M',
          
          'matha_mars','pholPK_mars','ptma_mars','puchaPT_mars','khotiPT_mars','MTpucha_mars','MTKhoti_mars',
          'khotiphol_mars','MTcheta_mars','MTphol_mars','MTS_mars','pholMT_mars','ptnd_mars','puchaTY_mars',
          'khotiTY_mars','SGPucha_mars','SGKhoti_mars','SGphol_mars','p_mars','sp_mars','SGcheta_mars',
          'mahaphol_mars','mars','mars_diff','mars_Z','mars_D','mars_M',          
          
          'matha_jupiter','pholPK_jupiter','ptma_jupiter','puchaPT_jupiter','khotiPT_jupiter','MTpucha_jupiter','MTKhoti_jupiter',
          'khotiphol_jupiter','MTcheta_jupiter','MTphol_jupiter','MTS_jupiter','pholMT_jupiter','ptnd_jupiter','puchaTY_jupiter',
          'khotiTY_jupiter','SGPucha_jupiter','SGKhoti_jupiter','SGphol_jupiter','p_jupiter','sp_jupiter','SGcheta_jupiter',
          'mahaphol_jupiter','jupiter','jupiter_diff','jupiter_Z','jupiter_D','jupiter_M',
          
          'matha_saturn','pholPK_saturn','ptma_saturn','puchaPT_saturn','khotiPT_saturn','MTpucha_saturn','MTKhoti_saturn',
          'khotiphol_saturn','MTcheta_saturn','MTphol_saturn','MTS_saturn','pholMT_saturn','ptnd_saturn','puchaTY_saturn',
          'khotiTY_saturn','SGPucha_saturn','SGKhoti_saturn','SGphol_saturn','p_saturn','sp_saturn','SGcheta_saturn',
          'mahaphol_saturn','saturn','saturn_diff','saturn_Z','saturn_D','saturn_M',
          
          'matha_uranus','pholPK_uranus','ptma_uranus','puchaPT_uranus','khotiPT_uranus','MTpucha_uranus','MTKhoti_uranus',
          'khotiphol_uranus','MTcheta_uranus','MTphol_uranus','MTS_uranus','pholMT_uranus','ptnd_uranus','puchaTY_uranus',
          'khotiTY_uranus','SGPucha_uranus','SGKhoti_uranus','SGphol_uranus','p_uranus','sp_uranus','SGcheta_uranus',
          'mahaphol_uranus','uranus','uranus_diff','uranus_Z','uranus_D','uranus_M'
          
        ]]
df1.to_csv(r"C:\Users\JACK\Desktop\1919_2124_day_all.csv")

#df1.to_pickle(("./1919_2124_day_all.pkl"))
# df1 = pd.read_pickle("./dummy.pkl")

# %%
#df1.to_pickle(("./1919_2124_day_all.pkl"))
df = pd.read_pickle("./1919_2124_day_all.pkl")
df_saturn =  df[['dt','matha_saturn','pholPK_saturn','ptma_saturn','puchaPT_saturn','khotiPT_saturn','MTpucha_saturn','MTKhoti_saturn',
          'khotiphol_saturn','MTcheta_saturn','MTphol_saturn','MTS_saturn','pholMT_saturn','ptnd_saturn','puchaTY_saturn',
          'khotiTY_saturn','SGPucha_saturn','SGKhoti_saturn','SGphol_saturn','p_saturn','sp_saturn','SGcheta_saturn',
          'mahaphol_saturn','saturn','saturn_diff','saturn_Z','saturn_D','saturn_M']]
# Out:
#                   dt  matha_saturn  pholPK_saturn  ptma_saturn  \
# 0       1/1/2462 0:0        6748.0        13528.0          3.0
# 1       2/1/2462 0:0        6750.0        13530.0          3.0
# 2       3/1/2462 0:0        6752.0        13532.0          3.0
# 3       4/1/2462 0:0        6754.0        13534.0          3.0
# 4       5/1/2462 0:0        6756.0        13536.0          3.0
# 5       6/1/2462 0:0        6758.0        13538.0          3.0
# 6       7/1/2462 0:0        6760.0        13540.0          3.0
# 7       8/1/2462 0:0        6762.0        13542.0          3.0
# 8       9/1/2462 0:0        6764.0        13544.0          3.0
# 9      10/1/2462 0:0        6766.0        13546.0          3.0
# 10     11/1/2462 0:0        6768.0        13548.0          3.0
# 11     12/1/2462 0:0        6769.0        13549.0          3.0
# 12     13/1/2462 0:0        6771.0        13551.0          3.0
# 13     14/1/2462 0:0        6773.0        13553.0          3.0
# 14     15/1/2462 0:0        6775.0        13555.0          3.0
# 15     16/1/2462 0:0        6777.0        13557.0          3.0
# 16     17/1/2462 0:0        6779.0        13559.0          3.0
# 17     18/1/2462 0:0        6782.0        13562.0          3.0
# 18     19/1/2462 0:0        6784.0        13564.0          3.0
# 19     20/1/2462 0:0        6786.0        13566.0          3.0
# 20     21/1/2462 0:0        6788.0        13568.0          3.0
# 21     22/1/2462 0:0        6790.0        13570.0          3.0
# 22     23/1/2462 0:0        6792.0        13572.0          3.0
# 23     24/1/2462 0:0        6794.0        13574.0          3.0
# 24     25/1/2462 0:0        6796.0        13576.0          3.0
# 25     26/1/2462 0:0        6798.0        13578.0          3.0
# 20          4.0       1.0      43.0
# 21          4.0       1.0      39.0
# 22          4.0       1.0      34.0
# 23          4.0       1.0      28.0
# 24          4.0       1.0      23.0
# 25          4.0       1.0      18.0
# 26          4.0       1.0      14.0
# 27          4.0       1.0       9.0
# 28          4.0       1.0       4.0
# 29          4.0       0.0      58.0
# ...         ...       ...       ...
# 74970       3.0       7.0      51.0
# 74971       3.0       7.0      53.0
# 74972       3.0       7.0      54.0
# 74973       3.0       7.0      56.0
# 74974       3.0       7.0      57.0
# 74975       3.0       7.0      58.0
# 74976       3.0       8.0       0.0
# 74977       3.0       8.0       1.0
# 74978       3.0       8.0       2.0
# 74979       3.0       8.0       3.0
# 74980       3.0       8.0       4.0
# 74981       3.0       8.0       6.0
# 74982       3.0       8.0       8.0
# 74983       3.0      21.0      50.0
# 74984       3.0       8.0      10.0
# 74985       3.0       8.0      13.0
# 74986       3.0       8.0      14.0
# 74987       3.0       8.0      14.0
# 74988       3.0       8.0      15.0
# 74989       3.0       8.0      17.0
# 74990       3.0       8.0      18.0
# 74991       3.0       8.0      20.0
# 74992       3.0       8.0      21.0
# 74993       3.0       8.0      22.0
# 74994       3.0       8.0      23.0
# 74995       3.0       8.0      25.0
# 74996       3.0       8.0      27.0
# 74997       3.0       8.0      28.0
# 74998       3.0       8.0      29.0
# 74999       3.0       8.0      31.0
#
# [75000 rows x 28 columns]

# %%
df1 = df[['dt','dtny','ahra','jultin','kj','aw','masG','dT','au','van',
         'stin','sec','ahra_','kj_','aw_','masG_','dT_','au_','van_',
         'sun','moon','rahu','geth','mars','mercury','venus','jupiter','saturn','uranus',
         'sun_Z','sun_D','sun_M',
         'moon_Z','moon_D','moon_M',
         'rahu_Z','rahu_D','rahu_M',
         'geth_Z','geth_D','geth_M',
         'mars_Z','mars_D','mars_M',
         'mercury_Z','mercury_D','mercury_M',
         'venus_Z','venus_D','venus_M',
         'jupiter_Z','jupiter_D','jupiter_M',
         'saturn_Z','saturn_D','saturn_M',
         'uranus_Z','uranus_D','uranus_M'
          
          
          
        ]]
df1.to_csv(r"C:\Users\JACK\Desktop\S_out.csv")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-a2427599bd16> in <module>
#      11          'jupiter_Z','jupiter_D','jupiter_M',
#      12          'saturn_Z','saturn_D','saturn_M',
# ---> 13          'uranus_Z','uranus_D','uranus_M'
#      14
#      15
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2932                 key = list(key)
#    2933             indexer = self.loc._convert_to_indexer(key, axis=1,
# -> 2934                                                    raise_missing=True)
#    2935
#    2936         # take() does not accept boolean indexers
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1352                 kwargs = {'raise_missing': True if is_setter else
#    1353                           raise_missing}
# -> 1354                 return self._get_listlike_indexer(obj, axis, **kwargs)[1]
#    1355         else:
#    1356             try:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1159         self._validate_read_indexer(keyarr, indexer,
#    1160                                     o._get_axis_number(axis),
# -> 1161                                     raise_missing=raise_missing)
#    1162         return keyarr, indexer
#    1163
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1250             if not(self.name == 'loc' and not raise_missing):
#    1251                 not_found = list(set(key) - set(ax))
# -> 1252                 raise KeyError("{} not in index".format(not_found))
#    1253
#    1254             # we skip the warning on Categorical/Interval
#
# KeyError: "['kj', 'aw_', 'aw', 'au_', 'dT', 'ahra_', 'masG_', 'dT_', 'masG', 'jultin', 'sec', 'kj_', 'stin', 'au', 'ahra', 'van_', 'van'] not in index"

# %%
dt1= datetime(2019,1,1,0,0)
dt2= datetime(1943,4,17,9,49)
dt3= datetime(2019,1,2,22,45)


test1= hora(dt1)
test2= hora(dt2)
test3= hora(dt3)

#Create dataframe
#Method1
data = {
    'dt': [dt1,dt2,dt3],
    'sun' : [test1.sun,test2.sun,test3.sun],
    'moon': [test1.moon,test2.moon,test3.moon],
    'rahu' : [test1.rahu,test2.rahu,test3.rahu],
    'geth' : [test1.geth,test2.geth,test3.geth],
    'mars' : [test1.mars,test2.mars,test3.mars],
    'mercury' : [test1.mercury,test2.mercury,test3.mercury],
    'venus' : [test1.venus,test2.venus,test3.venus],
    'jupiter' : [test1.jupiter,test2.jupiter,test3.jupiter],
    'saturn' : [test1.saturn,test2.saturn,test3.saturn],
    'uranus' : [test1.uranus,test2.uranus,test3.uranus]
}


#Method2
# data = [
#     {'dt': dt1, 'ssun': test1.sun, 'smoon': test1.moon},
#     {'dt': dt2, 'ssun': test2.sun, 'smoon': test2.moon},
#     {'dt': dt3, 'ssun': test3.sun, 'smoon': test3.moon},
# ]

df = pd.DataFrame(data)


loops = ['sun','moon','rahu','geth','mars','mercury','venus','jupiter','saturn','uranus'] 

for planet in loops:
    zodiac = planet+"_Z"
    degree = planet+"_D"
    minute = planet+"_M"
    df[zodiac] =  df[planet]//1800 
    df[degree] =  (df[planet]%1800)//60 
    df[minute] =  (df[planet]%1800)%60

# df['sun_Z'] =  df['ssun']//1800 
# df['sun_D'] =  (df['ssun']%1800)//60 
# df['sun_M'] =  (df['ssun']%1800)%60

df[['sun_Z','sun_D','sun_M','moon_Z','moon_D','moon_M','rahu_Z','rahu_D','rahu_M','geth_Z','geth_D','geth_M']]
#df[['mercury_Z','mercury_D','mercury_M','venus_Z','venus_D','venus_M']]
#df[['mars_Z','mars_D','mars_M','jupiter_Z','jupiter_D','jupiter_M','saturn_Z','saturn_D','saturn_M','uranus_Z','uranus_D','uranus_M']]
# Out:
# Smars = -1498 adjust to 20102
# MTS = -137 adjust to 21463
# SMercury = 22715 adjust to 1115
# Smars = -1431 adjust to 20169
#    sun_Z  sun_D  sun_M  moon_Z  moon_D  moon_M  rahu_Z  rahu_D  rahu_M  \
# 0      8     15     29       6      13      42       3       2      45
# 1      0      3     21       4      25      31       3      28      19
# 2      8     17     29       7       9      51       3       2      39
#
#    geth_Z  geth_D  geth_M
# 0       9       7      50
# 1       5      29       0
# 2       9       6      48

# %%
# Out:
#                   dt                dtny      ahra  jultin     kj     aw  \
# 0     16/4/2582 22:0  16/4/2581 17:11:24  511363.0   573.0  227.0  375.0
# 1     16/4/2582 22:1  16/4/2581 17:11:24  511363.0   573.0  227.0  375.0
# 2     16/4/2582 22:2  16/4/2581 17:11:24  511363.0   573.0  227.0  375.0
# 980    16809.0         16721.0            100.0  5959.0       3.0       9.0
# 981    16809.0         16721.0            100.0  5959.0       3.0       9.0
# 982    16809.0         16721.0            100.0  5959.0       3.0       9.0
# 983    16809.0         16721.0            100.0  5959.0       3.0       9.0
# 984    16809.0         16721.0            100.0  5959.0       3.0       9.0
# 985    16809.0         16721.0            100.0  5959.0       3.0       9.0
# 986    16809.0         16721.0            100.0  5959.0       3.0       9.0
# 987    16809.0         16721.0            100.0  5959.0       3.0       9.0
# 988    16809.0         16721.0            100.0  5959.0       3.0       9.0
# 989    16809.0         16721.0            100.0  5959.0       3.0       9.0
# 990    16809.0         16721.0            100.0  5959.0       3.0       9.0
# 991    16809.0         16721.0            100.0  5959.0       3.0       9.0
# 992    16809.0         16721.0            100.0  5959.0       3.0       9.0
# 993    16809.0         16721.0            100.0  5959.0       3.0       9.0
# 994    16809.0         16721.0            100.0  5959.0       3.0       9.0
# 995    16809.0         16721.0            100.0  5959.0       3.0       9.0
# 996    16809.0         16721.0            100.0  5959.0       3.0       9.0
# 997    16809.0         16721.0            100.0  5959.0       3.0       9.0
# 998    16809.0         16721.0            100.0  5959.0       3.0       9.0
# 999    16809.0         16721.0            100.0  5959.0       3.0       9.0
#
#      uranus_M
# 0        18.0
# 1        18.0
# 2        18.0
# 3        18.0
# 4        18.0
# 5        18.0
# 6        18.0
# 7        18.0
# 8        18.0
# 9        18.0
# 10       18.0
# 11       18.0
# 12       18.0
# 13       18.0
# 14       18.0
# 15       18.0
# 16       18.0
# 17       18.0
# 18       18.0
# 19       18.0
# 20       18.0
# 21       18.0
# 22       18.0
# 23       18.0
# 24       18.0
# 25       18.0
# 26       18.0
# 27       18.0
# 28       18.0
# 29       18.0
# ..        ...
# 970      19.0
# 971      19.0
# 972      19.0
# 973      19.0
# 974      19.0
# 975      19.0
# 976      19.0
# 977      19.0
# 978      19.0
# 979      19.0
# 980      19.0
# 981      19.0
# 982      19.0
# 983      19.0
# 984      19.0
# 985      19.0
# 986      19.0
# 987      19.0
# 988      19.0
# 989      19.0
# 990      19.0
# 991      19.0
# 992      19.0
# 993      19.0
# 994      19.0
# 995      19.0
# 996      19.0
# 997      19.0
# 998      19.0
# 999      19.0
#
# [1000 rows x 213 columns]

# %%
dt1= datetime(1984,1,27,9,49)
dt2= datetime(2007,3,30,8,55)
dt3= datetime(2010,1,27,22,52)


test1= hora(dt1)
test2= hora(dt2)
test3= hora(dt3)

#Create dataframe
#Method1
data = {
    'dt': [dt1,dt2,dt3],
    'ssun' : [test1.sun,test2.sun,test3.sun],
    'smoon': [test1.moon,test2.moon,test3.moon],
    'srahu' : [test1.rahu,test2.rahu,test3.rahu],
    'sgeth' : [test1.geth,test2.geth,test3.geth],
    'smars' : [test1.mars,test2.mars,test3.mars],
    'smercury' : [test1.mercury,test2.mercury,test3.mercury],
    'svenus' : [test1.venus,test2.venus,test3.venus],
    'jupiter' : [test1.jupiter,test2.jupiter,test3.jupiter],
    'ssaturn' : [test1.saturn,test2.saturn,test3.saturn],
    'suranus' : [test1.uranus,test2.uranus,test3.uranus]
}


#Method2
# data = [
#     {'dt': dt1, 'ssun': test1.sun, 'smoon': test1.moon},
#     {'dt': dt2, 'ssun': test2.sun, 'smoon': test2.moon},
#     {'dt': dt3, 'ssun': test3.sun, 'smoon': test3.moon},
# ]

df = pd.DataFrame(data)



#Add row to DataFrame
#METHOD1: add or update specify by row name 
#df.loc[2] = [dt3,10,20]
#df.loc[3] = [dt3,10,20]

#METHOD1.1: Add row to the end of dataframe 
#df.loc[len(df.index)] = [dt3,10,20]
#df.loc[len(df.index)] = [dt3,10,20]
# df.loc[len(df.index)] = [dt3,10,20]


#METHOD2: Add row to some columns
#df = df.append({'dt' : 'dateadded' , 'ssun' : 2222} , ignore_index=True)

#print(len(df.index))


#Change column name
#df.columns = 'a','b','c'

#create new column and data
#method1
#df['newcolumn1'] = ''
#df['newcolumn1'] = [1,2,3,4,5]

#Method2
#df.insert(4, "newcolumn2", [21, 23, 24, 21, 20], True) 
#df.insert(len(df.columns), "newcolumn2", [21, 23, 24, 21, 20], True) 

#Method3-Create new 
#df2 = df.assign(address = ['Delhi', 'Bangalore', 'Chennai', 'Patna', 'ddd']) 
#df2


#Drop column 
#df = df.drop(columns=['newcolumn1','newcolumn2'])


# df['sun_Z'] =  df['ssun']//1800 
# df['sun_D'] =  (df['ssun']%1800)//60 
# df['sun_M'] =  (df['ssun']%1800)%60

# df['moon_Z'] =  df['smoon']//1800 
# df['moon_D'] =  (df['smoon']%1800)//60 
# df['moon_M'] =  (df['smoon']%1800)%60

# df['rahu_Z'] =  df['srahu']//1800 
# df['rahu_D'] =  (df['srahu']%1800)//60 
# df['rahu_M'] =  (df['srahu']%1800)%60

# df['geth_Z'] =  df['sgeth']//1800 
# df['geth_D'] =  (df['sgeth']%1800)//60 
# df['geth_M'] =  (df['sgeth']%1800)%60

# df['mars_Z'] =  df['smars']//1800 
# df['mars_D'] =  (df['smars']%1800)//60 
# df['mars_M'] =  (df['smars']%1800)%60



# df[0:]




#sliding rows 
#df[2:3]

#sliding columns 
# df[['dt','ssun','smoon']]

#sliding rows and columns 
#df.loc[row,colmm]
# df.loc[:,:]
# df.loc[1,['dt']]
# df.loc[1:3,['dt','ssun','smoon']]
# df.loc[1:3,'dt':'ssun']

#Change index
# df.set_index("dt", inplace=True)
# df.loc[:,:]
# df.loc[dt1,:]
# df.loc[dt1:dt3,['ssun','smoon']]
# df.loc[dt1:dt3,'ssun':'ssun_m']

#boolean
# df.loc[df['smoon'] >= 7000,'ssun':'ssun_m']

df



#df.loc[0:3,'dt']>dt1
#df.loc[0:3,'dt']>dt1
#data.set_index("last_name", inplace=True)
# Out:
# uv = 14819
# pholGA = 4019
# khan = 4
# SVenus = 22652 adjust to 1052
# uv = 17719
# pholGA = 3881
# khan = 4
# uv = 7926
# pholGA = 2874
# khan = 3
#                    dt   ssun  smoon  srahu  sgeth  smars  smercury  svenus  \
# 0 1984-01-27 09:49:00  16953  12913   2933  12108  11722     15638   14765
# 1 2007-03-30 08:55:00  20702   7569  19222   2089  18000     19459    1052
# 2 2010-01-27 22:52:00  17003   4207  15932  12377   6532     15557   17071
#
#    jupiter  ssaturn  suranus
# 0    14973    11999    13324
# 1    14290     6638    19352
# 2    18534     9464    19983

# %%
#df[['dt','ssun','sun_Z','sun_D','sun_M','smoon','moon_Z','moon_D','moon_M']]

# %%
# s_ravi = {
#     'jya': [35,32,27,22,13,5],
#     'ravi': [0,35,67,94,116,129]
# }
# #df = pd.DataFrame(s_ravi)
# df = pd.DataFrame(s_ravi)
# #df.iloc[1] = [kj,Ssun]
# #df.append(data)
# df = df.append({'kj' : 'Sahil' , 'sun' : 22} , ignore_index=True)
# df = df.append({'kj' : 'Sahil' , 'sun' : 22} , ignore_index=True)

# df = df.append({'kj' : 'Sahil' , 'sun' : 22 , 'datetime' : dt} , ignore_index=True)
# df = df.append({'kj' : 'Sahil' , 'sun' : 22 , 'datetime' : dtny} , ignore_index=True)


#Create dataframe
df = pd.DataFrame()

# Creating an empty Dataframe with column names only
df = pd.DataFrame(columns=['User_ID', 'UserName', 'Action'])

# Create an empty Dataframe with columns or indices
#df = pd.DataFrame(columns=['User_ID', 'UserName', 'Action'], index=['a', 'b', 'c'])

print(df.head(5))
print(df.tail())

print(df.dtypes)
print(df.index)
print(df.columns)
print(df.values)

#for index,row in df.iterrows():
#    print (index, row['ssun'], row['smoon'])
# Out:
# Empty DataFrame
# Columns: [User_ID, UserName, Action]
# Index: []
# Empty DataFrame
# Columns: [User_ID, UserName, Action]
# Index: []
# User_ID     object
# UserName    object
# Action      object
# dtype: object
# Index([], dtype='object')
# Index(['User_ID', 'UserName', 'Action'], dtype='object')
# []

# %%
day,month,year,hour,minute = 27,1,2527,9,49
christ_year = year-543

dt= datetime(christ_year,month,day,hour,minute)

a = hora(dt)  
print('dt =', a.dt)
print('dtnt =', a.dtny)
print('ahra =', a.ahra)
print('jultin =', a.jultin)
print('kj =', a.kj)
print('aw =', a.aw)
print('masG =', a.masG)
print('dT =', a.dT)
print('au =', a.au)
print('van =', a.van)

print('stin =', a.stin)
print('sec =', a.sec)
print('ahra_ =', a.ahra_)
print('kj_ =', a.kj_)
print('aw_ =', a.aw_)
print('masG_ =', a.masG_)
print('dT_ =', a.dT_)
print('au_ =', a.au_)
print('van_ =', a.van_)

print('sun =', a.sun)
print('moon =', a.moon)
print('rahu =', a.rahu)
print('geth =', a.geth)
print('mars =', a.mars)
print('mercury =', a.mercury)
print('venus =', a.venus)
print('jupiter =', a.jupiter)
print('saturn =', a.saturn)
print('uranus =', a.uranus)
# Out:
# dt = 1984-01-27 09:31:00
# dtnt = 1983-04-16 11:38:24
# ahra = 491274
# jultin = 388
# kj = 412
# aw = 144
# masG = 16636
# dT = 4
# au = 2621
# van = 0
# stin = 286
# sec = 34260
# ahra_ = 491560
# kj_ = 228729
# aw_ = 97
# masG_ = 16645
# dT_ = 24
# au_ = 2907
# van_ = 6
# sun = 16953
# moon = 12913
# rahu = 2933
# geth = 12108
# mars = 11722
# mercury = 15638
# venus = 14765
# jupiter = 14973
# saturn = 11999
# uranus = 13324

# %% [markdown]
# #
