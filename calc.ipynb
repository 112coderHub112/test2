# %%
import math
from datetime import date
from datetime import datetime
from datetime import timedelta
import pandas as pd

# %%
def NYdate(jula_year):
    ny = jula_year*0.25875-int(jula_year/4 +0.5)+int(jula_year/100 +0.38)-int(jula_year/400 +0.595)-5.53375
    jultin =  ((jula_year*292207)+373)%800
    hour,frac = divmod(jultin*24,800)
    minute,frac = divmod(frac*60,800)
    second,frac = divmod(frac*60,800)
    christ_year = jula_year+638
    dtny = datetime(christ_year, 4, int(ny), hour , minute, second)
    return dtny;

# %%
class hora:
    sun_table = [[35,32,27,22,13,5,0], [0,35,67,94,116,129,134]]
    moon_table = [[77,71,61,47,30,10,0], [0,77,148,209,256,286,296]]
        
    def __init__(self,dt):
        offset = timedelta(minutes=18)
        dt= dt-offset
        jula_year = dt.year-638    
        d = date(dt.year,dt.month,dt.day)
        dtf= datetime(dt.year,dt.month,dt.day,0,0)        
        dtny = NYdate(jula_year)
        dny = date(dtny.year,dtny.month,dtny.day)
        
        if (dt>=dtny):
            jula_newyear = jula_year
        elif (dt<dtny):
            jula_newyear = jula_year-1
            dtny = NYdate(jula_newyear)
            dny = date(dtny.year,dtny.month,dtny.day)

            
        temp = (jula_newyear*292207)+373
        ahra = (temp//800)+1
        jultin =  temp%800

        kj = 800-jultin
        temp,aw= divmod((ahra*11)+650,692)
        masG,dT=divmod((ahra+temp),30)

        au = (ahra-621)%3232
        van = ahra%7

        stin = (d-dny).days
        sec = (dt-dtf).seconds

        ahra_ = ahra+stin
        stkm = (stin-1)*800
        kj_ = kj + stkm + sec//108

        awjt = (stin-1)*703+aw
        aws = awjt+(sec*703)//86400
        awdT,aw_=divmod(aws,692)
        temp,dT_=divmod((awdT+dT),30)
        masG_ = masG+temp
        van_=ahra_%7

        if (au+stin > 3232):
            au_ = au+stin-3232
        else: au_= au+stin        
        
        
##########################SUN###############################
        z = kj_ // 24350
        z_remainder = kj_ % 24350
        degree = z_remainder//811
        d_remainder = z_remainder % 811
        minute = d_remainder//14

        d_total = z*30+degree
        mathasun = d_total*60+minute-3


        if mathasun >= 21600:
            raise Exception('mathasun exceed or equal 21600')
        elif mathasun < 0:
            raise Exception('mathasun below 0')
        elif mathasun < 4800:
            pholsun = 21600+mathasun-4800
        else:
            pholsun = mathasun-4800


        if pholsun >= 21600:
            raise Exception('pholsun exceed or equal 21600')
        elif pholsun < 0:
            raise Exception('pholsun below 0')
        elif pholsun >= 0 and pholsun <5400:
            pholGA = pholsun

        elif pholsun >= 5400 and pholsun <10800:
            pholGA = 10800-pholsun

        elif pholsun >= 10800 and pholsun <16200:
            pholGA = pholsun-10800

        elif pholsun >= 16200:
            pholGA = 21600-pholsun


        khan = pholGA // 900
        pushlip = pholGA % 900


        jyaGA = (self.sun_table[0][khan]*pushlip) // 900
        ravipphol = self.sun_table[1][khan]+jyaGA


        if pholsun < 10800:
            Ssun = mathasun-ravipphol
        elif pholsun > 10800:
            Ssun= mathasun+ravipphol
        elif pholsun == 10800:
            if(ravipphol != 0):raise Exception('pholsun=10800 but ravipphol not 0')
            Ssun= mathasun

        if Ssun < 0:
            Ssun = Ssun+21600
        elif Ssun > 21600:
            Ssun= Ssun-21600
            
        #zodiac,frac = divmod(Ssun,1800)
        #degree,minute = divmod(frac,60)    
#        sun = []
#        sun.append(Ssun)
#         sun.append(Ssun//1800)
#         sun.append((Ssun%1800)//60)
#         sun.append((Ssun%1800)%60)

#         print('pholGA =',pholGA)
#         print('khan =',khan)
#         print('kj_ =',kj_)
#         print('mathasun =',mathasun)
#         print('Ssun =',Ssun)

##########################MOON###############################
        temp = (au_-1)*86400+sec

        #zodiac,frac = divmod(x,23270400)
        #degree,frac = divmod(frac,775680)
        #minute = frac // 12928

        zodiac = temp//23270400
        degree = (temp%23270400)//775680
        minute = ((temp%23270400)%775680)//12928
        d_total = zodiac*30+degree
        mtu = d_total*60+minute+2


        mathamoon = mathasun + aw_ +(aw_//25)+(dT_*720)-40
        if mathamoon >= 21600: 
            mathamoon = mathamoon-21600

        if mathamoon >= 21600:
            raise Exception('mathamoon exceed or equal 21600')
        elif mathamoon < 0:
            raise Exception('mathamoon below 0')
        elif mtu >= 21600:
            raise Exception('mtu exceed or equal 21600')
        elif mtu < 0:
            raise Exception('mtu below 0')
        elif mathamoon>=mtu:
            uv =  mathamoon-mtu
        elif mathamoon<mtu:
            uv = 21600+mathamoon-mtu


        if uv >= 21600:
            raise Exception('uv exceed or equal 21600')
        elif uv < 0:
            raise Exception('uv below 0')
        elif uv >= 0 and uv <5400:
            pholGA = uv
        elif uv >= 5400 and uv <10800:
            pholGA = 10800-uv
        elif uv >= 10800 and uv <16200:
            pholGA = uv-10800
        elif uv >= 16200:
            pholGA = 21600-uv


        khan = pholGA // 900
        pushlip = pholGA % 900

        jyaGA = (self.moon_table[0][khan]*pushlip) // 900
        chandraphol = self.moon_table[1][khan]+jyaGA

        if uv < 10800:
            Smoon = mathamoon-chandraphol
        elif uv > 10800:
            Smoon= mathamoon+chandraphol
        elif uv == 10800:
            if(chandraphol != 0):raise Exception('uv=10800 but chandraphol not 0')
            Smoon= mathamoon

        if Smoon < 0:
            Smoon = Smoon+21600
        elif Smoon > 21600:
            Smoon= Smoon-21600


##########################RAHU###############################
        matharavi = mathasun-23
        srb = jula_newyear-610
        manut = (srb*21600)+ matharavi

        a = manut//20
        b = manut//265
        pmt = (a+b)%21600

        Srahu = 15150-pmt
        if Srahu<0:
            Srahu = Srahu+21600

##########################GETH###############################
        pholgt = (ahra_-345)%679
        mathageth = (pholgt*21600 + (sec*21600)//86400)//679
        Sgeth = 21600-mathageth
        zodiac,frac = divmod(Sgeth,1800)
        degree,minute = divmod(frac,60)

        


                
##########################Inner Plannets##################################
        plannet = ['mercury','venus']
        for plannet in plannet: 
            if plannet  == 'mercury':
                matha = ((manut*7)//46 + (manut*4)//1 + 10642)%21600
                pholPK = matharavi-13200
            elif plannet == 'venus':
                matha = ((manut*5)//3 - (manut*10)//243 + 10944)%21600
                pholPK = matharavi-4800
                
            if pholPK<0:
                pholPK = pholPK+21600

            ptma = (pholPK//5400)+1
            if ptma == 1:
                puchaPT = pholPK
                khotiPT = 5400-pholPK
            elif ptma == 2:
                puchaPT = 10800-pholPK
                khotiPT = pholPK-5400
            elif ptma == 3:
                puchaPT = pholPK-10800
                khotiPT = 16200-pholPK
            elif ptma == 4:
                puchaPT = 21600-pholPK
                khotiPT = pholPK-16200

            # puchaPT = 1064
            # khotiPT = 4336

            if puchaPT < 0:
                raise Exception('puchaPT is below 0')
            elif puchaPT > 5400:
                raise Exception('puchaPT is greater than 5400')
            elif puchaPT < 1800:
                MTpucha = (puchaPT*14640)//1800
            elif (puchaPT >= 1800) and (puchaPT < 3600) :
                MTpucha = (((puchaPT-1800)*10980)//1800)+14640
            elif puchaPT >= 3600 :
                MTpucha = (((puchaPT-3600)*3660)//1800)+25620

            if khotiPT < 0:
                raise Exception('khotiPT is below 0')
            elif khotiPT > 5400:
                raise Exception('khotiPT is greater than 5400')
            elif khotiPT < 1800:
                MTKhoti = (khotiPT*14640)//1800
            elif (khotiPT >= 1800) and (khotiPT < 3600) :
                MTKhoti = (((khotiPT-1800)*10980)//1800)+14640
            elif khotiPT >= 3600 :
                MTKhoti = (((khotiPT-3600)*3660)//1800)+25620

            MTKhoti = (MTKhoti+30)//60
            khotiphol = MTKhoti//2


            if plannet == 'mercury':
                if (ptma ==1) or (ptma ==4):
                    MTcheta = 100*60 + khotiphol
                elif (ptma ==2) or (ptma ==3):
                    MTcheta=  100*60 - khotiphol
            elif plannet == 'venus':
                if (ptma ==1) or (ptma ==4):
                    MTcheta = 320*60 + khotiphol
                elif (ptma ==2) or (ptma ==3):
                    MTcheta=  320*60 - khotiphol          
            
            

            MTphol = (MTpucha*60)//MTcheta


            if (ptma ==1) or (ptma ==2):
                if (matharavi  - MTphol)>=0:
                    MTS = matharavi  - MTphol
                elif (matharavi  - MTphol)<0:
                    MTS =  matharavi  - MTphol + 21600
                    print('MTS =',matharavi  - MTphol,'adjust to',MTS)          

            elif (ptma ==3) or (ptma ==4):
                if (matharavi  + MTphol)>=21600:
                    MTS = matharavi  + MTphol - 21600
                    print('MTS =',matharavi  + MTphol,'adjust to',MTS)
                elif(matharavi  + MTphol)<21600:
                    MTS = matharavi  + MTphol


            pholMT = MTS-matha
            if pholMT<0:
                pholMT=pholMT+21600

            ptnd = (pholMT//5400)+1
            if ptnd == 1:
                puchaTY = pholMT
                khotiTY = 5400-pholMT
            elif ptnd == 2:
                puchaTY = 10800-pholMT
                khotiTY = pholMT-5400
            elif ptnd == 3:
                puchaTY = pholMT-10800
                khotiTY = 16200-pholMT
            elif ptnd == 4:
                puchaTY = 21600-pholMT
                khotiTY = pholMT-16200

            if puchaTY < 0:
                raise Exception('puchaTY is below 0')
            elif puchaTY > 5400:
                raise Exception('puchaTY is greater than 5400')
            elif puchaTY < 1800:
                SGPucha = (puchaTY*14640)//1800
            elif (puchaTY >= 1800) and (puchaTY < 3600) :
                SGPucha = (((puchaTY-1800)*10980)//1800)+14640
            elif puchaTY >= 3600 :
                SGPucha = (((puchaTY-3600)*3660)//1800)+25620

            if khotiTY < 0:
                raise Exception('khotiTY is below 0')
            elif khotiTY > 5400:
                raise Exception('khotiTY is greater than 5400')
            elif khotiTY < 1800:
                SGKhoti = (khotiTY*14640)//1800
            elif (khotiTY >= 1800) and (khotiTY < 3600) :
                SGKhoti = (((khotiTY-1800)*10980)//1800)+14640
            elif khotiTY >= 3600 :
                SGKhoti = (((khotiTY-3600)*3660)//1800)+25620

            SGKhoti = (SGKhoti+30)//60
            SGphol = ((SGPucha+30)//60)//3


            if plannet == 'mercury': p= 21*60
            elif plannet == 'venus': p= 11*60            
            
            
            sp = p+SGphol

            if (ptnd ==1) or (ptnd ==4):
                SGcheta = sp + SGKhoti
            elif (ptnd ==2) or (ptnd ==3):
                SGcheta = sp - SGKhoti

            if SGcheta < 0:
                raise Exception('SGcheta < 0')
            elif khotiTY > 21600:
                raise Exception('SGcheta > SGcheta')

            mahaphol = (SGPucha*60)//SGcheta
            
            
            
            if plannet == 'mercury': 
                if (ptnd ==1) or (ptnd ==2):
                    if (MTS - mahaphol)>=0:
                        SMercury = MTS - mahaphol
                    elif (MTS - mahaphol)<0:
                        SMercury =  MTS - mahaphol + 21600
                        print('Smercury =',MTS - mahaphol,'adjust to',SMercury)          

                elif (ptnd ==3) or (ptnd ==4):
                    if (MTS + mahaphol)>=21600:
                        SMercury = MTS + mahaphol - 21600
                        print('SMercury =',MTS + mahaphol,'adjust to',SMercury)
                    elif(MTS + mahaphol)<21600:
                        SMercury = MTS + mahaphol
            elif plannet == 'venus': 
                if (ptnd ==1) or (ptnd ==2):
                    if (MTS - mahaphol)>=0:
                        SVenus = MTS - mahaphol
                    elif (MTS - mahaphol)<0:
                        SVenus =  MTS - mahaphol + 21600
                        print('SVenus =',MTS - mahaphol,'adjust to',SVenus)          

                elif (ptnd ==3) or (ptnd ==4):
                    if (MTS + mahaphol)>=21600:
                        SVenus = MTS + mahaphol - 21600
                        print('SVenus =',MTS + mahaphol,'adjust to',SVenus)
                    elif(MTS + mahaphol)<21600:
                        SVenus = MTS + mahaphol               





                
##########################Other Plannets####################################

        plannet = ['mars','jupiter','saturn','uranus']
        for plannet in plannet: 
 
            if plannet  == 'mars':
                matha  =  ((manut*1)//2 + (manut*16)//505 + 5420)%21600         
                pholPK = matha-7620
            elif plannet == 'jupiter':
                matha  = ((manut*1)//12 + (manut*1)//1032 + 14297)%21600
                pholPK = matha-10320
            elif plannet == 'saturn':
                matha  = ((manut*1)//30 + (manut*6)//10000 + 11944)%21600
                pholPK = matha-14820
            elif plannet == 'uranus':
                matha  = ((manut*1)//84 + (manut*1)//7224 + 16277)%21600
                pholPK = matha-7440        

            if pholPK<0:
                pholPK = pholPK+21600


            ptma = (pholPK//5400)+1
            if ptma == 1:
                puchaPT = pholPK
                khotiPT = 5400-pholPK
            elif ptma == 2:
                puchaPT = 10800-pholPK
                khotiPT = pholPK-5400
            elif ptma == 3:
                puchaPT = pholPK-10800
                khotiPT = 16200-pholPK
            elif ptma == 4:
                puchaPT = 21600-pholPK
                khotiPT = pholPK-16200

            # puchaPT = 1064
            # khotiPT = 4336

            if puchaPT < 0:
                raise Exception('puchaPT is below 0')
            elif puchaPT > 5400:
                raise Exception('puchaPT is greater than 5400')
            elif puchaPT < 1800:
                MTpucha = (puchaPT*14640)//1800
            elif (puchaPT >= 1800) and (puchaPT < 3600) :
                MTpucha = (((puchaPT-1800)*10980)//1800)+14640
            elif puchaPT >= 3600 :
                MTpucha = (((puchaPT-3600)*3660)//1800)+25620

            if khotiPT < 0:
                raise Exception('khotiPT is below 0')
            elif khotiPT > 5400:
                raise Exception('khotiPT is greater than 5400')
            elif khotiPT < 1800:
                MTKhoti = (khotiPT*14640)//1800
            elif (khotiPT >= 1800) and (khotiPT < 3600) :
                MTKhoti = (((khotiPT-1800)*10980)//1800)+14640
            elif khotiPT >= 3600 :
                MTKhoti = (((khotiPT-3600)*3660)//1800)+25620

            MTKhoti = (MTKhoti+30)//60
            khotiphol = MTKhoti//2


            if plannet == 'mars':
                if (ptma ==1) or (ptma ==4):
                    MTcheta = 45*60 + khotiphol
                elif (ptma ==2) or (ptma ==3):
                    MTcheta=  45*60 - khotiphol
            elif plannet == 'jupiter':
                if (ptma ==1) or (ptma ==4):
                    MTcheta = 92*60 + khotiphol
                elif (ptma ==2) or (ptma ==3):
                    MTcheta=  92*60 - khotiphol
            elif plannet == 'saturn':
                if (ptma ==1) or (ptma ==4):
                    MTcheta = 63*60 + khotiphol
                elif (ptma ==2) or (ptma ==3):
                    MTcheta=  63*60 - khotiphol
            elif plannet == 'uranus':
                if (ptma ==1) or (ptma ==4):
                    MTcheta = 644*60 + khotiphol
                elif (ptma ==2) or (ptma ==3):
                    MTcheta=  644*60 - khotiphol  



            MTphol = (MTpucha*60)//MTcheta


            if (ptma ==1) or (ptma ==2):
                if (matha - MTphol)>=0:
                    MTS = matha - MTphol
                elif (matha - MTphol)<0:
                    MTS =  matha - MTphol + 21600
                    print('MTS =',matha - MTphol,'adjust to',MTS)          

            elif (ptma ==3) or (ptma ==4):
                if (matha + MTphol)>=21600:
                    MTS = matha + MTphol - 21600
                    print('MTS =',matha + MTphol,'adjust to',MTS)
                elif(matha + MTphol)<21600:
                    MTS = matha + MTphol


            pholMT = MTS-matharavi
            if pholMT<0:
                pholMT=pholMT+21600

            ptnd = (pholMT//5400)+1
            if ptnd == 1:
                puchaTY = pholMT
                khotiTY = 5400-pholMT
            elif ptnd == 2:
                puchaTY = 10800-pholMT
                khotiTY = pholMT-5400
            elif ptnd == 3:
                puchaTY = pholMT-10800
                khotiTY = 16200-pholMT
            elif ptnd == 4:
                puchaTY = 21600-pholMT
                khotiTY = pholMT-16200

            if puchaTY < 0:
                raise Exception('puchaTY is below 0')
            elif puchaTY > 5400:
                raise Exception('puchaTY is greater than 5400')
            elif puchaTY < 1800:
                SGPucha = (puchaTY*14640)//1800
            elif (puchaTY >= 1800) and (puchaTY < 3600) :
                SGPucha = (((puchaTY-1800)*10980)//1800)+14640
            elif puchaTY >= 3600 :
                SGPucha = (((puchaTY-3600)*3660)//1800)+25620

            if khotiTY < 0:
                raise Exception('khotiTY is below 0')
            elif khotiTY > 5400:
                raise Exception('khotiTY is greater than 5400')
            elif khotiTY < 1800:
                SGKhoti = (khotiTY*14640)//1800
            elif (khotiTY >= 1800) and (khotiTY < 3600) :
                SGKhoti = (((khotiTY-1800)*10980)//1800)+14640
            elif khotiTY >= 3600 :
                SGKhoti = (((khotiTY-3600)*3660)//1800)+25620

            SGKhoti = (SGKhoti+30)//60
            SGphol = ((SGPucha+30)//60)//3

            
            if plannet == 'mars': p= (4*MTcheta)//15 
            elif plannet == 'jupiter': p= (3*MTcheta)//7
            elif plannet == 'saturn': p= (7*MTcheta)//6 
            elif plannet == 'uranus':p= (3*MTcheta)//7 
    

            sp = p+SGphol
            if (ptnd ==1) or (ptnd ==4):
                SGcheta = sp + SGKhoti
            elif (ptnd ==2) or (ptnd ==3):
                SGcheta = sp - SGKhoti

            if SGcheta < 0:
                raise Exception('SGcheta < 0')
            elif khotiTY > 21600:
                raise Exception('SGcheta > SGcheta')

            mahaphol = (SGPucha*60)//SGcheta

            

            if plannet == 'mars':
                if (ptnd ==1) or (ptnd ==2):
                    if (MTS - mahaphol)>=0:
                        Smars = MTS - mahaphol
                    elif (MTS - mahaphol)<0:
                        Smars =  MTS - mahaphol + 21600
                        print('Smars =',MTS - mahaphol,'adjust to',Smars)          

                elif (ptnd ==3) or (ptnd ==4):
                    if (MTS + mahaphol)>=21600:
                        Smars = MTS + mahaphol - 21600
                        print('Smars =',MTS + mahaphol,'adjust to',Smars)
                    elif(MTS + mahaphol)<21600:
                        Smars = MTS + mahaphol 
            elif plannet == 'jupiter':
                if (ptnd ==1) or (ptnd ==2):
                    if (MTS - mahaphol)>=0:
                        Jupiter = MTS - mahaphol
                    elif (MTS - mahaphol)<0:
                        Jupiter =  MTS - mahaphol + 21600
                        print('Jupiter =',MTS - mahaphol,'adjust to',Jupiter)          

                elif (ptnd ==3) or (ptnd ==4):
                    if (MTS + mahaphol)>=21600:
                        Jupiter = MTS + mahaphol - 21600
                        print('Jupiter =',MTS + mahaphol,'adjust to',Jupiter)
                    elif(MTS + mahaphol)<21600:
                        Jupiter = MTS + mahaphol 
            elif plannet == 'saturn':
                if (ptnd ==1) or (ptnd ==2):
                    if (MTS - mahaphol)>=0:
                        SSaturn = MTS - mahaphol
                    elif (MTS - mahaphol)<0:
                        SSaturn =  MTS - mahaphol + 21600
                        print('SSaturn =',MTS - mahaphol,'adjust to',SSaturn)          

                elif (ptnd ==3) or (ptnd ==4):
                    if (MTS + mahaphol)>=21600:
                        SSaturn = MTS + mahaphol - 21600
                        print('SSaturn =',MTS + mahaphol,'adjust to',SSaturn)
                    elif(MTS + mahaphol)<21600:
                        SSaturn = MTS + mahaphol
            elif plannet == 'uranus':
                if (ptnd ==1) or (ptnd ==2):
                    if (MTS - mahaphol)>=0:
                        SUranus = MTS - mahaphol
                    elif (MTS - mahaphol)<0:
                        SUranus =  MTS - mahaphol + 21600
                        print('SUranus =',MTS - mahaphol,'adjust to',SUranus)          

                elif (ptnd ==3) or (ptnd ==4):
                    if (MTS + mahaphol)>=21600:
                        SUranus = MTS + mahaphol - 21600
                        print('SUranus =',MTS + mahaphol,'adjust to',SUranus)
                    elif(MTS + mahaphol)<21600:
                        SUranus = MTS + mahaphol 
    



        

#         print('uv =',uv)
#         print('pholGA =',pholGA)
#         print('khan =',khan)
#         print('Smoon =',Smoon)

#         print('au_ =',au_)
#         print('mtu =',mtu)
#         print('uv =',uv)
#         print('Smoon =',Smoon)

        #TS Parameter (yearly parameter) 
        self.dt = dt  
        self.dtny = dtny 
        self.dny = dny 
        self.ahra = ahra 
        self.jultin = jultin 
        self.kj = kj 
        self.aw = aw 
        self.masG = masG 
        self.dT = dT
        self.au = au 
        self.van = van 
        
        #Given Datetime parameter
        self.stin = stin 
        self.sec = sec 
        self.ahra_ = ahra_ 
        self.kj_ = kj_ 
        self.aw_ = aw_ 
        self.masG_ = masG_ 
        self.dT_ = dT_
        self.au_ = au_ 
        self.van_ = van_
     
        #locations in zodiac (minutes maximum = 21600) 
        self.sun = Ssun
        self.moon = Smoon
        self.rahu = Srahu
        self.geth = Sgeth
        self.mars = Smars
        self.mercury = SMercury
        self.venus = SVenus
        self.jupiter = Jupiter
        self.saturn = SSaturn
        self.uranus = SUranus

# %%
startdate = datetime(2019,5,10,0,0)
#startdate = datetime(2019,4,16,0,0) mathasun-
df = pd.DataFrame()
diff = 108000
#diff = 366
#diff = 2000


for i in range(0,diff):
    interval = timedelta(minutes=i)
#    interval = timedelta(days=i)
    dt = startdate+interval
    h = hora(dt)    
    data = {
        'dt': dt,
        'sun' : h.sun,
        'moon': h.moon,
        'rahu' : h.rahu,
        'geth' : h.geth,
        'mars' : h.mars,
        'mercury' : h.mercury,
        'venus' : h.venus,
        'jupiter' : h.jupiter,
        'saturn' : h.saturn,
        'uranus' : h.uranus
    }


    print(dt.day,dt.month,dt.year,dt.hour,':',dt.minute)
    #df = pd.DataFrame(data)
    df = df.append(data , ignore_index=True)
df
#loops = ['sun','moon','rahu','geth','mars','mercury','venus','jupiter','saturn','uranus'] 

# for planet in loops:
#     zodiac = planet+"_Z"
#     degree = planet+"_D"
#     minute = planet+"_M"
#     df[zodiac] =  df[planet]//1800 
#     df[degree] =  (df[planet]%1800)//60 
#     df[minute] =  (df[planet]%1800)%60
    
#df.dtypes



# data = {
#     'dt': [startdate],
#     'sun' : [h.sun],
#     'moon': [h.moon],
#     'rahu' : [h.rahu],
#     'geth' : [h.geth],
#     'mars' : [h.mars],
#     'mercury' : [h.mercury],
#     'venus' : [h.venus],
#     'jupiter' : [h.jupiter],
#     'saturn' : [h.saturn],
#     'uranus' : [h.uranus]
# }
# Out:
# SVenus = -178 adjust to 21422
# 10 5 2019 0 : 0
# SVenus = -178 adjust to 21422
# 10 5 2019 0 : 1
# SVenus = -178 adjust to 21422
# 10 5 2019 0 : 2
# SVenus = -178 adjust to 21422
# 10 5 2019 0 : 3
# SVenus = -178 adjust to 21422
# 10 5 2019 0 : 4
# SVenus = -178 adjust to 21422
# 10 5 2019 0 : 5
# SVenus = -178 adjust to 21422
# 10 5 2019 0 : 6
# SVenus = -178 adjust to 21422
# 10 5 2019 0 : 7
# SVenus = -178 adjust to 21422
# 10 5 2019 0 : 8
# SVenus = -178 adjust to 21422
# 10 5 2019 0 : 9
# SVenus = -178 adjust to 21422
# 10 5 2019 0 : 10
# SVenus = -177 adjust to 21423
# 10 5 2019 0 : 11
# SVenus = -177 adjust to 21423
# 10 5 2019 0 : 12
# SVenus = -177 adjust to 21423
# 10 5 2019 0 : 13
# SVenus = -177 adjust to 21423
# 10 5 2019 0 : 14
# SVenus = -177 adjust to 21423
# 10 5 2019 0 : 15
# SVenus = -177 adjust to 21423
# 10 5 2019 0 : 16
# SVenus = -177 adjust to 21423
# 10 5 2019 0 : 17
# SVenus = -177 adjust to 21423
# 10 5 2019 0 : 18
# SVenus = -177 adjust to 21423
# 10 5 2019 0 : 19
# SVenus = -177 adjust to 21423
# 10 5 2019 0 : 20
# SVenus = -177 adjust to 21423
# 10 5 2019 0 : 21
# SVenus = -177 adjust to 21423
# 10 5 2019 0 : 22
# SVenus = -177 adjust to 21423
# 10 5 2019 0 : 23
# SVenus = -177 adjust to 21423
# 10 5 2019 0 : 24
# SVenus = -177 adjust to 21423
# 10 5 2019 0 : 25
# SVenus = -177 adjust to 21423
# 10 5 2019 0 : 26
# SVenus = -177 adjust to 21423
# 10 5 2019 0 : 27
# SVenus = -177 adjust to 21423
# 10 5 2019 0 : 28
# SVenus = -177 adjust to 21423
# 10 5 2019 0 : 29
# SVenus = -177 adjust to 21423
# 10 5 2019 0 : 30
# SVenus = -177 adjust to 21423
# 10 5 2019 0 : 31
# SVenus = -177 adjust to 21423
# 10 5 2019 0 : 32
# SVenus = -177 adjust to 21423
# 10 5 2019 0 : 33
# SVenus = -177 adjust to 21423
# 10 5 2019 0 : 34
# SVenus = -177 adjust to 21423
# 10 5 2019 0 : 35
# SVenus = -176 adjust to 21424
# 10 5 2019 0 : 36
# SVenus = -176 adjust to 21424
# 10 5 2019 0 : 37
# SVenus = -176 adjust to 21424
# 10 5 2019 0 : 38
# SVenus = -176 adjust to 21424
# 10 5 2019 0 : 39
# SVenus = -176 adjust to 21424
# 10 5 2019 0 : 40
# SVenus = -176 adjust to 21424
# 10 5 2019 0 : 41
# SVenus = -176 adjust to 21424
# 10 5 2019 0 : 42
# SVenus = -176 adjust to 21424
# 10 5 2019 0 : 43
# SVenus = -176 adjust to 21424
# 10 5 2019 0 : 44
# SVenus = -176 adjust to 21424
# 10 5 2019 0 : 45
# SVenus = -176 adjust to 21424
# 10 5 2019 0 : 46
# SVenus = -176 adjust to 21424
# 10 5 2019 0 : 47
# SVenus = -176 adjust to 21424
# 10 5 2019 0 : 48
# SVenus = -176 adjust to 21424
# 10 5 2019 0 : 49
# SVenus = -176 adjust to 21424
# 10 5 2019 0 : 50
# SVenus = -176 adjust to 21424
# 10 5 2019 0 : 51
# SVenus = -176 adjust to 21424
# 10 5 2019 0 : 52
# SVenus = -176 adjust to 21424
# 10 5 2019 0 : 53
# SVenus = -176 adjust to 21424
# 10 5 2019 0 : 54
# SVenus = -176 adjust to 21424
# 10 5 2019 0 : 55
# SVenus = -176 adjust to 21424
# 10 5 2019 0 : 56
# SVenus = -176 adjust to 21424
# 10 5 2019 0 : 57
# SVenus = -176 adjust to 21424
# 10 5 2019 0 : 58
# SVenus = -176 adjust to 21424
# 10 5 2019 0 : 59
# SVenus = -176 adjust to 21424
# 10 5 2019 1 : 0
# SVenus = -176 adjust to 21424
# 10 5 2019 1 : 1
# SVenus = -175 adjust to 21425
# 10 5 2019 1 : 2
# SVenus = -175 adjust to 21425
# 10 5 2019 1 : 3
# SVenus = -175 adjust to 21425
# 10 5 2019 1 : 4
# SVenus = -175 adjust to 21425
# 10 5 2019 1 : 5
# SVenus = -175 adjust to 21425
# 10 5 2019 1 : 6
# SVenus = -175 adjust to 21425
# 10 5 2019 1 : 7
# SVenus = -175 adjust to 21425
# 10 5 2019 1 : 8
# SVenus = -175 adjust to 21425
# 10 5 2019 1 : 9
# SVenus = -175 adjust to 21425
# 10 5 2019 1 : 10
# SVenus = -175 adjust to 21425
# 10 5 2019 1 : 11
# SVenus = -175 adjust to 21425
# 10 5 2019 1 : 12
# SVenus = -175 adjust to 21425
# 10 5 2019 1 : 13
# SVenus = -175 adjust to 21425
# 10 5 2019 1 : 14
# SVenus = -175 adjust to 21425
# 10 5 2019 1 : 15
# SVenus = -175 adjust to 21425
# 10 5 2019 1 : 16
# SVenus = -175 adjust to 21425
# 10 5 2019 1 : 17
# SVenus = -175 adjust to 21425
# 10 5 2019 1 : 18
# SVenus = -175 adjust to 21425
# 10 5 2019 1 : 19
# SVenus = -175 adjust to 21425
# 10 5 2019 1 : 20
# SVenus = -175 adjust to 21425
# 10 5 2019 1 : 21
# SVenus = -175 adjust to 21425
# 10 5 2019 1 : 22
# SVenus = -175 adjust to 21425
# 10 5 2019 1 : 23
# SVenus = -175 adjust to 21425
# 10 5 2019 1 : 24
# SVenus = -175 adjust to 21425
# 10 5 2019 1 : 25
# SVenus = -175 adjust to 21425
# 10 5 2019 1 : 26
# SVenus = -174 adjust to 21426
# 10 5 2019 1 : 27
# SVenus = -174 adjust to 21426
# 10 5 2019 1 : 28
# SVenus = -174 adjust to 21426
# 10 5 2019 1 : 29
# SVenus = -174 adjust to 21426
# 10 5 2019 1 : 30
# SVenus = -174 adjust to 21426
# 10 5 2019 1 : 31
# SVenus = -174 adjust to 21426
# 10 5 2019 1 : 32
# SVenus = -174 adjust to 21426
# 10 5 2019 1 : 33
# SVenus = -174 adjust to 21426
# 10 5 2019 1 : 34
# SVenus = -174 adjust to 21426
# 10 5 2019 1 : 35
# SVenus = -174 adjust to 21426
# 10 5 2019 1 : 36
# SVenus = -174 adjust to 21426
# 10 5 2019 1 : 37
# SVenus = -174 adjust to 21426
# 10 5 2019 1 : 38
# SVenus = -174 adjust to 21426
# 10 5 2019 1 : 39
# SVenus = -174 adjust to 21426
# 10 5 2019 1 : 40
# SVenus = -174 adjust to 21426
# 10 5 2019 1 : 41
# SVenus = -174 adjust to 21426
# 10 5 2019 1 : 42
# SVenus = -174 adjust to 21426
# 10 5 2019 1 : 43
# SVenus = -174 adjust to 21426
# 10 5 2019 1 : 44
# SVenus = -174 adjust to 21426
# 10 5 2019 1 : 45
# SVenus = -174 adjust to 21426
# 10 5 2019 1 : 46
# SVenus = -174 adjust to 21426
# 10 5 2019 1 : 47
# SVenus = -174 adjust to 21426
# 10 5 2019 1 : 48
# SVenus = -174 adjust to 21426
# 10 5 2019 1 : 49
# SVenus = -174 adjust to 21426
# 10 5 2019 1 : 50
# SVenus = -174 adjust to 21426
# 10 5 2019 1 : 51
# SVenus = -173 adjust to 21427
# 10 5 2019 1 : 52
# SVenus = -173 adjust to 21427
# 10 5 2019 1 : 53
# SVenus = -173 adjust to 21427
# 10 5 2019 1 : 54
# SVenus = -173 adjust to 21427
# 10 5 2019 1 : 55
# SVenus = -173 adjust to 21427
# 10 5 2019 1 : 56
# SVenus = -173 adjust to 21427
# 10 5 2019 1 : 57
# SVenus = -173 adjust to 21427
# 10 5 2019 1 : 58
# SVenus = -173 adjust to 21427
# 10 5 2019 1 : 59
# SVenus = -173 adjust to 21427
# 10 5 2019 2 : 0
# SVenus = -173 adjust to 21427
# 10 5 2019 2 : 1
# SVenus = -173 adjust to 21427
# 10 5 2019 2 : 2
# SVenus = -173 adjust to 21427
# 10 5 2019 2 : 3
# SVenus = -173 adjust to 21427
# 10 5 2019 2 : 4
# SVenus = -173 adjust to 21427
# 10 5 2019 2 : 5
# SVenus = -173 adjust to 21427
# 10 5 2019 2 : 6
# SVenus = -173 adjust to 21427
# 10 5 2019 2 : 7
# SVenus = -173 adjust to 21427
# 10 5 2019 2 : 8
# SVenus = -173 adjust to 21427
# 10 5 2019 2 : 9
# SVenus = -173 adjust to 21427
# 10 5 2019 2 : 10
# SVenus = -173 adjust to 21427
# 10 5 2019 2 : 11
# SVenus = -173 adjust to 21427
# 10 5 2019 2 : 12
# SVenus = -173 adjust to 21427
# 10 5 2019 2 : 13
# SVenus = -173 adjust to 21427
# 10 5 2019 2 : 14
# SVenus = -173 adjust to 21427
# 10 5 2019 2 : 15
# SVenus = -173 adjust to 21427
# 10 5 2019 2 : 16
# SVenus = -172 adjust to 21428
# 10 5 2019 2 : 17
# SVenus = -172 adjust to 21428
# 10 5 2019 2 : 18
# SVenus = -172 adjust to 21428
# 10 5 2019 2 : 19
# SVenus = -172 adjust to 21428
# 10 5 2019 2 : 20
# SVenus = -172 adjust to 21428
# 10 5 2019 2 : 21
# SVenus = -172 adjust to 21428
# 10 5 2019 2 : 22
# SVenus = -172 adjust to 21428
# 10 5 2019 2 : 23
# SVenus = -172 adjust to 21428
# 10 5 2019 2 : 24
# SVenus = -172 adjust to 21428
# 10 5 2019 2 : 25
# SVenus = -172 adjust to 21428
# 10 5 2019 2 : 26
# SVenus = -172 adjust to 21428
# 10 5 2019 2 : 27
# SVenus = -172 adjust to 21428
# 10 5 2019 2 : 28
# SVenus = -172 adjust to 21428
# 10 5 2019 2 : 29
# SVenus = -172 adjust to 21428
# 10 5 2019 2 : 30
# SVenus = -172 adjust to 21428
# 10 5 2019 2 : 31
# SVenus = -172 adjust to 21428
# 10 5 2019 2 : 32
# SVenus = -172 adjust to 21428
# 10 5 2019 2 : 33
# SVenus = -172 adjust to 21428
# 10 5 2019 2 : 34
# SVenus = -172 adjust to 21428
# 10 5 2019 2 : 35
# SVenus = -172 adjust to 21428
# 10 5 2019 2 : 36
# SVenus = -172 adjust to 21428
# 10 5 2019 2 : 37
# SVenus = -172 adjust to 21428
# 10 5 2019 2 : 38
# SVenus = -172 adjust to 21428
# 10 5 2019 2 : 39
# SVenus = -172 adjust to 21428
# 10 5 2019 2 : 40
# SVenus = -172 adjust to 21428
# 10 5 2019 2 : 41
# SVenus = -171 adjust to 21429
# 10 5 2019 2 : 42
# SVenus = -171 adjust to 21429
# 10 5 2019 2 : 43
# SVenus = -171 adjust to 21429
# 10 5 2019 2 : 44
# SVenus = -171 adjust to 21429
# 10 5 2019 2 : 45
# SVenus = -171 adjust to 21429
# 10 5 2019 2 : 46
# SVenus = -171 adjust to 21429
# 10 5 2019 2 : 47
# SVenus = -171 adjust to 21429
# 10 5 2019 2 : 48
# SVenus = -171 adjust to 21429
# 10 5 2019 2 : 49
# SVenus = -171 adjust to 21429
# 10 5 2019 2 : 50
# SVenus = -171 adjust to 21429
# 10 5 2019 2 : 51
# SVenus = -171 adjust to 21429
# 10 5 2019 2 : 52
# SVenus = -171 adjust to 21429
# 10 5 2019 2 : 53
# SVenus = -171 adjust to 21429
# 10 5 2019 2 : 54
# SVenus = -171 adjust to 21429
# 10 5 2019 2 : 55
# SVenus = -171 adjust to 21429
# 10 5 2019 2 : 56
# SVenus = -171 adjust to 21429
# 10 5 2019 2 : 57
# SVenus = -171 adjust to 21429
# 10 5 2019 2 : 58
# SVenus = -171 adjust to 21429
# 10 5 2019 2 : 59
# SVenus = -171 adjust to 21429
# 10 5 2019 3 : 0
# SVenus = -171 adjust to 21429
# 10 5 2019 3 : 1
# SVenus = -171 adjust to 21429
# 10 5 2019 3 : 2
# SVenus = -171 adjust to 21429
# 10 5 2019 3 : 3
# SVenus = -171 adjust to 21429
# 10 5 2019 3 : 4
# SVenus = -171 adjust to 21429
# 10 5 2019 3 : 5
# SVenus = -167 adjust to 21433
# 10 5 2019 3 : 6
# SVenus = -167 adjust to 21433
# 10 5 2019 3 : 7
# SVenus = -167 adjust to 21433
# 10 5 2019 3 : 8
# SVenus = -167 adjust to 21433
# 10 5 2019 3 : 9
# SVenus = -167 adjust to 21433
# 10 5 2019 3 : 10
# SVenus = -167 adjust to 21433
# 10 5 2019 3 : 11
# SVenus = -167 adjust to 21433
# 10 5 2019 3 : 12
# SVenus = -167 adjust to 21433
# 10 5 2019 3 : 13
# SVenus = -167 adjust to 21433
# 10 5 2019 3 : 14
# SVenus = -167 adjust to 21433
# 10 5 2019 3 : 15
# SVenus = -167 adjust to 21433
# 10 5 2019 3 : 16
# SVenus = -167 adjust to 21433
# 10 5 2019 3 : 17
# SVenus = -167 adjust to 21433
# 10 5 2019 3 : 18
# SVenus = -167 adjust to 21433
# 10 5 2019 3 : 19
# SVenus = -167 adjust to 21433
# 10 5 2019 3 : 20
# SVenus = -167 adjust to 21433
# 10 5 2019 3 : 21
# SVenus = -167 adjust to 21433
# 10 5 2019 3 : 22
# SVenus = -167 adjust to 21433
# 10 5 2019 3 : 23
# SVenus = -167 adjust to 21433
# 10 5 2019 3 : 24
# SVenus = -167 adjust to 21433
# 10 5 2019 3 : 25
# SVenus = -167 adjust to 21433
# 10 5 2019 3 : 26
# SVenus = -167 adjust to 21433
# 10 5 2019 3 : 27
# SVenus = -167 adjust to 21433
# 10 5 2019 3 : 28
# SVenus = -167 adjust to 21433
# 10 5 2019 3 : 29
# SVenus = -167 adjust to 21433
# 10 5 2019 3 : 30
# SVenus = -166 adjust to 21434
# 10 5 2019 3 : 31
# SVenus = -166 adjust to 21434
# 10 5 2019 3 : 32
# SVenus = -166 adjust to 21434
# 10 5 2019 3 : 33
# SVenus = -166 adjust to 21434
# 10 5 2019 3 : 34
# SVenus = -166 adjust to 21434
# 10 5 2019 3 : 35
# SVenus = -166 adjust to 21434
# 10 5 2019 3 : 36
# SVenus = -166 adjust to 21434
# 10 5 2019 3 : 37
# SVenus = -166 adjust to 21434
# 10 5 2019 3 : 38
# SVenus = -166 adjust to 21434
# 10 5 2019 3 : 39
# SVenus = -166 adjust to 21434
# 10 5 2019 3 : 40
# SVenus = -166 adjust to 21434
# 10 5 2019 3 : 41
# SVenus = -166 adjust to 21434
# 10 5 2019 3 : 42
# SVenus = -166 adjust to 21434
# 10 5 2019 3 : 43
# SVenus = -166 adjust to 21434
# 10 5 2019 3 : 44
# SVenus = -166 adjust to 21434
# 10 5 2019 3 : 45
# SVenus = -166 adjust to 21434
# 10 5 2019 3 : 46
# SVenus = -166 adjust to 21434
# 10 5 2019 3 : 47
# SVenus = -166 adjust to 21434
# 10 5 2019 3 : 48
# SVenus = -166 adjust to 21434
# 10 5 2019 3 : 49
# SVenus = -166 adjust to 21434
# 10 5 2019 3 : 50
# SVenus = -166 adjust to 21434
# 10 5 2019 3 : 51
# SVenus = -166 adjust to 21434
# 10 5 2019 3 : 52
# SVenus = -166 adjust to 21434
# 10 5 2019 3 : 53
# SVenus = -166 adjust to 21434
# 10 5 2019 3 : 54
# SVenus = -166 adjust to 21434
# 10 5 2019 3 : 55
# SVenus = -165 adjust to 21435
# 10 5 2019 3 : 56
# SVenus = -165 adjust to 21435
# 10 5 2019 3 : 57
# SVenus = -165 adjust to 21435
# 10 5 2019 3 : 58
# SVenus = -165 adjust to 21435
# 10 5 2019 3 : 59
# SVenus = -165 adjust to 21435
# 10 5 2019 4 : 0
# SVenus = -165 adjust to 21435
# 10 5 2019 4 : 1
# SVenus = -165 adjust to 21435
# 10 5 2019 4 : 2
# SVenus = -165 adjust to 21435
# 10 5 2019 4 : 3
# SVenus = -165 adjust to 21435
# 10 5 2019 4 : 4
# SVenus = -165 adjust to 21435
# 10 5 2019 4 : 5
# SVenus = -165 adjust to 21435
# 10 5 2019 4 : 6
# SVenus = -165 adjust to 21435
# 10 5 2019 4 : 7
# SVenus = -165 adjust to 21435
# 10 5 2019 4 : 8
# SVenus = -165 adjust to 21435
# 10 5 2019 4 : 9
# SVenus = -165 adjust to 21435
# 10 5 2019 4 : 10
# SVenus = -165 adjust to 21435
# 10 5 2019 4 : 11
# SVenus = -165 adjust to 21435
# 10 5 2019 4 : 12
# SVenus = -165 adjust to 21435
# 10 5 2019 4 : 13
# SVenus = -165 adjust to 21435
# 10 5 2019 4 : 14
# SVenus = -165 adjust to 21435
# 10 5 2019 4 : 15
# SVenus = -165 adjust to 21435
# 10 5 2019 4 : 16
# SVenus = -165 adjust to 21435
# 10 5 2019 4 : 17
# SVenus = -165 adjust to 21435
# 10 5 2019 4 : 18
# SVenus = -165 adjust to 21435
# 10 5 2019 4 : 19
# SVenus = -165 adjust to 21435
# 10 5 2019 4 : 20
# SVenus = -164 adjust to 21436
# 10 5 2019 4 : 21
# SVenus = -164 adjust to 21436
# 10 5 2019 4 : 22
# SVenus = -164 adjust to 21436
# 10 5 2019 4 : 23
# SVenus = -164 adjust to 21436
# 10 5 2019 4 : 24
# SVenus = -164 adjust to 21436
# 10 5 2019 4 : 25
# SVenus = -164 adjust to 21436
# 10 5 2019 4 : 26
# SVenus = -164 adjust to 21436
# 10 5 2019 4 : 27
# SVenus = -164 adjust to 21436
# 10 5 2019 4 : 28
# SVenus = -164 adjust to 21436
# 10 5 2019 4 : 29
# SVenus = -164 adjust to 21436
# 10 5 2019 4 : 30
# SVenus = -164 adjust to 21436
# 10 5 2019 4 : 31
# SVenus = -164 adjust to 21436
# 10 5 2019 4 : 32
# SVenus = -164 adjust to 21436
# 10 5 2019 4 : 33
# SVenus = -164 adjust to 21436
# 10 5 2019 4 : 34
# SVenus = -164 adjust to 21436
# 10 5 2019 4 : 35
# SVenus = -164 adjust to 21436
# 10 5 2019 4 : 36
# SVenus = -164 adjust to 21436
# 10 5 2019 4 : 37
# SVenus = -164 adjust to 21436
# 10 5 2019 4 : 38
# SVenus = -164 adjust to 21436
# 10 5 2019 4 : 39
# SVenus = -164 adjust to 21436
# 10 5 2019 4 : 40
# SVenus = -164 adjust to 21436
# 10 5 2019 4 : 41
# SVenus = -164 adjust to 21436
# 10 5 2019 4 : 42
# SVenus = -164 adjust to 21436
# 10 5 2019 4 : 43
# SVenus = -164 adjust to 21436
# 10 5 2019 4 : 44
# SVenus = -164 adjust to 21436
# 10 5 2019 4 : 45
# SVenus = -164 adjust to 21436
# 10 5 2019 4 : 46
# SVenus = -161 adjust to 21439
# 10 5 2019 4 : 47
# SVenus = -161 adjust to 21439
# 10 5 2019 4 : 48
# SVenus = -161 adjust to 21439
# 10 5 2019 4 : 49
# SVenus = -161 adjust to 21439
# 10 5 2019 4 : 50
# SVenus = -161 adjust to 21439
# 10 5 2019 4 : 51
# SVenus = -161 adjust to 21439
# 10 5 2019 4 : 52
# SVenus = -161 adjust to 21439
# 10 5 2019 4 : 53
# SVenus = -161 adjust to 21439
# 10 5 2019 4 : 54
# SVenus = -161 adjust to 21439
# 10 5 2019 4 : 55
# SVenus = -161 adjust to 21439
# 10 5 2019 4 : 56
# SVenus = -161 adjust to 21439
# 10 5 2019 4 : 57
# SVenus = -161 adjust to 21439
# 10 5 2019 4 : 58
# SVenus = -161 adjust to 21439
# 10 5 2019 4 : 59
# SVenus = -161 adjust to 21439
# 10 5 2019 5 : 0
# SVenus = -161 adjust to 21439
# 10 5 2019 5 : 1
# SVenus = -161 adjust to 21439
# 10 5 2019 5 : 2
# SVenus = -161 adjust to 21439
# 10 5 2019 5 : 3
# SVenus = -161 adjust to 21439
# 10 5 2019 5 : 4
# SVenus = -161 adjust to 21439
# 10 5 2019 5 : 5
# SVenus = -161 adjust to 21439
# 10 5 2019 5 : 6
# SVenus = -161 adjust to 21439
# 10 5 2019 5 : 7
# SVenus = -161 adjust to 21439
# 10 5 2019 5 : 8
# SVenus = -161 adjust to 21439
# 10 5 2019 5 : 9
# SVenus = -161 adjust to 21439
# 10 5 2019 5 : 10
# SVenus = -161 adjust to 21439
# 10 5 2019 5 : 11
# SVenus = -160 adjust to 21440
# 10 5 2019 5 : 12
# SVenus = -160 adjust to 21440
# 10 5 2019 5 : 13
# SVenus = -160 adjust to 21440
# 10 5 2019 5 : 14
# SVenus = -160 adjust to 21440
# 10 5 2019 5 : 15
# SVenus = -160 adjust to 21440
# 10 5 2019 5 : 16
# SVenus = -160 adjust to 21440
# 10 5 2019 5 : 17
# SVenus = -160 adjust to 21440
# 10 5 2019 5 : 18
# SVenus = -160 adjust to 21440
# 10 5 2019 5 : 19
# SVenus = -160 adjust to 21440
# 10 5 2019 5 : 20
# SVenus = -160 adjust to 21440
# 10 5 2019 5 : 21
# SVenus = -160 adjust to 21440
# 10 5 2019 5 : 22
# SVenus = -160 adjust to 21440
# 10 5 2019 5 : 23
# SVenus = -160 adjust to 21440
# 10 5 2019 5 : 24
# SVenus = -160 adjust to 21440
# 10 5 2019 5 : 25
# SVenus = -160 adjust to 21440
# 10 5 2019 5 : 26
# SVenus = -160 adjust to 21440
# 10 5 2019 5 : 27
# SVenus = -160 adjust to 21440
# 10 5 2019 5 : 28
# SVenus = -160 adjust to 21440
# 10 5 2019 5 : 29
# SVenus = -160 adjust to 21440
# 10 5 2019 5 : 30
# SVenus = -160 adjust to 21440
# 10 5 2019 5 : 31
# SVenus = -160 adjust to 21440
# 10 5 2019 5 : 32
# SVenus = -160 adjust to 21440
# 10 5 2019 5 : 33
# SVenus = -160 adjust to 21440
# 10 5 2019 5 : 34
# SVenus = -160 adjust to 21440
# 10 5 2019 5 : 35
# SVenus = -160 adjust to 21440
# 10 5 2019 5 : 36
# SVenus = -159 adjust to 21441
# 10 5 2019 5 : 37
# SVenus = -159 adjust to 21441
# 10 5 2019 5 : 38
# SVenus = -159 adjust to 21441
# 10 5 2019 5 : 39
# SVenus = -159 adjust to 21441
# 10 5 2019 5 : 40
# SVenus = -159 adjust to 21441
# 10 5 2019 5 : 41
# SVenus = -159 adjust to 21441
# 10 5 2019 5 : 42
# SVenus = -159 adjust to 21441
# 10 5 2019 5 : 43
# SVenus = -159 adjust to 21441
# 10 5 2019 5 : 44
# SVenus = -159 adjust to 21441
# 10 5 2019 5 : 45
# SVenus = -159 adjust to 21441
# 10 5 2019 5 : 46
# SVenus = -159 adjust to 21441
# 10 5 2019 5 : 47
# SVenus = -159 adjust to 21441
# 10 5 2019 5 : 48
# SVenus = -159 adjust to 21441
# 10 5 2019 5 : 49
# SVenus = -159 adjust to 21441
# 10 5 2019 5 : 50
# SVenus = -159 adjust to 21441
# 10 5 2019 5 : 51
# SVenus = -159 adjust to 21441
# 10 5 2019 5 : 52
# SVenus = -159 adjust to 21441
# 10 5 2019 5 : 53
# SVenus = -159 adjust to 21441
# 10 5 2019 5 : 54
# SVenus = -159 adjust to 21441
# 10 5 2019 5 : 55
# SVenus = -159 adjust to 21441
# 10 5 2019 5 : 56
# SVenus = -159 adjust to 21441
# 10 5 2019 5 : 57
# SVenus = -159 adjust to 21441
# 10 5 2019 5 : 58
# SVenus = -159 adjust to 21441
# 10 5 2019 5 : 59
# SVenus = -159 adjust to 21441
# 10 5 2019 6 : 0
# SVenus = -159 adjust to 21441
# 10 5 2019 6 : 1
# SVenus = -158 adjust to 21442
# 10 5 2019 6 : 2
# SVenus = -158 adjust to 21442
# 10 5 2019 6 : 3
# SVenus = -158 adjust to 21442
# 10 5 2019 6 : 4
# SVenus = -158 adjust to 21442
# 10 5 2019 6 : 5
# SVenus = -158 adjust to 21442
# 10 5 2019 6 : 6
# SVenus = -158 adjust to 21442
# 10 5 2019 6 : 7
# SVenus = -158 adjust to 21442
# 10 5 2019 6 : 8
# SVenus = -158 adjust to 21442
# 10 5 2019 6 : 9
# SVenus = -158 adjust to 21442
# 10 5 2019 6 : 10
# SVenus = -158 adjust to 21442
# 10 5 2019 6 : 11
# SVenus = -158 adjust to 21442
# 10 5 2019 6 : 12
# SVenus = -158 adjust to 21442
# 10 5 2019 6 : 13
# SVenus = -158 adjust to 21442
# 10 5 2019 6 : 14
# SVenus = -158 adjust to 21442
# 10 5 2019 6 : 15
# SVenus = -158 adjust to 21442
# 10 5 2019 6 : 16
# SVenus = -158 adjust to 21442
# 10 5 2019 6 : 17
# SVenus = -158 adjust to 21442
# 10 5 2019 6 : 18
# SVenus = -158 adjust to 21442
# 10 5 2019 6 : 19
# SVenus = -158 adjust to 21442
# 10 5 2019 6 : 20
# SVenus = -158 adjust to 21442
# 10 5 2019 6 : 21
# SVenus = -158 adjust to 21442
# 10 5 2019 6 : 22
# SVenus = -158 adjust to 21442
# 10 5 2019 6 : 23
# SVenus = -158 adjust to 21442
# 10 5 2019 6 : 24
# SVenus = -158 adjust to 21442
# 10 5 2019 6 : 25
# SVenus = -158 adjust to 21442
# 10 5 2019 6 : 26
# SVenus = -157 adjust to 21443
# 10 5 2019 6 : 27
# SVenus = -157 adjust to 21443
# 10 5 2019 6 : 28
# SVenus = -157 adjust to 21443
# 10 5 2019 6 : 29
# SVenus = -157 adjust to 21443
# 10 5 2019 6 : 30
# SVenus = -157 adjust to 21443
# 10 5 2019 6 : 31
# SVenus = -157 adjust to 21443
# 10 5 2019 6 : 32
# SVenus = -157 adjust to 21443
# 10 5 2019 6 : 33
# SVenus = -157 adjust to 21443
# 10 5 2019 6 : 34
# SVenus = -157 adjust to 21443
# 10 5 2019 6 : 35
# SVenus = -157 adjust to 21443
# 10 5 2019 6 : 36
# SVenus = -157 adjust to 21443
# 10 5 2019 6 : 37
# SVenus = -157 adjust to 21443
# 10 5 2019 6 : 38
# SVenus = -157 adjust to 21443
# 10 5 2019 6 : 39
# SVenus = -157 adjust to 21443
# 10 5 2019 6 : 40
# SVenus = -157 adjust to 21443
# 10 5 2019 6 : 41
# SVenus = -157 adjust to 21443
# 10 5 2019 6 : 42
# SVenus = -157 adjust to 21443
# 10 5 2019 6 : 43
# SVenus = -157 adjust to 21443
# 10 5 2019 6 : 44
# SVenus = -157 adjust to 21443
# 10 5 2019 6 : 45
# SVenus = -157 adjust to 21443
# 10 5 2019 6 : 46
# SVenus = -157 adjust to 21443
# 10 5 2019 6 : 47
# SVenus = -157 adjust to 21443
# 10 5 2019 6 : 48
# SVenus = -157 adjust to 21443
# 10 5 2019 6 : 49
# SVenus = -157 adjust to 21443
# 10 5 2019 6 : 50
# SVenus = -157 adjust to 21443
# 10 5 2019 6 : 51
# SVenus = -157 adjust to 21443
# 10 5 2019 6 : 52
# SVenus = -156 adjust to 21444
# 10 5 2019 6 : 53
# SVenus = -156 adjust to 21444
# 10 5 2019 6 : 54
# SVenus = -156 adjust to 21444
# 10 5 2019 6 : 55
# SVenus = -156 adjust to 21444
# 10 5 2019 6 : 56
# SVenus = -156 adjust to 21444
# 10 5 2019 6 : 57
# SVenus = -156 adjust to 21444
# 10 5 2019 6 : 58
# SVenus = -156 adjust to 21444
# 10 5 2019 6 : 59
# SVenus = -156 adjust to 21444
# 10 5 2019 7 : 0
# SVenus = -156 adjust to 21444
# 10 5 2019 7 : 1
# SVenus = -156 adjust to 21444
# 10 5 2019 7 : 2
# SVenus = -156 adjust to 21444
# 10 5 2019 7 : 3
# SVenus = -156 adjust to 21444
# 10 5 2019 7 : 4
# SVenus = -156 adjust to 21444
# 10 5 2019 7 : 5
# SVenus = -156 adjust to 21444
# 10 5 2019 7 : 6
# SVenus = -156 adjust to 21444
# 10 5 2019 7 : 7
# SVenus = -156 adjust to 21444
# 10 5 2019 7 : 8
# SVenus = -156 adjust to 21444
# 10 5 2019 7 : 9
# SVenus = -156 adjust to 21444
# 10 5 2019 7 : 10
# SVenus = -156 adjust to 21444
# 10 5 2019 7 : 11
# SVenus = -156 adjust to 21444
# 10 5 2019 7 : 12
# SVenus = -156 adjust to 21444
# 10 5 2019 7 : 13
# SVenus = -156 adjust to 21444
# 10 5 2019 7 : 14
# SVenus = -156 adjust to 21444
# 10 5 2019 7 : 15
# SVenus = -156 adjust to 21444
# 10 5 2019 7 : 16
# SVenus = -156 adjust to 21444
# 10 5 2019 7 : 17
# SVenus = -155 adjust to 21445
# 10 5 2019 7 : 18
# SVenus = -155 adjust to 21445
# 10 5 2019 7 : 19
# SVenus = -155 adjust to 21445
# 10 5 2019 7 : 20
# SVenus = -155 adjust to 21445
# 10 5 2019 7 : 21
# SVenus = -155 adjust to 21445
# 10 5 2019 7 : 22
# SVenus = -155 adjust to 21445
# 10 5 2019 7 : 23
# SVenus = -155 adjust to 21445
# 10 5 2019 7 : 24
# SVenus = -155 adjust to 21445
# 10 5 2019 7 : 25
# SVenus = -155 adjust to 21445
# 10 5 2019 7 : 26
# SVenus = -155 adjust to 21445
# 10 5 2019 7 : 27
# SVenus = -155 adjust to 21445
# 10 5 2019 7 : 28
# SVenus = -155 adjust to 21445
# 10 5 2019 7 : 29
# SVenus = -155 adjust to 21445
# 10 5 2019 7 : 30
# SVenus = -155 adjust to 21445
# 10 5 2019 7 : 31
# SVenus = -155 adjust to 21445
# 10 5 2019 7 : 32
# SVenus = -155 adjust to 21445
# 10 5 2019 7 : 33
# SVenus = -155 adjust to 21445
# 10 5 2019 7 : 34
# SVenus = -155 adjust to 21445
# 10 5 2019 7 : 35
# SVenus = -155 adjust to 21445
# 10 5 2019 7 : 36
# SVenus = -155 adjust to 21445
# 10 5 2019 7 : 37
# SVenus = -155 adjust to 21445
# 10 5 2019 7 : 38
# SVenus = -155 adjust to 21445
# 10 5 2019 7 : 39
# SVenus = -155 adjust to 21445
# 10 5 2019 7 : 40
# SVenus = -155 adjust to 21445
# 10 5 2019 7 : 41
# SVenus = -155 adjust to 21445
# 10 5 2019 7 : 42
# SVenus = -154 adjust to 21446
# 10 5 2019 7 : 43
# SVenus = -154 adjust to 21446
# 10 5 2019 7 : 44
# SVenus = -154 adjust to 21446
# 10 5 2019 7 : 45
# SVenus = -154 adjust to 21446
# 10 5 2019 7 : 46
# SVenus = -154 adjust to 21446
# 10 5 2019 7 : 47
# SVenus = -154 adjust to 21446
# 10 5 2019 7 : 48
# SVenus = -154 adjust to 21446
# 10 5 2019 7 : 49
# SVenus = -154 adjust to 21446
# 10 5 2019 7 : 50
# SVenus = -154 adjust to 21446
# 10 5 2019 7 : 51
# SVenus = -154 adjust to 21446
# 10 5 2019 7 : 52
# SVenus = -154 adjust to 21446
# 10 5 2019 7 : 53
# SVenus = -154 adjust to 21446
# 10 5 2019 7 : 54
# SVenus = -154 adjust to 21446
# 10 5 2019 7 : 55
# SVenus = -154 adjust to 21446
# 10 5 2019 7 : 56
# SVenus = -154 adjust to 21446
# 10 5 2019 7 : 57
# SVenus = -154 adjust to 21446
# 10 5 2019 7 : 58
# SVenus = -154 adjust to 21446
# 10 5 2019 7 : 59
# SVenus = -154 adjust to 21446
# 10 5 2019 8 : 0
# SVenus = -154 adjust to 21446
# 10 5 2019 8 : 1
# SVenus = -154 adjust to 21446
# 10 5 2019 8 : 2
# SVenus = -154 adjust to 21446
# 10 5 2019 8 : 3
# SVenus = -154 adjust to 21446
# 10 5 2019 8 : 4
# SVenus = -154 adjust to 21446
# 10 5 2019 8 : 5
# SVenus = -154 adjust to 21446
# 10 5 2019 8 : 6
# SVenus = -154 adjust to 21446
# 10 5 2019 8 : 7
# SVenus = -153 adjust to 21447
# 10 5 2019 8 : 8
# SVenus = -153 adjust to 21447
# 10 5 2019 8 : 9
# SVenus = -153 adjust to 21447
# 10 5 2019 8 : 10
# SVenus = -153 adjust to 21447
# 10 5 2019 8 : 11
# SVenus = -153 adjust to 21447
# 10 5 2019 8 : 12
# SVenus = -153 adjust to 21447
# 10 5 2019 8 : 13
# SVenus = -153 adjust to 21447
# 10 5 2019 8 : 14
# SVenus = -153 adjust to 21447
# 10 5 2019 8 : 15
# SVenus = -153 adjust to 21447
# 10 5 2019 8 : 16
# SVenus = -153 adjust to 21447
# 10 5 2019 8 : 17
# SVenus = -153 adjust to 21447
# 10 5 2019 8 : 18
# SVenus = -153 adjust to 21447
# 10 5 2019 8 : 19
# SVenus = -153 adjust to 21447
# 10 5 2019 8 : 20
# SVenus = -153 adjust to 21447
# 10 5 2019 8 : 21
# SVenus = -153 adjust to 21447
# 10 5 2019 8 : 22
# SVenus = -153 adjust to 21447
# 10 5 2019 8 : 23
# SVenus = -153 adjust to 21447
# 10 5 2019 8 : 24
# SVenus = -153 adjust to 21447
# 10 5 2019 8 : 25
# SVenus = -153 adjust to 21447
# 10 5 2019 8 : 26
# SVenus = -153 adjust to 21447
# 10 5 2019 8 : 27
# SVenus = -153 adjust to 21447
# 10 5 2019 8 : 28
# SVenus = -153 adjust to 21447
# 10 5 2019 8 : 29
# SVenus = -153 adjust to 21447
# 10 5 2019 8 : 30
# SVenus = -153 adjust to 21447
# 10 5 2019 8 : 31
# SVenus = -153 adjust to 21447
# 10 5 2019 8 : 32
# SVenus = -152 adjust to 21448
# 10 5 2019 8 : 33
# SVenus = -152 adjust to 21448
# 10 5 2019 8 : 34
# SVenus = -152 adjust to 21448
# 10 5 2019 8 : 35
# SVenus = -152 adjust to 21448
# 10 5 2019 8 : 36
# SVenus = -152 adjust to 21448
# 10 5 2019 8 : 37
# SVenus = -152 adjust to 21448
# 10 5 2019 8 : 38
# SVenus = -152 adjust to 21448
# 10 5 2019 8 : 39
# SVenus = -152 adjust to 21448
# 10 5 2019 8 : 40
# SVenus = -152 adjust to 21448
# 10 5 2019 8 : 41
# SVenus = -152 adjust to 21448
# 10 5 2019 8 : 42
# SVenus = -152 adjust to 21448
# 10 5 2019 8 : 43
# SVenus = -152 adjust to 21448
# 10 5 2019 8 : 44
# SVenus = -152 adjust to 21448
# 10 5 2019 8 : 45
# SVenus = -152 adjust to 21448
# 10 5 2019 8 : 46
# SVenus = -152 adjust to 21448
# 10 5 2019 8 : 47
# SVenus = -152 adjust to 21448
# 10 5 2019 8 : 48
# SVenus = -152 adjust to 21448
# 10 5 2019 8 : 49
# SVenus = -152 adjust to 21448
# 10 5 2019 8 : 50
# SVenus = -152 adjust to 21448
# 10 5 2019 8 : 51
# SVenus = -152 adjust to 21448
# 10 5 2019 8 : 52
# SVenus = -152 adjust to 21448
# 10 5 2019 8 : 53
# SVenus = -152 adjust to 21448
# 10 5 2019 8 : 54
# SVenus = -152 adjust to 21448
# 10 5 2019 8 : 55
# SVenus = -152 adjust to 21448
# 10 5 2019 8 : 56
# SVenus = -152 adjust to 21448
# 10 5 2019 8 : 57
# SVenus = -152 adjust to 21448
# 10 5 2019 8 : 58
# SVenus = -149 adjust to 21451
# 10 5 2019 8 : 59
# SVenus = -149 adjust to 21451
# 10 5 2019 9 : 0
# SVenus = -149 adjust to 21451
# 10 5 2019 9 : 1
# SVenus = -149 adjust to 21451
# 10 5 2019 9 : 2
# SVenus = -149 adjust to 21451
# 10 5 2019 9 : 3
# SVenus = -149 adjust to 21451
# 10 5 2019 9 : 4
# SVenus = -149 adjust to 21451
# 10 5 2019 9 : 5
# SVenus = -149 adjust to 21451
# 10 5 2019 9 : 6
# SVenus = -149 adjust to 21451
# 10 5 2019 9 : 7
# SVenus = -149 adjust to 21451
# 10 5 2019 9 : 8
# SVenus = -149 adjust to 21451
# 10 5 2019 9 : 9
# SVenus = -149 adjust to 21451
# 10 5 2019 9 : 10
# SVenus = -149 adjust to 21451
# 10 5 2019 9 : 11
# SVenus = -149 adjust to 21451
# 10 5 2019 9 : 12
# SVenus = -149 adjust to 21451
# 10 5 2019 9 : 13
# SVenus = -149 adjust to 21451
# 10 5 2019 9 : 14
# SVenus = -149 adjust to 21451
# 10 5 2019 9 : 15
# SVenus = -149 adjust to 21451
# 10 5 2019 9 : 16
# SVenus = -149 adjust to 21451
# 10 5 2019 9 : 17
# SVenus = -149 adjust to 21451
# 10 5 2019 9 : 18
# SVenus = -149 adjust to 21451
# 10 5 2019 9 : 19
# SVenus = -149 adjust to 21451
# 10 5 2019 9 : 20
# SVenus = -149 adjust to 21451
# 10 5 2019 9 : 21
# SVenus = -149 adjust to 21451
# 10 5 2019 9 : 22
# SVenus = -149 adjust to 21451
# 10 5 2019 9 : 23
# SVenus = -148 adjust to 21452
# 10 5 2019 9 : 24
# SVenus = -148 adjust to 21452
# 10 5 2019 9 : 25
# SVenus = -148 adjust to 21452
# 10 5 2019 9 : 26
# SVenus = -148 adjust to 21452
# 10 5 2019 9 : 27
# SVenus = -148 adjust to 21452
# 10 5 2019 9 : 28
# SVenus = -148 adjust to 21452
# 10 5 2019 9 : 29
# SVenus = -148 adjust to 21452
# 10 5 2019 9 : 30
# SVenus = -148 adjust to 21452
# 10 5 2019 9 : 31
# SVenus = -148 adjust to 21452
# 10 5 2019 9 : 32
# SVenus = -148 adjust to 21452
# 10 5 2019 9 : 33
# SVenus = -148 adjust to 21452
# 10 5 2019 9 : 34
# SVenus = -148 adjust to 21452
# 10 5 2019 9 : 35
# SVenus = -148 adjust to 21452
# 10 5 2019 9 : 36
# SVenus = -148 adjust to 21452
# 10 5 2019 9 : 37
# SVenus = -148 adjust to 21452
# 10 5 2019 9 : 38
# SVenus = -148 adjust to 21452
# 10 5 2019 9 : 39
# SVenus = -148 adjust to 21452
# 10 5 2019 9 : 40
# SVenus = -148 adjust to 21452
# 10 5 2019 9 : 41
# SVenus = -148 adjust to 21452
# 10 5 2019 9 : 42
# SVenus = -148 adjust to 21452
# 10 5 2019 9 : 43
# SVenus = -148 adjust to 21452
# 10 5 2019 9 : 44
# SVenus = -148 adjust to 21452
# 10 5 2019 9 : 45
# SVenus = -148 adjust to 21452
# 10 5 2019 9 : 46
# SVenus = -148 adjust to 21452
# 10 5 2019 9 : 47
# SVenus = -148 adjust to 21452
# 10 5 2019 9 : 48
# SVenus = -147 adjust to 21453
# 10 5 2019 9 : 49
# SVenus = -147 adjust to 21453
# 10 5 2019 9 : 50
# SVenus = -147 adjust to 21453
# 10 5 2019 9 : 51
# SVenus = -147 adjust to 21453
# 10 5 2019 9 : 52
# SVenus = -147 adjust to 21453
# 10 5 2019 9 : 53
# SVenus = -147 adjust to 21453
# 10 5 2019 9 : 54
# SVenus = -147 adjust to 21453
# 10 5 2019 9 : 55
# SVenus = -147 adjust to 21453
# 10 5 2019 9 : 56
# SVenus = -147 adjust to 21453
# 10 5 2019 9 : 57
# SVenus = -147 adjust to 21453
# 10 5 2019 9 : 58
# SVenus = -147 adjust to 21453
# 10 5 2019 9 : 59
# SVenus = -147 adjust to 21453
# 10 5 2019 10 : 0
# SVenus = -147 adjust to 21453
# 10 5 2019 10 : 1
# SVenus = -147 adjust to 21453
# 10 5 2019 10 : 2
# SVenus = -147 adjust to 21453
# 10 5 2019 10 : 3
# SVenus = -147 adjust to 21453
# 10 5 2019 10 : 4
# SVenus = -147 adjust to 21453
# 10 5 2019 10 : 5
# SVenus = -147 adjust to 21453
# 10 5 2019 10 : 6
# SVenus = -147 adjust to 21453
# 10 5 2019 10 : 7
# SVenus = -147 adjust to 21453
# 10 5 2019 10 : 8
# SVenus = -147 adjust to 21453
# 10 5 2019 10 : 9
# SVenus = -147 adjust to 21453
# 10 5 2019 10 : 10
# SVenus = -147 adjust to 21453
# 10 5 2019 10 : 11
# SVenus = -147 adjust to 21453
# 10 5 2019 10 : 12
# SVenus = -147 adjust to 21453
# 10 5 2019 10 : 13
# SVenus = -146 adjust to 21454
# 10 5 2019 10 : 14
# SVenus = -146 adjust to 21454
# 10 5 2019 10 : 15
# SVenus = -146 adjust to 21454
# 10 5 2019 10 : 16
# SVenus = -146 adjust to 21454
# 10 5 2019 10 : 17
# SVenus = -146 adjust to 21454
# 10 5 2019 10 : 18
# SVenus = -146 adjust to 21454
# 10 5 2019 10 : 19
# SVenus = -146 adjust to 21454
# 10 5 2019 10 : 20
# SVenus = -146 adjust to 21454
# 10 5 2019 10 : 21
# SVenus = -146 adjust to 21454
# 10 5 2019 10 : 22
# SVenus = -146 adjust to 21454
# 10 5 2019 10 : 23
# SVenus = -146 adjust to 21454
# 10 5 2019 10 : 24
# SVenus = -146 adjust to 21454
# 10 5 2019 10 : 25
# SVenus = -146 adjust to 21454
# 10 5 2019 10 : 26
# SVenus = -146 adjust to 21454
# 10 5 2019 10 : 27
# SVenus = -146 adjust to 21454
# 10 5 2019 10 : 28
# SVenus = -146 adjust to 21454
# 10 5 2019 10 : 29
# SVenus = -146 adjust to 21454
# 10 5 2019 10 : 30
# SVenus = -146 adjust to 21454
# 10 5 2019 10 : 31
# SVenus = -146 adjust to 21454
# 10 5 2019 10 : 32
# SVenus = -146 adjust to 21454
# 10 5 2019 10 : 33
# SVenus = -146 adjust to 21454
# 10 5 2019 10 : 34
# SVenus = -146 adjust to 21454
# 10 5 2019 10 : 35
# SVenus = -146 adjust to 21454
# 10 5 2019 10 : 36
# SVenus = -146 adjust to 21454
# 10 5 2019 10 : 37
# SVenus = -146 adjust to 21454
# 10 5 2019 10 : 38
# SVenus = -145 adjust to 21455
# 10 5 2019 10 : 39
# SVenus = -145 adjust to 21455
# 10 5 2019 10 : 40
# SVenus = -145 adjust to 21455
# 10 5 2019 10 : 41
# SVenus = -145 adjust to 21455
# 10 5 2019 10 : 42
# SVenus = -145 adjust to 21455
# 10 5 2019 10 : 43
# SVenus = -145 adjust to 21455
# 10 5 2019 10 : 44
# SVenus = -145 adjust to 21455
# 10 5 2019 10 : 45
# SVenus = -145 adjust to 21455
# 10 5 2019 10 : 46
# SVenus = -145 adjust to 21455
# 10 5 2019 10 : 47
# SVenus = -145 adjust to 21455
# 10 5 2019 10 : 48
# SVenus = -145 adjust to 21455
# 10 5 2019 10 : 49
# SVenus = -145 adjust to 21455
# 10 5 2019 10 : 50
# SVenus = -145 adjust to 21455
# 10 5 2019 10 : 51
# SVenus = -145 adjust to 21455
# 10 5 2019 10 : 52
# SVenus = -145 adjust to 21455
# 10 5 2019 10 : 53
# SVenus = -145 adjust to 21455
# 10 5 2019 10 : 54
# SVenus = -145 adjust to 21455
# 10 5 2019 10 : 55
# SVenus = -145 adjust to 21455
# 10 5 2019 10 : 56
# SVenus = -145 adjust to 21455
# 10 5 2019 10 : 57
# SVenus = -145 adjust to 21455
# 10 5 2019 10 : 58
# SVenus = -145 adjust to 21455
# 10 5 2019 10 : 59
# SVenus = -145 adjust to 21455
# 10 5 2019 11 : 0
# SVenus = -145 adjust to 21455
# 10 5 2019 11 : 1
# SVenus = -145 adjust to 21455
# 10 5 2019 11 : 2
# SVenus = -145 adjust to 21455
# 10 5 2019 11 : 3
# SVenus = -145 adjust to 21455
# 10 5 2019 11 : 4
# SVenus = -144 adjust to 21456
# 10 5 2019 11 : 5
# SVenus = -144 adjust to 21456
# 10 5 2019 11 : 6
# SVenus = -144 adjust to 21456
# 10 5 2019 11 : 7
# SVenus = -144 adjust to 21456
# 10 5 2019 11 : 8
# SVenus = -144 adjust to 21456
# 10 5 2019 11 : 9
# SVenus = -144 adjust to 21456
# 10 5 2019 11 : 10
# SVenus = -144 adjust to 21456
# 10 5 2019 11 : 11
# SVenus = -144 adjust to 21456
# 10 5 2019 11 : 12
# SVenus = -144 adjust to 21456
# 10 5 2019 11 : 13
# SVenus = -144 adjust to 21456
# 10 5 2019 11 : 14
# SVenus = -144 adjust to 21456
# 10 5 2019 11 : 15
# SVenus = -144 adjust to 21456
# 10 5 2019 11 : 16
# SVenus = -144 adjust to 21456
# 10 5 2019 11 : 17
# SVenus = -144 adjust to 21456
# 10 5 2019 11 : 18
# SVenus = -144 adjust to 21456
# 10 5 2019 11 : 19
# SVenus = -144 adjust to 21456
# 10 5 2019 11 : 20
# SVenus = -144 adjust to 21456
# 10 5 2019 11 : 21
# SVenus = -144 adjust to 21456
# 10 5 2019 11 : 22
# SVenus = -144 adjust to 21456
# 10 5 2019 11 : 23
# SVenus = -144 adjust to 21456
# 10 5 2019 11 : 24
# SVenus = -144 adjust to 21456
# 10 5 2019 11 : 25
# SVenus = -144 adjust to 21456
# 10 5 2019 11 : 26
# SVenus = -144 adjust to 21456
# 10 5 2019 11 : 27
# SVenus = -144 adjust to 21456
# 10 5 2019 11 : 28
# SVenus = -144 adjust to 21456
# 10 5 2019 11 : 29
# SVenus = -142 adjust to 21458
# 10 5 2019 11 : 30
# SVenus = -142 adjust to 21458
# 10 5 2019 11 : 31
# SVenus = -142 adjust to 21458
# 10 5 2019 11 : 32
# SVenus = -142 adjust to 21458
# 10 5 2019 11 : 33
# SVenus = -142 adjust to 21458
# 10 5 2019 11 : 34
# SVenus = -142 adjust to 21458
# 10 5 2019 11 : 35
# SVenus = -142 adjust to 21458
# 10 5 2019 11 : 36
# SVenus = -142 adjust to 21458
# 10 5 2019 11 : 37
# SVenus = -142 adjust to 21458
# 10 5 2019 11 : 38
# SVenus = -142 adjust to 21458
# 10 5 2019 11 : 39
# SVenus = -142 adjust to 21458
# 10 5 2019 11 : 40
# SVenus = -142 adjust to 21458
# 10 5 2019 11 : 41
# SVenus = -142 adjust to 21458
# 10 5 2019 11 : 42
# SVenus = -142 adjust to 21458
# 10 5 2019 11 : 43
# SVenus = -142 adjust to 21458
# 10 5 2019 11 : 44
# SVenus = -142 adjust to 21458
# 10 5 2019 11 : 45
# SVenus = -142 adjust to 21458
# 10 5 2019 11 : 46
# SVenus = -142 adjust to 21458
# 10 5 2019 11 : 47
# SVenus = -142 adjust to 21458
# 10 5 2019 11 : 48
# SVenus = -142 adjust to 21458
# 10 5 2019 11 : 49
# SVenus = -142 adjust to 21458
# 10 5 2019 11 : 50
# SVenus = -142 adjust to 21458
# 10 5 2019 11 : 51
# SVenus = -142 adjust to 21458
# 10 5 2019 11 : 52
# SVenus = -142 adjust to 21458
# 10 5 2019 11 : 53
# SVenus = -142 adjust to 21458
# 10 5 2019 11 : 54
# SVenus = -141 adjust to 21459
# 10 5 2019 11 : 55
# SVenus = -141 adjust to 21459
# 10 5 2019 11 : 56
# SVenus = -141 adjust to 21459
# 10 5 2019 11 : 57
# SVenus = -141 adjust to 21459
# 10 5 2019 11 : 58
# SVenus = -141 adjust to 21459
# 10 5 2019 11 : 59
# SVenus = -141 adjust to 21459
# 10 5 2019 12 : 0
# SVenus = -141 adjust to 21459
# 10 5 2019 12 : 1
# SVenus = -141 adjust to 21459
# 10 5 2019 12 : 2
# SVenus = -141 adjust to 21459
# 10 5 2019 12 : 3
# SVenus = -141 adjust to 21459
# 10 5 2019 12 : 4
# SVenus = -141 adjust to 21459
# 10 5 2019 12 : 5
# SVenus = -141 adjust to 21459
# 10 5 2019 12 : 6
# SVenus = -141 adjust to 21459
# 10 5 2019 12 : 7
# SVenus = -141 adjust to 21459
# 10 5 2019 12 : 8
# SVenus = -141 adjust to 21459
# 10 5 2019 12 : 9
# SVenus = -141 adjust to 21459
# 10 5 2019 12 : 10
# SVenus = -141 adjust to 21459
# 10 5 2019 12 : 11
# SVenus = -141 adjust to 21459
# 10 5 2019 12 : 12
# SVenus = -141 adjust to 21459
# 10 5 2019 12 : 13
# SVenus = -141 adjust to 21459
# 10 5 2019 12 : 14
# SVenus = -141 adjust to 21459
# 10 5 2019 12 : 15
# SVenus = -141 adjust to 21459
# 10 5 2019 12 : 16
# SVenus = -141 adjust to 21459
# 10 5 2019 12 : 17
# SVenus = -141 adjust to 21459
# 10 5 2019 12 : 18
# SVenus = -141 adjust to 21459
# 10 5 2019 12 : 19
# SVenus = -140 adjust to 21460
# 10 5 2019 12 : 20
# SVenus = -140 adjust to 21460
# 10 5 2019 12 : 21
# SVenus = -140 adjust to 21460
# 10 5 2019 12 : 22
# SVenus = -140 adjust to 21460
# 10 5 2019 12 : 23
# SVenus = -140 adjust to 21460
# 10 5 2019 12 : 24
# SVenus = -140 adjust to 21460
# 10 5 2019 12 : 25
# SVenus = -140 adjust to 21460
# 10 5 2019 12 : 26
# SVenus = -140 adjust to 21460
# 10 5 2019 12 : 27
# SVenus = -140 adjust to 21460
# 10 5 2019 12 : 28
# SVenus = -140 adjust to 21460
# 10 5 2019 12 : 29
# SVenus = -140 adjust to 21460
# 10 5 2019 12 : 30
# SVenus = -140 adjust to 21460
# 10 5 2019 12 : 31
# SVenus = -140 adjust to 21460
# 10 5 2019 12 : 32
# SVenus = -140 adjust to 21460
# 10 5 2019 12 : 33
# SVenus = -140 adjust to 21460
# 10 5 2019 12 : 34
# SVenus = -140 adjust to 21460
# 10 5 2019 12 : 35
# SVenus = -140 adjust to 21460
# 10 5 2019 12 : 36
# SVenus = -140 adjust to 21460
# 10 5 2019 12 : 37
# SVenus = -140 adjust to 21460
# 10 5 2019 12 : 38
# SVenus = -140 adjust to 21460
# 10 5 2019 12 : 39
# SVenus = -140 adjust to 21460
# 10 5 2019 12 : 40
# SVenus = -140 adjust to 21460
# 10 5 2019 12 : 41
# SVenus = -140 adjust to 21460
# 10 5 2019 12 : 42
# SVenus = -140 adjust to 21460
# 10 5 2019 12 : 43
# SVenus = -140 adjust to 21460
# 10 5 2019 12 : 44
# SVenus = -139 adjust to 21461
# 10 5 2019 12 : 45
# SVenus = -139 adjust to 21461
# 10 5 2019 12 : 46
# SVenus = -139 adjust to 21461
# 10 5 2019 12 : 47
# SVenus = -139 adjust to 21461
# 10 5 2019 12 : 48
# SVenus = -139 adjust to 21461
# 10 5 2019 12 : 49
# SVenus = -139 adjust to 21461
# 10 5 2019 12 : 50
# SVenus = -139 adjust to 21461
# 10 5 2019 12 : 51
# SVenus = -139 adjust to 21461
# 10 5 2019 12 : 52
# SVenus = -139 adjust to 21461
# 10 5 2019 12 : 53
# SVenus = -139 adjust to 21461
# 10 5 2019 12 : 54
# SVenus = -139 adjust to 21461
# 10 5 2019 12 : 55
# SVenus = -139 adjust to 21461
# 10 5 2019 12 : 56
# SVenus = -139 adjust to 21461
# 10 5 2019 12 : 57
# SVenus = -139 adjust to 21461
# 10 5 2019 12 : 58
# SVenus = -139 adjust to 21461
# 10 5 2019 12 : 59
# SVenus = -139 adjust to 21461
# 10 5 2019 13 : 0
# SVenus = -139 adjust to 21461
# 10 5 2019 13 : 1
# SVenus = -139 adjust to 21461
# 10 5 2019 13 : 2
# SVenus = -139 adjust to 21461
# 10 5 2019 13 : 3
# SVenus = -139 adjust to 21461
# 10 5 2019 13 : 4
# SVenus = -139 adjust to 21461
# 10 5 2019 13 : 5
# SVenus = -139 adjust to 21461
# 10 5 2019 13 : 6
# SVenus = -139 adjust to 21461
# 10 5 2019 13 : 7
# SVenus = -139 adjust to 21461
# 10 5 2019 13 : 8
# SVenus = -139 adjust to 21461
# 10 5 2019 13 : 9
# SVenus = -139 adjust to 21461
# 10 5 2019 13 : 10
# SVenus = -138 adjust to 21462
# 10 5 2019 13 : 11
# SVenus = -138 adjust to 21462
# 10 5 2019 13 : 12
# SVenus = -138 adjust to 21462
# 10 5 2019 13 : 13
# SVenus = -138 adjust to 21462
# 10 5 2019 13 : 14
# SVenus = -138 adjust to 21462
# 10 5 2019 13 : 15
# SVenus = -138 adjust to 21462
# 10 5 2019 13 : 16
# SVenus = -138 adjust to 21462
# 10 5 2019 13 : 17
# SVenus = -138 adjust to 21462
# 10 5 2019 13 : 18
# SVenus = -138 adjust to 21462
# 10 5 2019 13 : 19
# SVenus = -138 adjust to 21462
# 10 5 2019 13 : 20
# SVenus = -138 adjust to 21462
# 10 5 2019 13 : 21
# SVenus = -138 adjust to 21462
# 10 5 2019 13 : 22
# SVenus = -138 adjust to 21462
# 10 5 2019 13 : 23
# SVenus = -138 adjust to 21462
# 10 5 2019 13 : 24
# SVenus = -138 adjust to 21462
# 10 5 2019 13 : 25
# SVenus = -138 adjust to 21462
# 10 5 2019 13 : 26
# SVenus = -138 adjust to 21462
# 10 5 2019 13 : 27
# SVenus = -138 adjust to 21462
# 10 5 2019 13 : 28
# SVenus = -138 adjust to 21462
# 10 5 2019 13 : 29
# SVenus = -138 adjust to 21462
# 10 5 2019 13 : 30
# SVenus = -138 adjust to 21462
# 10 5 2019 13 : 31
# SVenus = -138 adjust to 21462
# 10 5 2019 13 : 32
# SVenus = -138 adjust to 21462
# 10 5 2019 13 : 33
# SVenus = -138 adjust to 21462
# 10 5 2019 13 : 34
# SVenus = -138 adjust to 21462
# 10 5 2019 13 : 35
# SVenus = -137 adjust to 21463
# 10 5 2019 13 : 36
# SVenus = -137 adjust to 21463
# 10 5 2019 13 : 37
# SVenus = -137 adjust to 21463
# 10 5 2019 13 : 38
# SVenus = -137 adjust to 21463
# 10 5 2019 13 : 39
# SVenus = -137 adjust to 21463
# 10 5 2019 13 : 40
# SVenus = -137 adjust to 21463
# 10 5 2019 13 : 41
# SVenus = -137 adjust to 21463
# 10 5 2019 13 : 42
# SVenus = -137 adjust to 21463
# 10 5 2019 13 : 43
# SVenus = -137 adjust to 21463
# 10 5 2019 13 : 44
# SVenus = -137 adjust to 21463
# 10 5 2019 13 : 45
# SVenus = -137 adjust to 21463
# 10 5 2019 13 : 46
# SVenus = -137 adjust to 21463
# 10 5 2019 13 : 47
# SVenus = -137 adjust to 21463
# 10 5 2019 13 : 48
# SVenus = -137 adjust to 21463
# 10 5 2019 13 : 49
# SVenus = -137 adjust to 21463
# 10 5 2019 13 : 50
# SVenus = -137 adjust to 21463
# 10 5 2019 13 : 51
# SVenus = -137 adjust to 21463
# 10 5 2019 13 : 52
# SVenus = -137 adjust to 21463
# 10 5 2019 13 : 53
# SVenus = -137 adjust to 21463
# 10 5 2019 13 : 54
# SVenus = -137 adjust to 21463
# 10 5 2019 13 : 55
# SVenus = -137 adjust to 21463
# 10 5 2019 13 : 56
# SVenus = -137 adjust to 21463
# 10 5 2019 13 : 57
# SVenus = -137 adjust to 21463
# 10 5 2019 13 : 58
# SVenus = -137 adjust to 21463
# 10 5 2019 13 : 59
# SVenus = -137 adjust to 21463
# 10 5 2019 14 : 0
# SVenus = -134 adjust to 21466
# 10 5 2019 14 : 1
# SVenus = -134 adjust to 21466
# 10 5 2019 14 : 2
# SVenus = -134 adjust to 21466
# 10 5 2019 14 : 3
# SVenus = -134 adjust to 21466
# 10 5 2019 14 : 4
# SVenus = -134 adjust to 21466
# 10 5 2019 14 : 5
# SVenus = -134 adjust to 21466
# 10 5 2019 14 : 6
# SVenus = -134 adjust to 21466
# 10 5 2019 14 : 7
# SVenus = -134 adjust to 21466
# 10 5 2019 14 : 8
# SVenus = -134 adjust to 21466
# 10 5 2019 14 : 9
# SVenus = -134 adjust to 21466
# 10 5 2019 14 : 10
# SVenus = -134 adjust to 21466
# 10 5 2019 14 : 11
# SVenus = -134 adjust to 21466
# 10 5 2019 14 : 12
# SVenus = -134 adjust to 21466
# 10 5 2019 14 : 13
# SVenus = -134 adjust to 21466
# 10 5 2019 14 : 14
# SVenus = -134 adjust to 21466
# 10 5 2019 14 : 15
# SVenus = -134 adjust to 21466
# 10 5 2019 14 : 16
# SVenus = -134 adjust to 21466
# 10 5 2019 14 : 17
# SVenus = -134 adjust to 21466
# 10 5 2019 14 : 18
# SVenus = -134 adjust to 21466
# 10 5 2019 14 : 19
# SVenus = -134 adjust to 21466
# 10 5 2019 14 : 20
# SVenus = -134 adjust to 21466
# 10 5 2019 14 : 21
# SVenus = -134 adjust to 21466
# 10 5 2019 14 : 22
# SVenus = -134 adjust to 21466
# 10 5 2019 14 : 23
# SVenus = -134 adjust to 21466
# 10 5 2019 14 : 24
# SVenus = -134 adjust to 21466
# 10 5 2019 14 : 25
# SVenus = -133 adjust to 21467
# 10 5 2019 14 : 26
# SVenus = -133 adjust to 21467
# 10 5 2019 14 : 27
# SVenus = -133 adjust to 21467
# 10 5 2019 14 : 28
# SVenus = -133 adjust to 21467
# 10 5 2019 14 : 29
# SVenus = -133 adjust to 21467
# 10 5 2019 14 : 30
# SVenus = -133 adjust to 21467
# 10 5 2019 14 : 31
# SVenus = -133 adjust to 21467
# 10 5 2019 14 : 32
# SVenus = -133 adjust to 21467
# 10 5 2019 14 : 33
# SVenus = -133 adjust to 21467
# 10 5 2019 14 : 34
# SVenus = -133 adjust to 21467
# 10 5 2019 14 : 35
# SVenus = -133 adjust to 21467
# 10 5 2019 14 : 36
# SVenus = -133 adjust to 21467
# 10 5 2019 14 : 37
# SVenus = -133 adjust to 21467
# 10 5 2019 14 : 38
# SVenus = -133 adjust to 21467
# 10 5 2019 14 : 39
# SVenus = -133 adjust to 21467
# 10 5 2019 14 : 40
# SVenus = -133 adjust to 21467
# 10 5 2019 14 : 41
# SVenus = -133 adjust to 21467
# 10 5 2019 14 : 42
# SVenus = -133 adjust to 21467
# 10 5 2019 14 : 43
# SVenus = -133 adjust to 21467
# 10 5 2019 14 : 44
# SVenus = -133 adjust to 21467
# 10 5 2019 14 : 45
# SVenus = -133 adjust to 21467
# 10 5 2019 14 : 46
# SVenus = -133 adjust to 21467
# 10 5 2019 14 : 47
# SVenus = -133 adjust to 21467
# 10 5 2019 14 : 48
# SVenus = -133 adjust to 21467
# 10 5 2019 14 : 49
# SVenus = -133 adjust to 21467
# 10 5 2019 14 : 50
# SVenus = -132 adjust to 21468
# 10 5 2019 14 : 51
# SVenus = -132 adjust to 21468
# 10 5 2019 14 : 52
# SVenus = -132 adjust to 21468
# 10 5 2019 14 : 53
# SVenus = -132 adjust to 21468
# 10 5 2019 14 : 54
# SVenus = -132 adjust to 21468
# 10 5 2019 14 : 55
# SVenus = -132 adjust to 21468
# 10 5 2019 14 : 56
# SVenus = -132 adjust to 21468
# 10 5 2019 14 : 57
# SVenus = -132 adjust to 21468
# 10 5 2019 14 : 58
# SVenus = -132 adjust to 21468
# 10 5 2019 14 : 59
# SVenus = -132 adjust to 21468
# 10 5 2019 15 : 0
# SVenus = -132 adjust to 21468
# 10 5 2019 15 : 1
# SVenus = -132 adjust to 21468
# 10 5 2019 15 : 2
# SVenus = -132 adjust to 21468
# 10 5 2019 15 : 3
# SVenus = -132 adjust to 21468
# 10 5 2019 15 : 4
# SVenus = -132 adjust to 21468
# 10 5 2019 15 : 5
# SVenus = -132 adjust to 21468
# 10 5 2019 15 : 6
# SVenus = -132 adjust to 21468
# 10 5 2019 15 : 7
# SVenus = -132 adjust to 21468
# 10 5 2019 15 : 8
# SVenus = -132 adjust to 21468
# 10 5 2019 15 : 9
# SVenus = -132 adjust to 21468
# 10 5 2019 15 : 10
# SVenus = -132 adjust to 21468
# 10 5 2019 15 : 11
# SVenus = -132 adjust to 21468
# 10 5 2019 15 : 12
# SVenus = -132 adjust to 21468
# 10 5 2019 15 : 13
# SVenus = -132 adjust to 21468
# 10 5 2019 15 : 14
# SVenus = -132 adjust to 21468
# 10 5 2019 15 : 15
# SVenus = -132 adjust to 21468
# 10 5 2019 15 : 16
# SVenus = -131 adjust to 21469
# 10 5 2019 15 : 17
# SVenus = -131 adjust to 21469
# 10 5 2019 15 : 18
# SVenus = -131 adjust to 21469
# 10 5 2019 15 : 19
# SVenus = -131 adjust to 21469
# 10 5 2019 15 : 20
# SVenus = -131 adjust to 21469
# 10 5 2019 15 : 21
# SVenus = -131 adjust to 21469
# 10 5 2019 15 : 22
# SVenus = -131 adjust to 21469
# 10 5 2019 15 : 23
# SVenus = -131 adjust to 21469
# 10 5 2019 15 : 24
# SVenus = -131 adjust to 21469
# 10 5 2019 15 : 25
# SVenus = -131 adjust to 21469
# 10 5 2019 15 : 26
# SVenus = -131 adjust to 21469
# 10 5 2019 15 : 27
# SVenus = -131 adjust to 21469
# 10 5 2019 15 : 28
# SVenus = -131 adjust to 21469
# 10 5 2019 15 : 29
# SVenus = -131 adjust to 21469
# 10 5 2019 15 : 30
# SVenus = -131 adjust to 21469
# 10 5 2019 15 : 31
# SVenus = -131 adjust to 21469
# 10 5 2019 15 : 32
# SVenus = -131 adjust to 21469
# 10 5 2019 15 : 33
# SVenus = -131 adjust to 21469
# 10 5 2019 15 : 34
# SVenus = -131 adjust to 21469
# 10 5 2019 15 : 35
# SVenus = -131 adjust to 21469
# 10 5 2019 15 : 36
# SVenus = -131 adjust to 21469
# 10 5 2019 15 : 37
# SVenus = -131 adjust to 21469
# 10 5 2019 15 : 38
# SVenus = -131 adjust to 21469
# 10 5 2019 15 : 39
# SVenus = -131 adjust to 21469
# 10 5 2019 15 : 40
# SVenus = -131 adjust to 21469
# 10 5 2019 15 : 41
# SVenus = -130 adjust to 21470
# 10 5 2019 15 : 42
# SVenus = -130 adjust to 21470
# 10 5 2019 15 : 43
# SVenus = -130 adjust to 21470
# 10 5 2019 15 : 44
# SVenus = -130 adjust to 21470
# 10 5 2019 15 : 45
# SVenus = -130 adjust to 21470
# 10 5 2019 15 : 46
# SVenus = -130 adjust to 21470
# 10 5 2019 15 : 47
# SVenus = -130 adjust to 21470
# 10 5 2019 15 : 48
# SVenus = -130 adjust to 21470
# 10 5 2019 15 : 49
# SVenus = -130 adjust to 21470
# 10 5 2019 15 : 50
# SVenus = -130 adjust to 21470
# 10 5 2019 15 : 51
# SVenus = -130 adjust to 21470
# 10 5 2019 15 : 52
# SVenus = -130 adjust to 21470
# 10 5 2019 15 : 53
# SVenus = -130 adjust to 21470
# 10 5 2019 15 : 54
# SVenus = -130 adjust to 21470
# 10 5 2019 15 : 55
# SVenus = -130 adjust to 21470
# 10 5 2019 15 : 56
# SVenus = -130 adjust to 21470
# 10 5 2019 15 : 57
# SVenus = -130 adjust to 21470
# 10 5 2019 15 : 58
# SVenus = -130 adjust to 21470
# 10 5 2019 15 : 59
# SVenus = -130 adjust to 21470
# 10 5 2019 16 : 0
# SVenus = -130 adjust to 21470
# 10 5 2019 16 : 1
# SVenus = -130 adjust to 21470
# 10 5 2019 16 : 2
# SVenus = -130 adjust to 21470
# 10 5 2019 16 : 3
# SVenus = -130 adjust to 21470
# 10 5 2019 16 : 4
# SVenus = -130 adjust to 21470
# 10 5 2019 16 : 5
# SVenus = -130 adjust to 21470
# 10 5 2019 16 : 6
# SVenus = -129 adjust to 21471
# 10 5 2019 16 : 7
# SVenus = -129 adjust to 21471
# 10 5 2019 16 : 8
# SVenus = -129 adjust to 21471
# 10 5 2019 16 : 9
# SVenus = -129 adjust to 21471
# 10 5 2019 16 : 10
# SVenus = -129 adjust to 21471
# 10 5 2019 16 : 11
# SVenus = -129 adjust to 21471
# 10 5 2019 16 : 12
# SVenus = -129 adjust to 21471
# 10 5 2019 16 : 13
# SVenus = -129 adjust to 21471
# 10 5 2019 16 : 14
# SVenus = -129 adjust to 21471
# 10 5 2019 16 : 15
# SVenus = -129 adjust to 21471
# 10 5 2019 16 : 16
# SVenus = -129 adjust to 21471
# 10 5 2019 16 : 17
# SVenus = -129 adjust to 21471
# 10 5 2019 16 : 18
# SVenus = -129 adjust to 21471
# 10 5 2019 16 : 19
# SVenus = -129 adjust to 21471
# 10 5 2019 16 : 20
# SVenus = -129 adjust to 21471
# 10 5 2019 16 : 21
# SVenus = -129 adjust to 21471
# 10 5 2019 16 : 22
# SVenus = -129 adjust to 21471
# 10 5 2019 16 : 23
# SVenus = -129 adjust to 21471
# 10 5 2019 16 : 24
# SVenus = -129 adjust to 21471
# 10 5 2019 16 : 25
# SVenus = -129 adjust to 21471
# 10 5 2019 16 : 26
# SVenus = -129 adjust to 21471
# 10 5 2019 16 : 27
# SVenus = -129 adjust to 21471
# 10 5 2019 16 : 28
# SVenus = -129 adjust to 21471
# 10 5 2019 16 : 29
# SVenus = -129 adjust to 21471
# 10 5 2019 16 : 30
# SVenus = -129 adjust to 21471
# 10 5 2019 16 : 31
# SVenus = -130 adjust to 21470
# 10 5 2019 16 : 32
# SVenus = -130 adjust to 21470
# 10 5 2019 16 : 33
# SVenus = -130 adjust to 21470
# 10 5 2019 16 : 34
# SVenus = -130 adjust to 21470
# 10 5 2019 16 : 35
# SVenus = -130 adjust to 21470
# 10 5 2019 16 : 36
# SVenus = -130 adjust to 21470
# 10 5 2019 16 : 37
# SVenus = -130 adjust to 21470
# 10 5 2019 16 : 38
# SVenus = -130 adjust to 21470
# 10 5 2019 16 : 39
# SVenus = -130 adjust to 21470
# 10 5 2019 16 : 40
# SVenus = -130 adjust to 21470
# 10 5 2019 16 : 41
# SVenus = -130 adjust to 21470
# 10 5 2019 16 : 42
# SVenus = -130 adjust to 21470
# 10 5 2019 16 : 43
# SVenus = -130 adjust to 21470
# 10 5 2019 16 : 44
# SVenus = -130 adjust to 21470
# 10 5 2019 16 : 45
# SVenus = -130 adjust to 21470
# 10 5 2019 16 : 46
# SVenus = -130 adjust to 21470
# 10 5 2019 16 : 47
# SVenus = -130 adjust to 21470
# 10 5 2019 16 : 48
# SVenus = -130 adjust to 21470
# 10 5 2019 16 : 49
# SVenus = -130 adjust to 21470
# 10 5 2019 16 : 50
# SVenus = -130 adjust to 21470
# 10 5 2019 16 : 51
# SVenus = -130 adjust to 21470
# 10 5 2019 16 : 52
# SVenus = -130 adjust to 21470
# 10 5 2019 16 : 53
# SVenus = -130 adjust to 21470
# 10 5 2019 16 : 54
# SVenus = -130 adjust to 21470
# 10 5 2019 16 : 55
# ...
# 12 5 2019 19 : 56
# 12 5 2019 19 : 57
# 12 5 2019 19 : 58
# 12 5 2019 19 : 59
# 12 5 2019 20 : 0
# 12 5 2019 20 : 1
# 12 5 2019 20 : 2
# 12 5 2019 20 : 3
# 12 5 2019 20 : 4
# 12 5 2019 20 : 5
# 12 5 2019 20 : 6
# 12 5 2019 20 : 7
# 12 5 2019 20 : 8
# 12 5 2019 20 : 9
# 12 5 2019 20 : 10
# 12 5 2019 20 : 11
# 12 5 2019 20 : 12
# 12 5 2019 20 : 13
# 12 5 2019 20 : 14
# 12 5 2019 20 : 15
# 12 5 2019 20 : 16
# 12 5 2019 20 : 17
# 12 5 2019 20 : 18
# 12 5 2019 20 : 19
# 12 5 2019 20 : 20
# 12 5 2019 20 : 21
# 12 5 2019 20 : 22
# 12 5 2019 20 : 23
# 12 5 2019 20 : 24
# 12 5 2019 20 : 25
# 12 5 2019 20 : 26
# 12 5 2019 20 : 27
# 12 5 2019 20 : 28
# 12 5 2019 20 : 29
# 12 5 2019 20 : 30
# 12 5 2019 20 : 31
# 12 5 2019 20 : 32
# 12 5 2019 20 : 33
# 12 5 2019 20 : 34
# 12 5 2019 20 : 35
# 12 5 2019 20 : 36
# 12 5 2019 20 : 37
# 12 5 2019 20 : 38
# 12 5 2019 20 : 39
# 12 5 2019 20 : 40
# 12 5 2019 20 : 41
# 12 5 2019 20 : 42
# 12 5 2019 20 : 43
# 12 5 2019 20 : 44
# 12 5 2019 20 : 45
# 12 5 2019 20 : 46
# 12 5 2019 20 : 47
# 12 5 2019 20 : 48
# 12 5 2019 20 : 49
# 12 5 2019 20 : 50
# 12 5 2019 20 : 51
# 12 5 2019 20 : 52
# 12 5 2019 20 : 53
# 12 5 2019 20 : 54
# 12 5 2019 20 : 55
# 12 5 2019 20 : 56
# 12 5 2019 20 : 57
# 12 5 2019 20 : 58
# 12 5 2019 20 : 59
# 12 5 2019 21 : 0
# 12 5 2019 21 : 1
# 12 5 2019 21 : 2
# 12 5 2019 21 : 3
# 12 5 2019 21 : 4
# 12 5 2019 21 : 5
# 12 5 2019 21 : 6
# 12 5 2019 21 : 7
# 12 5 2019 21 : 8
# 12 5 2019 21 : 9
# 12 5 2019 21 : 10
# 12 5 2019 21 : 11
# 12 5 2019 21 : 12
# 12 5 2019 21 : 13
# 12 5 2019 21 : 14
# 12 5 2019 21 : 15
# 12 5 2019 21 : 16
# 12 5 2019 21 : 17
# 12 5 2019 21 : 18
# 12 5 2019 21 : 19
# 12 5 2019 21 : 20
# 12 5 2019 21 : 21
# 12 5 2019 21 : 22
# 12 5 2019 21 : 23
# 12 5 2019 21 : 24
# 12 5 2019 21 : 25
# 12 5 2019 21 : 26
# 12 5 2019 21 : 27
# 12 5 2019 21 : 28
# 12 5 2019 21 : 29
# 12 5 2019 21 : 30
# 12 5 2019 21 : 31
# 12 5 2019 21 : 32
# 12 5 2019 21 : 33
# 12 5 2019 21 : 34
# 12 5 2019 21 : 35
# 12 5 2019 21 : 36
# 12 5 2019 21 : 37
# 12 5 2019 21 : 38
# 12 5 2019 21 : 39
# 12 5 2019 21 : 40
# 12 5 2019 21 : 41
# 12 5 2019 21 : 42
# 12 5 2019 21 : 43
# 12 5 2019 21 : 44
# 12 5 2019 21 : 45
# 12 5 2019 21 : 46
# 12 5 2019 21 : 47
# 12 5 2019 21 : 48
# 12 5 2019 21 : 49
# 12 5 2019 21 : 50
# 12 5 2019 21 : 51
# 12 5 2019 21 : 52
# 12 5 2019 21 : 53
# 12 5 2019 21 : 54
# 12 5 2019 21 : 55
# 12 5 2019 21 : 56
# 12 5 2019 21 : 57
# 12 5 2019 21 : 58
# 12 5 2019 21 : 59
# 12 5 2019 22 : 0
# 12 5 2019 22 : 1
# 12 5 2019 22 : 2
# 12 5 2019 22 : 3
# 12 5 2019 22 : 4
# 12 5 2019 22 : 5
# 12 5 2019 22 : 6
# 12 5 2019 22 : 7
# 12 5 2019 22 : 8
# 12 5 2019 22 : 9
# 12 5 2019 22 : 10
# 12 5 2019 22 : 11
# 12 5 2019 22 : 12
# 12 5 2019 22 : 13
# 12 5 2019 22 : 14
# 12 5 2019 22 : 15
# 12 5 2019 22 : 16
# 12 5 2019 22 : 17
# 12 5 2019 22 : 18
# 12 5 2019 22 : 19
# 12 5 2019 22 : 20
# 12 5 2019 22 : 21
# 12 5 2019 22 : 22
# 12 5 2019 22 : 23
# 12 5 2019 22 : 24
# 12 5 2019 22 : 25
# 12 5 2019 22 : 26
# 12 5 2019 22 : 27
# 12 5 2019 22 : 28
# 12 5 2019 22 : 29
# 12 5 2019 22 : 30
# 12 5 2019 22 : 31
# 12 5 2019 22 : 32
# 12 5 2019 22 : 33
# 12 5 2019 22 : 34
# 12 5 2019 22 : 35
# 12 5 2019 22 : 36
# 12 5 2019 22 : 37
# 12 5 2019 22 : 38
# 12 5 2019 22 : 39
# 12 5 2019 22 : 40
# 12 5 2019 22 : 41
# 12 5 2019 22 : 42
# 12 5 2019 22 : 43
# 12 5 2019 22 : 44
# 12 5 2019 22 : 45
# 12 5 2019 22 : 46
# 12 5 2019 22 : 47
# 12 5 2019 22 : 48
# 12 5 2019 22 : 49
# 12 5 2019 22 : 50
# 12 5 2019 22 : 51
# 12 5 2019 22 : 52
# 12 5 2019 22 : 53
# 12 5 2019 22 : 54
# 12 5 2019 22 : 55
# 12 5 2019 22 : 56
# 12 5 2019 22 : 57
# 12 5 2019 22 : 58
# 12 5 2019 22 : 59
# 12 5 2019 23 : 0
# 12 5 2019 23 : 1
# 12 5 2019 23 : 2
# 12 5 2019 23 : 3
# 12 5 2019 23 : 4
# 12 5 2019 23 : 5
# 12 5 2019 23 : 6
# 12 5 2019 23 : 7
# 12 5 2019 23 : 8
# 12 5 2019 23 : 9
# 12 5 2019 23 : 10
# 12 5 2019 23 : 11
# 12 5 2019 23 : 12
# 12 5 2019 23 : 13
# 12 5 2019 23 : 14
# 12 5 2019 23 : 15
# 12 5 2019 23 : 16
# 12 5 2019 23 : 17
# 12 5 2019 23 : 18
# 12 5 2019 23 : 19
# 12 5 2019 23 : 20
# 12 5 2019 23 : 21
# 12 5 2019 23 : 22
# 12 5 2019 23 : 23
# 12 5 2019 23 : 24
# 12 5 2019 23 : 25
# 12 5 2019 23 : 26
# 12 5 2019 23 : 27
# 12 5 2019 23 : 28
# 12 5 2019 23 : 29
# 12 5 2019 23 : 30
# 12 5 2019 23 : 31
# 12 5 2019 23 : 32
# 12 5 2019 23 : 33
# 12 5 2019 23 : 34
# 12 5 2019 23 : 35
# 12 5 2019 23 : 36
# 12 5 2019 23 : 37
# 12 5 2019 23 : 38
# 12 5 2019 23 : 39
# 12 5 2019 23 : 40
# 12 5 2019 23 : 41
# 12 5 2019 23 : 42
# 12 5 2019 23 : 43
# 12 5 2019 23 : 44
# 12 5 2019 23 : 45
# 12 5 2019 23 : 46
# 12 5 2019 23 : 47
# 12 5 2019 23 : 48
# 12 5 2019 23 : 49
# 12 5 2019 23 : 50
# 12 5 2019 23 : 51
# 12 5 2019 23 : 52
# 12 5 2019 23 : 53
# 12 5 2019 23 : 54
# 12 5 2019 23 : 55
# 12 5 2019 23 : 56
# 12 5 2019 23 : 57
# 12 5 2019 23 : 58
# 12 5 2019 23 : 59
# 13 5 2019 0 : 0
# 13 5 2019 0 : 1
# 13 5 2019 0 : 2
# 13 5 2019 0 : 3
# 13 5 2019 0 : 4
# 13 5 2019 0 : 5
# 13 5 2019 0 : 6
# 13 5 2019 0 : 7
# 13 5 2019 0 : 8
# 13 5 2019 0 : 9
# 13 5 2019 0 : 10
# 13 5 2019 0 : 11
# 13 5 2019 0 : 12
# 13 5 2019 0 : 13
# 13 5 2019 0 : 14
# 13 5 2019 0 : 15
# 13 5 2019 0 : 16
# 13 5 2019 0 : 17
# 13 5 2019 0 : 18
# 13 5 2019 0 : 19
# 13 5 2019 0 : 20
# 13 5 2019 0 : 21
# 13 5 2019 0 : 22
# 13 5 2019 0 : 23
# 13 5 2019 0 : 24
# 13 5 2019 0 : 25
# 13 5 2019 0 : 26
# 13 5 2019 0 : 27
# 13 5 2019 0 : 28
# 13 5 2019 0 : 29
# 13 5 2019 0 : 30
# 13 5 2019 0 : 31
# 13 5 2019 0 : 32
# 13 5 2019 0 : 33
# 13 5 2019 0 : 34
# 13 5 2019 0 : 35
# 13 5 2019 0 : 36
# 13 5 2019 0 : 37
# 13 5 2019 0 : 38
# 13 5 2019 0 : 39
# 13 5 2019 0 : 40
# 13 5 2019 0 : 41
# 13 5 2019 0 : 42
# 13 5 2019 0 : 43
# 13 5 2019 0 : 44
# 13 5 2019 0 : 45
# 13 5 2019 0 : 46
# 13 5 2019 0 : 47
# 13 5 2019 0 : 48
# 13 5 2019 0 : 49
# 13 5 2019 0 : 50
# 13 5 2019 0 : 51
# 13 5 2019 0 : 52
# 13 5 2019 0 : 53
# 13 5 2019 0 : 54
# 13 5 2019 0 : 55
# 13 5 2019 0 : 56
# 13 5 2019 0 : 57
# 13 5 2019 0 : 58
# 13 5 2019 0 : 59
# 13 5 2019 1 : 0
# 13 5 2019 1 : 1
# 13 5 2019 1 : 2
# 13 5 2019 1 : 3
# 13 5 2019 1 : 4
# 13 5 2019 1 : 5
# 13 5 2019 1 : 6
# 13 5 2019 1 : 7
# 13 5 2019 1 : 8
# 13 5 2019 1 : 9
# 13 5 2019 1 : 10
# 13 5 2019 1 : 11
# 13 5 2019 1 : 12
# 13 5 2019 1 : 13
# 13 5 2019 1 : 14
# 13 5 2019 1 : 15
# 13 5 2019 1 : 16
# 13 5 2019 1 : 17
# 13 5 2019 1 : 18
# 13 5 2019 1 : 19
# 13 5 2019 1 : 20
# 13 5 2019 1 : 21
# 13 5 2019 1 : 22
# 13 5 2019 1 : 23
# 13 5 2019 1 : 24
# 13 5 2019 1 : 25
# 13 5 2019 1 : 26
# 13 5 2019 1 : 27
# 13 5 2019 1 : 28
# 13 5 2019 1 : 29
# 13 5 2019 1 : 30
# 13 5 2019 1 : 31
# 13 5 2019 1 : 32
# 13 5 2019 1 : 33
# 13 5 2019 1 : 34
# 13 5 2019 1 : 35
# 13 5 2019 1 : 36
# 13 5 2019 1 : 37
# 13 5 2019 1 : 38
# 13 5 2019 1 : 39
# 13 5 2019 1 : 40
# 13 5 2019 1 : 41
# 13 5 2019 1 : 42
# 13 5 2019 1 : 43
# 13 5 2019 1 : 44
# 13 5 2019 1 : 45
# 13 5 2019 1 : 46
# 13 5 2019 1 : 47
# 13 5 2019 1 : 48
# 13 5 2019 1 : 49
# 13 5 2019 1 : 50
# 13 5 2019 1 : 51
# 13 5 2019 1 : 52
# 13 5 2019 1 : 53
# 13 5 2019 1 : 54
# 13 5 2019 1 : 55
# 13 5 2019 1 : 56
# 13 5 2019 1 : 57
# 13 5 2019 1 : 58
# 13 5 2019 1 : 59
# 13 5 2019 2 : 0
# 13 5 2019 2 : 1
# 13 5 2019 2 : 2
# 13 5 2019 2 : 3
# 13 5 2019 2 : 4
# 13 5 2019 2 : 5
# 13 5 2019 2 : 6
# 13 5 2019 2 : 7
# 13 5 2019 2 : 8
# 13 5 2019 2 : 9
# 13 5 2019 2 : 10
# 13 5 2019 2 : 11
# 13 5 2019 2 : 12
# 13 5 2019 2 : 13
# 13 5 2019 2 : 14
# 13 5 2019 2 : 15
# 13 5 2019 2 : 16
# 13 5 2019 2 : 17
# 13 5 2019 2 : 18
# 13 5 2019 2 : 19
# 13 5 2019 2 : 20
# 13 5 2019 2 : 21
# 13 5 2019 2 : 22
# 13 5 2019 2 : 23
# 13 5 2019 2 : 24
# 13 5 2019 2 : 25
# 13 5 2019 2 : 26
# 13 5 2019 2 : 27
# 13 5 2019 2 : 28
# 13 5 2019 2 : 29
# 13 5 2019 2 : 30
# 13 5 2019 2 : 31
# 13 5 2019 2 : 32
# 13 5 2019 2 : 33
# 13 5 2019 2 : 34
# 13 5 2019 2 : 35
# 13 5 2019 2 : 36
# 13 5 2019 2 : 37
# 13 5 2019 2 : 38
# 13 5 2019 2 : 39
# 13 5 2019 2 : 40
# 13 5 2019 2 : 41
# 13 5 2019 2 : 42
# 13 5 2019 2 : 43
# 13 5 2019 2 : 44
# 13 5 2019 2 : 45
# 13 5 2019 2 : 46
# 13 5 2019 2 : 47
# 13 5 2019 2 : 48
# 13 5 2019 2 : 49
# 13 5 2019 2 : 50
# 13 5 2019 2 : 51
# 13 5 2019 2 : 52
# 13 5 2019 2 : 53
# 13 5 2019 2 : 54
# 13 5 2019 2 : 55
# 13 5 2019 2 : 56
# 13 5 2019 2 : 57
# 13 5 2019 2 : 58
# 13 5 2019 2 : 59
# 13 5 2019 3 : 0
# 13 5 2019 3 : 1
# 13 5 2019 3 : 2
# 13 5 2019 3 : 3
# 13 5 2019 3 : 4
# 13 5 2019 3 : 5
# 13 5 2019 3 : 6
# 13 5 2019 3 : 7
# 13 5 2019 3 : 8
# 13 5 2019 3 : 9
# 13 5 2019 3 : 10
# 13 5 2019 3 : 11
# 13 5 2019 3 : 12
# 13 5 2019 3 : 13
# 13 5 2019 3 : 14
# 13 5 2019 3 : 15
# 13 5 2019 3 : 16
# 13 5 2019 3 : 17
# 13 5 2019 3 : 18
# 13 5 2019 3 : 19
# 13 5 2019 3 : 20
# 13 5 2019 3 : 21
# 13 5 2019 3 : 22
# 13 5 2019 3 : 23
# 13 5 2019 3 : 24
# 13 5 2019 3 : 25
# 13 5 2019 3 : 26
# 13 5 2019 3 : 27
# 13 5 2019 3 : 28
# 13 5 2019 3 : 29
# 13 5 2019 3 : 30
# 13 5 2019 3 : 31
# 13 5 2019 3 : 32
# 13 5 2019 3 : 33
# 13 5 2019 3 : 34
# 13 5 2019 3 : 35
# 13 5 2019 3 : 36
# 13 5 2019 3 : 37
# 13 5 2019 3 : 38
# 13 5 2019 3 : 39
# 13 5 2019 3 : 40
# 13 5 2019 3 : 41
# 13 5 2019 3 : 42
# 13 5 2019 3 : 43
# 13 5 2019 3 : 44
# 13 5 2019 3 : 45
# 13 5 2019 3 : 46
# 13 5 2019 3 : 47
# 13 5 2019 3 : 48
# 13 5 2019 3 : 49
# 13 5 2019 3 : 50
# 13 5 2019 3 : 51
# 13 5 2019 3 : 52
# 13 5 2019 3 : 53
# 13 5 2019 3 : 54
# 13 5 2019 3 : 55
# 13 5 2019 3 : 56
# 13 5 2019 3 : 57
# 13 5 2019 3 : 58
# 13 5 2019 3 : 59
# 13 5 2019 4 : 0
# 13 5 2019 4 : 1
# 13 5 2019 4 : 2
# 13 5 2019 4 : 3
# 13 5 2019 4 : 4
# 13 5 2019 4 : 5
# 13 5 2019 4 : 6
# 13 5 2019 4 : 7
# 13 5 2019 4 : 8
# 13 5 2019 4 : 9
# 13 5 2019 4 : 10
# 13 5 2019 4 : 11
# 13 5 2019 4 : 12
# 13 5 2019 4 : 13
# 13 5 2019 4 : 14
# 13 5 2019 4 : 15
# 13 5 2019 4 : 16
# 13 5 2019 4 : 17
# 13 5 2019 4 : 18
# 13 5 2019 4 : 19
# 13 5 2019 4 : 20
# 13 5 2019 4 : 21
# 13 5 2019 4 : 22
# 13 5 2019 4 : 23
# 13 5 2019 4 : 24
# 13 5 2019 4 : 25
# 13 5 2019 4 : 26
# 13 5 2019 4 : 27
# 13 5 2019 4 : 28
# 13 5 2019 4 : 29
# 13 5 2019 4 : 30
# 13 5 2019 4 : 31
# 13 5 2019 4 : 32
# 13 5 2019 4 : 33
# 13 5 2019 4 : 34
# 13 5 2019 4 : 35
# 13 5 2019 4 : 36
# 13 5 2019 4 : 37
# 13 5 2019 4 : 38
# 13 5 2019 4 : 39
# 13 5 2019 4 : 40
# 13 5 2019 4 : 41
# 13 5 2019 4 : 42
# 13 5 2019 4 : 43
# 13 5 2019 4 : 44
# 13 5 2019 4 : 45
# 13 5 2019 4 : 46
# 13 5 2019 4 : 47
# 13 5 2019 4 : 48
# 13 5 2019 4 : 49
# 13 5 2019 4 : 50
# 13 5 2019 4 : 51
# 13 5 2019 4 : 52
# 13 5 2019 4 : 53
# 13 5 2019 4 : 54
# 13 5 2019 4 : 55
# 13 5 2019 4 : 56
# 13 5 2019 4 : 57
# 13 5 2019 4 : 58
# 13 5 2019 4 : 59
# 13 5 2019 5 : 0
# 13 5 2019 5 : 1
# 13 5 2019 5 : 2
# 13 5 2019 5 : 3
# 13 5 2019 5 : 4
# 13 5 2019 5 : 5
# 13 5 2019 5 : 6
# 13 5 2019 5 : 7
# 13 5 2019 5 : 8
# 13 5 2019 5 : 9
# 13 5 2019 5 : 10
# 13 5 2019 5 : 11
# 13 5 2019 5 : 12
# 13 5 2019 5 : 13
# 13 5 2019 5 : 14
# 13 5 2019 5 : 15
# 13 5 2019 5 : 16
# 13 5 2019 5 : 17
# 13 5 2019 5 : 18
# 13 5 2019 5 : 19
# 13 5 2019 5 : 20
# 13 5 2019 5 : 21
# 13 5 2019 5 : 22
# 13 5 2019 5 : 23
# 13 5 2019 5 : 24
# 13 5 2019 5 : 25
# 13 5 2019 5 : 26
# 13 5 2019 5 : 27
# 13 5 2019 5 : 28
# 13 5 2019 5 : 29
# 13 5 2019 5 : 30
# 13 5 2019 5 : 31
# 13 5 2019 5 : 32
# 13 5 2019 5 : 33
# 13 5 2019 5 : 34
# 13 5 2019 5 : 35
# 13 5 2019 5 : 36
# 13 5 2019 5 : 37
# 13 5 2019 5 : 38
# 13 5 2019 5 : 39
# 13 5 2019 5 : 40
# 13 5 2019 5 : 41
# 13 5 2019 5 : 42
# 13 5 2019 5 : 43
# 13 5 2019 5 : 44
# 13 5 2019 5 : 45
# 13 5 2019 5 : 46
# 13 5 2019 5 : 47
# 13 5 2019 5 : 48
# 13 5 2019 5 : 49
# 13 5 2019 5 : 50
# 13 5 2019 5 : 51
# 13 5 2019 5 : 52
# 13 5 2019 5 : 53
# 13 5 2019 5 : 54
# 13 5 2019 5 : 55
# 13 5 2019 5 : 56
# 13 5 2019 5 : 57
# 13 5 2019 5 : 58
# 13 5 2019 5 : 59
# 13 5 2019 6 : 0
# 13 5 2019 6 : 1
# 13 5 2019 6 : 2
# 13 5 2019 6 : 3
# 13 5 2019 6 : 4
# 13 5 2019 6 : 5
# 13 5 2019 6 : 6
# 13 5 2019 6 : 7
# 13 5 2019 6 : 8
# 13 5 2019 6 : 9
# 13 5 2019 6 : 10
# 13 5 2019 6 : 11
# 13 5 2019 6 : 12
# 13 5 2019 6 : 13
# 13 5 2019 6 : 14
# 13 5 2019 6 : 15
# 13 5 2019 6 : 16
# 13 5 2019 6 : 17
# 13 5 2019 6 : 18
# 13 5 2019 6 : 19
# 13 5 2019 6 : 20
# 13 5 2019 6 : 21
# 13 5 2019 6 : 22
# 13 5 2019 6 : 23
# 13 5 2019 6 : 24
# 13 5 2019 6 : 25
# 13 5 2019 6 : 26
# 13 5 2019 6 : 27
# 13 5 2019 6 : 28
# 13 5 2019 6 : 29
# 13 5 2019 6 : 30
# 13 5 2019 6 : 31
# 13 5 2019 6 : 32
# 13 5 2019 6 : 33
# 13 5 2019 6 : 34
# 13 5 2019 6 : 35
# 13 5 2019 6 : 36
# 13 5 2019 6 : 37
# 13 5 2019 6 : 38
# 13 5 2019 6 : 39
# 13 5 2019 6 : 40
# 13 5 2019 6 : 41
# 13 5 2019 6 : 42
# 13 5 2019 6 : 43
# 13 5 2019 6 : 44
# 13 5 2019 6 : 45
# 13 5 2019 6 : 46
# 13 5 2019 6 : 47
# 13 5 2019 6 : 48
# 13 5 2019 6 : 49
# 13 5 2019 6 : 50
# 13 5 2019 6 : 51
# 13 5 2019 6 : 52
# 13 5 2019 6 : 53
# 13 5 2019 6 : 54
# 13 5 2019 6 : 55
# 13 5 2019 6 : 56
# 13 5 2019 6 : 57
# 13 5 2019 6 : 58
# 13 5 2019 6 : 59
# 13 5 2019 7 : 0
# 13 5 2019 7 : 1
# 13 5 2019 7 : 2
# 13 5 2019 7 : 3
# 13 5 2019 7 : 4
# 13 5 2019 7 : 5
# 13 5 2019 7 : 6
# 13 5 2019 7 : 7
# 13 5 2019 7 : 8
# 13 5 2019 7 : 9
# 13 5 2019 7 : 10
# 13 5 2019 7 : 11
# 13 5 2019 7 : 12
# 13 5 2019 7 : 13
# 13 5 2019 7 : 14
# 13 5 2019 7 : 15
# 13 5 2019 7 : 16
# 13 5 2019 7 : 17
# 13 5 2019 7 : 18
# 13 5 2019 7 : 19
# 13 5 2019 7 : 20
# 13 5 2019 7 : 21
# 13 5 2019 7 : 22
# 13 5 2019 7 : 23
# 13 5 2019 7 : 24
# 13 5 2019 7 : 25
# 13 5 2019 7 : 26
# 13 5 2019 7 : 27
# 13 5 2019 7 : 28
# 13 5 2019 7 : 29
# 13 5 2019 7 : 30
# 13 5 2019 7 : 31
# 13 5 2019 7 : 32
# 13 5 2019 7 : 33
# 13 5 2019 7 : 34
# 13 5 2019 7 : 35
# 13 5 2019 7 : 36
# 13 5 2019 7 : 37
# 13 5 2019 7 : 38
# 13 5 2019 7 : 39
# 13 5 2019 7 : 40
# 13 5 2019 7 : 41
# 13 5 2019 7 : 42
# 13 5 2019 7 : 43
# 13 5 2019 7 : 44
# 13 5 2019 7 : 45
# 13 5 2019 7 : 46
# 13 5 2019 7 : 47
# 13 5 2019 7 : 48
# 13 5 2019 7 : 49
# 13 5 2019 7 : 50
# 13 5 2019 7 : 51
# 13 5 2019 7 : 52
# 13 5 2019 7 : 53
# 13 5 2019 7 : 54
# 13 5 2019 7 : 55
# 13 5 2019 7 : 56
# 13 5 2019 7 : 57
# 13 5 2019 7 : 58
# 13 5 2019 7 : 59
# 13 5 2019 8 : 0
# 13 5 2019 8 : 1
# 13 5 2019 8 : 2
# 13 5 2019 8 : 3
# 13 5 2019 8 : 4
# 13 5 2019 8 : 5
# 13 5 2019 8 : 6
# 13 5 2019 8 : 7
# 13 5 2019 8 : 8
# 13 5 2019 8 : 9
# 13 5 2019 8 : 10
# 13 5 2019 8 : 11
# 13 5 2019 8 : 12
# 13 5 2019 8 : 13
# 13 5 2019 8 : 14
# 13 5 2019 8 : 15
# 13 5 2019 8 : 16
# 13 5 2019 8 : 17
# 13 5 2019 8 : 18
# 13 5 2019 8 : 19
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-d92c07e8caa0> in <module>
#      29     print(dt.day,dt.month,dt.year,dt.hour,':',dt.minute)
#      30     #df = pd.DataFrame(data)
# ---> 31     df = df.append(data , ignore_index=True)
#      32 df
#      33 #loops = ['sun','moon','rahu','geth','mars','mercury','venus','jupiter','saturn','uranus']
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in append(self, other, ignore_index, verify_integrity, sort)
#    6675                               index=index,
#    6676                               columns=combined_columns)
# -> 6677             other = other._convert(datetime=True, timedelta=True)
#    6678             if not self.columns.equals(combined_columns):
#    6679                 self = self.reindex(columns=combined_columns)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _convert(self, datetime, numeric, timedelta, coerce, copy)
#    5848             self._data.convert(datetime=datetime, numeric=numeric,
#    5849                                timedelta=timedelta, coerce=coerce,
# -> 5850                                copy=copy)).__finalize__(self)
#    5851
#    5852     def convert_objects(self, convert_dates=True, convert_numeric=False,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in convert(self, **kwargs)
#     532
#     533     def convert(self, **kwargs):
# --> 534         return self.apply('convert', **kwargs)
#     535
#     536     def replace(self, **kwargs):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#     400         bm = self.__class__(result_blocks, axes or self.axes,
#     401                             do_integrity_check=do_integrity_check)
# --> 402         bm._consolidate_inplace()
#     403         return bm
#     404
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in _consolidate_inplace(self)
#     927     def _consolidate_inplace(self):
#     928         if not self.is_consolidated():
# --> 929             self.blocks = tuple(_consolidate(self.blocks))
#     930             self._is_consolidated = True
#     931             self._known_consolidated = True
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in _consolidate(blocks)
#    1897     for (_can_consolidate, dtype), group_blocks in grouper:
#    1898         merged_blocks = _merge_blocks(list(group_blocks), dtype=dtype,
# -> 1899                                       _can_consolidate=_can_consolidate)
#    1900         new_blocks = _extend_blocks(merged_blocks, new_blocks)
#    1901     return new_blocks
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\blocks.py in _merge_blocks(blocks, dtype, _can_consolidate)
#    3143         # FIXME: optimization potential in case all mgrs contain slices and
#    3144         # combination of those slices is a slice, too.
# -> 3145         new_mgr_locs = np.concatenate([b.mgr_locs.as_array for b in blocks])
#    3146         new_values = np.vstack([b.values for b in blocks])
#    3147
#
# KeyboardInterrupt:

# %%
dt1= datetime(2019,1,1,0,0)
dt2= datetime(1943,4,17,9,49)
dt3= datetime(2019,1,2,22,45)


test1= hora(dt1)
test2= hora(dt2)
test3= hora(dt3)

#Create dataframe
#Method1
data = {
    'dt': [dt1,dt2,dt3],
    'sun' : [test1.sun,test2.sun,test3.sun],
    'moon': [test1.moon,test2.moon,test3.moon],
    'rahu' : [test1.rahu,test2.rahu,test3.rahu],
    'geth' : [test1.geth,test2.geth,test3.geth],
    'mars' : [test1.mars,test2.mars,test3.mars],
    'mercury' : [test1.mercury,test2.mercury,test3.mercury],
    'venus' : [test1.venus,test2.venus,test3.venus],
    'jupiter' : [test1.jupiter,test2.jupiter,test3.jupiter],
    'saturn' : [test1.saturn,test2.saturn,test3.saturn],
    'uranus' : [test1.uranus,test2.uranus,test3.uranus]
}


#Method2
# data = [
#     {'dt': dt1, 'ssun': test1.sun, 'smoon': test1.moon},
#     {'dt': dt2, 'ssun': test2.sun, 'smoon': test2.moon},
#     {'dt': dt3, 'ssun': test3.sun, 'smoon': test3.moon},
# ]

df = pd.DataFrame(data)


loops = ['sun','moon','rahu','geth','mars','mercury','venus','jupiter','saturn','uranus'] 

for planet in loops:
    zodiac = planet+"_Z"
    degree = planet+"_D"
    minute = planet+"_M"
    df[zodiac] =  df[planet]//1800 
    df[degree] =  (df[planet]%1800)//60 
    df[minute] =  (df[planet]%1800)%60

# df['sun_Z'] =  df['ssun']//1800 
# df['sun_D'] =  (df['ssun']%1800)//60 
# df['sun_M'] =  (df['ssun']%1800)%60

df[['sun_Z','sun_D','sun_M','moon_Z','moon_D','moon_M','rahu_Z','rahu_D','rahu_M','geth_Z','geth_D','geth_M']]
#df[['mercury_Z','mercury_D','mercury_M','venus_Z','venus_D','venus_M']]
#df[['mars_Z','mars_D','mars_M','jupiter_Z','jupiter_D','jupiter_M','saturn_Z','saturn_D','saturn_M','uranus_Z','uranus_D','uranus_M']]
# Out:
# Smars = -1498 adjust to 20102
# MTS = -137 adjust to 21463
# SMercury = 22715 adjust to 1115
# Smars = -1431 adjust to 20169
#    sun_Z  sun_D  sun_M  moon_Z  moon_D  moon_M  rahu_Z  rahu_D  rahu_M  \
# 0      8     15     29       6      13      42       3       2      45
# 1      0      3     21       4      25      31       3      28      19
# 2      8     17     29       7       9      51       3       2      39
#
#    geth_Z  geth_D  geth_M
# 0       9       7      50
# 1       5      29       0
# 2       9       6      48

# %%
dt1= datetime(1984,1,27,9,49)
dt2= datetime(2007,3,30,8,55)
dt3= datetime(2010,1,27,22,52)


test1= hora(dt1)
test2= hora(dt2)
test3= hora(dt3)

#Create dataframe
#Method1
data = {
    'dt': [dt1,dt2,dt3],
    'ssun' : [test1.sun,test2.sun,test3.sun],
    'smoon': [test1.moon,test2.moon,test3.moon],
    'srahu' : [test1.rahu,test2.rahu,test3.rahu],
    'sgeth' : [test1.geth,test2.geth,test3.geth],
    'smars' : [test1.mars,test2.mars,test3.mars],
    'smercury' : [test1.mercury,test2.mercury,test3.mercury],
    'svenus' : [test1.venus,test2.venus,test3.venus],
    'jupiter' : [test1.jupiter,test2.jupiter,test3.jupiter],
    'ssaturn' : [test1.saturn,test2.saturn,test3.saturn],
    'suranus' : [test1.uranus,test2.uranus,test3.uranus]
}


#Method2
# data = [
#     {'dt': dt1, 'ssun': test1.sun, 'smoon': test1.moon},
#     {'dt': dt2, 'ssun': test2.sun, 'smoon': test2.moon},
#     {'dt': dt3, 'ssun': test3.sun, 'smoon': test3.moon},
# ]

df = pd.DataFrame(data)



#Add row to DataFrame
#METHOD1: add or update specify by row name 
#df.loc[2] = [dt3,10,20]
#df.loc[3] = [dt3,10,20]

#METHOD1.1: Add row to the end of dataframe 
#df.loc[len(df.index)] = [dt3,10,20]
#df.loc[len(df.index)] = [dt3,10,20]
# df.loc[len(df.index)] = [dt3,10,20]


#METHOD2: Add row to some columns
#df = df.append({'dt' : 'dateadded' , 'ssun' : 2222} , ignore_index=True)

#print(len(df.index))


#Change column name
#df.columns = 'a','b','c'

#create new column and data
#method1
#df['newcolumn1'] = ''
#df['newcolumn1'] = [1,2,3,4,5]

#Method2
#df.insert(4, "newcolumn2", [21, 23, 24, 21, 20], True) 
#df.insert(len(df.columns), "newcolumn2", [21, 23, 24, 21, 20], True) 

#Method3-Create new 
#df2 = df.assign(address = ['Delhi', 'Bangalore', 'Chennai', 'Patna', 'ddd']) 
#df2


#Drop column 
#df = df.drop(columns=['newcolumn1','newcolumn2'])


# df['sun_Z'] =  df['ssun']//1800 
# df['sun_D'] =  (df['ssun']%1800)//60 
# df['sun_M'] =  (df['ssun']%1800)%60

# df['moon_Z'] =  df['smoon']//1800 
# df['moon_D'] =  (df['smoon']%1800)//60 
# df['moon_M'] =  (df['smoon']%1800)%60

# df['rahu_Z'] =  df['srahu']//1800 
# df['rahu_D'] =  (df['srahu']%1800)//60 
# df['rahu_M'] =  (df['srahu']%1800)%60

# df['geth_Z'] =  df['sgeth']//1800 
# df['geth_D'] =  (df['sgeth']%1800)//60 
# df['geth_M'] =  (df['sgeth']%1800)%60

# df['mars_Z'] =  df['smars']//1800 
# df['mars_D'] =  (df['smars']%1800)//60 
# df['mars_M'] =  (df['smars']%1800)%60



# df[0:]




#sliding rows 
#df[2:3]

#sliding columns 
# df[['dt','ssun','smoon']]

#sliding rows and columns 
#df.loc[row,colmm]
# df.loc[:,:]
# df.loc[1,['dt']]
# df.loc[1:3,['dt','ssun','smoon']]
# df.loc[1:3,'dt':'ssun']

#Change index
# df.set_index("dt", inplace=True)
# df.loc[:,:]
# df.loc[dt1,:]
# df.loc[dt1:dt3,['ssun','smoon']]
# df.loc[dt1:dt3,'ssun':'ssun_m']

#boolean
# df.loc[df['smoon'] >= 7000,'ssun':'ssun_m']

df



#df.loc[0:3,'dt']>dt1
#df.loc[0:3,'dt']>dt1
#data.set_index("last_name", inplace=True)
# Out:
# uv = 14819
# pholGA = 4019
# khan = 4
# SVenus = 22652 adjust to 1052
# uv = 17719
# pholGA = 3881
# khan = 4
# uv = 7926
# pholGA = 2874
# khan = 3
#                    dt   ssun  smoon  srahu  sgeth  smars  smercury  svenus  \
# 0 1984-01-27 09:49:00  16953  12913   2933  12108  11722     15638   14765
# 1 2007-03-30 08:55:00  20702   7569  19222   2089  18000     19459    1052
# 2 2010-01-27 22:52:00  17003   4207  15932  12377   6532     15557   17071
#
#    jupiter  ssaturn  suranus
# 0    14973    11999    13324
# 1    14290     6638    19352
# 2    18534     9464    19983

# %%
#df[['dt','ssun','sun_Z','sun_D','sun_M','smoon','moon_Z','moon_D','moon_M']]

# %%
# s_ravi = {
#     'jya': [35,32,27,22,13,5],
#     'ravi': [0,35,67,94,116,129]
# }
# #df = pd.DataFrame(s_ravi)
# df = pd.DataFrame(s_ravi)
# #df.iloc[1] = [kj,Ssun]
# #df.append(data)
# df = df.append({'kj' : 'Sahil' , 'sun' : 22} , ignore_index=True)
# df = df.append({'kj' : 'Sahil' , 'sun' : 22} , ignore_index=True)

# df = df.append({'kj' : 'Sahil' , 'sun' : 22 , 'datetime' : dt} , ignore_index=True)
# df = df.append({'kj' : 'Sahil' , 'sun' : 22 , 'datetime' : dtny} , ignore_index=True)


#Create dataframe
df = pd.DataFrame()

# Creating an empty Dataframe with column names only
df = pd.DataFrame(columns=['User_ID', 'UserName', 'Action'])

# Create an empty Dataframe with columns or indices
#df = pd.DataFrame(columns=['User_ID', 'UserName', 'Action'], index=['a', 'b', 'c'])

print(df.head(5))
print(df.tail())

print(df.dtypes)
print(df.index)
print(df.columns)
print(df.values)

#for index,row in df.iterrows():
#    print (index, row['ssun'], row['smoon'])
# Out:
# Empty DataFrame
# Columns: [User_ID, UserName, Action]
# Index: []
# Empty DataFrame
# Columns: [User_ID, UserName, Action]
# Index: []
# User_ID     object
# UserName    object
# Action      object
# dtype: object
# Index([], dtype='object')
# Index(['User_ID', 'UserName', 'Action'], dtype='object')
# []

# %%
day,month,year,hour,minute = 27,1,2527,9,49
christ_year = year-543

dt= datetime(christ_year,month,day,hour,minute)

a = hora(dt)  
print('dt =', a.dt)
print('dtnt =', a.dtny)
print('ahra =', a.ahra)
print('jultin =', a.jultin)
print('kj =', a.kj)
print('aw =', a.aw)
print('masG =', a.masG)
print('dT =', a.dT)
print('au =', a.au)
print('van =', a.van)

print('stin =', a.stin)
print('sec =', a.sec)
print('ahra_ =', a.ahra_)
print('kj_ =', a.kj_)
print('aw_ =', a.aw_)
print('masG_ =', a.masG_)
print('dT_ =', a.dT_)
print('au_ =', a.au_)
print('van_ =', a.van_)

print('sun =', a.sun)
print('moon =', a.moon)
print('rahu =', a.rahu)
print('geth =', a.geth)
print('mars =', a.mars)
print('mercury =', a.mercury)
print('venus =', a.venus)
print('jupiter =', a.jupiter)
print('saturn =', a.saturn)
print('uranus =', a.uranus)
# Out:
# dt = 1984-01-27 09:31:00
# dtnt = 1983-04-16 11:38:24
# ahra = 491274
# jultin = 388
# kj = 412
# aw = 144
# masG = 16636
# dT = 4
# au = 2621
# van = 0
# stin = 286
# sec = 34260
# ahra_ = 491560
# kj_ = 228729
# aw_ = 97
# masG_ = 16645
# dT_ = 24
# au_ = 2907
# van_ = 6
# sun = 16953
# moon = 12913
# rahu = 2933
# geth = 12108
# mars = 11722
# mercury = 15638
# venus = 14765
# jupiter = 14973
# saturn = 11999
# uranus = 13324

# %% [markdown]
# #
