# %%
import math
from datetime import date
from datetime import datetime
from datetime import timedelta
import pandas as pd

# %%
def NYdate(jula_year):
    ny = jula_year*0.25875-int(jula_year/4 +0.5)+int(jula_year/100 +0.38)-int(jula_year/400 +0.595)-5.53375
    jultin =  ((jula_year*292207)+373)%800
    hour,frac = divmod(jultin*24,800)
    minute,frac = divmod(frac*60,800)
    second,frac = divmod(frac*60,800)
    christ_year = jula_year+638
    dtny = datetime(christ_year, 4, int(ny), hour , minute, second)
    return dtny;

# %%
class hora:
    def __init__(self,dt):
        offset = timedelta(minutes=18)
        dt= dt-offset
        jula_year = dt.year-638    
        d = date(dt.year,dt.month,dt.day)
        dtf= datetime(dt.year,dt.month,dt.day,0,0)        
        dtny = NYdate(jula_year)
        dny = date(dtny.year,dtny.month,dtny.day)
        
        if (dt>=dtny):
            jula_newyear = jula_year
        elif (dt<dtny):
            jula_newyear = jula_year-1
            dtny = NYdate(jula_newyear)
            dny = date(dtny.year,dtny.month,dtny.day)

            
        temp = (jula_newyear*292207)+373
        ahra = (temp//800)+1
        jultin =  temp%800

        kj = 800-jultin
        temp,aw= divmod((ahra*11)+650,692)
        masG,dT=divmod((ahra+temp),30)

        au = (ahra-621)%3232
        van = ahra%7

        stin = (d-dny).days
        sec = (dt-dtf).seconds

        ahra_ = ahra+stin
        stkm = (stin-1)*800
        kj_ = kj + stkm + sec//108

        awjt = (stin-1)*703+aw
        aws = awjt+(sec*703)//86400
        awdT,aw_=divmod(aws,692)
        temp,dT_=divmod((awdT+dT),30)
        masG_ = masG+temp
        van_=ahra_%7

        if (au+stin > 3232):
            au_ = au+stin-3232
        else: au_= au+stin        
        
        
##########################SUN###############################
        sun_table = [[35,32,27,22,13,5,0],
                     [0,35,67,94,116,129,134]]

        z = kj_ // 24350
        z_remainder = kj_ % 24350
        degree = z_remainder//811
        d_remainder = z_remainder % 811
        minute = d_remainder//14

        d_total = z*30+degree
        mathasun = d_total*60+minute-3


        if mathasun >= 21600:
            raise Exception('mathasun exceed or equal 21600')
        elif mathasun < 0:
            raise Exception('mathasun below 0')
        elif mathasun < 4800:
            pholsun = 21600+mathasun-4800
        else:
            pholsun = mathasun-4800


        if pholsun >= 21600:
            raise Exception('pholsun exceed or equal 21600')
        elif pholsun < 0:
            raise Exception('pholsun below 0')
        elif pholsun >= 0 and pholsun <5400:
            pholGA = pholsun

        elif pholsun >= 5400 and pholsun <10800:
            pholGA = 10800-pholsun

        elif pholsun >= 10800 and pholsun <16200:
            pholGA = pholsun-10800

        elif pholsun >= 16200:
            pholGA = 21600-pholsun


        khan = pholGA // 900
        pushlip = pholGA % 900


        jyaGA = (sun_table[0][khan]*pushlip) // 900
        ravipphol = sun_table[1][khan]+jyaGA


        if pholsun < 10800:
            Ssun = mathasun-ravipphol
        elif pholsun > 10800:
            Ssun= mathasun+ravipphol
        elif pholsun == 10800:
            if(ravipphol != 0):raise Exception('pholsun=10800 but ravipphol not 0')
            Ssun= mathasun

        if Ssun < 0:
            Ssun = Ssun+21600
        elif Ssun > 21600:
            Ssun= Ssun-21600
            
        #zodiac,frac = divmod(Ssun,1800)
        #degree,minute = divmod(frac,60)    
#        sun = []
#        sun.append(Ssun)
#         sun.append(Ssun//1800)
#         sun.append((Ssun%1800)//60)
#         sun.append((Ssun%1800)%60)

#         print('pholGA =',pholGA)
#         print('khan =',khan)
#         print('kj_ =',kj_)
#         print('mathasun =',mathasun)
#         print('Ssun =',Ssun)

##########################MOON###############################

        moon_table = [[77,71,61,47,30,10,0],
                     [0,77,148,209,256,286,296]]

        temp = (au_-1)*86400+sec

        #zodiac,frac = divmod(x,23270400)
        #degree,frac = divmod(frac,775680)
        #minute = frac // 12928

        zodiac = temp//23270400
        degree = (temp%23270400)//775680
        minute = ((temp%23270400)%775680)//12928
        d_total = zodiac*30+degree
        mtu = d_total*60+minute+2


        mathamoon = mathasun + aw_ +(aw_//25)+(dT_*720)-40
        if mathamoon >= 21600: 
            mathamoon = mathamoon-21600

        if mathamoon >= 21600:
            raise Exception('mathamoon exceed or equal 21600')
        elif mathamoon < 0:
            raise Exception('mathamoon below 0')
        elif mtu >= 21600:
            raise Exception('mtu exceed or equal 21600')
        elif mtu < 0:
            raise Exception('mtu below 0')
        elif mathamoon>=mtu:
            uv =  mathamoon-mtu
        elif mathamoon<mtu:
            uv = 21600+mathamoon-mtu


        if uv >= 21600:
            raise Exception('uv exceed or equal 21600')
        elif uv < 0:
            raise Exception('uv below 0')
        elif uv >= 0 and uv <5400:
            pholGA = uv
        elif uv >= 5400 and uv <10800:
            pholGA = 10800-uv
        elif uv >= 10800 and uv <16200:
            pholGA = uv-10800
        elif uv >= 16200:
            pholGA = 21600-uv


        khan = pholGA // 900
        pushlip = pholGA % 900

        jyaGA = (moon_table[0][khan]*pushlip) // 900
        chandraphol = moon_table[1][khan]+jyaGA

        if uv < 10800:
            Smoon = mathamoon-chandraphol
        elif uv > 10800:
            Smoon= mathamoon+chandraphol
        elif uv == 10800:
            if(chandraphol != 0):raise Exception('uv=10800 but chandraphol not 0')
            Smoon= mathamoon

        if Smoon < 0:
            Smoon = Smoon+21600
        elif Smoon > 21600:
            Smoon= Smoon-21600


##########################RAHU###############################
        matharavi = mathasun-23
        srb = jula_newyear-610
        manut = (srb*21600)+ matharavi

        a = manut//20
        b = manut//265
        pmt = (a+b)%21600

        Srahu = 15150-pmt
        if Srahu<0:
            Srahu = Srahu+21600

##########################GETH###############################
        pholgt = (ahra_-345)%679
        mathageth = (pholgt*21600 + (sec*21600)//86400)//679
        Sgeth = 21600-mathageth
        zodiac,frac = divmod(Sgeth,1800)
        degree,minute = divmod(frac,60)

        


                
##########################Inner Plannets##################################
        plannet = ['mercury','venus']
        for plannet in plannet: 
            if plannet  == 'mercury':
                matha = ((manut*7)//46 + (manut*4)//1 + 10642)%21600
                pholPK = matharavi-13200
            elif plannet == 'venus':
                matha = ((manut*5)//3 - (manut*10)//243 + 10944)%21600
                pholPK = matharavi-4800
                
            if pholPK<0:
                pholPK = pholPK+21600

            ptma = (pholPK//5400)+1
            if ptma == 1:
                puchaPT = pholPK
                khotiPT = 5400-pholPK
            elif ptma == 2:
                puchaPT = 10800-pholPK
                khotiPT = pholPK-5400
            elif ptma == 3:
                puchaPT = pholPK-10800
                khotiPT = 16200-pholPK
            elif ptma == 4:
                puchaPT = 21600-pholPK
                khotiPT = pholPK-16200

            # puchaPT = 1064
            # khotiPT = 4336

            if puchaPT < 0:
                raise Exception('puchaPT is below 0')
            elif puchaPT > 5400:
                raise Exception('puchaPT is greater than 5400')
            elif puchaPT < 1800:
                MTpucha = (puchaPT*14640)//1800
            elif (puchaPT >= 1800) and (puchaPT < 3600) :
                MTpucha = (((puchaPT-1800)*10980)//1800)+14640
            elif puchaPT >= 3600 :
                MTpucha = (((puchaPT-3600)*3660)//1800)+25620

            if khotiPT < 0:
                raise Exception('khotiPT is below 0')
            elif khotiPT > 5400:
                raise Exception('khotiPT is greater than 5400')
            elif khotiPT < 1800:
                MTKhoti = (khotiPT*14640)//1800
            elif (khotiPT >= 1800) and (khotiPT < 3600) :
                MTKhoti = (((khotiPT-1800)*10980)//1800)+14640
            elif khotiPT >= 3600 :
                MTKhoti = (((khotiPT-3600)*3660)//1800)+25620

            MTKhoti = (MTKhoti+30)//60
            khotiphol = MTKhoti//2


            if plannet == 'mercury':
                if (ptma ==1) or (ptma ==4):
                    MTcheta = 100*60 + khotiphol
                elif (ptma ==2) or (ptma ==3):
                    MTcheta=  100*60 - khotiphol
            elif plannet == 'venus':
                if (ptma ==1) or (ptma ==4):
                    MTcheta = 320*60 + khotiphol
                elif (ptma ==2) or (ptma ==3):
                    MTcheta=  320*60 - khotiphol          
            
            

            MTphol = (MTpucha*60)//MTcheta


            if (ptma ==1) or (ptma ==2):
                if (matharavi  - MTphol)>=0:
                    MTS = matharavi  - MTphol
                elif (matharavi  - MTphol)<0:
                    MTS =  matharavi  - MTphol + 21600
                    print('MTS =',matharavi  - MTphol,'adjust to',MTS)          

            elif (ptma ==3) or (ptma ==4):
                if (matharavi  + MTphol)>=21600:
                    MTS = matharavi  + MTphol - 21600
                    print('MTS =',matharavi  + MTphol,'adjust to',MTS)
                elif(matharavi  + MTphol)<21600:
                    MTS = matharavi  + MTphol


            pholMT = MTS-matha
            if pholMT<0:
                pholMT=pholMT+21600

            ptnd = (pholMT//5400)+1
            if ptnd == 1:
                puchaTY = pholMT
                khotiTY = 5400-pholMT
            elif ptnd == 2:
                puchaTY = 10800-pholMT
                khotiTY = pholMT-5400
            elif ptnd == 3:
                puchaTY = pholMT-10800
                khotiTY = 16200-pholMT
            elif ptnd == 4:
                puchaTY = 21600-pholMT
                khotiTY = pholMT-16200

            if puchaTY < 0:
                raise Exception('puchaTY is below 0')
            elif puchaTY > 5400:
                raise Exception('puchaTY is greater than 5400')
            elif puchaTY < 1800:
                SGPucha = (puchaTY*14640)//1800
            elif (puchaTY >= 1800) and (puchaTY < 3600) :
                SGPucha = (((puchaTY-1800)*10980)//1800)+14640
            elif puchaTY >= 3600 :
                SGPucha = (((puchaTY-3600)*3660)//1800)+25620

            if khotiTY < 0:
                raise Exception('khotiTY is below 0')
            elif khotiTY > 5400:
                raise Exception('khotiTY is greater than 5400')
            elif khotiTY < 1800:
                SGKhoti = (khotiTY*14640)//1800
            elif (khotiTY >= 1800) and (khotiTY < 3600) :
                SGKhoti = (((khotiTY-1800)*10980)//1800)+14640
            elif khotiTY >= 3600 :
                SGKhoti = (((khotiTY-3600)*3660)//1800)+25620

            SGKhoti = (SGKhoti+30)//60
            SGphol = ((SGPucha+30)//60)//3


            if plannet == 'mercury': p= 21*60
            elif plannet == 'venus': p= 11*60            
            
            
            sp = p+SGphol

            if (ptnd ==1) or (ptnd ==4):
                SGcheta = sp + SGKhoti
            elif (ptnd ==2) or (ptnd ==3):
                SGcheta = sp - SGKhoti

            if SGcheta < 0:
                raise Exception('SGcheta < 0')
            elif khotiTY > 21600:
                raise Exception('SGcheta > SGcheta')

            mahaphol = (SGPucha*60)//SGcheta
            
            
            
            if plannet == 'mercury': 
                if (ptnd ==1) or (ptnd ==2):
                    if (MTS - mahaphol)>=0:
                        SMercury = MTS - mahaphol
                    elif (MTS - mahaphol)<0:
                        SMercury =  MTS - mahaphol + 21600
                        print('Smercury =',MTS - mahaphol,'adjust to',SMercury)          

                elif (ptnd ==3) or (ptnd ==4):
                    if (MTS + mahaphol)>=21600:
                        SMercury = MTS + mahaphol - 21600
                        print('SMercury =',MTS + mahaphol,'adjust to',SMercury)
                    elif(MTS + mahaphol)<21600:
                        SMercury = MTS + mahaphol
            elif plannet == 'venus': 
                if (ptnd ==1) or (ptnd ==2):
                    if (MTS - mahaphol)>=0:
                        SVenus = MTS - mahaphol
                    elif (MTS - mahaphol)<0:
                        SVenus =  MTS - mahaphol + 21600
                        print('SVenus =',MTS - mahaphol,'adjust to',SVenus)          

                elif (ptnd ==3) or (ptnd ==4):
                    if (MTS + mahaphol)>=21600:
                        SVenus = MTS + mahaphol - 21600
                        print('SVenus =',MTS + mahaphol,'adjust to',SVenus)
                    elif(MTS + mahaphol)<21600:
                        SVenus = MTS + mahaphol               





                
##########################Other Plannets####################################

        plannet = ['mars','jupiter','saturn','uranus']
        for plannet in plannet: 
 
            if plannet  == 'mars':
                matha  =  ((manut*1)//2 + (manut*16)//505 + 5420)%21600         
                pholPK = matha-7620
            elif plannet == 'jupiter':
                matha  = ((manut*1)//12 + (manut*1)//1032 + 14297)%21600
                pholPK = matha-10320
            elif plannet == 'saturn':
                matha  = ((manut*1)//30 + (manut*6)//10000 + 11944)%21600
                pholPK = matha-14820
            elif plannet == 'uranus':
                matha  = ((manut*1)//84 + (manut*1)//7224 + 16277)%21600
                pholPK = matha-7440        

            if pholPK<0:
                pholPK = pholPK+21600


            ptma = (pholPK//5400)+1
            if ptma == 1:
                puchaPT = pholPK
                khotiPT = 5400-pholPK
            elif ptma == 2:
                puchaPT = 10800-pholPK
                khotiPT = pholPK-5400
            elif ptma == 3:
                puchaPT = pholPK-10800
                khotiPT = 16200-pholPK
            elif ptma == 4:
                puchaPT = 21600-pholPK
                khotiPT = pholPK-16200

            # puchaPT = 1064
            # khotiPT = 4336

            if puchaPT < 0:
                raise Exception('puchaPT is below 0')
            elif puchaPT > 5400:
                raise Exception('puchaPT is greater than 5400')
            elif puchaPT < 1800:
                MTpucha = (puchaPT*14640)//1800
            elif (puchaPT >= 1800) and (puchaPT < 3600) :
                MTpucha = (((puchaPT-1800)*10980)//1800)+14640
            elif puchaPT >= 3600 :
                MTpucha = (((puchaPT-3600)*3660)//1800)+25620

            if khotiPT < 0:
                raise Exception('khotiPT is below 0')
            elif khotiPT > 5400:
                raise Exception('khotiPT is greater than 5400')
            elif khotiPT < 1800:
                MTKhoti = (khotiPT*14640)//1800
            elif (khotiPT >= 1800) and (khotiPT < 3600) :
                MTKhoti = (((khotiPT-1800)*10980)//1800)+14640
            elif khotiPT >= 3600 :
                MTKhoti = (((khotiPT-3600)*3660)//1800)+25620

            MTKhoti = (MTKhoti+30)//60
            khotiphol = MTKhoti//2


            if plannet == 'mars':
                if (ptma ==1) or (ptma ==4):
                    MTcheta = 45*60 + khotiphol
                elif (ptma ==2) or (ptma ==3):
                    MTcheta=  45*60 - khotiphol
            elif plannet == 'jupiter':
                if (ptma ==1) or (ptma ==4):
                    MTcheta = 92*60 + khotiphol
                elif (ptma ==2) or (ptma ==3):
                    MTcheta=  92*60 - khotiphol
            elif plannet == 'saturn':
                if (ptma ==1) or (ptma ==4):
                    MTcheta = 63*60 + khotiphol
                elif (ptma ==2) or (ptma ==3):
                    MTcheta=  63*60 - khotiphol
            elif plannet == 'uranus':
                if (ptma ==1) or (ptma ==4):
                    MTcheta = 644*60 + khotiphol
                elif (ptma ==2) or (ptma ==3):
                    MTcheta=  644*60 - khotiphol  



            MTphol = (MTpucha*60)//MTcheta


            if (ptma ==1) or (ptma ==2):
                if (matha - MTphol)>=0:
                    MTS = matha - MTphol
                elif (matha - MTphol)<0:
                    MTS =  matha - MTphol + 21600
                    print('MTS =',matha - MTphol,'adjust to',MTS)          

            elif (ptma ==3) or (ptma ==4):
                if (matha + MTphol)>=21600:
                    MTS = matha + MTphol - 21600
                    print('MTS =',matha + MTphol,'adjust to',MTS)
                elif(matha + MTphol)<21600:
                    MTS = matha + MTphol


            pholMT = MTS-matharavi
            if pholMT<0:
                pholMT=pholMT+21600

            ptnd = (pholMT//5400)+1
            if ptnd == 1:
                puchaTY = pholMT
                khotiTY = 5400-pholMT
            elif ptnd == 2:
                puchaTY = 10800-pholMT
                khotiTY = pholMT-5400
            elif ptnd == 3:
                puchaTY = pholMT-10800
                khotiTY = 16200-pholMT
            elif ptnd == 4:
                puchaTY = 21600-pholMT
                khotiTY = pholMT-16200

            if puchaTY < 0:
                raise Exception('puchaTY is below 0')
            elif puchaTY > 5400:
                raise Exception('puchaTY is greater than 5400')
            elif puchaTY < 1800:
                SGPucha = (puchaTY*14640)//1800
            elif (puchaTY >= 1800) and (puchaTY < 3600) :
                SGPucha = (((puchaTY-1800)*10980)//1800)+14640
            elif puchaTY >= 3600 :
                SGPucha = (((puchaTY-3600)*3660)//1800)+25620

            if khotiTY < 0:
                raise Exception('khotiTY is below 0')
            elif khotiTY > 5400:
                raise Exception('khotiTY is greater than 5400')
            elif khotiTY < 1800:
                SGKhoti = (khotiTY*14640)//1800
            elif (khotiTY >= 1800) and (khotiTY < 3600) :
                SGKhoti = (((khotiTY-1800)*10980)//1800)+14640
            elif khotiTY >= 3600 :
                SGKhoti = (((khotiTY-3600)*3660)//1800)+25620

            SGKhoti = (SGKhoti+30)//60
            SGphol = ((SGPucha+30)//60)//3

            
            if plannet == 'mars': p= (4*MTcheta)//15 
            elif plannet == 'jupiter': p= (3*MTcheta)//7
            elif plannet == 'saturn': p= (7*MTcheta)//6 
            elif plannet == 'uranus':p= (3*MTcheta)//7 
    

            sp = p+SGphol
            if (ptnd ==1) or (ptnd ==4):
                SGcheta = sp + SGKhoti
            elif (ptnd ==2) or (ptnd ==3):
                SGcheta = sp - SGKhoti

            if SGcheta < 0:
                raise Exception('SGcheta < 0')
            elif khotiTY > 21600:
                raise Exception('SGcheta > SGcheta')

            mahaphol = (SGPucha*60)//SGcheta

            

            if plannet == 'mars':
                if (ptnd ==1) or (ptnd ==2):
                    if (MTS - mahaphol)>=0:
                        Smars = MTS - mahaphol
                    elif (MTS - mahaphol)<0:
                        Smars =  MTS - mahaphol + 21600
                        print('Smars =',MTS - mahaphol,'adjust to',Smars)          

                elif (ptnd ==3) or (ptnd ==4):
                    if (MTS + mahaphol)>=21600:
                        Smars = MTS + mahaphol - 21600
                        print('Smars =',MTS + mahaphol,'adjust to',Smars)
                    elif(MTS + mahaphol)<21600:
                        Smars = MTS + mahaphol 
            elif plannet == 'jupiter':
                if (ptnd ==1) or (ptnd ==2):
                    if (MTS - mahaphol)>=0:
                        Jupiter = MTS - mahaphol
                    elif (MTS - mahaphol)<0:
                        Jupiter =  MTS - mahaphol + 21600
                        print('Jupiter =',MTS - mahaphol,'adjust to',Jupiter)          

                elif (ptnd ==3) or (ptnd ==4):
                    if (MTS + mahaphol)>=21600:
                        Jupiter = MTS + mahaphol - 21600
                        print('Jupiter =',MTS + mahaphol,'adjust to',Jupiter)
                    elif(MTS + mahaphol)<21600:
                        Jupiter = MTS + mahaphol 
            elif plannet == 'saturn':
                if (ptnd ==1) or (ptnd ==2):
                    if (MTS - mahaphol)>=0:
                        SSaturn = MTS - mahaphol
                    elif (MTS - mahaphol)<0:
                        SSaturn =  MTS - mahaphol + 21600
                        print('SSaturn =',MTS - mahaphol,'adjust to',SSaturn)          

                elif (ptnd ==3) or (ptnd ==4):
                    if (MTS + mahaphol)>=21600:
                        SSaturn = MTS + mahaphol - 21600
                        print('SSaturn =',MTS + mahaphol,'adjust to',SSaturn)
                    elif(MTS + mahaphol)<21600:
                        SSaturn = MTS + mahaphol
            elif plannet == 'uranus':
                if (ptnd ==1) or (ptnd ==2):
                    if (MTS - mahaphol)>=0:
                        SUranus = MTS - mahaphol
                    elif (MTS - mahaphol)<0:
                        SUranus =  MTS - mahaphol + 21600
                        print('SUranus =',MTS - mahaphol,'adjust to',SUranus)          

                elif (ptnd ==3) or (ptnd ==4):
                    if (MTS + mahaphol)>=21600:
                        SUranus = MTS + mahaphol - 21600
                        print('SUranus =',MTS + mahaphol,'adjust to',SUranus)
                    elif(MTS + mahaphol)<21600:
                        SUranus = MTS + mahaphol 
    



        

#         print('uv =',uv)
#         print('pholGA =',pholGA)
#         print('khan =',khan)
#         print('Smoon =',Smoon)

#         print('au_ =',au_)
#         print('mtu =',mtu)
#         print('uv =',uv)
#         print('Smoon =',Smoon)

        #TS Parameter (yearly parameter) 
        self.dt = dt  
        self.dtny = dtny 
        self.dny = dny 
        self.ahra = ahra 
        self.jultin = jultin 
        self.kj = kj 
        self.aw = aw 
        self.masG = masG 
        self.dT = dT
        self.au = au 
        self.van = van 
        
        #Given Datetime parameter
        self.stin = stin 
        self.sec = sec 
        self.ahra_ = ahra_ 
        self.kj_ = kj_ 
        self.aw_ = aw_ 
        self.masG_ = masG_ 
        self.dT_ = dT_
        self.au_ = au_ 
        self.van_ = van_
     
        #locations in zodiac (minutes maximum = 21600) 
        self.sun = Ssun
        self.moon = Smoon
        self.rahu = Srahu
        self.geth = Sgeth
        self.mars = Smars
        self.mercury = SMercury
        self.venus = SVenus
        self.jupiter = Jupiter
        self.saturn = SSaturn
        self.uranus = SUranus

# %%
startdate = datetime(2019,1,1,0,0)
df = pd.DataFrame()
#count = 108000
count = 1000
#count = 2000

#select timeframe
interval = 'day'
#interval = 'minutes'

for i in range(0,count):
    if interval=='minutes':
        diff = timedelta(minutes=i)
    elif interval=='day':
        diff = timedelta(days=i)
        
    dt = startdate+diff
    h = hora(dt)    
    data = {
        #'dt': dt,
        #'dtny': h.dtny,        
        'dt': str(dt.day)+'/'+str(dt.month)+'/'+str(dt.year+543)+' '+str(dt.hour)+':'+str(dt.minute)+':'+str(dt.second),
        'dtny': str(h.dtny.day)+'/'+str(h.dtny.month)+'/'+str(h.dtny.year+543)+' '+str(h.dtny.hour)+':'+str(h.dtny.minute)+':'+str(h.dtny.second),
        'ahra' : h.ahra,
        'jultin': h.jultin,
        'kj' : h.kj,
        'aw' : h.aw,
        'masG' : h.masG,
        'dT' : h.dT,
        'au' : h.au,
        'van' : h.van,
        
        'stin' : h.stin,
        'sec': h.sec,
        'ahra_' : h.ahra_,
        'kj_' : h.kj_,
        'aw_' : h.aw_,
        'masG_' : h.masG_,
        'dT_' : h.dT_,
        'au_' : h.au_,
        'van_' : h.van_,

        'sun' : h.sun,
        'moon': h.moon,
        'rahu' : h.rahu,
        'geth' : h.geth,
        'mars' : h.mars,
        'mercury' : h.mercury,
        'venus' : h.venus,
        'jupiter' : h.jupiter,
        'saturn' : h.saturn,
        'uranus' : h.uranus
    }


    print(dt.day,dt.month,dt.year,dt.hour,':',dt.minute)
    #df = pd.DataFrame(data)
    df = df.append(data , ignore_index=True)


ListofPlannets = ['sun','moon','rahu','geth','mars','mercury','venus','jupiter','saturn','uranus'] 
for planet in ListofPlannets:
    zodiac = planet+"_Z"
    degree = planet+"_D"
    minute = planet+"_M"
    df[zodiac] =  df[planet]//1800 
    df[degree] =  (df[planet]%1800)//60 
    df[minute] =  (df[planet]%1800)%60
    
#df['sun_delta'] = df['sun'] 


#df.to_csv(r"C:\Users\JACK\Desktop\S_out.csv")

#df.dtypes

# data = {
#     'dt': [startdate],
#     'sun' : [h.sun],
#     'moon': [h.moon],
#     'rahu' : [h.rahu],
#     'geth' : [h.geth],
#     'mars' : [h.mars],
#     'mercury' : [h.mercury],
#     'venus' : [h.venus],
#     'jupiter' : [h.jupiter],
#     'saturn' : [h.saturn],
#     'uranus' : [h.uranus]
# }
#startdate = datetime(2019,4,16,0,0) mathasun-
# Out:
# Smars = -1498 adjust to 20102
# 1 1 2019 0 : 0
# Smars = -1469 adjust to 20131
# 2 1 2019 0 : 0
# Smars = -1430 adjust to 20170
# 3 1 2019 0 : 0
# Smars = -1397 adjust to 20203
# 4 1 2019 0 : 0
# Smars = -1359 adjust to 20241
# 5 1 2019 0 : 0
# Smars = -1324 adjust to 20276
# 6 1 2019 0 : 0
# Smars = -1293 adjust to 20307
# 7 1 2019 0 : 0
# Smars = -1254 adjust to 20346
# 8 1 2019 0 : 0
# Smars = -1219 adjust to 20381
# 9 1 2019 0 : 0
# Smars = -1170 adjust to 20430
# 10 1 2019 0 : 0
# Smars = -1126 adjust to 20474
# 11 1 2019 0 : 0
# Smars = -1078 adjust to 20522
# 12 1 2019 0 : 0
# Smars = -1033 adjust to 20567
# 13 1 2019 0 : 0
# Smars = -986 adjust to 20614
# 14 1 2019 0 : 0
# Smars = -940 adjust to 20660
# 15 1 2019 0 : 0
# Smars = -901 adjust to 20699
# 16 1 2019 0 : 0
# Smars = -850 adjust to 20750
# 17 1 2019 0 : 0
# Smars = -807 adjust to 20793
# 18 1 2019 0 : 0
# Smars = -764 adjust to 20836
# 19 1 2019 0 : 0
# Smars = -718 adjust to 20882
# 20 1 2019 0 : 0
# Smars = -675 adjust to 20925
# 21 1 2019 0 : 0
# Smars = -628 adjust to 20972
# 22 1 2019 0 : 0
# Smars = -587 adjust to 21013
# 23 1 2019 0 : 0
# Smars = -541 adjust to 21059
# 24 1 2019 0 : 0
# Smars = -498 adjust to 21102
# 25 1 2019 0 : 0
# Smars = -453 adjust to 21147
# 26 1 2019 0 : 0
# Smars = -407 adjust to 21193
# 27 1 2019 0 : 0
# Smars = -366 adjust to 21234
# 28 1 2019 0 : 0
# Smars = -324 adjust to 21276
# 29 1 2019 0 : 0
# Smars = -282 adjust to 21318
# 30 1 2019 0 : 0
# Smars = -236 adjust to 21364
# 31 1 2019 0 : 0
# Smars = -197 adjust to 21403
# 1 2 2019 0 : 0
# Smars = -153 adjust to 21447
# 2 2 2019 0 : 0
# Smars = -109 adjust to 21491
# 3 2 2019 0 : 0
# Smars = -67 adjust to 21533
# 4 2 2019 0 : 0
# Smars = -24 adjust to 21576
# 5 2 2019 0 : 0
# 6 2 2019 0 : 0
# 7 2 2019 0 : 0
# 8 2 2019 0 : 0
# 9 2 2019 0 : 0
# 10 2 2019 0 : 0
# 11 2 2019 0 : 0
# 12 2 2019 0 : 0
# 13 2 2019 0 : 0
# 14 2 2019 0 : 0
# 15 2 2019 0 : 0
# 16 2 2019 0 : 0
# 17 2 2019 0 : 0
# 18 2 2019 0 : 0
# 19 2 2019 0 : 0
# 20 2 2019 0 : 0
# 21 2 2019 0 : 0
# 22 2 2019 0 : 0
# 23 2 2019 0 : 0
# 24 2 2019 0 : 0
# 25 2 2019 0 : 0
# 26 2 2019 0 : 0
# 27 2 2019 0 : 0
# 28 2 2019 0 : 0
# 1 3 2019 0 : 0
# 2 3 2019 0 : 0
# 3 3 2019 0 : 0
# 4 3 2019 0 : 0
# 5 3 2019 0 : 0
# 6 3 2019 0 : 0
# 7 3 2019 0 : 0
# 8 3 2019 0 : 0
# 9 3 2019 0 : 0
# 10 3 2019 0 : 0
# 11 3 2019 0 : 0
# 12 3 2019 0 : 0
# 13 3 2019 0 : 0
# 14 3 2019 0 : 0
# 15 3 2019 0 : 0
# 16 3 2019 0 : 0
# 17 3 2019 0 : 0
# 18 3 2019 0 : 0
# 19 3 2019 0 : 0
# 20 3 2019 0 : 0
# 21 3 2019 0 : 0
# 22 3 2019 0 : 0
# 23 3 2019 0 : 0
# 24 3 2019 0 : 0
# 25 3 2019 0 : 0
# 26 3 2019 0 : 0
# 27 3 2019 0 : 0
# 28 3 2019 0 : 0
# 29 3 2019 0 : 0
# 30 3 2019 0 : 0
# 31 3 2019 0 : 0
# 1 4 2019 0 : 0
# 2 4 2019 0 : 0
# 3 4 2019 0 : 0
# 4 4 2019 0 : 0
# 5 4 2019 0 : 0
# 6 4 2019 0 : 0
# 7 4 2019 0 : 0
# 8 4 2019 0 : 0
# 9 4 2019 0 : 0
# 10 4 2019 0 : 0
# 11 4 2019 0 : 0
# 12 4 2019 0 : 0
# 13 4 2019 0 : 0
# 14 4 2019 0 : 0
# 15 4 2019 0 : 0
# MTS = 21614 adjust to 14
# SVenus = -1911 adjust to 19689
# 16 4 2019 0 : 0
# MTS = -205 adjust to 21395
# SVenus = -1838 adjust to 19762
# 17 4 2019 0 : 0
# MTS = -143 adjust to 21457
# SVenus = -1766 adjust to 19834
# 18 4 2019 0 : 0
# MTS = -79 adjust to 21521
# SVenus = -1691 adjust to 19909
# 19 4 2019 0 : 0
# MTS = -16 adjust to 21584
# SVenus = -1619 adjust to 19981
# 20 4 2019 0 : 0
# Smercury = -745 adjust to 20855
# SVenus = -1544 adjust to 20056
# 21 4 2019 0 : 0
# Smercury = -637 adjust to 20963
# SVenus = -1473 adjust to 20127
# 22 4 2019 0 : 0
# Smercury = -528 adjust to 21072
# SVenus = -1398 adjust to 20202
# 23 4 2019 0 : 0
# Smercury = -422 adjust to 21178
# SVenus = -1325 adjust to 20275
# 24 4 2019 0 : 0
# Smercury = -316 adjust to 21284
# SVenus = -1253 adjust to 20347
# 25 4 2019 0 : 0
# Smercury = -211 adjust to 21389
# SVenus = -1180 adjust to 20420
# 26 4 2019 0 : 0
# Smercury = -107 adjust to 21493
# SVenus = -1109 adjust to 20491
# 27 4 2019 0 : 0
# SVenus = -1033 adjust to 20567
# 28 4 2019 0 : 0
# SVenus = -963 adjust to 20637
# 29 4 2019 0 : 0
# SVenus = -890 adjust to 20710
# 30 4 2019 0 : 0
# SVenus = -821 adjust to 20779
# 1 5 2019 0 : 0
# SVenus = -749 adjust to 20851
# 2 5 2019 0 : 0
# SVenus = -675 adjust to 20925
# 3 5 2019 0 : 0
# SVenus = -606 adjust to 20994
# 4 5 2019 0 : 0
# SVenus = -533 adjust to 21067
# 5 5 2019 0 : 0
# SVenus = -461 adjust to 21139
# 6 5 2019 0 : 0
# SVenus = -392 adjust to 21208
# 7 5 2019 0 : 0
# SVenus = -319 adjust to 21281
# 8 5 2019 0 : 0
# SVenus = -251 adjust to 21349
# 9 5 2019 0 : 0
# SVenus = -178 adjust to 21422
# 10 5 2019 0 : 0
# SVenus = -109 adjust to 21491
# 11 5 2019 0 : 0
# SVenus = -37 adjust to 21563
# 12 5 2019 0 : 0
# 13 5 2019 0 : 0
# 14 5 2019 0 : 0
# 15 5 2019 0 : 0
# 16 5 2019 0 : 0
# 17 5 2019 0 : 0
# 18 5 2019 0 : 0
# 19 5 2019 0 : 0
# 20 5 2019 0 : 0
# 21 5 2019 0 : 0
# 22 5 2019 0 : 0
# 23 5 2019 0 : 0
# 24 5 2019 0 : 0
# 25 5 2019 0 : 0
# 26 5 2019 0 : 0
# 27 5 2019 0 : 0
# 28 5 2019 0 : 0
# 29 5 2019 0 : 0
# 30 5 2019 0 : 0
# 31 5 2019 0 : 0
# 1 6 2019 0 : 0
# 2 6 2019 0 : 0
# 3 6 2019 0 : 0
# 4 6 2019 0 : 0
# 5 6 2019 0 : 0
# 6 6 2019 0 : 0
# 7 6 2019 0 : 0
# 8 6 2019 0 : 0
# 9 6 2019 0 : 0
# 10 6 2019 0 : 0
# 11 6 2019 0 : 0
# 12 6 2019 0 : 0
# 13 6 2019 0 : 0
# 14 6 2019 0 : 0
# 15 6 2019 0 : 0
# 16 6 2019 0 : 0
# 17 6 2019 0 : 0
# 18 6 2019 0 : 0
# 19 6 2019 0 : 0
# 20 6 2019 0 : 0
# 21 6 2019 0 : 0
# 22 6 2019 0 : 0
# 23 6 2019 0 : 0
# 24 6 2019 0 : 0
# 25 6 2019 0 : 0
# 26 6 2019 0 : 0
# 27 6 2019 0 : 0
# 28 6 2019 0 : 0
# 29 6 2019 0 : 0
# 30 6 2019 0 : 0
# 1 7 2019 0 : 0
# 2 7 2019 0 : 0
# 3 7 2019 0 : 0
# 4 7 2019 0 : 0
# 5 7 2019 0 : 0
# 6 7 2019 0 : 0
# 7 7 2019 0 : 0
# 8 7 2019 0 : 0
# 9 7 2019 0 : 0
# 10 7 2019 0 : 0
# 11 7 2019 0 : 0
# 12 7 2019 0 : 0
# 13 7 2019 0 : 0
# 14 7 2019 0 : 0
# 15 7 2019 0 : 0
# 16 7 2019 0 : 0
# 17 7 2019 0 : 0
# 18 7 2019 0 : 0
# 19 7 2019 0 : 0
# 20 7 2019 0 : 0
# 21 7 2019 0 : 0
# 22 7 2019 0 : 0
# 23 7 2019 0 : 0
# 24 7 2019 0 : 0
# 25 7 2019 0 : 0
# 26 7 2019 0 : 0
# 27 7 2019 0 : 0
# 28 7 2019 0 : 0
# 29 7 2019 0 : 0
# 30 7 2019 0 : 0
# 31 7 2019 0 : 0
# 1 8 2019 0 : 0
# 2 8 2019 0 : 0
# 3 8 2019 0 : 0
# 4 8 2019 0 : 0
# 5 8 2019 0 : 0
# 6 8 2019 0 : 0
# 7 8 2019 0 : 0
# 8 8 2019 0 : 0
# 9 8 2019 0 : 0
# 10 8 2019 0 : 0
# 11 8 2019 0 : 0
# 12 8 2019 0 : 0
# 13 8 2019 0 : 0
# 14 8 2019 0 : 0
# 15 8 2019 0 : 0
# 16 8 2019 0 : 0
# 17 8 2019 0 : 0
# 18 8 2019 0 : 0
# 19 8 2019 0 : 0
# 20 8 2019 0 : 0
# 21 8 2019 0 : 0
# 22 8 2019 0 : 0
# 23 8 2019 0 : 0
# 24 8 2019 0 : 0
# 25 8 2019 0 : 0
# 26 8 2019 0 : 0
# 27 8 2019 0 : 0
# 28 8 2019 0 : 0
# 29 8 2019 0 : 0
# 30 8 2019 0 : 0
# 31 8 2019 0 : 0
# 1 9 2019 0 : 0
# 2 9 2019 0 : 0
# 3 9 2019 0 : 0
# 4 9 2019 0 : 0
# 5 9 2019 0 : 0
# 6 9 2019 0 : 0
# 7 9 2019 0 : 0
# 8 9 2019 0 : 0
# 9 9 2019 0 : 0
# 10 9 2019 0 : 0
# 11 9 2019 0 : 0
# 12 9 2019 0 : 0
# 13 9 2019 0 : 0
# 14 9 2019 0 : 0
# 15 9 2019 0 : 0
# 16 9 2019 0 : 0
# 17 9 2019 0 : 0
# 18 9 2019 0 : 0
# 19 9 2019 0 : 0
# 20 9 2019 0 : 0
# 21 9 2019 0 : 0
# 22 9 2019 0 : 0
# 23 9 2019 0 : 0
# 24 9 2019 0 : 0
# 25 9 2019 0 : 0
# 26 9 2019 0 : 0
# 27 9 2019 0 : 0
# 28 9 2019 0 : 0
# 29 9 2019 0 : 0
# 30 9 2019 0 : 0
# 1 10 2019 0 : 0
# 2 10 2019 0 : 0
# 3 10 2019 0 : 0
# 4 10 2019 0 : 0
# 5 10 2019 0 : 0
# 6 10 2019 0 : 0
# 7 10 2019 0 : 0
# 8 10 2019 0 : 0
# 9 10 2019 0 : 0
# 10 10 2019 0 : 0
# 11 10 2019 0 : 0
# 12 10 2019 0 : 0
# 13 10 2019 0 : 0
# 14 10 2019 0 : 0
# 15 10 2019 0 : 0
# 16 10 2019 0 : 0
# 17 10 2019 0 : 0
# 18 10 2019 0 : 0
# 19 10 2019 0 : 0
# 20 10 2019 0 : 0
# 21 10 2019 0 : 0
# 22 10 2019 0 : 0
# 23 10 2019 0 : 0
# 24 10 2019 0 : 0
# 25 10 2019 0 : 0
# 26 10 2019 0 : 0
# 27 10 2019 0 : 0
# 28 10 2019 0 : 0
# 29 10 2019 0 : 0
# 30 10 2019 0 : 0
# 31 10 2019 0 : 0
# 1 11 2019 0 : 0
# 2 11 2019 0 : 0
# 3 11 2019 0 : 0
# 4 11 2019 0 : 0
# 5 11 2019 0 : 0
# 6 11 2019 0 : 0
# 7 11 2019 0 : 0
# 8 11 2019 0 : 0
# 9 11 2019 0 : 0
# 10 11 2019 0 : 0
# 11 11 2019 0 : 0
# 12 11 2019 0 : 0
# 13 11 2019 0 : 0
# 14 11 2019 0 : 0
# 15 11 2019 0 : 0
# 16 11 2019 0 : 0
# 17 11 2019 0 : 0
# 18 11 2019 0 : 0
# 19 11 2019 0 : 0
# 20 11 2019 0 : 0
# 21 11 2019 0 : 0
# 22 11 2019 0 : 0
# 23 11 2019 0 : 0
# 24 11 2019 0 : 0
# 25 11 2019 0 : 0
# 26 11 2019 0 : 0
# 27 11 2019 0 : 0
# 28 11 2019 0 : 0
# 29 11 2019 0 : 0
# 30 11 2019 0 : 0
# 1 12 2019 0 : 0
# 2 12 2019 0 : 0
# 3 12 2019 0 : 0
# 4 12 2019 0 : 0
# 5 12 2019 0 : 0
# 6 12 2019 0 : 0
# 7 12 2019 0 : 0
# 8 12 2019 0 : 0
# 9 12 2019 0 : 0
# 10 12 2019 0 : 0
# 11 12 2019 0 : 0
# 12 12 2019 0 : 0
# 13 12 2019 0 : 0
# 14 12 2019 0 : 0
# 15 12 2019 0 : 0
# 16 12 2019 0 : 0
# 17 12 2019 0 : 0
# 18 12 2019 0 : 0
# 19 12 2019 0 : 0
# 20 12 2019 0 : 0
# 21 12 2019 0 : 0
# 22 12 2019 0 : 0
# 23 12 2019 0 : 0
# 24 12 2019 0 : 0
# 25 12 2019 0 : 0
# 26 12 2019 0 : 0
# 27 12 2019 0 : 0
# 28 12 2019 0 : 0
# 29 12 2019 0 : 0
# 30 12 2019 0 : 0
# 31 12 2019 0 : 0
# 1 1 2020 0 : 0
# 2 1 2020 0 : 0
# 3 1 2020 0 : 0
# 4 1 2020 0 : 0
# 5 1 2020 0 : 0
# 6 1 2020 0 : 0
# 7 1 2020 0 : 0
# 8 1 2020 0 : 0
# 9 1 2020 0 : 0
# 10 1 2020 0 : 0
# 11 1 2020 0 : 0
# 12 1 2020 0 : 0
# 13 1 2020 0 : 0
# 14 1 2020 0 : 0
# 15 1 2020 0 : 0
# 16 1 2020 0 : 0
# 17 1 2020 0 : 0
# 18 1 2020 0 : 0
# 19 1 2020 0 : 0
# 20 1 2020 0 : 0
# 21 1 2020 0 : 0
# 22 1 2020 0 : 0
# 23 1 2020 0 : 0
# 24 1 2020 0 : 0
# 25 1 2020 0 : 0
# 26 1 2020 0 : 0
# 27 1 2020 0 : 0
# 28 1 2020 0 : 0
# 29 1 2020 0 : 0
# 30 1 2020 0 : 0
# 31 1 2020 0 : 0
# 1 2 2020 0 : 0
# 2 2 2020 0 : 0
# 3 2 2020 0 : 0
# 4 2 2020 0 : 0
# 5 2 2020 0 : 0
# 6 2 2020 0 : 0
# 7 2 2020 0 : 0
# 8 2 2020 0 : 0
# 9 2 2020 0 : 0
# 10 2 2020 0 : 0
# 11 2 2020 0 : 0
# 12 2 2020 0 : 0
# 13 2 2020 0 : 0
# 14 2 2020 0 : 0
# 15 2 2020 0 : 0
# 16 2 2020 0 : 0
# 17 2 2020 0 : 0
# 18 2 2020 0 : 0
# 19 2 2020 0 : 0
# 20 2 2020 0 : 0
# 21 2 2020 0 : 0
# 22 2 2020 0 : 0
# 23 2 2020 0 : 0
# 24 2 2020 0 : 0
# 25 2 2020 0 : 0
# 26 2 2020 0 : 0
# 27 2 2020 0 : 0
# 28 2 2020 0 : 0
# 29 2 2020 0 : 0
# 1 3 2020 0 : 0
# SVenus = 21623 adjust to 23
# 2 3 2020 0 : 0
# SVenus = 21703 adjust to 103
# 3 3 2020 0 : 0
# SVenus = 21779 adjust to 179
# 4 3 2020 0 : 0
# SVenus = 21859 adjust to 259
# 5 3 2020 0 : 0
# SVenus = 21931 adjust to 331
# 6 3 2020 0 : 0
# SVenus = 22007 adjust to 407
# 7 3 2020 0 : 0
# SVenus = 22087 adjust to 487
# 8 3 2020 0 : 0
# SVenus = 22162 adjust to 562
# 9 3 2020 0 : 0
# SVenus = 22216 adjust to 616
# 10 3 2020 0 : 0
# SVenus = 22278 adjust to 678
# 11 3 2020 0 : 0
# SVenus = 22337 adjust to 737
# 12 3 2020 0 : 0
# SVenus = 22403 adjust to 803
# 13 3 2020 0 : 0
# SVenus = 22459 adjust to 859
# 14 3 2020 0 : 0
# SVenus = 22519 adjust to 919
# 15 3 2020 0 : 0
# SVenus = 22577 adjust to 977
# 16 3 2020 0 : 0
# SVenus = 22633 adjust to 1033
# 17 3 2020 0 : 0
# SVenus = 22698 adjust to 1098
# 18 3 2020 0 : 0
# SVenus = 22757 adjust to 1157
# 19 3 2020 0 : 0
# SVenus = 22820 adjust to 1220
# 20 3 2020 0 : 0
# SVenus = 22874 adjust to 1274
# 21 3 2020 0 : 0
# SVenus = 22939 adjust to 1339
# 22 3 2020 0 : 0
# SVenus = 23000 adjust to 1400
# 23 3 2020 0 : 0
# SVenus = 23060 adjust to 1460
# 24 3 2020 0 : 0
# SVenus = 23116 adjust to 1516
# 25 3 2020 0 : 0
# SVenus = 23181 adjust to 1581
# 26 3 2020 0 : 0
# SVenus = 23241 adjust to 1641
# 27 3 2020 0 : 0
# SVenus = 23297 adjust to 1697
# 28 3 2020 0 : 0
# SVenus = 23357 adjust to 1757
# 29 3 2020 0 : 0
# SVenus = 23422 adjust to 1822
# 30 3 2020 0 : 0
# SVenus = 23484 adjust to 1884
# 31 3 2020 0 : 0
# SVenus = 23538 adjust to 1938
# 1 4 2020 0 : 0
# SVenus = 23597 adjust to 1997
# 2 4 2020 0 : 0
# SVenus = 23666 adjust to 2066
# 3 4 2020 0 : 0
# SVenus = 23726 adjust to 2126
# 4 4 2020 0 : 0
# SVenus = 23781 adjust to 2181
# 5 4 2020 0 : 0
# SVenus = 23840 adjust to 2240
# 6 4 2020 0 : 0
# SVenus = 23908 adjust to 2308
# 7 4 2020 0 : 0
# SVenus = 23966 adjust to 2366
# 8 4 2020 0 : 0
# SVenus = 24019 adjust to 2419
# 9 4 2020 0 : 0
# SVenus = 24078 adjust to 2478
# 10 4 2020 0 : 0
# SVenus = 24144 adjust to 2544
# 11 4 2020 0 : 0
# SVenus = 24204 adjust to 2604
# 12 4 2020 0 : 0
# SVenus = 24262 adjust to 2662
# 13 4 2020 0 : 0
# SVenus = 24315 adjust to 2715
# 14 4 2020 0 : 0
# SVenus = 24381 adjust to 2781
# 15 4 2020 0 : 0
# MTS = 21656 adjust to 56
# 16 4 2020 0 : 0
# MTS = -160 adjust to 21440
# 17 4 2020 0 : 0
# MTS = -97 adjust to 21503
# 18 4 2020 0 : 0
# MTS = -34 adjust to 21566
# 19 4 2020 0 : 0
# 20 4 2020 0 : 0
# 21 4 2020 0 : 0
# 22 4 2020 0 : 0
# 23 4 2020 0 : 0
# 24 4 2020 0 : 0
# 25 4 2020 0 : 0
# 26 4 2020 0 : 0
# 27 4 2020 0 : 0
# 28 4 2020 0 : 0
# 29 4 2020 0 : 0
# 30 4 2020 0 : 0
# 1 5 2020 0 : 0
# 2 5 2020 0 : 0
# 3 5 2020 0 : 0
# 4 5 2020 0 : 0
# 5 5 2020 0 : 0
# 6 5 2020 0 : 0
# 7 5 2020 0 : 0
# 8 5 2020 0 : 0
# 9 5 2020 0 : 0
# 10 5 2020 0 : 0
# 11 5 2020 0 : 0
# 12 5 2020 0 : 0
# 13 5 2020 0 : 0
# 14 5 2020 0 : 0
# 15 5 2020 0 : 0
# 16 5 2020 0 : 0
# 17 5 2020 0 : 0
# 18 5 2020 0 : 0
# 19 5 2020 0 : 0
# 20 5 2020 0 : 0
# 21 5 2020 0 : 0
# 22 5 2020 0 : 0
# 23 5 2020 0 : 0
# 24 5 2020 0 : 0
# 25 5 2020 0 : 0
# 26 5 2020 0 : 0
# 27 5 2020 0 : 0
# 28 5 2020 0 : 0
# 29 5 2020 0 : 0
# 30 5 2020 0 : 0
# 31 5 2020 0 : 0
# 1 6 2020 0 : 0
# 2 6 2020 0 : 0
# 3 6 2020 0 : 0
# 4 6 2020 0 : 0
# 5 6 2020 0 : 0
# 6 6 2020 0 : 0
# 7 6 2020 0 : 0
# 8 6 2020 0 : 0
# 9 6 2020 0 : 0
# 10 6 2020 0 : 0
# 11 6 2020 0 : 0
# 12 6 2020 0 : 0
# 13 6 2020 0 : 0
# 14 6 2020 0 : 0
# 15 6 2020 0 : 0
# 16 6 2020 0 : 0
# 17 6 2020 0 : 0
# 18 6 2020 0 : 0
# 19 6 2020 0 : 0
# 20 6 2020 0 : 0
# 21 6 2020 0 : 0
# 22 6 2020 0 : 0
# 23 6 2020 0 : 0
# 24 6 2020 0 : 0
# 25 6 2020 0 : 0
# 26 6 2020 0 : 0
# 27 6 2020 0 : 0
# 28 6 2020 0 : 0
# 29 6 2020 0 : 0
# 30 6 2020 0 : 0
# 1 7 2020 0 : 0
# 2 7 2020 0 : 0
# 3 7 2020 0 : 0
# 4 7 2020 0 : 0
# 5 7 2020 0 : 0
# 6 7 2020 0 : 0
# 7 7 2020 0 : 0
# 8 7 2020 0 : 0
# 9 7 2020 0 : 0
# 10 7 2020 0 : 0
# 11 7 2020 0 : 0
# 12 7 2020 0 : 0
# 13 7 2020 0 : 0
# 14 7 2020 0 : 0
# 15 7 2020 0 : 0
# 16 7 2020 0 : 0
# 17 7 2020 0 : 0
# 18 7 2020 0 : 0
# 19 7 2020 0 : 0
# 20 7 2020 0 : 0
# 21 7 2020 0 : 0
# 22 7 2020 0 : 0
# 23 7 2020 0 : 0
# 24 7 2020 0 : 0
# 25 7 2020 0 : 0
# 26 7 2020 0 : 0
# 27 7 2020 0 : 0
# 28 7 2020 0 : 0
# 29 7 2020 0 : 0
# 30 7 2020 0 : 0
# 31 7 2020 0 : 0
# 1 8 2020 0 : 0
# 2 8 2020 0 : 0
# 3 8 2020 0 : 0
# 4 8 2020 0 : 0
# 5 8 2020 0 : 0
# 6 8 2020 0 : 0
# 7 8 2020 0 : 0
# 8 8 2020 0 : 0
# 9 8 2020 0 : 0
# 10 8 2020 0 : 0
# Smars = 21604 adjust to 4
# 11 8 2020 0 : 0
# Smars = 21618 adjust to 18
# 12 8 2020 0 : 0
# Smars = 21635 adjust to 35
# 13 8 2020 0 : 0
# Smars = 21642 adjust to 42
# 14 8 2020 0 : 0
# Smars = 21649 adjust to 49
# 15 8 2020 0 : 0
# Smars = 21665 adjust to 65
# 16 8 2020 0 : 0
# Smars = 21680 adjust to 80
# 17 8 2020 0 : 0
# Smars = 21692 adjust to 92
# 18 8 2020 0 : 0
# Smars = 21698 adjust to 98
# 19 8 2020 0 : 0
# Smars = 21713 adjust to 113
# 20 8 2020 0 : 0
# Smars = 21729 adjust to 129
# 21 8 2020 0 : 0
# Smars = 21734 adjust to 134
# 22 8 2020 0 : 0
# Smars = 21739 adjust to 139
# 23 8 2020 0 : 0
# Smars = 21751 adjust to 151
# 24 8 2020 0 : 0
# Smars = 21767 adjust to 167
# 25 8 2020 0 : 0
# Smars = 21774 adjust to 174
# 26 8 2020 0 : 0
# Smars = 21777 adjust to 177
# 27 8 2020 0 : 0
# Smars = 21792 adjust to 192
# 28 8 2020 0 : 0
# Smars = 21806 adjust to 206
# 29 8 2020 0 : 0
# Smars = 21804 adjust to 204
# 30 8 2020 0 : 0
# Smars = 21817 adjust to 217
# 31 8 2020 0 : 0
# Smars = 21829 adjust to 229
# 1 9 2020 0 : 0
# Smars = 21841 adjust to 241
# 2 9 2020 0 : 0
# Smars = 21843 adjust to 243
# 3 9 2020 0 : 0
# Smars = 21844 adjust to 244
# 4 9 2020 0 : 0
# Smars = 21855 adjust to 255
# 5 9 2020 0 : 0
# Smars = 21855 adjust to 255
# 6 9 2020 0 : 0
# Smars = 21862 adjust to 262
# 7 9 2020 0 : 0
# Smars = 21872 adjust to 272
# 8 9 2020 0 : 0
# Smars = 21878 adjust to 278
# 9 9 2020 0 : 0
# Smars = 21880 adjust to 280
# 10 9 2020 0 : 0
# Smars = 21878 adjust to 278
# 11 9 2020 0 : 0
# Smars = 21885 adjust to 285
# 12 9 2020 0 : 0
# Smars = 21890 adjust to 290
# 13 9 2020 0 : 0
# Smars = 21887 adjust to 287
# 14 9 2020 0 : 0
# Smars = 21890 adjust to 290
# 15 9 2020 0 : 0
# Smars = 21894 adjust to 294
# 16 9 2020 0 : 0
# Smars = 21896 adjust to 296
# 17 9 2020 0 : 0
# Smars = 21897 adjust to 297
# 18 9 2020 0 : 0
# Smars = 21889 adjust to 289
# 19 9 2020 0 : 0
# Smars = 21886 adjust to 286
# 20 9 2020 0 : 0
# Smars = 21876 adjust to 276
# 21 9 2020 0 : 0
# Smars = 21863 adjust to 263
# 22 9 2020 0 : 0
# Smars = 21853 adjust to 253
# 23 9 2020 0 : 0
# Smars = 21844 adjust to 244
# 24 9 2020 0 : 0
# Smars = 21834 adjust to 234
# 25 9 2020 0 : 0
# Smars = 21821 adjust to 221
# 26 9 2020 0 : 0
# Smars = 21809 adjust to 209
# 27 9 2020 0 : 0
# Smars = 21799 adjust to 199
# 28 9 2020 0 : 0
# Smars = 21787 adjust to 187
# 29 9 2020 0 : 0
# Smars = 21770 adjust to 170
# 30 9 2020 0 : 0
# Smars = 21755 adjust to 155
# 1 10 2020 0 : 0
# Smars = 21739 adjust to 139
# 2 10 2020 0 : 0
# Smars = 21721 adjust to 121
# 3 10 2020 0 : 0
# Smars = 21711 adjust to 111
# 4 10 2020 0 : 0
# Smars = 21692 adjust to 92
# 5 10 2020 0 : 0
# Smars = 21674 adjust to 74
# 6 10 2020 0 : 0
# Smars = 21657 adjust to 57
# 7 10 2020 0 : 0
# Smars = 21635 adjust to 35
# 8 10 2020 0 : 0
# Smars = 21613 adjust to 13
# 9 10 2020 0 : 0
# 10 10 2020 0 : 0
# 11 10 2020 0 : 0
# 12 10 2020 0 : 0
# 13 10 2020 0 : 0
# 14 10 2020 0 : 0
# 15 10 2020 0 : 0
# 16 10 2020 0 : 0
# 17 10 2020 0 : 0
# MTS = 21621 adjust to 21
# Smars = -200 adjust to 21400
# 18 10 2020 0 : 0
# MTS = 21658 adjust to 58
# Smars = -216 adjust to 21384
# 19 10 2020 0 : 0
# MTS = 21694 adjust to 94
# Smars = -234 adjust to 21366
# 20 10 2020 0 : 0
# MTS = 21729 adjust to 129
# Smars = -256 adjust to 21344
# 21 10 2020 0 : 0
# MTS = 21765 adjust to 165
# Smars = -270 adjust to 21330
# 22 10 2020 0 : 0
# MTS = 21801 adjust to 201
# Smars = -284 adjust to 21316
# 23 10 2020 0 : 0
# MTS = 21837 adjust to 237
# Smars = -297 adjust to 21303
# 24 10 2020 0 : 0
# MTS = 21872 adjust to 272
# Smars = -313 adjust to 21287
# 25 10 2020 0 : 0
# MTS = 21907 adjust to 307
# Smars = -331 adjust to 21269
# 26 10 2020 0 : 0
# MTS = 21943 adjust to 343
# Smars = -338 adjust to 21262
# 27 10 2020 0 : 0
# MTS = 21979 adjust to 379
# Smars = -344 adjust to 21256
# 28 10 2020 0 : 0
# MTS = 22015 adjust to 415
# Smars = -355 adjust to 21245
# 29 10 2020 0 : 0
# MTS = 22051 adjust to 451
# Smars = -363 adjust to 21237
# 30 10 2020 0 : 0
# MTS = 22086 adjust to 486
# Smars = -373 adjust to 21227
# 31 10 2020 0 : 0
# MTS = 22122 adjust to 522
# Smars = -380 adjust to 21220
# 1 11 2020 0 : 0
# Smars = -382 adjust to 21218
# 2 11 2020 0 : 0
# Smars = -387 adjust to 21213
# 3 11 2020 0 : 0
# Smars = -390 adjust to 21210
# 4 11 2020 0 : 0
# Smars = -397 adjust to 21203
# 5 11 2020 0 : 0
# Smars = -399 adjust to 21201
# 6 11 2020 0 : 0
# Smars = -398 adjust to 21202
# 7 11 2020 0 : 0
# Smars = -401 adjust to 21199
# 8 11 2020 0 : 0
# Smars = -401 adjust to 21199
# 9 11 2020 0 : 0
# Smars = -404 adjust to 21196
# 10 11 2020 0 : 0
# Smars = -403 adjust to 21197
# 11 11 2020 0 : 0
# Smars = -399 adjust to 21201
# 12 11 2020 0 : 0
# Smars = -400 adjust to 21200
# 13 11 2020 0 : 0
# Smars = -397 adjust to 21203
# 14 11 2020 0 : 0
# Smars = -397 adjust to 21203
# 15 11 2020 0 : 0
# Smars = -392 adjust to 21208
# 16 11 2020 0 : 0
# Smars = -399 adjust to 21201
# 17 11 2020 0 : 0
# Smars = -400 adjust to 21200
# 18 11 2020 0 : 0
# Smars = -405 adjust to 21195
# 19 11 2020 0 : 0
# Smars = -401 adjust to 21199
# 20 11 2020 0 : 0
# Smars = -400 adjust to 21200
# 21 11 2020 0 : 0
# Smars = -395 adjust to 21205
# 22 11 2020 0 : 0
# Smars = -398 adjust to 21202
# 23 11 2020 0 : 0
# Smars = -401 adjust to 21199
# 24 11 2020 0 : 0
# Smars = -397 adjust to 21203
# 25 11 2020 0 : 0
# Smars = -393 adjust to 21207
# 26 11 2020 0 : 0
# Smars = -385 adjust to 21215
# 27 11 2020 0 : 0
# Smars = -385 adjust to 21215
# 28 11 2020 0 : 0
# Smars = -379 adjust to 21221
# 29 11 2020 0 : 0
# Smars = -370 adjust to 21230
# 30 11 2020 0 : 0
# Smars = -366 adjust to 21234
# 1 12 2020 0 : 0
# Smars = -356 adjust to 21244
# 2 12 2020 0 : 0
# Smars = -353 adjust to 21247
# 3 12 2020 0 : 0
# Smars = -347 adjust to 21253
# 4 12 2020 0 : 0
# Smars = -342 adjust to 21258
# 5 12 2020 0 : 0
# Smars = -333 adjust to 21267
# 6 12 2020 0 : 0
# Smars = -323 adjust to 21277
# 7 12 2020 0 : 0
# Smars = -316 adjust to 21284
# 8 12 2020 0 : 0
# Smars = -306 adjust to 21294
# 9 12 2020 0 : 0
# Smars = -293 adjust to 21307
# 10 12 2020 0 : 0
# Smars = -284 adjust to 21316
# 11 12 2020 0 : 0
# Smars = -278 adjust to 21322
# 12 12 2020 0 : 0
# Smars = -263 adjust to 21337
# 13 12 2020 0 : 0
# Smars = -251 adjust to 21349
# 14 12 2020 0 : 0
# Smars = -242 adjust to 21358
# 15 12 2020 0 : 0
# Smars = -228 adjust to 21372
# 16 12 2020 0 : 0
# Smars = -221 adjust to 21379
# 17 12 2020 0 : 0
# Smars = -205 adjust to 21395
# 18 12 2020 0 : 0
# Smars = -199 adjust to 21401
# 19 12 2020 0 : 0
# Smars = -178 adjust to 21422
# 20 12 2020 0 : 0
# Smars = -161 adjust to 21439
# 21 12 2020 0 : 0
# Smars = -153 adjust to 21447
# 22 12 2020 0 : 0
# Smars = -137 adjust to 21463
# 23 12 2020 0 : 0
# Smars = -121 adjust to 21479
# 24 12 2020 0 : 0
# Smars = -94 adjust to 21506
# 25 12 2020 0 : 0
# Smars = -74 adjust to 21526
# 26 12 2020 0 : 0
# Smars = -38 adjust to 21562
# 27 12 2020 0 : 0
# 28 12 2020 0 : 0
# 29 12 2020 0 : 0
# 30 12 2020 0 : 0
# 31 12 2020 0 : 0
# 1 1 2021 0 : 0
# 2 1 2021 0 : 0
# 3 1 2021 0 : 0
# 4 1 2021 0 : 0
# 5 1 2021 0 : 0
# 6 1 2021 0 : 0
# 7 1 2021 0 : 0
# 8 1 2021 0 : 0
# 9 1 2021 0 : 0
# 10 1 2021 0 : 0
# 11 1 2021 0 : 0
# 12 1 2021 0 : 0
# 13 1 2021 0 : 0
# 14 1 2021 0 : 0
# 15 1 2021 0 : 0
# 16 1 2021 0 : 0
# 17 1 2021 0 : 0
# 18 1 2021 0 : 0
# 19 1 2021 0 : 0
# 20 1 2021 0 : 0
# 21 1 2021 0 : 0
# 22 1 2021 0 : 0
# 23 1 2021 0 : 0
# 24 1 2021 0 : 0
# 25 1 2021 0 : 0
# 26 1 2021 0 : 0
# 27 1 2021 0 : 0
# 28 1 2021 0 : 0
# 29 1 2021 0 : 0
# 30 1 2021 0 : 0
# 31 1 2021 0 : 0
# 1 2 2021 0 : 0
# 2 2 2021 0 : 0
# 3 2 2021 0 : 0
# 4 2 2021 0 : 0
# 5 2 2021 0 : 0
# 6 2 2021 0 : 0
# 7 2 2021 0 : 0
# 8 2 2021 0 : 0
# 9 2 2021 0 : 0
# 10 2 2021 0 : 0
# 11 2 2021 0 : 0
# 12 2 2021 0 : 0
# 13 2 2021 0 : 0
# 14 2 2021 0 : 0
# 15 2 2021 0 : 0
# 16 2 2021 0 : 0
# 17 2 2021 0 : 0
# 18 2 2021 0 : 0
# 19 2 2021 0 : 0
# 20 2 2021 0 : 0
# 21 2 2021 0 : 0
# 22 2 2021 0 : 0
# 23 2 2021 0 : 0
# 24 2 2021 0 : 0
# 25 2 2021 0 : 0
# 26 2 2021 0 : 0
# 27 2 2021 0 : 0
# 28 2 2021 0 : 0
# 1 3 2021 0 : 0
# 2 3 2021 0 : 0
# 3 3 2021 0 : 0
# 4 3 2021 0 : 0
# 5 3 2021 0 : 0
# 6 3 2021 0 : 0
# 7 3 2021 0 : 0
# 8 3 2021 0 : 0
# 9 3 2021 0 : 0
# 10 3 2021 0 : 0
# 11 3 2021 0 : 0
# 12 3 2021 0 : 0
# 13 3 2021 0 : 0
# 14 3 2021 0 : 0
# 15 3 2021 0 : 0
# 16 3 2021 0 : 0
# 17 3 2021 0 : 0
# 18 3 2021 0 : 0
# 19 3 2021 0 : 0
# 20 3 2021 0 : 0
# 21 3 2021 0 : 0
# 22 3 2021 0 : 0
# 23 3 2021 0 : 0
# 24 3 2021 0 : 0
# 25 3 2021 0 : 0
# 26 3 2021 0 : 0
# 27 3 2021 0 : 0
# 28 3 2021 0 : 0
# 29 3 2021 0 : 0
# 30 3 2021 0 : 0
# 31 3 2021 0 : 0
# 1 4 2021 0 : 0
# 2 4 2021 0 : 0
# 3 4 2021 0 : 0
# 4 4 2021 0 : 0
# 5 4 2021 0 : 0
# 6 4 2021 0 : 0
# 7 4 2021 0 : 0
# 8 4 2021 0 : 0
# 9 4 2021 0 : 0
# 10 4 2021 0 : 0
# 11 4 2021 0 : 0
# SMercury = 21649 adjust to 49
# 12 4 2021 0 : 0
# SMercury = 21753 adjust to 153
# SVenus = 21636 adjust to 36
# 13 4 2021 0 : 0
# SMercury = 21859 adjust to 259
# SVenus = 21711 adjust to 111
# 14 4 2021 0 : 0
# SMercury = 21964 adjust to 364
# SVenus = 21786 adjust to 186
# 15 4 2021 0 : 0
# SMercury = 22073 adjust to 473
# MTS = 21642 adjust to 42
# 16 4 2021 0 : 0
# MTS = -175 adjust to 21425
# SMercury = 22177 adjust to 577
# 17 4 2021 0 : 0
# MTS = -113 adjust to 21487
# SMercury = 22284 adjust to 684
# 18 4 2021 0 : 0
# MTS = -50 adjust to 21550
# SMercury = 22393 adjust to 793
# 19 4 2021 0 : 0
# 20 4 2021 0 : 0
# 21 4 2021 0 : 0
# 22 4 2021 0 : 0
# 23 4 2021 0 : 0
# 24 4 2021 0 : 0
# 25 4 2021 0 : 0
# 26 4 2021 0 : 0
# 27 4 2021 0 : 0
# 28 4 2021 0 : 0
# 29 4 2021 0 : 0
# 30 4 2021 0 : 0
# 1 5 2021 0 : 0
# 2 5 2021 0 : 0
# 3 5 2021 0 : 0
# 4 5 2021 0 : 0
# 5 5 2021 0 : 0
# 6 5 2021 0 : 0
# 7 5 2021 0 : 0
# 8 5 2021 0 : 0
# 9 5 2021 0 : 0
# 10 5 2021 0 : 0
# 11 5 2021 0 : 0
# 12 5 2021 0 : 0
# 13 5 2021 0 : 0
# 14 5 2021 0 : 0
# 15 5 2021 0 : 0
# 16 5 2021 0 : 0
# 17 5 2021 0 : 0
# 18 5 2021 0 : 0
# 19 5 2021 0 : 0
# 20 5 2021 0 : 0
# 21 5 2021 0 : 0
# 22 5 2021 0 : 0
# 23 5 2021 0 : 0
# 24 5 2021 0 : 0
# 25 5 2021 0 : 0
# 26 5 2021 0 : 0
# 27 5 2021 0 : 0
# 28 5 2021 0 : 0
# 29 5 2021 0 : 0
# 30 5 2021 0 : 0
# 31 5 2021 0 : 0
# 1 6 2021 0 : 0
# 2 6 2021 0 : 0
# 3 6 2021 0 : 0
# 4 6 2021 0 : 0
# 5 6 2021 0 : 0
# 6 6 2021 0 : 0
# 7 6 2021 0 : 0
# 8 6 2021 0 : 0
# 9 6 2021 0 : 0
# 10 6 2021 0 : 0
# 11 6 2021 0 : 0
# 12 6 2021 0 : 0
# 13 6 2021 0 : 0
# 14 6 2021 0 : 0
# 15 6 2021 0 : 0
# 16 6 2021 0 : 0
# 17 6 2021 0 : 0
# 18 6 2021 0 : 0
# 19 6 2021 0 : 0
# 20 6 2021 0 : 0
# 21 6 2021 0 : 0
# 22 6 2021 0 : 0
# 23 6 2021 0 : 0
# 24 6 2021 0 : 0
# 25 6 2021 0 : 0
# 26 6 2021 0 : 0
# 27 6 2021 0 : 0
# 28 6 2021 0 : 0
# 29 6 2021 0 : 0
# 30 6 2021 0 : 0
# 1 7 2021 0 : 0
# 2 7 2021 0 : 0
# 3 7 2021 0 : 0
# 4 7 2021 0 : 0
# 5 7 2021 0 : 0
# 6 7 2021 0 : 0
# 7 7 2021 0 : 0
# 8 7 2021 0 : 0
# 9 7 2021 0 : 0
# 10 7 2021 0 : 0
# 11 7 2021 0 : 0
# 12 7 2021 0 : 0
# 13 7 2021 0 : 0
# 14 7 2021 0 : 0
# 15 7 2021 0 : 0
# 16 7 2021 0 : 0
# 17 7 2021 0 : 0
# 18 7 2021 0 : 0
# 19 7 2021 0 : 0
# 20 7 2021 0 : 0
# 21 7 2021 0 : 0
# 22 7 2021 0 : 0
# 23 7 2021 0 : 0
# 24 7 2021 0 : 0
# 25 7 2021 0 : 0
# 26 7 2021 0 : 0
# 27 7 2021 0 : 0
# 28 7 2021 0 : 0
# 29 7 2021 0 : 0
# 30 7 2021 0 : 0
# 31 7 2021 0 : 0
# 1 8 2021 0 : 0
# 2 8 2021 0 : 0
# 3 8 2021 0 : 0
# 4 8 2021 0 : 0
# 5 8 2021 0 : 0
# 6 8 2021 0 : 0
# 7 8 2021 0 : 0
# 8 8 2021 0 : 0
# 9 8 2021 0 : 0
# 10 8 2021 0 : 0
# 11 8 2021 0 : 0
# 12 8 2021 0 : 0
# 13 8 2021 0 : 0
# 14 8 2021 0 : 0
# 15 8 2021 0 : 0
# 16 8 2021 0 : 0
# 17 8 2021 0 : 0
# 18 8 2021 0 : 0
# 19 8 2021 0 : 0
# 20 8 2021 0 : 0
# 21 8 2021 0 : 0
# 22 8 2021 0 : 0
# 23 8 2021 0 : 0
# 24 8 2021 0 : 0
# 25 8 2021 0 : 0
# 26 8 2021 0 : 0
# 27 8 2021 0 : 0
# 28 8 2021 0 : 0
# 29 8 2021 0 : 0
# 30 8 2021 0 : 0
# 31 8 2021 0 : 0
# 1 9 2021 0 : 0
# 2 9 2021 0 : 0
# 3 9 2021 0 : 0
# 4 9 2021 0 : 0
# 5 9 2021 0 : 0
# 6 9 2021 0 : 0
# 7 9 2021 0 : 0
# 8 9 2021 0 : 0
# 9 9 2021 0 : 0
# 10 9 2021 0 : 0
# 11 9 2021 0 : 0
# 12 9 2021 0 : 0
# 13 9 2021 0 : 0
# 14 9 2021 0 : 0
# 15 9 2021 0 : 0
# 16 9 2021 0 : 0
# 17 9 2021 0 : 0
# 18 9 2021 0 : 0
# 19 9 2021 0 : 0
# 20 9 2021 0 : 0
# 21 9 2021 0 : 0
# 22 9 2021 0 : 0
# 23 9 2021 0 : 0
# 24 9 2021 0 : 0
# 25 9 2021 0 : 0
# 26 9 2021 0 : 0

# %%
df = df[['dt','dtny','ahra','jultin','kj','aw','masG','dT','au','van',
         'stin','sec','ahra_','kj_','aw_','masG_','dT_','au_','van_',
         'sun','moon','rahu','geth','mars','mercury','venus','jupiter','saturn','uranus',
         'sun_Z','sun_D','sun_M',
         'moon_Z','moon_D','moon_M',
         'rahu_Z','rahu_D','rahu_M',
         'geth_Z','geth_D','geth_M',
         'mars_Z','mars_D','mars_M',
         'mercury_Z','mercury_D','mercury_M',
         'venus_Z','venus_D','venus_M',
         'jupiter_Z','jupiter_D','jupiter_M',
         'saturn_Z','saturn_D','saturn_M',
         'uranus_Z','uranus_D','uranus_M'
        ]]
df.to_csv(r"C:\Users\JACK\Desktop\S_out.csv")

# %%
dt1= datetime(2019,1,1,0,0)
dt2= datetime(1943,4,17,9,49)
dt3= datetime(2019,1,2,22,45)


test1= hora(dt1)
test2= hora(dt2)
test3= hora(dt3)

#Create dataframe
#Method1
data = {
    'dt': [dt1,dt2,dt3],
    'sun' : [test1.sun,test2.sun,test3.sun],
    'moon': [test1.moon,test2.moon,test3.moon],
    'rahu' : [test1.rahu,test2.rahu,test3.rahu],
    'geth' : [test1.geth,test2.geth,test3.geth],
    'mars' : [test1.mars,test2.mars,test3.mars],
    'mercury' : [test1.mercury,test2.mercury,test3.mercury],
    'venus' : [test1.venus,test2.venus,test3.venus],
    'jupiter' : [test1.jupiter,test2.jupiter,test3.jupiter],
    'saturn' : [test1.saturn,test2.saturn,test3.saturn],
    'uranus' : [test1.uranus,test2.uranus,test3.uranus]
}


#Method2
# data = [
#     {'dt': dt1, 'ssun': test1.sun, 'smoon': test1.moon},
#     {'dt': dt2, 'ssun': test2.sun, 'smoon': test2.moon},
#     {'dt': dt3, 'ssun': test3.sun, 'smoon': test3.moon},
# ]

df = pd.DataFrame(data)


loops = ['sun','moon','rahu','geth','mars','mercury','venus','jupiter','saturn','uranus'] 

for planet in loops:
    zodiac = planet+"_Z"
    degree = planet+"_D"
    minute = planet+"_M"
    df[zodiac] =  df[planet]//1800 
    df[degree] =  (df[planet]%1800)//60 
    df[minute] =  (df[planet]%1800)%60

# df['sun_Z'] =  df['ssun']//1800 
# df['sun_D'] =  (df['ssun']%1800)//60 
# df['sun_M'] =  (df['ssun']%1800)%60

df[['sun_Z','sun_D','sun_M','moon_Z','moon_D','moon_M','rahu_Z','rahu_D','rahu_M','geth_Z','geth_D','geth_M']]
#df[['mercury_Z','mercury_D','mercury_M','venus_Z','venus_D','venus_M']]
#df[['mars_Z','mars_D','mars_M','jupiter_Z','jupiter_D','jupiter_M','saturn_Z','saturn_D','saturn_M','uranus_Z','uranus_D','uranus_M']]
# Out:
# Smars = -1498 adjust to 20102
# MTS = -137 adjust to 21463
# SMercury = 22715 adjust to 1115
# Smars = -1431 adjust to 20169
#    sun_Z  sun_D  sun_M  moon_Z  moon_D  moon_M  rahu_Z  rahu_D  rahu_M  \
# 0      8     15     29       6      13      42       3       2      45
# 1      0      3     21       4      25      31       3      28      19
# 2      8     17     29       7       9      51       3       2      39
#
#    geth_Z  geth_D  geth_M
# 0       9       7      50
# 1       5      29       0
# 2       9       6      48

# %%
dt1= datetime(1984,1,27,9,49)
dt2= datetime(2007,3,30,8,55)
dt3= datetime(2010,1,27,22,52)


test1= hora(dt1)
test2= hora(dt2)
test3= hora(dt3)

#Create dataframe
#Method1
data = {
    'dt': [dt1,dt2,dt3],
    'ssun' : [test1.sun,test2.sun,test3.sun],
    'smoon': [test1.moon,test2.moon,test3.moon],
    'srahu' : [test1.rahu,test2.rahu,test3.rahu],
    'sgeth' : [test1.geth,test2.geth,test3.geth],
    'smars' : [test1.mars,test2.mars,test3.mars],
    'smercury' : [test1.mercury,test2.mercury,test3.mercury],
    'svenus' : [test1.venus,test2.venus,test3.venus],
    'jupiter' : [test1.jupiter,test2.jupiter,test3.jupiter],
    'ssaturn' : [test1.saturn,test2.saturn,test3.saturn],
    'suranus' : [test1.uranus,test2.uranus,test3.uranus]
}


#Method2
# data = [
#     {'dt': dt1, 'ssun': test1.sun, 'smoon': test1.moon},
#     {'dt': dt2, 'ssun': test2.sun, 'smoon': test2.moon},
#     {'dt': dt3, 'ssun': test3.sun, 'smoon': test3.moon},
# ]

df = pd.DataFrame(data)



#Add row to DataFrame
#METHOD1: add or update specify by row name 
#df.loc[2] = [dt3,10,20]
#df.loc[3] = [dt3,10,20]

#METHOD1.1: Add row to the end of dataframe 
#df.loc[len(df.index)] = [dt3,10,20]
#df.loc[len(df.index)] = [dt3,10,20]
# df.loc[len(df.index)] = [dt3,10,20]


#METHOD2: Add row to some columns
#df = df.append({'dt' : 'dateadded' , 'ssun' : 2222} , ignore_index=True)

#print(len(df.index))


#Change column name
#df.columns = 'a','b','c'

#create new column and data
#method1
#df['newcolumn1'] = ''
#df['newcolumn1'] = [1,2,3,4,5]

#Method2
#df.insert(4, "newcolumn2", [21, 23, 24, 21, 20], True) 
#df.insert(len(df.columns), "newcolumn2", [21, 23, 24, 21, 20], True) 

#Method3-Create new 
#df2 = df.assign(address = ['Delhi', 'Bangalore', 'Chennai', 'Patna', 'ddd']) 
#df2


#Drop column 
#df = df.drop(columns=['newcolumn1','newcolumn2'])


# df['sun_Z'] =  df['ssun']//1800 
# df['sun_D'] =  (df['ssun']%1800)//60 
# df['sun_M'] =  (df['ssun']%1800)%60

# df['moon_Z'] =  df['smoon']//1800 
# df['moon_D'] =  (df['smoon']%1800)//60 
# df['moon_M'] =  (df['smoon']%1800)%60

# df['rahu_Z'] =  df['srahu']//1800 
# df['rahu_D'] =  (df['srahu']%1800)//60 
# df['rahu_M'] =  (df['srahu']%1800)%60

# df['geth_Z'] =  df['sgeth']//1800 
# df['geth_D'] =  (df['sgeth']%1800)//60 
# df['geth_M'] =  (df['sgeth']%1800)%60

# df['mars_Z'] =  df['smars']//1800 
# df['mars_D'] =  (df['smars']%1800)//60 
# df['mars_M'] =  (df['smars']%1800)%60



# df[0:]




#sliding rows 
#df[2:3]

#sliding columns 
# df[['dt','ssun','smoon']]

#sliding rows and columns 
#df.loc[row,colmm]
# df.loc[:,:]
# df.loc[1,['dt']]
# df.loc[1:3,['dt','ssun','smoon']]
# df.loc[1:3,'dt':'ssun']

#Change index
# df.set_index("dt", inplace=True)
# df.loc[:,:]
# df.loc[dt1,:]
# df.loc[dt1:dt3,['ssun','smoon']]
# df.loc[dt1:dt3,'ssun':'ssun_m']

#boolean
# df.loc[df['smoon'] >= 7000,'ssun':'ssun_m']

df



#df.loc[0:3,'dt']>dt1
#df.loc[0:3,'dt']>dt1
#data.set_index("last_name", inplace=True)
# Out:
# uv = 14819
# pholGA = 4019
# khan = 4
# SVenus = 22652 adjust to 1052
# uv = 17719
# pholGA = 3881
# khan = 4
# uv = 7926
# pholGA = 2874
# khan = 3
#                    dt   ssun  smoon  srahu  sgeth  smars  smercury  svenus  \
# 0 1984-01-27 09:49:00  16953  12913   2933  12108  11722     15638   14765
# 1 2007-03-30 08:55:00  20702   7569  19222   2089  18000     19459    1052
# 2 2010-01-27 22:52:00  17003   4207  15932  12377   6532     15557   17071
#
#    jupiter  ssaturn  suranus
# 0    14973    11999    13324
# 1    14290     6638    19352
# 2    18534     9464    19983

# %%
#df[['dt','ssun','sun_Z','sun_D','sun_M','smoon','moon_Z','moon_D','moon_M']]

# %%
# s_ravi = {
#     'jya': [35,32,27,22,13,5],
#     'ravi': [0,35,67,94,116,129]
# }
# #df = pd.DataFrame(s_ravi)
# df = pd.DataFrame(s_ravi)
# #df.iloc[1] = [kj,Ssun]
# #df.append(data)
# df = df.append({'kj' : 'Sahil' , 'sun' : 22} , ignore_index=True)
# df = df.append({'kj' : 'Sahil' , 'sun' : 22} , ignore_index=True)

# df = df.append({'kj' : 'Sahil' , 'sun' : 22 , 'datetime' : dt} , ignore_index=True)
# df = df.append({'kj' : 'Sahil' , 'sun' : 22 , 'datetime' : dtny} , ignore_index=True)


#Create dataframe
df = pd.DataFrame()

# Creating an empty Dataframe with column names only
df = pd.DataFrame(columns=['User_ID', 'UserName', 'Action'])

# Create an empty Dataframe with columns or indices
#df = pd.DataFrame(columns=['User_ID', 'UserName', 'Action'], index=['a', 'b', 'c'])

print(df.head(5))
print(df.tail())

print(df.dtypes)
print(df.index)
print(df.columns)
print(df.values)

#for index,row in df.iterrows():
#    print (index, row['ssun'], row['smoon'])
# Out:
# Empty DataFrame
# Columns: [User_ID, UserName, Action]
# Index: []
# Empty DataFrame
# Columns: [User_ID, UserName, Action]
# Index: []
# User_ID     object
# UserName    object
# Action      object
# dtype: object
# Index([], dtype='object')
# Index(['User_ID', 'UserName', 'Action'], dtype='object')
# []

# %%
day,month,year,hour,minute = 27,1,2527,9,49
christ_year = year-543

dt= datetime(christ_year,month,day,hour,minute)

a = hora(dt)  
print('dt =', a.dt)
print('dtnt =', a.dtny)
print('ahra =', a.ahra)
print('jultin =', a.jultin)
print('kj =', a.kj)
print('aw =', a.aw)
print('masG =', a.masG)
print('dT =', a.dT)
print('au =', a.au)
print('van =', a.van)

print('stin =', a.stin)
print('sec =', a.sec)
print('ahra_ =', a.ahra_)
print('kj_ =', a.kj_)
print('aw_ =', a.aw_)
print('masG_ =', a.masG_)
print('dT_ =', a.dT_)
print('au_ =', a.au_)
print('van_ =', a.van_)

print('sun =', a.sun)
print('moon =', a.moon)
print('rahu =', a.rahu)
print('geth =', a.geth)
print('mars =', a.mars)
print('mercury =', a.mercury)
print('venus =', a.venus)
print('jupiter =', a.jupiter)
print('saturn =', a.saturn)
print('uranus =', a.uranus)
# Out:
# dt = 1984-01-27 09:31:00
# dtnt = 1983-04-16 11:38:24
# ahra = 491274
# jultin = 388
# kj = 412
# aw = 144
# masG = 16636
# dT = 4
# au = 2621
# van = 0
# stin = 286
# sec = 34260
# ahra_ = 491560
# kj_ = 228729
# aw_ = 97
# masG_ = 16645
# dT_ = 24
# au_ = 2907
# van_ = 6
# sun = 16953
# moon = 12913
# rahu = 2933
# geth = 12108
# mars = 11722
# mercury = 15638
# venus = 14765
# jupiter = 14973
# saturn = 11999
# uranus = 13324

# %% [markdown]
# #
